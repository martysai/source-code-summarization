# %%
import parse_python3
import ast
import sys
import json as json
import os
import numpy as np
import string
import pandas as pd
import astor

# %%
print(1)

# %%
os.system('~/miniconda3/envs/python2/bin/2to3 data/0xcite/fingerping/fingerping.py -o new_files -w -n --no-diffs')

# %%
filenm = "new_files/fingerping.py"
astree_json = parse_python3.parse_file(filenm)

# %%
def read_file_to_string(filename):
    f = open(filename, 'rt')
    s = f.read()
    f.close()
    return s

# %%
astree = ast.parse(read_file_to_string(filenm), filenm)

# %%
with open(filenm) as f:
    print(f.read())
# Out:
# #!/usr/bin/python
# #
# # fingerping: A PNG library fingerprinting tool.
# #
# # @author:Dominique Bongard
# #
# #
# # Code is licensed under -- Apache License 2.0 http://www.apache.org/licenses/
# #
#
# from collections import namedtuple
# from operator import *
# from struct import *
# import os.path
# import sys
# import zlib
# import binascii
# import itertools
# from xpng import *
#
# # A named tuple representing a fingerprint test
# # name = name of the test
# # filename = filename of the png file to test
# # function = function to call to execute the test
# # description = description of the test
# Test = namedtuple("test", "name filename function description")
#
# # A named tuple representing the fingerprint of a PNG library
# # name = name of the language / library / tool
# # description = description of the library (e.g. version number)
# # results = a dictionary of test fingerprint test results
# Fingerprint = namedtuple("fingerprint","name description results")
#
#
# ###############################################
# #
# # Fingerprinting functions
# #
# ###############################################
#
#
# # The most simple fingerprinting function
# #
# # Returns 0 if the image is absent or empty (meaning the target failed to decode the input image)
# # Returns 10 if the image looks valid at least in surface
# # Returns between 1 and 9 if the image is corrupt
# def conversionSuccess(image):
#   return image.valid
#
# # All the following tests should return values > 10 (or any kind of object like a list actually)
# ################################################################################################
#
# # Fingerprint depending on the correctness of the checksums of the output image
# def correctChecksums(image):
#   if image.verifyChecksums():
#     return 11
#   else:
#     return 12
#
# # Fingerprint resulting from the set of filters used in the scanlines of the output image (returns a sorted list of the filters)
# def filtersUsed(image):
#   return sorted(image.filtersUsed)
#
# # Fingerprint depending on the palette used to decode images with two palettes (when not rejected)
# def paletteUsed(image):
#   if image.hasColor([185,96,142]) :
#     return 11
#   elif image.hasColor([96,142,185]) :
#     return 12
#   else:
#     return 13
#
# # Fingerprint depending on how the decoder treated the gamma information from the input image
# def gamma(image):
#   pixel = image.getPixelRgb(120,140)
#   if pixel[0]+pixel[1] + pixel[2] < 96 :
#     return 11
#   else:
#     chunk = image.getChunk("gAMA")
#     if chunk == None:
#       return 12
#     gammav = unpack("!I",chunk.content)
#     if gammav[0] == 400000 :
#       return 13
#     return 14
#
# # Fingerprint depending on the ihdr used to decode images with two ihdr (when not rejected)
# def ihdrUsed(image):
#   if image.width == 252:
#     return 11
#   elif image.width == 189:
#     return 12
#   else :
#     return 13
#
# # Fingerprint depending on the treatment of images with invalid scanline filters
# def badIdatFilter(image):
#   pixel = image.getPixelRgb(5,0)
#   if pixel == [65,83,255] :
#     return 11 # Most libraries return the correct image
#   elif pixel == [57,82,255] :
#     return 12 # One library outputs a corrupted image
#   return 13
#
# # Fingerprint depending on the zlib compression level flag of the output image
# def zlibCompression(image):
#   return 11+ image.zlevel
#
# # Fingerprint depending on how the decoder treated the phys information in the input image
# def physChunk(image):
#   chunk = image.getChunk("pHYs")
#   if chunk == None:
#     return 11
#   x,y,u = unpack("!IIB",chunk.content)
#   if x == 1:
#     return 12
#   if x == 1500:
#     return 13
#   if x == 1499:
#     return 14 # .net
#   return 15
#
# # Fingerprint depending on how the decoder treated an input image with a tRNS chunk
# def truecolorTrns(image):
#   if image.colorType == 6 :
#     return 11
#   chunk = image.getChunk("tRNS")
#   if chunk == None:
#     return 12
#   return 13
#
# ###############################################
#
# # include all the tests and fingerprints from external files
#
# exec(compile(open("tests.py", "rb").read(), "tests.py", 'exec'))
# exec(compile(open("fingerprints.py", "rb").read(), "fingerprints.py", 'exec'))
#
# ###############################################
#
#
# # Test all the images in a directory (don't print warnings when generating fingerprints)
# def doTests(tests,fingerprints, warn):
#   results  = {}
#   fingerprintScores = {}
#   # Initialite the count of matching tests to zero for each fingerprint
#   for fingerprint in fingerprints :
#     fingerprintScores[fingerprint.name] = 0
#   # Execute each test
#   for test in tests:
#     image = Png(directory + test.filename+".png")
#     if not image.valid == 0:
#             # Only execute the test if there is an image to test
#       result = test.function(image)
#     else :
#       result = 0
#     # Save the result of the test
#     results[test.name] = result
#
#     # Check if the result matches some of the fingeprints and if so, increment the match counter
#     for fingerprint in fingerprints :
#       if not test.name in fingerprint.results:
#             # warn if a fingerprint is missing the result for the test being run
#         if warn:
#           print("warning, missing key", test.name,"in", fingerprint.name)
#       elif fingerprint.results[test.name] == result :
#         fingerprintScores[fingerprint.name] += 1
#   return results,fingerprintScores
#
# # Generate a csv table with all the test results for each fingerprint (which you can then import in LibreOffice or whatever)
# def generateCsv(tests,fingerprints):
#   header = "/"
#   for test in tests:
#     header = header+ "\t"+test.name
#   print(header)
#
#   for fingerprint in fingerprints:
#     row = fingerprint.name
#     for test in tests:
#       if not test.name in fingerprint.results:
#         row += "\t\"\""
#       else:
#         row += "\t"+ str(fingerprint.results[test.name])
#     print(row)
#
# # Show the fingerprinting result with the most likely library match at the bottom
# def showResults(scores, nb):
#   ordered = sorted(iter(scores.items()), key=itemgetter(1))
#   for result in ordered :
#     print('{:20s} {:3d}/{:3d}'.format(result[0], result[1], nb))
#
# # check if the command line has valid options
# def checkCommandLine(line):
#   if len(line) == 3 :
#     if not line[1] == "-gen":
#       return False
#     else:
#       return True
#   if len(line) == 2:
#     if (line[1][0] == "-") and not (line[1] == "-csv"):
#       return False
#     return True
#   return False
#
#
# ###############################################
# #
# # Main program
# #
# ###############################################
#
#
# # use reflection to get all the tests and all the fingeprints in lists
# locals =  locals().copy()
# tests = sorted( [t for t in locals.values() if isinstance(t,Test)], key=attrgetter('name'))
# fingerprints = [t for t in locals.values() if isinstance(t,Fingerprint)]
#
# if not checkCommandLine(sys.argv):
#   print("usage:")
#   print("")
#   print("fingerping.py path        # Matches the images in the path folder with the fingerprint of known PNG libraries")
#   print("fingerping.py -gen path   # Generates a new library fingerprint from the images in the path folder")
#   print("fingerping.py -csv        # prints all the known fingerprints as a CSV table")
#   sys.exit(0)
#
# # Generate a csv output with all the test results for each library fingerprint known to the tool
# if sys.argv[1] == "-csv" :
#   generateCsv(tests,fingerprints)
#   sys.exit(0)
#
# # last command line argument is the directory with all the images to use in a fingerprint test
# directory = sys.argv[len(sys.argv)-1] + "/"
#
# results, fingerprintScores = doTests(tests,fingerprints,sys.argv[1] != "-gen")
#
# # If the -gen parameter is given on the command line, don't give the fingerprinting results
# # but instead generate a new fingerprint
# if sys.argv[1] == "-gen" :
#   print(results)
# else:
#   showResults(fingerprintScores,len(tests))

# %%
astree

# %%
compile(astree, filename="mycode", mode="exec")
# Out:
# <code object <module> at 0x7f63cf526a50, file "mycode", line 11>

# %%
print(astor.to_source(astree))
# Out:
# from collections import namedtuple
# from operator import *
# from struct import *
# import os.path
# import sys
# import zlib
# import binascii
# import itertools
# from xpng import *
# Test = namedtuple('test', 'name filename function description')
# Fingerprint = namedtuple('fingerprint', 'name description results')
#
#
# def conversionSuccess(image):
#     return image.valid
#
#
# def correctChecksums(image):
#     if image.verifyChecksums():
#         return 11
#     else:
#         return 12
#
#
# def filtersUsed(image):
#     return sorted(image.filtersUsed)
#
#
# def paletteUsed(image):
#     if image.hasColor([185, 96, 142]):
#         return 11
#     elif image.hasColor([96, 142, 185]):
#         return 12
#     else:
#         return 13
#
#
# def gamma(image):
#     pixel = image.getPixelRgb(120, 140)
#     if pixel[0] + pixel[1] + pixel[2] < 96:
#         return 11
#     else:
#         chunk = image.getChunk('gAMA')
#         if chunk == None:
#             return 12
#         gammav = unpack('!I', chunk.content)
#         if gammav[0] == 400000:
#             return 13
#         return 14
#
#
# def ihdrUsed(image):
#     if image.width == 252:
#         return 11
#     elif image.width == 189:
#         return 12
#     else:
#         return 13
#
#
# def badIdatFilter(image):
#     pixel = image.getPixelRgb(5, 0)
#     if pixel == [65, 83, 255]:
#         return 11
#     elif pixel == [57, 82, 255]:
#         return 12
#     return 13
#
#
# def zlibCompression(image):
#     return 11 + image.zlevel
#
#
# def physChunk(image):
#     chunk = image.getChunk('pHYs')
#     if chunk == None:
#         return 11
#     x, y, u = unpack('!IIB', chunk.content)
#     if x == 1:
#         return 12
#     if x == 1500:
#         return 13
#     if x == 1499:
#         return 14
#     return 15
#
#
# def truecolorTrns(image):
#     if image.colorType == 6:
#         return 11
#     chunk = image.getChunk('tRNS')
#     if chunk == None:
#         return 12
#     return 13
#
#
# exec(compile(open('tests.py', 'rb').read(), 'tests.py', 'exec'))
# exec(compile(open('fingerprints.py', 'rb').read(), 'fingerprints.py', 'exec'))
#
#
# def doTests(tests, fingerprints, warn):
#     results = {}
#     fingerprintScores = {}
#     for fingerprint in fingerprints:
#         fingerprintScores[fingerprint.name] = 0
#     for test in tests:
#         image = Png(directory + test.filename + '.png')
#         if not image.valid == 0:
#             result = test.function(image)
#         else:
#             result = 0
#         results[test.name] = result
#         for fingerprint in fingerprints:
#             if not test.name in fingerprint.results:
#                 if warn:
#                     print('warning, missing key', test.name, 'in',
#                         fingerprint.name)
#             elif fingerprint.results[test.name] == result:
#                 fingerprintScores[fingerprint.name] += 1
#     return results, fingerprintScores
#
#
# def generateCsv(tests, fingerprints):
#     header = '/'
#     for test in tests:
#         header = header + '\t' + test.name
#     print(header)
#     for fingerprint in fingerprints:
#         row = fingerprint.name
#         for test in tests:
#             if not test.name in fingerprint.results:
#                 row += '\t""'
#             else:
#                 row += '\t' + str(fingerprint.results[test.name])
#         print(row)
#
#
# def showResults(scores, nb):
#     ordered = sorted(iter(scores.items()), key=itemgetter(1))
#     for result in ordered:
#         print('{:20s} {:3d}/{:3d}'.format(result[0], result[1], nb))
#
#
# def checkCommandLine(line):
#     if len(line) == 3:
#         if not line[1] == '-gen':
#             return False
#         else:
#             return True
#     if len(line) == 2:
#         if line[1][0] == '-' and not line[1] == '-csv':
#             return False
#         return True
#     return False
#
#
# locals = locals().copy()
# tests = sorted([t for t in locals.values() if isinstance(t, Test)], key=
#     attrgetter('name'))
# fingerprints = [t for t in locals.values() if isinstance(t, Fingerprint)]
# if not checkCommandLine(sys.argv):
#     print('usage:')
#     print('')
#     print(
#         'fingerping.py path        # Matches the images in the path folder with the fingerprint of known PNG libraries'
#         )
#     print(
#         'fingerping.py -gen path   # Generates a new library fingerprint from the images in the path folder'
#         )
#     print(
#         'fingerping.py -csv        # prints all the known fingerprints as a CSV table'
#         )
#     sys.exit(0)
# if sys.argv[1] == '-csv':
#     generateCsv(tests, fingerprints)
#     sys.exit(0)
# directory = sys.argv[len(sys.argv) - 1] + '/'
# results, fingerprintScores = doTests(tests, fingerprints, sys.argv[1] != '-gen'
#     )
# if sys.argv[1] == '-gen':
#     print(results)
# else:
#     showResults(fingerprintScores, len(tests))

# %%
for node in ast.walk(astree):
    if isinstance(node, ast.Name):
        print(node.id, node.col_offset, node.ctx, node.lineno)
        if isinstance(node.ctx, ast.Load):
            print("load")
# Out:
# Test 0 <_ast.Store object at 0x7f6403b53208> 26
# Fingerprint 0 <_ast.Store object at 0x7f6403b53208> 32
# locals 0 <_ast.Store object at 0x7f6403b53208> 214
# tests 0 <_ast.Store object at 0x7f6403b53208> 215
# fingerprints 0 <_ast.Store object at 0x7f6403b53208> 216
# directory 0 <_ast.Store object at 0x7f6403b53208> 232
# namedtuple 7 <_ast.Load object at 0x7f6403b53160> 26
# load
# namedtuple 14 <_ast.Load object at 0x7f6403b53160> 32
# load
# pixel 2 <_ast.Store object at 0x7f6403b53208> 75
# pixel 2 <_ast.Store object at 0x7f6403b53208> 98
# chunk 2 <_ast.Store object at 0x7f6403b53208> 111
# chunk 2 <_ast.Store object at 0x7f6403b53208> 127
# exec 0 <_ast.Load object at 0x7f6403b53160> 136
# load
# exec 0 <_ast.Load object at 0x7f6403b53160> 137
# load
# results 2 <_ast.Store object at 0x7f6403b53208> 144
# fingerprintScores 2 <_ast.Store object at 0x7f6403b53208> 145
# fingerprint 6 <_ast.Store object at 0x7f6403b53208> 147
# fingerprints 21 <_ast.Load object at 0x7f6403b53160> 147
# load
# test 6 <_ast.Store object at 0x7f6403b53208> 150
# tests 14 <_ast.Load object at 0x7f6403b53160> 150
# load
# header 2 <_ast.Store object at 0x7f6403b53208> 172
# test 6 <_ast.Store object at 0x7f6403b53208> 173
# tests 14 <_ast.Load object at 0x7f6403b53160> 173
# load
# fingerprint 6 <_ast.Store object at 0x7f6403b53208> 177
# fingerprints 21 <_ast.Load object at 0x7f6403b53160> 177
# load
# ordered 2 <_ast.Store object at 0x7f6403b53208> 188
# result 6 <_ast.Store object at 0x7f6403b53208> 189
# ordered 16 <_ast.Load object at 0x7f6403b53160> 189
# load
# sorted 8 <_ast.Load object at 0x7f6403b53160> 215
# load
# t 16 <_ast.Load object at 0x7f6403b53160> 216
# load
# results 0 <_ast.Store object at 0x7f6403b53208> 234
# fingerprintScores 9 <_ast.Store object at 0x7f6403b53208> 234
# doTests 29 <_ast.Load object at 0x7f6403b53160> 234
# load
# tests 37 <_ast.Load object at 0x7f6403b53160> 234
# load
# fingerprints 43 <_ast.Load object at 0x7f6403b53160> 234
# load
# image 9 <_ast.Load object at 0x7f6403b53160> 48
# load
# sorted 9 <_ast.Load object at 0x7f6403b53160> 62
# load
# chunk 4 <_ast.Store object at 0x7f6403b53208> 79
# gammav 4 <_ast.Store object at 0x7f6403b53208> 82
# pixel 5 <_ast.Load object at 0x7f6403b53160> 99
# load
# chunk 5 <_ast.Load object at 0x7f6403b53160> 112
# load
# x 2 <_ast.Store object at 0x7f6403b53208> 114
# y 4 <_ast.Store object at 0x7f6403b53208> 114
# u 6 <_ast.Store object at 0x7f6403b53208> 114
# unpack 10 <_ast.Load object at 0x7f6403b53160> 114
# load
# x 5 <_ast.Load object at 0x7f6403b53160> 115
# load
# x 5 <_ast.Load object at 0x7f6403b53160> 117
# load
# x 5 <_ast.Load object at 0x7f6403b53160> 119
# load
# chunk 5 <_ast.Load object at 0x7f6403b53160> 128
# load
# compile 5 <_ast.Load object at 0x7f6403b53160> 136
# load
# compile 5 <_ast.Load object at 0x7f6403b53160> 137
# load
# image 4 <_ast.Store object at 0x7f6403b53208> 151
# result 25 <_ast.Load object at 0x7f6403b53160> 158
# load
# fingerprint 8 <_ast.Store object at 0x7f6403b53208> 161
# fingerprints 23 <_ast.Load object at 0x7f6403b53160> 161
# load
# results 9 <_ast.Load object at 0x7f6403b53160> 168
# load
# fingerprintScores 17 <_ast.Load object at 0x7f6403b53160> 168
# load
# header 4 <_ast.Store object at 0x7f6403b53208> 174
# print 2 <_ast.Load object at 0x7f6403b53160> 175
# load
# header 8 <_ast.Load object at 0x7f6403b53160> 175
# load
# row 4 <_ast.Store object at 0x7f6403b53208> 178
# test 8 <_ast.Store object at 0x7f6403b53208> 179
# tests 16 <_ast.Load object at 0x7f6403b53160> 179
# load
# sorted 12 <_ast.Load object at 0x7f6403b53160> 188
# load
# t 17 <_ast.Load object at 0x7f6403b53160> 215
# load
# t 22 <_ast.Store object at 0x7f6403b53208> 216
# checkCommandLine 7 <_ast.Load object at 0x7f6403b53160> 218
# load
# print 2 <_ast.Load object at 0x7f6403b53160> 219
# load
# print 2 <_ast.Load object at 0x7f6403b53160> 220
# load
# print 2 <_ast.Load object at 0x7f6403b53160> 221
# load
# print 2 <_ast.Load object at 0x7f6403b53160> 222
# load
# print 2 <_ast.Load object at 0x7f6403b53160> 223
# load
# generateCsv 2 <_ast.Load object at 0x7f6403b53160> 228
# load
# tests 14 <_ast.Load object at 0x7f6403b53160> 228
# load
# fingerprints 20 <_ast.Load object at 0x7f6403b53160> 228
# load
# print 2 <_ast.Load object at 0x7f6403b53160> 239
# load
# results 8 <_ast.Load object at 0x7f6403b53160> 239
# load
# showResults 2 <_ast.Load object at 0x7f6403b53160> 241
# load
# fingerprintScores 14 <_ast.Load object at 0x7f6403b53160> 241
# load
# image 5 <_ast.Load object at 0x7f6403b53160> 55
# load
# image 16 <_ast.Load object at 0x7f6403b53160> 62
# load
# image 5 <_ast.Load object at 0x7f6403b53160> 66
# load
# image 10 <_ast.Load object at 0x7f6403b53160> 75
# load
# chunk 7 <_ast.Load object at 0x7f6403b53160> 80
# load
# unpack 13 <_ast.Load object at 0x7f6403b53160> 82
# load
# image 5 <_ast.Load object at 0x7f6403b53160> 89
# load
# image 10 <_ast.Load object at 0x7f6403b53160> 98
# load
# pixel 7 <_ast.Load object at 0x7f6403b53160> 101
# load
# image 13 <_ast.Load object at 0x7f6403b53160> 107
# load
# image 10 <_ast.Load object at 0x7f6403b53160> 111
# load
# chunk 24 <_ast.Load object at 0x7f6403b53160> 114
# load
# image 5 <_ast.Load object at 0x7f6403b53160> 125
# load
# image 10 <_ast.Load object at 0x7f6403b53160> 127
# load
# fingerprintScores 4 <_ast.Load object at 0x7f6403b53160> 148
# load
# Png 12 <_ast.Load object at 0x7f6403b53160> 151
# load
# result 6 <_ast.Store object at 0x7f6403b53208> 154
# result 6 <_ast.Store object at 0x7f6403b53208> 156
# results 4 <_ast.Load object at 0x7f6403b53160> 158
# load
# fingerprint 10 <_ast.Load object at 0x7f6403b53160> 178
# load
# print 4 <_ast.Load object at 0x7f6403b53160> 184
# load
# row 10 <_ast.Load object at 0x7f6403b53160> 184
# load
# iter 19 <_ast.Load object at 0x7f6403b53160> 188
# load
# print 4 <_ast.Load object at 0x7f6403b53160> 190
# load
# len 5 <_ast.Load object at 0x7f6403b53160> 194
# load
# line 9 <_ast.Load object at 0x7f6403b53160> 194
# load
# len 5 <_ast.Load object at 0x7f6403b53160> 199
# load
# line 9 <_ast.Load object at 0x7f6403b53160> 199
# load
# locals 10 <_ast.Load object at 0x7f6403b53160> 214
# load
# t 23 <_ast.Store object at 0x7f6403b53208> 215
# attrgetter 72 <_ast.Load object at 0x7f6403b53160> 215
# load
# isinstance 46 <_ast.Load object at 0x7f6403b53160> 216
# load
# t 57 <_ast.Load object at 0x7f6403b53160> 216
# load
# Fingerprint 59 <_ast.Load object at 0x7f6403b53160> 216
# load
# sys 24 <_ast.Load object at 0x7f6403b53160> 218
# load
# sys 2 <_ast.Load object at 0x7f6403b53160> 224
# load
# sys 3 <_ast.Load object at 0x7f6403b53160> 227
# load
# sys 2 <_ast.Load object at 0x7f6403b53160> 229
# load
# sys 12 <_ast.Load object at 0x7f6403b53160> 232
# load
# sys 3 <_ast.Load object at 0x7f6403b53160> 238
# load
# len 32 <_ast.Load object at 0x7f6403b53160> 241
# load
# tests 36 <_ast.Load object at 0x7f6403b53160> 241
# load
# image 7 <_ast.Load object at 0x7f6403b53160> 68
# load
# pixel 25 <_ast.Load object at 0x7f6403b53160> 76
# load
# image 12 <_ast.Load object at 0x7f6403b53160> 79
# load
# chunk 25 <_ast.Load object at 0x7f6403b53160> 82
# load
# gammav 7 <_ast.Load object at 0x7f6403b53160> 83
# load
# image 7 <_ast.Load object at 0x7f6403b53160> 91
# load
# image 29 <_ast.Load object at 0x7f6403b53160> 154
# load
# warn 11 <_ast.Load object at 0x7f6403b53160> 164
# load
# header 13 <_ast.Load object at 0x7f6403b53160> 174
# load
# test 26 <_ast.Load object at 0x7f6403b53160> 174
# load
# row 8 <_ast.Store object at 0x7f6403b53208> 181
# row 8 <_ast.Store object at 0x7f6403b53208> 183
# itemgetter 45 <_ast.Load object at 0x7f6403b53160> 188
# load
# nb 60 <_ast.Load object at 0x7f6403b53160> 190
# load
# isinstance 47 <_ast.Load object at 0x7f6403b53160> 215
# load
# t 58 <_ast.Load object at 0x7f6403b53160> 215
# load
# Test 60 <_ast.Load object at 0x7f6403b53160> 215
# load
# locals 27 <_ast.Load object at 0x7f6403b53160> 216
# load
# sys 56 <_ast.Load object at 0x7f6403b53160> 234
# load
# pixel 5 <_ast.Load object at 0x7f6403b53160> 76
# load
# pixel 14 <_ast.Load object at 0x7f6403b53160> 76
# load
# open 13 <_ast.Load object at 0x7f6403b53160> 136
# load
# open 13 <_ast.Load object at 0x7f6403b53160> 137
# load
# fingerprint 22 <_ast.Load object at 0x7f6403b53160> 148
# load
# directory 16 <_ast.Load object at 0x7f6403b53160> 151
# load
# image 11 <_ast.Load object at 0x7f6403b53160> 152
# load
# test 15 <_ast.Load object at 0x7f6403b53160> 154
# load
# test 12 <_ast.Load object at 0x7f6403b53160> 158
# load
# result 45 <_ast.Load object at 0x7f6403b53160> 166
# load
# scores 24 <_ast.Load object at 0x7f6403b53160> 188
# load
# result 38 <_ast.Load object at 0x7f6403b53160> 190
# load
# result 49 <_ast.Load object at 0x7f6403b53160> 190
# load
# line 11 <_ast.Load object at 0x7f6403b53160> 195
# load
# locals 28 <_ast.Load object at 0x7f6403b53160> 215
# load
# len 21 <_ast.Load object at 0x7f6403b53160> 232
# load
# test 28 <_ast.Load object at 0x7f6403b53160> 151
# load
# test 13 <_ast.Load object at 0x7f6403b53160> 162
# load
# fingerprint 26 <_ast.Load object at 0x7f6403b53160> 162
# load
# print 10 <_ast.Load object at 0x7f6403b53160> 165
# load
# fingerprintScores 8 <_ast.Load object at 0x7f6403b53160> 167
# load
# test 13 <_ast.Load object at 0x7f6403b53160> 180
# load
# fingerprint 26 <_ast.Load object at 0x7f6403b53160> 180
# load
# str 21 <_ast.Load object at 0x7f6403b53160> 183
# load
# line 8 <_ast.Load object at 0x7f6403b53160> 200
# load
# line 36 <_ast.Load object at 0x7f6403b53160> 200
# load
# sys 25 <_ast.Load object at 0x7f6403b53160> 232
# load
# test 40 <_ast.Load object at 0x7f6403b53160> 165
# load
# fingerprint 56 <_ast.Load object at 0x7f6403b53160> 165
# load
# fingerprint 11 <_ast.Load object at 0x7f6403b53160> 166
# load
# test 31 <_ast.Load object at 0x7f6403b53160> 166
# load
# fingerprint 26 <_ast.Load object at 0x7f6403b53160> 167
# load
# fingerprint 25 <_ast.Load object at 0x7f6403b53160> 183
# load
# test 45 <_ast.Load object at 0x7f6403b53160> 183
# load

# %%
pairs = []
def gen_pairs(node, scope):
    if isinstance(node, ast.FunctionDef):
        scope = scope + [arg.arg for arg in node.args.args]
        for child in node.body+node.orelse:
            gen_pairs(child, scope)
    elif isinstance(node, ast.If):
        for child in [node.test]+node.body+node.orelse:
            gen_pairs(node.test, scope)
    elif isinstance(node, ast.For):
        pass
    elif isinstance(node, ast.Name)

# %%
for child in ast.iter_child_nodes(astree):
    if isinstance(child, ast.FunctionDef):
        print(child.name)
        break
        for node in ast.walk(child):
            if isinstance(node, ast.Name):
                print(node.id, node.col_offset, node.ctx, node.lineno)
                if isinstance(node.ctx, ast.Load):
                    print("load")
# Out:
# conversionSuccess

# %%
for child in ast.iter_child_nodes(astree):
    if isinstance(child, ast.FunctionDef):
        print(astor.to_source(child))
# Out:
# def conversionSuccess(image):
#     return image.valid
#
# def correctChecksums(image):
#     if image.verifyChecksums():
#         return 11
#     else:
#         return 12
#
# def filtersUsed(image):
#     return sorted(image.filtersUsed)
#
# def paletteUsed(image):
#     if image.hasColor([185, 96, 142]):
#         return 11
#     elif image.hasColor([96, 142, 185]):
#         return 12
#     else:
#         return 13
#
# def gamma(image):
#     pixel = image.getPixelRgb(120, 140)
#     if pixel[0] + pixel[1] + pixel[2] < 96:
#         return 11
#     else:
#         chunk = image.getChunk('gAMA')
#         if chunk == None:
#             return 12
#         gammav = unpack('!I', chunk.content)
#         if gammav[0] == 400000:
#             return 13
#         return 14
#
# def ihdrUsed(image):
#     if image.width == 252:
#         return 11
#     elif image.width == 189:
#         return 12
#     else:
#         return 13
#
# def badIdatFilter(image):
#     pixel = image.getPixelRgb(5, 0)
#     if pixel == [65, 83, 255]:
#         return 11
#     elif pixel == [57, 82, 255]:
#         return 12
#     return 13
#
# def zlibCompression(image):
#     return 11 + image.zlevel
#
# def physChunk(image):
#     chunk = image.getChunk('pHYs')
#     if chunk == None:
#         return 11
#     x, y, u = unpack('!IIB', chunk.content)
#     if x == 1:
#         return 12
#     if x == 1500:
#         return 13
#     if x == 1499:
#         return 14
#     return 15
#
# def truecolorTrns(image):
#     if image.colorType == 6:
#         return 11
#     chunk = image.getChunk('tRNS')
#     if chunk == None:
#         return 12
#     return 13
#
# def doTests(tests, fingerprints, warn):
#     results = {}
#     fingerprintScores = {}
#     for fingerprint in fingerprints:
#         fingerprintScores[fingerprint.name] = 0
#     for test in tests:
#         image = Png(directory + test.filename + '.png')
#         if not image.valid == 0:
#             result = test.function(image)
#         else:
#             result = 0
#         results[test.name] = result
#         for fingerprint in fingerprints:
#             if not test.name in fingerprint.results:
#                 if warn:
#                     print('warning, missing key', test.name, 'in',
#                         fingerprint.name)
#             elif fingerprint.results[test.name] == result:
#                 fingerprintScores[fingerprint.name] += 1
#     return results, fingerprintScores
#
# def generateCsv(tests, fingerprints):
#     header = '/'
#     for test in tests:
#         header = header + '\t' + test.name
#     print(header)
#     for fingerprint in fingerprints:
#         row = fingerprint.name
#         for test in tests:
#             if not test.name in fingerprint.results:
#                 row += '\t""'
#             else:
#                 row += '\t' + str(fingerprint.results[test.name])
#         print(row)
#
# def showResults(scores, nb):
#     ordered = sorted(iter(scores.items()), key=itemgetter(1))
#     for result in ordered:
#         print('{:20s} {:3d}/{:3d}'.format(result[0], result[1], nb))
#
# def checkCommandLine(line):
#     if len(line) == 3:
#         if not line[1] == '-gen':
#             return False
#         else:
#             return True
#     if len(line) == 2:
#         if line[1][0] == '-' and not line[1] == '-csv':
#             return False
#         return True
#     return False
#
# def conversionSuccess(image):
#     return image.valid
#
# def correctChecksums(image):
#     if image.verifyChecksums():
#         return 11
#     else:
#         return 12
#
# def filtersUsed(image):
#     return sorted(image.filtersUsed)
#
# def paletteUsed(image):
#     if image.hasColor([185, 96, 142]):
#         return 11
#     elif image.hasColor([96, 142, 185]):
#         return 12
#     else:
#         return 13
#
# def gamma(image):
#     pixel = image.getPixelRgb(120, 140)
#     if pixel[0] + pixel[1] + pixel[2] < 96:
#         return 11
#     else:
#         chunk = image.getChunk('gAMA')
#         if chunk == None:
#             return 12
#         gammav = unpack('!I', chunk.content)
#         if gammav[0] == 400000:
#             return 13
#         return 14
#
# def ihdrUsed(image):
#     if image.width == 252:
#         return 11
#     elif image.width == 189:
#         return 12
#     else:
#         return 13
#
# def badIdatFilter(image):
#     pixel = image.getPixelRgb(5, 0)
#     if pixel == [65, 83, 255]:
#         return 11
#     elif pixel == [57, 82, 255]:
#         return 12
#     return 13
#
# def zlibCompression(image):
#     return 11 + image.zlevel
#
# def physChunk(image):
#     chunk = image.getChunk('pHYs')
#     if chunk == None:
#         return 11
#     x, y, u = unpack('!IIB', chunk.content)
#     if x == 1:
#         return 12
#     if x == 1500:
#         return 13
#     if x == 1499:
#         return 14
#     return 15
#
# def truecolorTrns(image):
#     if image.colorType == 6:
#         return 11
#     chunk = image.getChunk('tRNS')
#     if chunk == None:
#         return 12
#     return 13
#
# def doTests(tests, fingerprints, warn):
#     results = {}
#     fingerprintScores = {}
#     for fingerprint in fingerprints:
#         fingerprintScores[fingerprint.name] = 0
#     for test in tests:
#         image = Png(directory + test.filename + '.png')
#         if not image.valid == 0:
#             result = test.function(image)
#         else:
#             result = 0
#         results[test.name] = result
#         for fingerprint in fingerprints:
#             if not test.name in fingerprint.results:
#                 if warn:
#                     print('warning, missing key', test.name, 'in',
#                         fingerprint.name)
#             elif fingerprint.results[test.name] == result:
#                 fingerprintScores[fingerprint.name] += 1
#     return results, fingerprintScores
#
# def generateCsv(tests, fingerprints):
#     header = '/'
#     for test in tests:
#         header = header + '\t' + test.name
#     print(header)
#     for fingerprint in fingerprints:
#         row = fingerprint.name
#         for test in tests:
#             if not test.name in fingerprint.results:
#                 row += '\t""'
#             else:
#                 row += '\t' + str(fingerprint.results[test.name])
#         print(row)
#
# def showResults(scores, nb):
#     ordered = sorted(iter(scores.items()), key=itemgetter(1))
#     for result in ordered:
#         print('{:20s} {:3d}/{:3d}'.format(result[0], result[1], nb))
#
# def checkCommandLine(line):
#     if len(line) == 3:
#         if not line[1] == '-gen':
#             return False
#         else:
#             return True
#     if len(line) == 2:
#         if line[1][0] == '-' and not line[1] == '-csv':
#             return False
#         return True
#     return False

# %%
f = astor.to_source(child)

# %%
# !pip install tokenize
# Out:
# Collecting tokenize
# Collecting tokenize
#   Could not find a version that satisfies the requirement tokenize (from versions: )
# No matching distribution found for tokenize
#   Could not find a version that satisfies the requirement tokenize (from versions: )
# No matching distribution found for tokenize
# You are using pip version 10.0.1, however version 19.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# You are using pip version 10.0.1, however version 19.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import tokenize

# %%
for five_tuple in tokenize.tokenize(f):
        print(five_tuple.type)
        print(five_tuple.string)
        print(five_tuple.start)
        print(five_tuple.end)
        print(five_tuple.line)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-103-76824408bb54> in <module>
# ----> 1 for five_tuple in tokenize.tokenize(f):
#       2         print(five_tuple.type)
#       3         print(five_tuple.string)
#       4         print(five_tuple.start)
#       5         print(five_tuple.end)
#
# ~/miniconda3/lib/python3.7/tokenize.py in tokenize(readline)
#     479     # built yet and tokenize is imported.
#     480     from itertools import chain, repeat
# --> 481     encoding, consumed = detect_encoding(readline)
#     482     rl_gen = iter(readline, b"")
#     483     empty = repeat(b"")
#
# ~/miniconda3/lib/python3.7/tokenize.py in detect_encoding(readline)
#     416         return encoding
#     417
# --> 418     first = read_or_stop()
#     419     if first.startswith(BOM_UTF8):
#     420         bom_found = True
#
# ~/miniconda3/lib/python3.7/tokenize.py in read_or_stop()
#     374     def read_or_stop():
#     375         try:
# --> 376             return readline()
#     377         except StopIteration:
#     378             return b''
#
# TypeError: 'str' object is not callable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-103-76824408bb54> in <module>
# ----> 1 for five_tuple in tokenize.tokenize(f):
#       2         print(five_tuple.type)
#       3         print(five_tuple.string)
#       4         print(five_tuple.start)
#       5         print(five_tuple.end)
#
# ~/miniconda3/lib/python3.7/tokenize.py in tokenize(readline)
#     479     # built yet and tokenize is imported.
#     480     from itertools import chain, repeat
# --> 481     encoding, consumed = detect_encoding(readline)
#     482     rl_gen = iter(readline, b"")
#     483     empty = repeat(b"")
#
# ~/miniconda3/lib/python3.7/tokenize.py in detect_encoding(readline)
#     416         return encoding
#     417
# --> 418     first = read_or_stop()
#     419     if first.startswith(BOM_UTF8):
#     420         bom_found = True
#
# ~/miniconda3/lib/python3.7/tokenize.py in read_or_stop()
#     374     def read_or_stop():
#     375         try:
# --> 376             return readline()
#     377         except StopIteration:
#     378             return b''
#
# TypeError: 'str' object is not callable

# %%
import pygments
import pygments.lexers
from pygments.filters import TokenMergeFilter, VisibleWhitespaceFilter
code = re.sub(' +', ' ', f.replace("\n", " ").strip())
l = pygments.lexers.PythonLexer()
l.add_filter(TokenMergeFilter())
for token in pygments.lex(code, l):
    print(token)
# Out:
# (Token.Keyword, 'if')
# (Token.Text, ' ')
# (Token.Name, 'sys')
# (Token.Operator, '.')
# (Token.Name, 'argv')
# (Token.Punctuation, '[')
# (Token.Literal.Number.Integer, '1')
# (Token.Punctuation, ']')
# (Token.Text, ' ')
# (Token.Operator, '==')
# (Token.Text, ' ')
# (Token.Literal.String.Single, "'-gen'")
# (Token.Punctuation, ':')
# (Token.Text, ' ')
# (Token.Keyword, 'print')
# (Token.Punctuation, '(')
# (Token.Name, 'results')
# (Token.Punctuation, ')')
# (Token.Text, ' ')
# (Token.Keyword, 'else')
# (Token.Punctuation, ':')
# (Token.Text, ' ')
# (Token.Name, 'showResults')
# (Token.Punctuation, '(')
# (Token.Name, 'fingerprintScores')
# (Token.Punctuation, ',')
# (Token.Text, ' ')
# (Token.Name.Builtin, 'len')
# (Token.Punctuation, '(')
# (Token.Name, 'tests')
# (Token.Punctuation, '))')
# (Token.Text, '\n')
# (Token.Keyword, 'if')
# (Token.Text, ' ')
# (Token.Name, 'sys')
# (Token.Operator, '.')
# (Token.Name, 'argv')
# (Token.Punctuation, '[')
# (Token.Literal.Number.Integer, '1')
# (Token.Punctuation, ']')
# (Token.Text, ' ')
# (Token.Operator, '==')
# (Token.Text, ' ')
# (Token.Literal.String.Single, "'-gen'")
# (Token.Punctuation, ':')
# (Token.Text, ' ')
# (Token.Keyword, 'print')
# (Token.Punctuation, '(')
# (Token.Name, 'results')
# (Token.Punctuation, ')')
# (Token.Text, ' ')
# (Token.Keyword, 'else')
# (Token.Punctuation, ':')
# (Token.Text, ' ')
# (Token.Name, 'showResults')
# (Token.Punctuation, '(')
# (Token.Name, 'fingerprintScores')
# (Token.Punctuation, ',')
# (Token.Text, ' ')
# (Token.Name.Builtin, 'len')
# (Token.Punctuation, '(')
# (Token.Name, 'tests')
# (Token.Punctuation, '))')
# (Token.Text, '\n')

# %%
import re
re.sub(' +', ' ', f.replace("\n", " ").strip())
# Out:
# "if sys.argv[1] == '-gen': print(results) else: showResults(fingerprintScores, len(tests))"
# "if sys.argv[1] == '-gen': print(results) else: showResults(fingerprintScores, len(tests))"

# %%
line = "s    \t\t\ta b\t \t\t  c \t"
code = re.sub('\t+', ' ', line.strip())
code = re.sub(' +', ' ', code)
code
# Out:
# 's a b c'

# %%
class CommentProcessor:
    def __init__(self):
        self.comments = {}
    
    def parse_comments(self, code):
        for lineno, line in enumerate(code.split("\n")):
            if "#" in line:
                comment = line[line.find("#")+1:]
                line = line[:line.find("#")]
                quotes1 = line.count('"')
                quotes2 = line.count("'")
                comment = re.sub('\t+', ' ', comment.strip().replace("#", ""))
                comment = re.sub(' +', ' ', comment)
                if len(comment) and quotes1 % 2 == 0 and quotes2 % 2 == 0:
                    self.comments[lineno] = comment

# %%
line, line.count('"')
# Out:
# ('print("fingerping.py path        # Matches the images in the path folder with the fingerprint of known PNG libraries")',
#  2)

# %%
import re
import tokenize
from io import BytesIO

def get_tokens(f, special_word, remember_word):
    code = re.sub('\t+', ' ', f.strip())
    code = re.sub(' +', ' ', code)
    tokens = []
    remember_idxs = []
    special_idx = -1
    for token in tokenize.tokenize(BytesIO(code.encode('utf-8')).readline):
        print(token)
        tokens.append(token.string)
        if token.string == special_word:
            special_idx = len(tokens)-2
        if token.string == remember_word:
            remember_idxs.append(len(tokens)-2)
    return tokens[1:-2], special_idx, remember_idxs

# %%
special_word = "JKMCFHNBVCXSDJ"
data = []

code = read_file_to_string(filenm)
astree = ast.parse(code, filenm)

cp = CommentProcessor()
cp.parse_comments(code)
lines_ast = {}

for fun in ast.iter_child_nodes(astree):
    if isinstance(fun, ast.FunctionDef):
        scope = [arg.arg for arg in fun.args.args]
        for node in ast.walk(fun):
            # collecting scope
            if isinstance(node, ast.Name) and isinstance(node.ctx, ast.Store):
                scope.append(node.id)
            # collecting comments_ast
            # the later - the righter idea
            if hasattr(node, "lineno"):
                lines_ast[node.lineno-1] = node
        for lineno in lines_ast:
            node = lines_ast[lineno]
            if lineno in cp.comments:
                node.comment = "# "+cp.comments[lineno]
        scope = set(scope)
        #print(fun.name, scope)
        #walk_ = 0
        first = True
        if len(scope) >= 3:
            for node in ast.walk(fun):
                if isinstance(node, ast.Name) and isinstance(node.ctx, ast.Load) and node.id in scope:
                    #if len(scope) >= 3 or (len(scope) >= 2 and not node.id in scope):
                        id_ = node.id
                        node.id = special_word
                        tokens, idx, remember_idxs = get_tokens(astor.to_source(fun), special_word, id_)
                        assert tokens[idx] == special_word
                        assert np.all([tokens[remem_idx]==id_ for remem_idx in remember_idxs])
                        print(tokens, idx, remember_idxs)
                        node.id = id_
                        #if len(remember_idxs) >= 1:
                        if first:
                            tokens[idx] = id_
                            data.append([tokens, scope, []])
                            first = False
                        data[-1][2].append([id_, id_, idx, remember_idxs]) # correct, correct
                        buggy_id = list(scope.difference({id_}))\
                                   [np.random.randint(low=0, high=len(scope)-1)]
                        data[-1][2].append([id_, buggy_id, idx, remember_idxs]) # correct, buggy
        if not first and len(data[-1][2]) <= 2:
            del data[-1]
                            
                        #walk_ += 1
# Out:
# ['def', 'gamma', '(', 'image', ')', ':', '\n', ' ', 'pixel', '=', 'JKMCFHNBVCXSDJ', '.', 'getPixelRgb', '(', '120', ',', '140', ')', '\n', 'if', 'pixel', '[', '0', ']', '+', 'pixel', '[', '1', ']', '+', 'pixel', '[', '2', ']', '<', '96', ':', '\n', 'return', '11', '\n', 'else', ':', '\n', 'chunk', '=', 'image', '.', 'getChunk', '(', "'gAMA'", ')', '\n', 'if', 'chunk', '==', 'None', ':', '\n', 'return', '12', '\n', 'gammav', '=', 'unpack', '(', "'!I'", ',', 'chunk', '.', 'content', ')', '\n', 'if', 'gammav', '[', '0', ']', '==', '400000', ':', '\n', 'return', '13', '\n', 'return', '14', ''] 10 [3, 46]
# ['def', 'gamma', '(', 'image', ')', ':', '\n', ' ', 'pixel', '=', 'image', '.', 'getPixelRgb', '(', '120', ',', '140', ')', '\n', 'if', 'pixel', '[', '0', ']', '+', 'pixel', '[', '1', ']', '+', 'pixel', '[', '2', ']', '<', '96', ':', '\n', 'return', '11', '\n', 'else', ':', '\n', 'chunk', '=', 'image', '.', 'getChunk', '(', "'gAMA'", ')', '\n', 'if', 'JKMCFHNBVCXSDJ', '==', 'None', ':', '\n', 'return', '12', '\n', 'gammav', '=', 'unpack', '(', "'!I'", ',', 'chunk', '.', 'content', ')', '\n', 'if', 'gammav', '[', '0', ']', '==', '400000', ':', '\n', 'return', '13', '\n', 'return', '14', ''] 54 [44, 68]
# ['def', 'gamma', '(', 'image', ')', ':', '\n', ' ', 'pixel', '=', 'image', '.', 'getPixelRgb', '(', '120', ',', '140', ')', '\n', 'if', 'pixel', '[', '0', ']', '+', 'pixel', '[', '1', ']', '+', 'JKMCFHNBVCXSDJ', '[', '2', ']', '<', '96', ':', '\n', 'return', '11', '\n', 'else', ':', '\n', 'chunk', '=', 'image', '.', 'getChunk', '(', "'gAMA'", ')', '\n', 'if', 'chunk', '==', 'None', ':', '\n', 'return', '12', '\n', 'gammav', '=', 'unpack', '(', "'!I'", ',', 'chunk', '.', 'content', ')', '\n', 'if', 'gammav', '[', '0', ']', '==', '400000', ':', '\n', 'return', '13', '\n', 'return', '14', ''] 30 [8, 20, 25]
# ['def', 'gamma', '(', 'image', ')', ':', '\n', ' ', 'pixel', '=', 'image', '.', 'getPixelRgb', '(', '120', ',', '140', ')', '\n', 'if', 'pixel', '[', '0', ']', '+', 'pixel', '[', '1', ']', '+', 'pixel', '[', '2', ']', '<', '96', ':', '\n', 'return', '11', '\n', 'else', ':', '\n', 'chunk', '=', 'JKMCFHNBVCXSDJ', '.', 'getChunk', '(', "'gAMA'", ')', '\n', 'if', 'chunk', '==', 'None', ':', '\n', 'return', '12', '\n', 'gammav', '=', 'unpack', '(', "'!I'", ',', 'chunk', '.', 'content', ')', '\n', 'if', 'gammav', '[', '0', ']', '==', '400000', ':', '\n', 'return', '13', '\n', 'return', '14', ''] 46 [3, 10]
# ['def', 'gamma', '(', 'image', ')', ':', '\n', ' ', 'pixel', '=', 'image', '.', 'getPixelRgb', '(', '120', ',', '140', ')', '\n', 'if', 'pixel', '[', '0', ']', '+', 'pixel', '[', '1', ']', '+', 'pixel', '[', '2', ']', '<', '96', ':', '\n', 'return', '11', '\n', 'else', ':', '\n', 'chunk', '=', 'image', '.', 'getChunk', '(', "'gAMA'", ')', '\n', 'if', 'chunk', '==', 'None', ':', '\n', 'return', '12', '\n', 'gammav', '=', 'unpack', '(', "'!I'", ',', 'JKMCFHNBVCXSDJ', '.', 'content', ')', '\n', 'if', 'gammav', '[', '0', ']', '==', '400000', ':', '\n', 'return', '13', '\n', 'return', '14', ''] 68 [44, 54]
# ['def', 'gamma', '(', 'image', ')', ':', '\n', ' ', 'pixel', '=', 'image', '.', 'getPixelRgb', '(', '120', ',', '140', ')', '\n', 'if', 'pixel', '[', '0', ']', '+', 'pixel', '[', '1', ']', '+', 'pixel', '[', '2', ']', '<', '96', ':', '\n', 'return', '11', '\n', 'else', ':', '\n', 'chunk', '=', 'image', '.', 'getChunk', '(', "'gAMA'", ')', '\n', 'if', 'chunk', '==', 'None', ':', '\n', 'return', '12', '\n', 'gammav', '=', 'unpack', '(', "'!I'", ',', 'chunk', '.', 'content', ')', '\n', 'if', 'JKMCFHNBVCXSDJ', '[', '0', ']', '==', '400000', ':', '\n', 'return', '13', '\n', 'return', '14', ''] 74 [62]
# ['def', 'gamma', '(', 'image', ')', ':', '\n', ' ', 'pixel', '=', 'image', '.', 'getPixelRgb', '(', '120', ',', '140', ')', '\n', 'if', 'JKMCFHNBVCXSDJ', '[', '0', ']', '+', 'pixel', '[', '1', ']', '+', 'pixel', '[', '2', ']', '<', '96', ':', '\n', 'return', '11', '\n', 'else', ':', '\n', 'chunk', '=', 'image', '.', 'getChunk', '(', "'gAMA'", ')', '\n', 'if', 'chunk', '==', 'None', ':', '\n', 'return', '12', '\n', 'gammav', '=', 'unpack', '(', "'!I'", ',', 'chunk', '.', 'content', ')', '\n', 'if', 'gammav', '[', '0', ']', '==', '400000', ':', '\n', 'return', '13', '\n', 'return', '14', ''] 20 [8, 25, 30]
# ['def', 'gamma', '(', 'image', ')', ':', '\n', ' ', 'pixel', '=', 'image', '.', 'getPixelRgb', '(', '120', ',', '140', ')', '\n', 'if', 'pixel', '[', '0', ']', '+', 'JKMCFHNBVCXSDJ', '[', '1', ']', '+', 'pixel', '[', '2', ']', '<', '96', ':', '\n', 'return', '11', '\n', 'else', ':', '\n', 'chunk', '=', 'image', '.', 'getChunk', '(', "'gAMA'", ')', '\n', 'if', 'chunk', '==', 'None', ':', '\n', 'return', '12', '\n', 'gammav', '=', 'unpack', '(', "'!I'", ',', 'chunk', '.', 'content', ')', '\n', 'if', 'gammav', '[', '0', ']', '==', '400000', ':', '\n', 'return', '13', '\n', 'return', '14', ''] 25 [8, 20, 30]
# ['def', 'physChunk', '(', 'image', ')', ':', '\n', ' ', 'chunk', '=', 'image', '.', 'getChunk', '(', "'pHYs'", ')', '\n', 'if', 'JKMCFHNBVCXSDJ', '==', 'None', ':', '\n', 'return', '11', '\n', 'x', ',', 'y', ',', 'u', '=', 'unpack', '(', "'!IIB'", ',', 'chunk', '.', 'content', ')', '\n', 'if', 'x', '==', '1', ':', '\n', 'return', '12', '\n', 'if', 'x', '==', '1500', ':', '\n', 'return', '13', '\n', 'if', 'x', '==', '1499', ':', '\n', 'return', '14', '\n', 'return', '15', ''] 18 [8, 36]
# ['def', 'physChunk', '(', 'image', ')', ':', '\n', ' ', 'chunk', '=', 'image', '.', 'getChunk', '(', "'pHYs'", ')', '\n', 'if', 'chunk', '==', 'None', ':', '\n', 'return', '11', '\n', 'x', ',', 'y', ',', 'u', '=', 'unpack', '(', "'!IIB'", ',', 'chunk', '.', 'content', ')', '\n', 'if', 'JKMCFHNBVCXSDJ', '==', '1', ':', '\n', 'return', '12', '\n', 'if', 'x', '==', '1500', ':', '\n', 'return', '13', '\n', 'if', 'x', '==', '1499', ':', '\n', 'return', '14', '\n', 'return', '15', ''] 42 [26, 51, 60]
# ['def', 'physChunk', '(', 'image', ')', ':', '\n', ' ', 'chunk', '=', 'image', '.', 'getChunk', '(', "'pHYs'", ')', '\n', 'if', 'chunk', '==', 'None', ':', '\n', 'return', '11', '\n', 'x', ',', 'y', ',', 'u', '=', 'unpack', '(', "'!IIB'", ',', 'chunk', '.', 'content', ')', '\n', 'if', 'x', '==', '1', ':', '\n', 'return', '12', '\n', 'if', 'JKMCFHNBVCXSDJ', '==', '1500', ':', '\n', 'return', '13', '\n', 'if', 'x', '==', '1499', ':', '\n', 'return', '14', '\n', 'return', '15', ''] 51 [26, 42, 60]
# ['def', 'physChunk', '(', 'image', ')', ':', '\n', ' ', 'chunk', '=', 'image', '.', 'getChunk', '(', "'pHYs'", ')', '\n', 'if', 'chunk', '==', 'None', ':', '\n', 'return', '11', '\n', 'x', ',', 'y', ',', 'u', '=', 'unpack', '(', "'!IIB'", ',', 'chunk', '.', 'content', ')', '\n', 'if', 'x', '==', '1', ':', '\n', 'return', '12', '\n', 'if', 'x', '==', '1500', ':', '\n', 'return', '13', '\n', 'if', 'JKMCFHNBVCXSDJ', '==', '1499', ':', '\n', 'return', '14', '\n', 'return', '15', ''] 60 [26, 42, 51]
# ['def', 'physChunk', '(', 'image', ')', ':', '\n', ' ', 'chunk', '=', 'JKMCFHNBVCXSDJ', '.', 'getChunk', '(', "'pHYs'", ')', '\n', 'if', 'chunk', '==', 'None', ':', '\n', 'return', '11', '\n', 'x', ',', 'y', ',', 'u', '=', 'unpack', '(', "'!IIB'", ',', 'chunk', '.', 'content', ')', '\n', 'if', 'x', '==', '1', ':', '\n', 'return', '12', '\n', 'if', 'x', '==', '1500', ':', '\n', 'return', '13', '\n', 'if', 'x', '==', '1499', ':', '\n', 'return', '14', '\n', 'return', '15', ''] 10 [3]
# ['def', 'physChunk', '(', 'image', ')', ':', '\n', ' ', 'chunk', '=', 'image', '.', 'getChunk', '(', "'pHYs'", ')', '\n', 'if', 'chunk', '==', 'None', ':', '\n', 'return', '11', '\n', 'x', ',', 'y', ',', 'u', '=', 'unpack', '(', "'!IIB'", ',', 'JKMCFHNBVCXSDJ', '.', 'content', ')', '\n', 'if', 'x', '==', '1', ':', '\n', 'return', '12', '\n', 'if', 'x', '==', '1500', ':', '\n', 'return', '13', '\n', 'if', 'x', '==', '1499', ':', '\n', 'return', '14', '\n', 'return', '15', ''] 36 [8, 18]
# ['def', 'doTests', '(', 'tests', ',', 'fingerprints', ',', 'warn', ')', ':', '\n', ' ', 'results', '=', '{', '}', '\n', 'fingerprintScores', '=', '{', '}', '\n', 'for', 'fingerprint', 'in', 'JKMCFHNBVCXSDJ', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '=', '0', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'image', '=', 'Png', '(', 'directory', '+', 'test', '.', 'filename', '+', "'.png'", ')', '\n', 'if', 'not', 'image', '.', 'valid', '==', '0', ':', '\n', 'result', '=', 'test', '.', 'function', '(', 'image', ')', '\n', 'else', ':', '\n', 'result', '=', '0', '\n', 'results', '[', 'test', '.', 'name', ']', '=', 'result', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', 'if', 'warn', ':', '\n', 'print', '(', "'warning, missing key'", ',', 'test', '.', 'name', ',', "'in'", ',', '\n', 'fingerprint', '.', 'name', ')', '\n', 'elif', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', '==', 'result', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '+=', '1', '\n', 'return', 'results', ',', 'fingerprintScores', ''] 25 [5, 93]
# ['def', 'doTests', '(', 'tests', ',', 'fingerprints', ',', 'warn', ')', ':', '\n', ' ', 'results', '=', '{', '}', '\n', 'fingerprintScores', '=', '{', '}', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '=', '0', '\n', 'for', 'test', 'in', 'JKMCFHNBVCXSDJ', ':', '\n', 'image', '=', 'Png', '(', 'directory', '+', 'test', '.', 'filename', '+', "'.png'", ')', '\n', 'if', 'not', 'image', '.', 'valid', '==', '0', ':', '\n', 'result', '=', 'test', '.', 'function', '(', 'image', ')', '\n', 'else', ':', '\n', 'result', '=', '0', '\n', 'results', '[', 'test', '.', 'name', ']', '=', 'result', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', 'if', 'warn', ':', '\n', 'print', '(', "'warning, missing key'", ',', 'test', '.', 'name', ',', "'in'", ',', '\n', 'fingerprint', '.', 'name', ')', '\n', 'elif', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', '==', 'result', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '+=', '1', '\n', 'return', 'results', ',', 'fingerprintScores', ''] 40 [3]
# ['def', 'doTests', '(', 'tests', ',', 'fingerprints', ',', 'warn', ')', ':', '\n', ' ', 'results', '=', '{', '}', '\n', 'fingerprintScores', '=', '{', '}', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '=', '0', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'image', '=', 'Png', '(', 'directory', '+', 'test', '.', 'filename', '+', "'.png'", ')', '\n', 'if', 'not', 'image', '.', 'valid', '==', '0', ':', '\n', 'result', '=', 'test', '.', 'function', '(', 'image', ')', '\n', 'else', ':', '\n', 'result', '=', '0', '\n', 'results', '[', 'test', '.', 'name', ']', '=', 'JKMCFHNBVCXSDJ', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', 'if', 'warn', ':', '\n', 'print', '(', "'warning, missing key'", ',', 'test', '.', 'name', ',', "'in'", ',', '\n', 'fingerprint', '.', 'name', ')', '\n', 'elif', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', '==', 'result', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '+=', '1', '\n', 'return', 'results', ',', 'fingerprintScores', ''] 88 [65, 77, 137]
# ['def', 'doTests', '(', 'tests', ',', 'fingerprints', ',', 'warn', ')', ':', '\n', ' ', 'results', '=', '{', '}', '\n', 'fingerprintScores', '=', '{', '}', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '=', '0', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'image', '=', 'Png', '(', 'directory', '+', 'test', '.', 'filename', '+', "'.png'", ')', '\n', 'if', 'not', 'image', '.', 'valid', '==', '0', ':', '\n', 'result', '=', 'test', '.', 'function', '(', 'image', ')', '\n', 'else', ':', '\n', 'result', '=', '0', '\n', 'results', '[', 'test', '.', 'name', ']', '=', 'result', '\n', 'for', 'fingerprint', 'in', 'JKMCFHNBVCXSDJ', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', 'if', 'warn', ':', '\n', 'print', '(', "'warning, missing key'", ',', 'test', '.', 'name', ',', "'in'", ',', '\n', 'fingerprint', '.', 'name', ')', '\n', 'elif', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', '==', 'result', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '+=', '1', '\n', 'return', 'results', ',', 'fingerprintScores', ''] 93 [5, 25]
# ['def', 'doTests', '(', 'tests', ',', 'fingerprints', ',', 'warn', ')', ':', '\n', ' ', 'results', '=', '{', '}', '\n', 'fingerprintScores', '=', '{', '}', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '=', '0', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'image', '=', 'Png', '(', 'directory', '+', 'test', '.', 'filename', '+', "'.png'", ')', '\n', 'if', 'not', 'image', '.', 'valid', '==', '0', ':', '\n', 'result', '=', 'test', '.', 'function', '(', 'image', ')', '\n', 'else', ':', '\n', 'result', '=', '0', '\n', 'results', '[', 'test', '.', 'name', ']', '=', 'result', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', 'if', 'warn', ':', '\n', 'print', '(', "'warning, missing key'", ',', 'test', '.', 'name', ',', "'in'", ',', '\n', 'fingerprint', '.', 'name', ')', '\n', 'elif', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', '==', 'result', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '+=', '1', '\n', 'return', 'JKMCFHNBVCXSDJ', ',', 'fingerprintScores', ''] 150 [12, 81, 104, 130]
# ['def', 'doTests', '(', 'tests', ',', 'fingerprints', ',', 'warn', ')', ':', '\n', ' ', 'results', '=', '{', '}', '\n', 'fingerprintScores', '=', '{', '}', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '=', '0', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'image', '=', 'Png', '(', 'directory', '+', 'test', '.', 'filename', '+', "'.png'", ')', '\n', 'if', 'not', 'image', '.', 'valid', '==', '0', ':', '\n', 'result', '=', 'test', '.', 'function', '(', 'image', ')', '\n', 'else', ':', '\n', 'result', '=', '0', '\n', 'results', '[', 'test', '.', 'name', ']', '=', 'result', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', 'if', 'warn', ':', '\n', 'print', '(', "'warning, missing key'", ',', 'test', '.', 'name', ',', "'in'", ',', '\n', 'fingerprint', '.', 'name', ')', '\n', 'elif', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', '==', 'result', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '+=', '1', '\n', 'return', 'results', ',', 'JKMCFHNBVCXSDJ', ''] 152 [17, 28, 140]
# ['def', 'doTests', '(', 'tests', ',', 'fingerprints', ',', 'warn', ')', ':', '\n', ' ', 'results', '=', '{', '}', '\n', 'fingerprintScores', '=', '{', '}', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'JKMCFHNBVCXSDJ', '[', 'fingerprint', '.', 'name', ']', '=', '0', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'image', '=', 'Png', '(', 'directory', '+', 'test', '.', 'filename', '+', "'.png'", ')', '\n', 'if', 'not', 'image', '.', 'valid', '==', '0', ':', '\n', 'result', '=', 'test', '.', 'function', '(', 'image', ')', '\n', 'else', ':', '\n', 'result', '=', '0', '\n', 'results', '[', 'test', '.', 'name', ']', '=', 'result', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', 'if', 'warn', ':', '\n', 'print', '(', "'warning, missing key'", ',', 'test', '.', 'name', ',', "'in'", ',', '\n', 'fingerprint', '.', 'name', ')', '\n', 'elif', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', '==', 'result', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '+=', '1', '\n', 'return', 'results', ',', 'fingerprintScores', ''] 28 [17, 140, 152]
# ['def', 'doTests', '(', 'tests', ',', 'fingerprints', ',', 'warn', ')', ':', '\n', ' ', 'results', '=', '{', '}', '\n', 'fingerprintScores', '=', '{', '}', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '=', '0', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'image', '=', 'Png', '(', 'directory', '+', 'test', '.', 'filename', '+', "'.png'", ')', '\n', 'if', 'not', 'image', '.', 'valid', '==', '0', ':', '\n', 'result', '=', 'test', '.', 'function', '(', 'image', ')', '\n', 'else', ':', '\n', 'result', '=', '0', '\n', 'JKMCFHNBVCXSDJ', '[', 'test', '.', 'name', ']', '=', 'result', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', 'if', 'warn', ':', '\n', 'print', '(', "'warning, missing key'", ',', 'test', '.', 'name', ',', "'in'", ',', '\n', 'fingerprint', '.', 'name', ')', '\n', 'elif', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', '==', 'result', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '+=', '1', '\n', 'return', 'results', ',', 'fingerprintScores', ''] 81 [12, 104, 130, 150]
# ['def', 'doTests', '(', 'tests', ',', 'fingerprints', ',', 'warn', ')', ':', '\n', ' ', 'results', '=', '{', '}', '\n', 'fingerprintScores', '=', '{', '}', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '=', '0', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'image', '=', 'Png', '(', 'directory', '+', 'test', '.', 'filename', '+', "'.png'", ')', '\n', 'if', 'not', 'image', '.', 'valid', '==', '0', ':', '\n', 'result', '=', 'test', '.', 'function', '(', 'JKMCFHNBVCXSDJ', ')', '\n', 'else', ':', '\n', 'result', '=', '0', '\n', 'results', '[', 'test', '.', 'name', ']', '=', 'result', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', 'if', 'warn', ':', '\n', 'print', '(', "'warning, missing key'", ',', 'test', '.', 'name', ',', "'in'", ',', '\n', 'fingerprint', '.', 'name', ')', '\n', 'elif', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', '==', 'result', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '+=', '1', '\n', 'return', 'results', ',', 'fingerprintScores', ''] 71 [43, 58]
# ['def', 'doTests', '(', 'tests', ',', 'fingerprints', ',', 'warn', ')', ':', '\n', ' ', 'results', '=', '{', '}', '\n', 'fingerprintScores', '=', '{', '}', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '=', '0', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'image', '=', 'Png', '(', 'directory', '+', 'test', '.', 'filename', '+', "'.png'", ')', '\n', 'if', 'not', 'image', '.', 'valid', '==', '0', ':', '\n', 'result', '=', 'test', '.', 'function', '(', 'image', ')', '\n', 'else', ':', '\n', 'result', '=', '0', '\n', 'results', '[', 'test', '.', 'name', ']', '=', 'result', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', 'if', 'JKMCFHNBVCXSDJ', ':', '\n', 'print', '(', "'warning, missing key'", ',', 'test', '.', 'name', ',', "'in'", ',', '\n', 'fingerprint', '.', 'name', ')', '\n', 'elif', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', '==', 'result', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '+=', '1', '\n', 'return', 'results', ',', 'fingerprintScores', ''] 108 [7]
# ['def', 'doTests', '(', 'tests', ',', 'fingerprints', ',', 'warn', ')', ':', '\n', ' ', 'results', '=', '{', '}', '\n', 'fingerprintScores', '=', '{', '}', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'fingerprintScores', '[', 'JKMCFHNBVCXSDJ', '.', 'name', ']', '=', '0', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'image', '=', 'Png', '(', 'directory', '+', 'test', '.', 'filename', '+', "'.png'", ')', '\n', 'if', 'not', 'image', '.', 'valid', '==', '0', ':', '\n', 'result', '=', 'test', '.', 'function', '(', 'image', ')', '\n', 'else', ':', '\n', 'result', '=', '0', '\n', 'results', '[', 'test', '.', 'name', ']', '=', 'result', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', 'if', 'warn', ':', '\n', 'print', '(', "'warning, missing key'", ',', 'test', '.', 'name', ',', "'in'", ',', '\n', 'fingerprint', '.', 'name', ')', '\n', 'elif', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', '==', 'result', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '+=', '1', '\n', 'return', 'results', ',', 'fingerprintScores', ''] 30 [23, 91, 102, 122, 128, 142]
# ['def', 'doTests', '(', 'tests', ',', 'fingerprints', ',', 'warn', ')', ':', '\n', ' ', 'results', '=', '{', '}', '\n', 'fingerprintScores', '=', '{', '}', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '=', '0', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'image', '=', 'Png', '(', 'directory', '+', 'test', '.', 'filename', '+', "'.png'", ')', '\n', 'if', 'not', 'JKMCFHNBVCXSDJ', '.', 'valid', '==', '0', ':', '\n', 'result', '=', 'test', '.', 'function', '(', 'image', ')', '\n', 'else', ':', '\n', 'result', '=', '0', '\n', 'results', '[', 'test', '.', 'name', ']', '=', 'result', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', 'if', 'warn', ':', '\n', 'print', '(', "'warning, missing key'", ',', 'test', '.', 'name', ',', "'in'", ',', '\n', 'fingerprint', '.', 'name', ')', '\n', 'elif', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', '==', 'result', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '+=', '1', '\n', 'return', 'results', ',', 'fingerprintScores', ''] 58 [43, 71]
# ['def', 'doTests', '(', 'tests', ',', 'fingerprints', ',', 'warn', ')', ':', '\n', ' ', 'results', '=', '{', '}', '\n', 'fingerprintScores', '=', '{', '}', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '=', '0', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'image', '=', 'Png', '(', 'directory', '+', 'test', '.', 'filename', '+', "'.png'", ')', '\n', 'if', 'not', 'image', '.', 'valid', '==', '0', ':', '\n', 'result', '=', 'JKMCFHNBVCXSDJ', '.', 'function', '(', 'image', ')', '\n', 'else', ':', '\n', 'result', '=', '0', '\n', 'results', '[', 'test', '.', 'name', ']', '=', 'result', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', 'if', 'warn', ':', '\n', 'print', '(', "'warning, missing key'", ',', 'test', '.', 'name', ',', "'in'", ',', '\n', 'fingerprint', '.', 'name', ')', '\n', 'elif', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', '==', 'result', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '+=', '1', '\n', 'return', 'results', ',', 'fingerprintScores', ''] 67 [38, 49, 83, 98, 115, 132]
# ['def', 'doTests', '(', 'tests', ',', 'fingerprints', ',', 'warn', ')', ':', '\n', ' ', 'results', '=', '{', '}', '\n', 'fingerprintScores', '=', '{', '}', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '=', '0', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'image', '=', 'Png', '(', 'directory', '+', 'test', '.', 'filename', '+', "'.png'", ')', '\n', 'if', 'not', 'image', '.', 'valid', '==', '0', ':', '\n', 'result', '=', 'test', '.', 'function', '(', 'image', ')', '\n', 'else', ':', '\n', 'result', '=', '0', '\n', 'results', '[', 'JKMCFHNBVCXSDJ', '.', 'name', ']', '=', 'result', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', 'if', 'warn', ':', '\n', 'print', '(', "'warning, missing key'", ',', 'test', '.', 'name', ',', "'in'", ',', '\n', 'fingerprint', '.', 'name', ')', '\n', 'elif', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', '==', 'result', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '+=', '1', '\n', 'return', 'results', ',', 'fingerprintScores', ''] 83 [38, 49, 67, 98, 115, 132]
# ['def', 'doTests', '(', 'tests', ',', 'fingerprints', ',', 'warn', ')', ':', '\n', ' ', 'results', '=', '{', '}', '\n', 'fingerprintScores', '=', '{', '}', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '=', '0', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'image', '=', 'Png', '(', 'directory', '+', 'test', '.', 'filename', '+', "'.png'", ')', '\n', 'if', 'not', 'image', '.', 'valid', '==', '0', ':', '\n', 'result', '=', 'test', '.', 'function', '(', 'image', ')', '\n', 'else', ':', '\n', 'result', '=', '0', '\n', 'results', '[', 'test', '.', 'name', ']', '=', 'result', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', 'if', 'warn', ':', '\n', 'print', '(', "'warning, missing key'", ',', 'test', '.', 'name', ',', "'in'", ',', '\n', 'fingerprint', '.', 'name', ')', '\n', 'elif', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', '==', 'JKMCFHNBVCXSDJ', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '+=', '1', '\n', 'return', 'results', ',', 'fingerprintScores', ''] 137 [65, 77, 88]
# ['def', 'doTests', '(', 'tests', ',', 'fingerprints', ',', 'warn', ')', ':', '\n', ' ', 'results', '=', '{', '}', '\n', 'fingerprintScores', '=', '{', '}', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '=', '0', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'image', '=', 'Png', '(', 'directory', '+', 'JKMCFHNBVCXSDJ', '.', 'filename', '+', "'.png'", ')', '\n', 'if', 'not', 'image', '.', 'valid', '==', '0', ':', '\n', 'result', '=', 'test', '.', 'function', '(', 'image', ')', '\n', 'else', ':', '\n', 'result', '=', '0', '\n', 'results', '[', 'test', '.', 'name', ']', '=', 'result', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', 'if', 'warn', ':', '\n', 'print', '(', "'warning, missing key'", ',', 'test', '.', 'name', ',', "'in'", ',', '\n', 'fingerprint', '.', 'name', ')', '\n', 'elif', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', '==', 'result', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '+=', '1', '\n', 'return', 'results', ',', 'fingerprintScores', ''] 49 [38, 67, 83, 98, 115, 132]
# ['def', 'doTests', '(', 'tests', ',', 'fingerprints', ',', 'warn', ')', ':', '\n', ' ', 'results', '=', '{', '}', '\n', 'fingerprintScores', '=', '{', '}', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '=', '0', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'image', '=', 'Png', '(', 'directory', '+', 'test', '.', 'filename', '+', "'.png'", ')', '\n', 'if', 'not', 'image', '.', 'valid', '==', '0', ':', '\n', 'result', '=', 'test', '.', 'function', '(', 'image', ')', '\n', 'else', ':', '\n', 'result', '=', '0', '\n', 'results', '[', 'test', '.', 'name', ']', '=', 'result', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'if', 'not', 'JKMCFHNBVCXSDJ', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', 'if', 'warn', ':', '\n', 'print', '(', "'warning, missing key'", ',', 'test', '.', 'name', ',', "'in'", ',', '\n', 'fingerprint', '.', 'name', ')', '\n', 'elif', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', '==', 'result', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '+=', '1', '\n', 'return', 'results', ',', 'fingerprintScores', ''] 98 [38, 49, 67, 83, 115, 132]
# ['def', 'doTests', '(', 'tests', ',', 'fingerprints', ',', 'warn', ')', ':', '\n', ' ', 'results', '=', '{', '}', '\n', 'fingerprintScores', '=', '{', '}', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '=', '0', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'image', '=', 'Png', '(', 'directory', '+', 'test', '.', 'filename', '+', "'.png'", ')', '\n', 'if', 'not', 'image', '.', 'valid', '==', '0', ':', '\n', 'result', '=', 'test', '.', 'function', '(', 'image', ')', '\n', 'else', ':', '\n', 'result', '=', '0', '\n', 'results', '[', 'test', '.', 'name', ']', '=', 'result', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'JKMCFHNBVCXSDJ', '.', 'results', ':', '\n', 'if', 'warn', ':', '\n', 'print', '(', "'warning, missing key'", ',', 'test', '.', 'name', ',', "'in'", ',', '\n', 'fingerprint', '.', 'name', ')', '\n', 'elif', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', '==', 'result', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '+=', '1', '\n', 'return', 'results', ',', 'fingerprintScores', ''] 102 [23, 30, 91, 122, 128, 142]
# ['def', 'doTests', '(', 'tests', ',', 'fingerprints', ',', 'warn', ')', ':', '\n', ' ', 'results', '=', '{', '}', '\n', 'fingerprintScores', '=', '{', '}', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '=', '0', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'image', '=', 'Png', '(', 'directory', '+', 'test', '.', 'filename', '+', "'.png'", ')', '\n', 'if', 'not', 'image', '.', 'valid', '==', '0', ':', '\n', 'result', '=', 'test', '.', 'function', '(', 'image', ')', '\n', 'else', ':', '\n', 'result', '=', '0', '\n', 'results', '[', 'test', '.', 'name', ']', '=', 'result', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', 'if', 'warn', ':', '\n', 'print', '(', "'warning, missing key'", ',', 'test', '.', 'name', ',', "'in'", ',', '\n', 'fingerprint', '.', 'name', ')', '\n', 'elif', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', '==', 'result', ':', '\n', 'JKMCFHNBVCXSDJ', '[', 'fingerprint', '.', 'name', ']', '+=', '1', '\n', 'return', 'results', ',', 'fingerprintScores', ''] 140 [17, 28, 152]
# ['def', 'doTests', '(', 'tests', ',', 'fingerprints', ',', 'warn', ')', ':', '\n', ' ', 'results', '=', '{', '}', '\n', 'fingerprintScores', '=', '{', '}', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '=', '0', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'image', '=', 'Png', '(', 'directory', '+', 'test', '.', 'filename', '+', "'.png'", ')', '\n', 'if', 'not', 'image', '.', 'valid', '==', '0', ':', '\n', 'result', '=', 'test', '.', 'function', '(', 'image', ')', '\n', 'else', ':', '\n', 'result', '=', '0', '\n', 'results', '[', 'test', '.', 'name', ']', '=', 'result', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', 'if', 'warn', ':', '\n', 'print', '(', "'warning, missing key'", ',', 'JKMCFHNBVCXSDJ', '.', 'name', ',', "'in'", ',', '\n', 'fingerprint', '.', 'name', ')', '\n', 'elif', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', '==', 'result', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '+=', '1', '\n', 'return', 'results', ',', 'fingerprintScores', ''] 115 [38, 49, 67, 83, 98, 132]
# ['def', 'doTests', '(', 'tests', ',', 'fingerprints', ',', 'warn', ')', ':', '\n', ' ', 'results', '=', '{', '}', '\n', 'fingerprintScores', '=', '{', '}', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '=', '0', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'image', '=', 'Png', '(', 'directory', '+', 'test', '.', 'filename', '+', "'.png'", ')', '\n', 'if', 'not', 'image', '.', 'valid', '==', '0', ':', '\n', 'result', '=', 'test', '.', 'function', '(', 'image', ')', '\n', 'else', ':', '\n', 'result', '=', '0', '\n', 'results', '[', 'test', '.', 'name', ']', '=', 'result', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', 'if', 'warn', ':', '\n', 'print', '(', "'warning, missing key'", ',', 'test', '.', 'name', ',', "'in'", ',', '\n', 'JKMCFHNBVCXSDJ', '.', 'name', ')', '\n', 'elif', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', '==', 'result', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '+=', '1', '\n', 'return', 'results', ',', 'fingerprintScores', ''] 122 [23, 30, 91, 102, 128, 142]
# ['def', 'doTests', '(', 'tests', ',', 'fingerprints', ',', 'warn', ')', ':', '\n', ' ', 'results', '=', '{', '}', '\n', 'fingerprintScores', '=', '{', '}', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '=', '0', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'image', '=', 'Png', '(', 'directory', '+', 'test', '.', 'filename', '+', "'.png'", ')', '\n', 'if', 'not', 'image', '.', 'valid', '==', '0', ':', '\n', 'result', '=', 'test', '.', 'function', '(', 'image', ')', '\n', 'else', ':', '\n', 'result', '=', '0', '\n', 'results', '[', 'test', '.', 'name', ']', '=', 'result', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', 'if', 'warn', ':', '\n', 'print', '(', "'warning, missing key'", ',', 'test', '.', 'name', ',', "'in'", ',', '\n', 'fingerprint', '.', 'name', ')', '\n', 'elif', 'JKMCFHNBVCXSDJ', '.', 'results', '[', 'test', '.', 'name', ']', '==', 'result', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '+=', '1', '\n', 'return', 'results', ',', 'fingerprintScores', ''] 128 [23, 30, 91, 102, 122, 142]
# ['def', 'doTests', '(', 'tests', ',', 'fingerprints', ',', 'warn', ')', ':', '\n', ' ', 'results', '=', '{', '}', '\n', 'fingerprintScores', '=', '{', '}', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '=', '0', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'image', '=', 'Png', '(', 'directory', '+', 'test', '.', 'filename', '+', "'.png'", ')', '\n', 'if', 'not', 'image', '.', 'valid', '==', '0', ':', '\n', 'result', '=', 'test', '.', 'function', '(', 'image', ')', '\n', 'else', ':', '\n', 'result', '=', '0', '\n', 'results', '[', 'test', '.', 'name', ']', '=', 'result', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', 'if', 'warn', ':', '\n', 'print', '(', "'warning, missing key'", ',', 'test', '.', 'name', ',', "'in'", ',', '\n', 'fingerprint', '.', 'name', ')', '\n', 'elif', 'fingerprint', '.', 'results', '[', 'JKMCFHNBVCXSDJ', '.', 'name', ']', '==', 'result', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '+=', '1', '\n', 'return', 'results', ',', 'fingerprintScores', ''] 132 [38, 49, 67, 83, 98, 115]
# ['def', 'doTests', '(', 'tests', ',', 'fingerprints', ',', 'warn', ')', ':', '\n', ' ', 'results', '=', '{', '}', '\n', 'fingerprintScores', '=', '{', '}', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '=', '0', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'image', '=', 'Png', '(', 'directory', '+', 'test', '.', 'filename', '+', "'.png'", ')', '\n', 'if', 'not', 'image', '.', 'valid', '==', '0', ':', '\n', 'result', '=', 'test', '.', 'function', '(', 'image', ')', '\n', 'else', ':', '\n', 'result', '=', '0', '\n', 'results', '[', 'test', '.', 'name', ']', '=', 'result', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', 'if', 'warn', ':', '\n', 'print', '(', "'warning, missing key'", ',', 'test', '.', 'name', ',', "'in'", ',', '\n', 'fingerprint', '.', 'name', ')', '\n', 'elif', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', '==', 'result', ':', '\n', 'fingerprintScores', '[', 'JKMCFHNBVCXSDJ', '.', 'name', ']', '+=', '1', '\n', 'return', 'results', ',', 'fingerprintScores', ''] 142 [23, 30, 91, 102, 122, 128]
# ['def', 'generateCsv', '(', 'tests', ',', 'fingerprints', ')', ':', '\n', ' ', 'header', '=', "'/'", '\n', 'for', 'test', 'in', 'JKMCFHNBVCXSDJ', ':', '\n', 'header', '=', 'header', '+', "'\\t'", '+', 'test', '.', 'name', '\n', 'print', '(', 'header', ')', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'row', '=', 'fingerprint', '.', 'name', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', 'row', '+=', '\'\\t""\'', '\n', 'else', ':', '\n', 'row', '+=', "'\\t'", '+', 'str', '(', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', ')', '\n', 'print', '(', 'row', ')', ''] 17 [3, 50]
# ['def', 'generateCsv', '(', 'tests', ',', 'fingerprints', ')', ':', '\n', ' ', 'header', '=', "'/'", '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'header', '=', 'header', '+', "'\\t'", '+', 'test', '.', 'name', '\n', 'print', '(', 'header', ')', '\n', 'for', 'fingerprint', 'in', 'JKMCFHNBVCXSDJ', ':', '\n', 'row', '=', 'fingerprint', '.', 'name', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', 'row', '+=', '\'\\t""\'', '\n', 'else', ':', '\n', 'row', '+=', "'\\t'", '+', 'str', '(', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', ')', '\n', 'print', '(', 'row', ')', ''] 38 [5]
# ['def', 'generateCsv', '(', 'tests', ',', 'fingerprints', ')', ':', '\n', ' ', 'header', '=', "'/'", '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'header', '=', 'header', '+', "'\\t'", '+', 'test', '.', 'name', '\n', 'print', '(', 'JKMCFHNBVCXSDJ', ')', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'row', '=', 'fingerprint', '.', 'name', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', 'row', '+=', '\'\\t""\'', '\n', 'else', ':', '\n', 'row', '+=', "'\\t'", '+', 'str', '(', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', ')', '\n', 'print', '(', 'row', ')', ''] 32 [10, 20, 22]
# ['def', 'generateCsv', '(', 'tests', ',', 'fingerprints', ')', ':', '\n', ' ', 'header', '=', "'/'", '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'header', '=', 'header', '+', "'\\t'", '+', 'test', '.', 'name', '\n', 'print', '(', 'header', ')', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'row', '=', 'fingerprint', '.', 'name', '\n', 'for', 'test', 'in', 'JKMCFHNBVCXSDJ', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', 'row', '+=', '\'\\t""\'', '\n', 'else', ':', '\n', 'row', '+=', "'\\t'", '+', 'str', '(', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', ')', '\n', 'print', '(', 'row', ')', ''] 50 [3, 17]
# ['def', 'generateCsv', '(', 'tests', ',', 'fingerprints', ')', ':', '\n', ' ', 'header', '=', "'/'", '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'header', '=', 'header', '+', "'\\t'", '+', 'test', '.', 'name', '\n', 'print', '(', 'header', ')', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'row', '=', 'JKMCFHNBVCXSDJ', '.', 'name', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', 'row', '+=', '\'\\t""\'', '\n', 'else', ':', '\n', 'row', '+=', "'\\t'", '+', 'str', '(', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', ')', '\n', 'print', '(', 'row', ')', ''] 43 [36, 59, 77]
# ['def', 'generateCsv', '(', 'tests', ',', 'fingerprints', ')', ':', '\n', ' ', 'header', '=', "'/'", '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'header', '=', 'header', '+', "'\\t'", '+', 'test', '.', 'name', '\n', 'print', '(', 'header', ')', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'row', '=', 'fingerprint', '.', 'name', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', 'row', '+=', '\'\\t""\'', '\n', 'else', ':', '\n', 'row', '+=', "'\\t'", '+', 'str', '(', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', ')', '\n', 'print', '(', 'JKMCFHNBVCXSDJ', ')', ''] 89 [41, 64, 71]
# ['def', 'generateCsv', '(', 'tests', ',', 'fingerprints', ')', ':', '\n', ' ', 'header', '=', "'/'", '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'header', '=', 'JKMCFHNBVCXSDJ', '+', "'\\t'", '+', 'test', '.', 'name', '\n', 'print', '(', 'header', ')', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'row', '=', 'fingerprint', '.', 'name', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', 'row', '+=', '\'\\t""\'', '\n', 'else', ':', '\n', 'row', '+=', "'\\t'", '+', 'str', '(', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', ')', '\n', 'print', '(', 'row', ')', ''] 22 [10, 20, 32]
# ['def', 'generateCsv', '(', 'tests', ',', 'fingerprints', ')', ':', '\n', ' ', 'header', '=', "'/'", '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'header', '=', 'header', '+', "'\\t'", '+', 'JKMCFHNBVCXSDJ', '.', 'name', '\n', 'print', '(', 'header', ')', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'row', '=', 'fingerprint', '.', 'name', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', 'row', '+=', '\'\\t""\'', '\n', 'else', ':', '\n', 'row', '+=', "'\\t'", '+', 'str', '(', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', ')', '\n', 'print', '(', 'row', ')', ''] 26 [15, 48, 55, 81]
# ['def', 'generateCsv', '(', 'tests', ',', 'fingerprints', ')', ':', '\n', ' ', 'header', '=', "'/'", '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'header', '=', 'header', '+', "'\\t'", '+', 'test', '.', 'name', '\n', 'print', '(', 'header', ')', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'row', '=', 'fingerprint', '.', 'name', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'if', 'not', 'JKMCFHNBVCXSDJ', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', 'row', '+=', '\'\\t""\'', '\n', 'else', ':', '\n', 'row', '+=', "'\\t'", '+', 'str', '(', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', ')', '\n', 'print', '(', 'row', ')', ''] 55 [15, 26, 48, 81]
# ['def', 'generateCsv', '(', 'tests', ',', 'fingerprints', ')', ':', '\n', ' ', 'header', '=', "'/'", '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'header', '=', 'header', '+', "'\\t'", '+', 'test', '.', 'name', '\n', 'print', '(', 'header', ')', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'row', '=', 'fingerprint', '.', 'name', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'JKMCFHNBVCXSDJ', '.', 'results', ':', '\n', 'row', '+=', '\'\\t""\'', '\n', 'else', ':', '\n', 'row', '+=', "'\\t'", '+', 'str', '(', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', ')', '\n', 'print', '(', 'row', ')', ''] 59 [36, 43, 77]
# ['def', 'generateCsv', '(', 'tests', ',', 'fingerprints', ')', ':', '\n', ' ', 'header', '=', "'/'", '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'header', '=', 'header', '+', "'\\t'", '+', 'test', '.', 'name', '\n', 'print', '(', 'header', ')', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'row', '=', 'fingerprint', '.', 'name', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', 'row', '+=', '\'\\t""\'', '\n', 'else', ':', '\n', 'row', '+=', "'\\t'", '+', 'str', '(', 'JKMCFHNBVCXSDJ', '.', 'results', '[', 'test', '.', 'name', ']', ')', '\n', 'print', '(', 'row', ')', ''] 77 [36, 43, 59]
# ['def', 'generateCsv', '(', 'tests', ',', 'fingerprints', ')', ':', '\n', ' ', 'header', '=', "'/'", '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'header', '=', 'header', '+', "'\\t'", '+', 'test', '.', 'name', '\n', 'print', '(', 'header', ')', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'row', '=', 'fingerprint', '.', 'name', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', 'row', '+=', '\'\\t""\'', '\n', 'else', ':', '\n', 'row', '+=', "'\\t'", '+', 'str', '(', 'fingerprint', '.', 'results', '[', 'JKMCFHNBVCXSDJ', '.', 'name', ']', ')', '\n', 'print', '(', 'row', ')', ''] 81 [15, 26, 48, 55]
# ['def', 'showResults', '(', 'scores', ',', 'nb', ')', ':', '\n', ' ', 'ordered', '=', 'sorted', '(', 'iter', '(', 'scores', '.', 'items', '(', ')', ')', ',', 'key', '=', 'itemgetter', '(', '1', ')', ')', '\n', 'for', 'result', 'in', 'JKMCFHNBVCXSDJ', ':', '\n', 'print', '(', "'{:20s} {:3d}/{:3d}'", '.', 'format', '(', 'result', '[', '0', ']', ',', 'result', '[', '1', ']', ',', 'nb', ')', ')', ''] 34 [10]
# ['def', 'showResults', '(', 'scores', ',', 'nb', ')', ':', '\n', ' ', 'ordered', '=', 'sorted', '(', 'iter', '(', 'scores', '.', 'items', '(', ')', ')', ',', 'key', '=', 'itemgetter', '(', '1', ')', ')', '\n', 'for', 'result', 'in', 'ordered', ':', '\n', 'print', '(', "'{:20s} {:3d}/{:3d}'", '.', 'format', '(', 'result', '[', '0', ']', ',', 'result', '[', '1', ']', ',', 'JKMCFHNBVCXSDJ', ')', '\n', ')', ''] 53 [5]
# ['def', 'showResults', '(', 'scores', ',', 'nb', ')', ':', '\n', ' ', 'ordered', '=', 'sorted', '(', 'iter', '(', 'JKMCFHNBVCXSDJ', '.', 'items', '(', ')', ')', ',', 'key', '=', 'itemgetter', '(', '1', ')', ')', '\n', 'for', 'result', 'in', 'ordered', ':', '\n', 'print', '(', "'{:20s} {:3d}/{:3d}'", '.', 'format', '(', 'result', '[', '0', ']', ',', 'result', '[', '1', ']', ',', 'nb', ')', ')', ''] 16 [3]
# ['def', 'showResults', '(', 'scores', ',', 'nb', ')', ':', '\n', ' ', 'ordered', '=', 'sorted', '(', 'iter', '(', 'scores', '.', 'items', '(', ')', ')', ',', 'key', '=', 'itemgetter', '(', '1', ')', ')', '\n', 'for', 'result', 'in', 'ordered', ':', '\n', 'print', '(', "'{:20s} {:3d}/{:3d}'", '.', 'format', '(', 'JKMCFHNBVCXSDJ', '[', '0', ']', ',', 'result', '[', '1', ']', ',', 'nb', ')', ')', ''] 43 [32, 48]
# ['def', 'showResults', '(', 'scores', ',', 'nb', ')', ':', '\n', ' ', 'ordered', '=', 'sorted', '(', 'iter', '(', 'scores', '.', 'items', '(', ')', ')', ',', 'key', '=', 'itemgetter', '(', '1', ')', ')', '\n', 'for', 'result', 'in', 'ordered', ':', '\n', 'print', '(', "'{:20s} {:3d}/{:3d}'", '.', 'format', '(', 'result', '[', '0', ']', ',', 'JKMCFHNBVCXSDJ', '[', '1', ']', ',', 'nb', ')', ')', ''] 48 [32, 43]

# %%
cp.comments
# Out:
# {0: '!/usr/bin/python',
#  2: 'fingerping: A PNG library fingerprinting tool.',
#  4: '@author:Dominique Bongard',
#  7: 'Code is licensed under -- Apache License 2.0 http://www.apache.org/licenses/',
#  20: 'A named tuple representing a fingerprint test',
#  21: 'name = name of the test',
#  22: 'filename = filename of the png file to test',
#  23: 'function = function to call to execute the test',
#  24: 'description = description of the test',
#  27: 'A named tuple representing the fingerprint of a PNG library',
#  28: 'name = name of the language / library / tool',
#  29: 'description = description of the library (e.g. version number)',
#  30: 'results = a dictionary of test fingerprint test results',
#  36: 'Fingerprinting functions',
#  41: 'The most simple fingerprinting function',
#  43: 'Returns 0 if the image is absent or empty (meaning the target failed to decode the input image)',
#  44: 'Returns 10 if the image looks valid at least in surface',
#  45: 'Returns between 1 and 9 if the image is corrupt',
#  49: 'All the following tests should return values > 10 (or any kind of object like a list actually)',
#  52: 'Fingerprint depending on the correctness of the checksums of the output image',
#  59: 'Fingerprint resulting from the set of filters used in the scanlines of the output image (returns a sorted list of the filters)',
#  63: 'Fingerprint depending on the palette used to decode images with two palettes (when not rejected)',
#  72: 'Fingerprint depending on how the decoder treated the gamma information from the input image',
#  86: 'Fingerprint depending on the ihdr used to decode images with two ihdr (when not rejected)',
#  95: 'Fingerprint depending on the treatment of images with invalid scanline filters',
#  99: 'Most libraries return the correct image',
#  101: 'One library outputs a corrupted image',
#  104: 'Fingerprint depending on the zlib compression level flag of the output image',
#  108: 'Fingerprint depending on how the decoder treated the phys information in the input image',
#  119: '.net',
#  122: 'Fingerprint depending on how the decoder treated an input image with a tRNS chunk',
#  133: 'include all the tests and fingerprints from external files',
#  141: "Test all the images in a directory (don't print warnings when generating fingerprints)",
#  145: 'Initialite the count of matching tests to zero for each fingerprint',
#  148: 'Execute each test',
#  152: 'Only execute the test if there is an image to test',
#  156: 'Save the result of the test',
#  159: 'Check if the result matches some of the fingeprints and if so, increment the match counter',
#  162: 'warn if a fingerprint is missing the result for the test being run',
#  169: 'Generate a csv table with all the test results for each fingerprint (which you can then import in LibreOffice or whatever)',
#  185: 'Show the fingerprinting result with the most likely library match at the bottom',
#  191: 'check if the command line has valid options',
#  207: 'Main program',
#  212: 'use reflection to get all the tests and all the fingeprints in lists',
#  225: 'Generate a csv output with all the test results for each library fingerprint known to the tool',
#  230: 'last command line argument is the directory with all the images to use in a fingerprint test',
#  235: "If the -gen parameter is given on the command line, don't give the fingerprinting results",
#  236: 'but instead generate a new fingerprint'}

# %%
lines_ast
# Out:
# {46: <_ast.arg at 0x7f6071cbcf28>,
#  47: <_ast.Name at 0x7f6071cbc9e8>,
#  53: <_ast.arg at 0x7f607087c0b8>,
#  54: <_ast.Name at 0x7f607087c208>,
#  55: <_ast.Num at 0x7f607087c438>,
#  57: <_ast.Num at 0x7f607087c940>,
#  60: <_ast.arg at 0x7f607087cb00>,
#  61: <_ast.Name at 0x7f6070854198>,
#  64: <_ast.arg at 0x7f6070854550>,
#  65: <_ast.Num at 0x7f6070854f60>,
#  66: <_ast.Num at 0x7f6070854f98>,
#  67: <_ast.Num at 0x7f60708edf28>,
#  68: <_ast.Num at 0x7f60708edb70>,
#  70: <_ast.Num at 0x7f607084df60>,
#  73: <_ast.arg at 0x7f60707c81d0>,
#  74: <_ast.Name at 0x7f607079f9b0>,
#  75: <_ast.Num at 0x7f6071574710>,
#  76: <_ast.Num at 0x7f6071574c88>,
#  78: <_ast.Name at 0x7f6071574cf8>,
#  79: <_ast.NameConstant at 0x7f6071574fd0>,
#  81: <_ast.Name at 0x7f60707e1160>,
#  82: <_ast.Num at 0x7f607086e978>,
#  84: <_ast.Num at 0x7f607086e0b8>,
#  80: <_ast.Num at 0x7f6071574e80>,
#  83: <_ast.Num at 0x7f607086e7b8>,
#  87: <_ast.arg at 0x7f607086e048>,
#  88: <_ast.Name at 0x7f607086ec50>,
#  89: <_ast.Num at 0x7f607086e780>,
#  90: <_ast.Name at 0x7f607086ee80>,
#  91: <_ast.Num at 0x7f607086e470>,
#  93: <_ast.Num at 0x7f607086e588>,
#  96: <_ast.arg at 0x7f60708b9160>,
#  97: <_ast.Name at 0x7f60708b9080>,
#  98: <_ast.Num at 0x7f60708b9b70>,
#  102: <_ast.Num at 0x7f60708b9cc0>,
#  99: <_ast.Num at 0x7f60708b9c18>,
#  100: <_ast.Num at 0x7f60708b9f60>,
#  101: <_ast.Num at 0x7f60708b9438>,
#  105: <_ast.arg at 0x7f60708b9550>,
#  106: <_ast.Name at 0x7f60708b9198>,
#  109: <_ast.arg at 0x7f60719eb9b0>,
#  110: <_ast.Name at 0x7f60719eb978>,
#  111: <_ast.NameConstant at 0x7f60707bc978>,
#  113: <_ast.Name at 0x7f607083e2b0>,
#  114: <_ast.Num at 0x7f607083ea90>,
#  116: <_ast.Num at 0x7f607083e4e0>,
#  118: <_ast.Num at 0x7f607083e390>,
#  120: <_ast.Num at 0x7f607083ebe0>,
#  112: <_ast.Num at 0x7f60707bcf60>,
#  115: <_ast.Num at 0x7f607083efd0>,
#  117: <_ast.Num at 0x7f607083e240>,
#  119: <_ast.Num at 0x7f607083ecf8>,
#  123: <_ast.arg at 0x7f607083eac8>,
#  124: <_ast.Name at 0x7f607083e128>,
#  126: <_ast.Name at 0x7f607083e400>,
#  127: <_ast.NameConstant at 0x7f607083e358>,
#  129: <_ast.Num at 0x7f607083eef0>,
#  125: <_ast.Num at 0x7f607083e470>,
#  128: <_ast.Num at 0x7f607083e630>,
#  142: <_ast.arg at 0x7f60708116a0>,
#  143: <_ast.Dict at 0x7f6070811048>,
#  144: <_ast.Dict at 0x7f6070811b70>,
#  146: <_ast.Name at 0x7f6070811f98>,
#  149: <_ast.Name at 0x7f60709d37b8>,
#  167: <_ast.Name at 0x7f6071a4f0b8>,
#  147: <_ast.Name at 0x7f60709d35f8>,
#  150: <_ast.Name at 0x7f60709d3b38>,
#  151: <_ast.Name at 0x7f6072a84978>,
#  157: <_ast.Name at 0x7f6070f56b00>,
#  160: <_ast.Name at 0x7f6070f56a20>,
#  153: <_ast.Name at 0x7f60719de1d0>,
#  155: <_ast.Num at 0x7f60719de518>,
#  161: <_ast.Name at 0x7f6070ef5588>,
#  163: <_ast.Name at 0x7f60718d31d0>,
#  165: <_ast.Name at 0x7f60708ac898>,
#  164: <_ast.Name at 0x7f60709f98d0>,
#  166: <_ast.Name at 0x7f6071a4f518>,
#  170: <_ast.arg at 0x7f6071a4f9e8>,
#  171: <_ast.Str at 0x7f6071a4f630>,
#  172: <_ast.Name at 0x7f6071a4f128>,
#  174: <_ast.Name at 0x7f6070835860>,
#  176: <_ast.Name at 0x7f6070835940>,
#  173: <_ast.Name at 0x7f60708353c8>,
#  177: <_ast.Name at 0x7f6070835ef0>,
#  178: <_ast.Name at 0x7f60708431d0>,
#  183: <_ast.Name at 0x7f6070843ac8>,
#  179: <_ast.Name at 0x7f6070843390>,
#  180: <_ast.Str at 0x7f6070843518>,
#  182: <_ast.Name at 0x7f6070843a20>,
#  186: <_ast.arg at 0x7f6070843da0>,
#  187: <_ast.Name at 0x7f607081bb00>,
#  188: <_ast.Name at 0x7f607081b1d0>,
#  189: <_ast.Num at 0x7f607081b6a0>,
#  192: <_ast.arg at 0x7f607081b780>,
#  193: <_ast.Name at 0x7f607081b898>,
#  198: <_ast.Name at 0x7f6070844940>,
#  202: <_ast.NameConstant at 0x7f6070844eb8>,
#  194: <_ast.Num at 0x7f6070833ac8>,
#  199: <_ast.Num at 0x7f6070844d30>,
#  201: <_ast.NameConstant at 0x7f6070844e48>,
#  195: <_ast.NameConstant at 0x7f6070833dd8>,
#  197: <_ast.NameConstant at 0x7f6070844710>,
#  200: <_ast.NameConstant at 0x7f6070844dd8>}

# %%
data_v0 = data

# %%
import asttokens

special_word = "JKMCFHNBVCXSDJ"
data = []

code = read_file_to_string(filenm)
code_lines = code.splitlines()
#astree = ast.parse(code, filenm)
atok = asttokens.ASTTokens(code, parse=True)
astree = atok.tree

#cp = CommentProcessor()
#cp.parse_comments(code)
#lines_ast = {}
for fun in ast.iter_child_nodes(astree):
    if isinstance(fun, ast.FunctionDef) and len(fun.body) > 0:
        a_fun, b_fun = fun.first_token.startpos, fun.last_token.endpos
        precomment, postcomment = get_pre_post_comments(fun, code_lines)
        body_start = fun.body[0].first_token.startpos
        docstring = ast.get_docstring(fun)
        if not docstring:
            docstring = ""
        else:
            docstring = "###DCSTR### " + docstring + "\n"
        scope = [arg.arg for arg in fun.args.args]
        for node in ast.walk(fun):
            # collecting scope
            if isinstance(node, ast.Name) and isinstance(node.ctx, ast.Store):
                scope.append(node.id)
            # collecting comments_ast
            # the later - the righter idea
            #if hasattr(node, "lineno"):
            #    lines_ast[node.lineno-1] = node
        #for lineno in lines_ast:
        #    node = lines_ast[lineno]
        #    if lineno in cp.comments:
        #        node.comment = "# "+cp.comments[lineno]
        scope = set(scope)
        #print(fun.name, scope)
        #walk_ = 0
        first = True
        if len(scope) >= 3:
            for node in ast.walk(fun):
                if isinstance(node, ast.Name) and isinstance(node.ctx, ast.Load) and node.id in scope:
                    #if len(scope) >= 3 or (len(scope) >= 2 and not node.id in scope):
                        id_ = node.id
                        a, b = node.first_token.startpos, node.last_token.endpos
                        node_code = precomment + code[a_fun:body_start]+docstring+\
                        code[body_start:a] + special_word + code[b:b_fun] + postcomment
                        #node.id = special_word
                        tokens, idx, remember_idxs, comments = get_tokens(node_code, special_word, id_)
                        assert tokens[idx] == special_word
                        assert np.all([tokens[remem_idx]==id_ for remem_idx in remember_idxs])
                        print(tokens, idx, remember_idxs)
                        node.id = id_
                        #if len(remember_idxs) >= 1:
                        if first:
                            tokens[idx] = id_
                            data.append([tokens, comments, scope, []])
                            first = False
                        data[-1][3].append([id_, id_, idx, remember_idxs]) # correct, correct
                        buggy_id = list(scope.difference({id_}))\
                                   [np.random.randint(low=0, high=len(scope)-1)]
                        data[-1][3].append([id_, buggy_id, idx, remember_idxs]) # correct, buggy
        if not first and len(data[-1][3]) <= 2:
            del data[-1]
                            
                        #walk_ += 1
# Out:
# ['\n', 'def', 'gamma', '(', 'image', ')', ':', '\n', ' ', 'pixel', '=', 'JKMCFHNBVCXSDJ', '.', 'getPixelRgb', '(', '120', ',', '140', ')', '\n', 'if', 'pixel', '[', '0', ']', '+', 'pixel', '[', '1', ']', '+', 'pixel', '[', '2', ']', '<', '96', ':', '\n', 'return', '11', '\n', 'else', ':', '\n', 'chunk', '=', 'image', '.', 'getChunk', '(', '"gAMA"', ')', '\n', 'if', 'chunk', '==', 'None', ':', '\n', 'return', '12', '\n', 'gammav', '=', 'unpack', '(', '"!I"', ',', 'chunk', '.', 'content', ')', '\n', 'if', 'gammav', '[', '0', ']', '==', '400000', ':', '\n', 'return', '13', '\n', 'return', '14', ''] 11 [4, 47]
# ['\n', 'def', 'gamma', '(', 'image', ')', ':', '\n', ' ', 'pixel', '=', 'image', '.', 'getPixelRgb', '(', '120', ',', '140', ')', '\n', 'if', 'pixel', '[', '0', ']', '+', 'pixel', '[', '1', ']', '+', 'pixel', '[', '2', ']', '<', '96', ':', '\n', 'return', '11', '\n', 'else', ':', '\n', 'chunk', '=', 'image', '.', 'getChunk', '(', '"gAMA"', ')', '\n', 'if', 'JKMCFHNBVCXSDJ', '==', 'None', ':', '\n', 'return', '12', '\n', 'gammav', '=', 'unpack', '(', '"!I"', ',', 'chunk', '.', 'content', ')', '\n', 'if', 'gammav', '[', '0', ']', '==', '400000', ':', '\n', 'return', '13', '\n', 'return', '14', ''] 55 [45, 69]
# ['\n', 'def', 'gamma', '(', 'image', ')', ':', '\n', ' ', 'pixel', '=', 'image', '.', 'getPixelRgb', '(', '120', ',', '140', ')', '\n', 'if', 'pixel', '[', '0', ']', '+', 'pixel', '[', '1', ']', '+', 'JKMCFHNBVCXSDJ', '[', '2', ']', '<', '96', ':', '\n', 'return', '11', '\n', 'else', ':', '\n', 'chunk', '=', 'image', '.', 'getChunk', '(', '"gAMA"', ')', '\n', 'if', 'chunk', '==', 'None', ':', '\n', 'return', '12', '\n', 'gammav', '=', 'unpack', '(', '"!I"', ',', 'chunk', '.', 'content', ')', '\n', 'if', 'gammav', '[', '0', ']', '==', '400000', ':', '\n', 'return', '13', '\n', 'return', '14', ''] 31 [9, 21, 26]
# ['\n', 'def', 'gamma', '(', 'image', ')', ':', '\n', ' ', 'pixel', '=', 'image', '.', 'getPixelRgb', '(', '120', ',', '140', ')', '\n', 'if', 'pixel', '[', '0', ']', '+', 'pixel', '[', '1', ']', '+', 'pixel', '[', '2', ']', '<', '96', ':', '\n', 'return', '11', '\n', 'else', ':', '\n', 'chunk', '=', 'JKMCFHNBVCXSDJ', '.', 'getChunk', '(', '"gAMA"', ')', '\n', 'if', 'chunk', '==', 'None', ':', '\n', 'return', '12', '\n', 'gammav', '=', 'unpack', '(', '"!I"', ',', 'chunk', '.', 'content', ')', '\n', 'if', 'gammav', '[', '0', ']', '==', '400000', ':', '\n', 'return', '13', '\n', 'return', '14', ''] 47 [4, 11]
# ['\n', 'def', 'gamma', '(', 'image', ')', ':', '\n', ' ', 'pixel', '=', 'image', '.', 'getPixelRgb', '(', '120', ',', '140', ')', '\n', 'if', 'pixel', '[', '0', ']', '+', 'pixel', '[', '1', ']', '+', 'pixel', '[', '2', ']', '<', '96', ':', '\n', 'return', '11', '\n', 'else', ':', '\n', 'chunk', '=', 'image', '.', 'getChunk', '(', '"gAMA"', ')', '\n', 'if', 'chunk', '==', 'None', ':', '\n', 'return', '12', '\n', 'gammav', '=', 'unpack', '(', '"!I"', ',', 'JKMCFHNBVCXSDJ', '.', 'content', ')', '\n', 'if', 'gammav', '[', '0', ']', '==', '400000', ':', '\n', 'return', '13', '\n', 'return', '14', ''] 69 [45, 55]
# ['\n', 'def', 'gamma', '(', 'image', ')', ':', '\n', ' ', 'pixel', '=', 'image', '.', 'getPixelRgb', '(', '120', ',', '140', ')', '\n', 'if', 'pixel', '[', '0', ']', '+', 'pixel', '[', '1', ']', '+', 'pixel', '[', '2', ']', '<', '96', ':', '\n', 'return', '11', '\n', 'else', ':', '\n', 'chunk', '=', 'image', '.', 'getChunk', '(', '"gAMA"', ')', '\n', 'if', 'chunk', '==', 'None', ':', '\n', 'return', '12', '\n', 'gammav', '=', 'unpack', '(', '"!I"', ',', 'chunk', '.', 'content', ')', '\n', 'if', 'JKMCFHNBVCXSDJ', '[', '0', ']', '==', '400000', ':', '\n', 'return', '13', '\n', 'return', '14', ''] 75 [63]
# ['\n', 'def', 'gamma', '(', 'image', ')', ':', '\n', ' ', 'pixel', '=', 'image', '.', 'getPixelRgb', '(', '120', ',', '140', ')', '\n', 'if', 'JKMCFHNBVCXSDJ', '[', '0', ']', '+', 'pixel', '[', '1', ']', '+', 'pixel', '[', '2', ']', '<', '96', ':', '\n', 'return', '11', '\n', 'else', ':', '\n', 'chunk', '=', 'image', '.', 'getChunk', '(', '"gAMA"', ')', '\n', 'if', 'chunk', '==', 'None', ':', '\n', 'return', '12', '\n', 'gammav', '=', 'unpack', '(', '"!I"', ',', 'chunk', '.', 'content', ')', '\n', 'if', 'gammav', '[', '0', ']', '==', '400000', ':', '\n', 'return', '13', '\n', 'return', '14', ''] 21 [9, 26, 31]
# ['\n', 'def', 'gamma', '(', 'image', ')', ':', '\n', ' ', 'pixel', '=', 'image', '.', 'getPixelRgb', '(', '120', ',', '140', ')', '\n', 'if', 'pixel', '[', '0', ']', '+', 'JKMCFHNBVCXSDJ', '[', '1', ']', '+', 'pixel', '[', '2', ']', '<', '96', ':', '\n', 'return', '11', '\n', 'else', ':', '\n', 'chunk', '=', 'image', '.', 'getChunk', '(', '"gAMA"', ')', '\n', 'if', 'chunk', '==', 'None', ':', '\n', 'return', '12', '\n', 'gammav', '=', 'unpack', '(', '"!I"', ',', 'chunk', '.', 'content', ')', '\n', 'if', 'gammav', '[', '0', ']', '==', '400000', ':', '\n', 'return', '13', '\n', 'return', '14', ''] 26 [9, 21, 31]
# ['\n', 'def', 'physChunk', '(', 'image', ')', ':', '\n', ' ', 'chunk', '=', 'image', '.', 'getChunk', '(', '"pHYs"', ')', '\n', 'if', 'JKMCFHNBVCXSDJ', '==', 'None', ':', '\n', 'return', '11', '\n', 'x', ',', 'y', ',', 'u', '=', 'unpack', '(', '"!IIB"', ',', 'chunk', '.', 'content', ')', '\n', 'if', 'x', '==', '1', ':', '\n', 'return', '12', '\n', 'if', 'x', '==', '1500', ':', '\n', 'return', '13', '\n', 'if', 'x', '==', '1499', ':', '\n', 'return', '14', '\n', 'return', '15', ''] 19 [9, 37]
# ['\n', 'def', 'physChunk', '(', 'image', ')', ':', '\n', ' ', 'chunk', '=', 'image', '.', 'getChunk', '(', '"pHYs"', ')', '\n', 'if', 'chunk', '==', 'None', ':', '\n', 'return', '11', '\n', 'x', ',', 'y', ',', 'u', '=', 'unpack', '(', '"!IIB"', ',', 'chunk', '.', 'content', ')', '\n', 'if', 'JKMCFHNBVCXSDJ', '==', '1', ':', '\n', 'return', '12', '\n', 'if', 'x', '==', '1500', ':', '\n', 'return', '13', '\n', 'if', 'x', '==', '1499', ':', '\n', 'return', '14', '\n', 'return', '15', ''] 43 [27, 52, 61]
# ['\n', 'def', 'physChunk', '(', 'image', ')', ':', '\n', ' ', 'chunk', '=', 'image', '.', 'getChunk', '(', '"pHYs"', ')', '\n', 'if', 'chunk', '==', 'None', ':', '\n', 'return', '11', '\n', 'x', ',', 'y', ',', 'u', '=', 'unpack', '(', '"!IIB"', ',', 'chunk', '.', 'content', ')', '\n', 'if', 'x', '==', '1', ':', '\n', 'return', '12', '\n', 'if', 'JKMCFHNBVCXSDJ', '==', '1500', ':', '\n', 'return', '13', '\n', 'if', 'x', '==', '1499', ':', '\n', 'return', '14', '\n', 'return', '15', ''] 52 [27, 43, 61]
# ['\n', 'def', 'physChunk', '(', 'image', ')', ':', '\n', ' ', 'chunk', '=', 'image', '.', 'getChunk', '(', '"pHYs"', ')', '\n', 'if', 'chunk', '==', 'None', ':', '\n', 'return', '11', '\n', 'x', ',', 'y', ',', 'u', '=', 'unpack', '(', '"!IIB"', ',', 'chunk', '.', 'content', ')', '\n', 'if', 'x', '==', '1', ':', '\n', 'return', '12', '\n', 'if', 'x', '==', '1500', ':', '\n', 'return', '13', '\n', 'if', 'JKMCFHNBVCXSDJ', '==', '1499', ':', '\n', 'return', '14', '\n', 'return', '15', ''] 61 [27, 43, 52]
# ['\n', 'def', 'physChunk', '(', 'image', ')', ':', '\n', ' ', 'chunk', '=', 'JKMCFHNBVCXSDJ', '.', 'getChunk', '(', '"pHYs"', ')', '\n', 'if', 'chunk', '==', 'None', ':', '\n', 'return', '11', '\n', 'x', ',', 'y', ',', 'u', '=', 'unpack', '(', '"!IIB"', ',', 'chunk', '.', 'content', ')', '\n', 'if', 'x', '==', '1', ':', '\n', 'return', '12', '\n', 'if', 'x', '==', '1500', ':', '\n', 'return', '13', '\n', 'if', 'x', '==', '1499', ':', '\n', 'return', '14', '\n', 'return', '15', ''] 11 [4]
# ['\n', 'def', 'physChunk', '(', 'image', ')', ':', '\n', ' ', 'chunk', '=', 'image', '.', 'getChunk', '(', '"pHYs"', ')', '\n', 'if', 'chunk', '==', 'None', ':', '\n', 'return', '11', '\n', 'x', ',', 'y', ',', 'u', '=', 'unpack', '(', '"!IIB"', ',', 'JKMCFHNBVCXSDJ', '.', 'content', ')', '\n', 'if', 'x', '==', '1', ':', '\n', 'return', '12', '\n', 'if', 'x', '==', '1500', ':', '\n', 'return', '13', '\n', 'if', 'x', '==', '1499', ':', '\n', 'return', '14', '\n', 'return', '15', ''] 37 [9, 19]
# ['\n', 'def', 'doTests', '(', 'tests', ',', 'fingerprints', ',', 'warn', ')', ':', '\n', '\n', '"""\n my documentation\n """', '\n', ' ', 'results', '=', '{', '}', '\n', 'fingerprintScores', '=', '{', '}', '\n', '\n', 'for', 'fingerprint', 'in', 'JKMCFHNBVCXSDJ', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '=', '0', '\n', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'image', '=', 'Png', '(', 'directory', '+', 'test', '.', 'filename', '+', '".png"', ')', '\n', 'if', 'not', 'image', '.', 'valid', '==', '0', ':', '\n', '\n', 'result', '=', 'test', '.', 'function', '(', 'image', ')', '\n', 'else', ':', '\n', 'result', '=', '0', '\n', '"""\n my long comment\n """', '\n', '\n', 'results', '[', 'test', '.', 'name', ']', '=', 'result', '\n', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', '\n', 'if', 'warn', ':', '\n', 'print', '(', '"warning, missing key"', ',', 'test', '.', 'name', ',', '"in"', ',', 'fingerprint', '.', 'name', ')', '\n', 'elif', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', '==', 'result', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '+=', '1', '\n', 'return', 'results', ',', 'fingerprintScores', ''] 30 [6, 105]
# ['\n', 'def', 'doTests', '(', 'tests', ',', 'fingerprints', ',', 'warn', ')', ':', '\n', '\n', '"""\n my documentation\n """', '\n', ' ', 'results', '=', '{', '}', '\n', 'fingerprintScores', '=', '{', '}', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '=', '0', '\n', '\n', 'for', 'test', 'in', 'JKMCFHNBVCXSDJ', ':', '\n', 'image', '=', 'Png', '(', 'directory', '+', 'test', '.', 'filename', '+', '".png"', ')', '\n', 'if', 'not', 'image', '.', 'valid', '==', '0', ':', '\n', '\n', 'result', '=', 'test', '.', 'function', '(', 'image', ')', '\n', 'else', ':', '\n', 'result', '=', '0', '\n', '"""\n my long comment\n """', '\n', '\n', 'results', '[', 'test', '.', 'name', ']', '=', 'result', '\n', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', '\n', 'if', 'warn', ':', '\n', 'print', '(', '"warning, missing key"', ',', 'test', '.', 'name', ',', '"in"', ',', 'fingerprint', '.', 'name', ')', '\n', 'elif', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', '==', 'result', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '+=', '1', '\n', 'return', 'results', ',', 'fingerprintScores', ''] 46 [4]
# ['\n', 'def', 'doTests', '(', 'tests', ',', 'fingerprints', ',', 'warn', ')', ':', '\n', '\n', '"""\n my documentation\n """', '\n', ' ', 'results', '=', '{', '}', '\n', 'fingerprintScores', '=', '{', '}', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '=', '0', '\n', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'image', '=', 'Png', '(', 'directory', '+', 'test', '.', 'filename', '+', '".png"', ')', '\n', 'if', 'not', 'image', '.', 'valid', '==', '0', ':', '\n', '\n', 'result', '=', 'test', '.', 'function', '(', 'image', ')', '\n', 'else', ':', '\n', 'result', '=', '0', '\n', '"""\n my long comment\n """', '\n', '\n', 'results', '[', 'test', '.', 'name', ']', '=', 'JKMCFHNBVCXSDJ', '\n', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', '\n', 'if', 'warn', ':', '\n', 'print', '(', '"warning, missing key"', ',', 'test', '.', 'name', ',', '"in"', ',', 'fingerprint', '.', 'name', ')', '\n', 'elif', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', '==', 'result', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '+=', '1', '\n', 'return', 'results', ',', 'fingerprintScores', ''] 98 [72, 84, 149]
# ['\n', 'def', 'doTests', '(', 'tests', ',', 'fingerprints', ',', 'warn', ')', ':', '\n', '\n', '"""\n my documentation\n """', '\n', ' ', 'results', '=', '{', '}', '\n', 'fingerprintScores', '=', '{', '}', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '=', '0', '\n', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'image', '=', 'Png', '(', 'directory', '+', 'test', '.', 'filename', '+', '".png"', ')', '\n', 'if', 'not', 'image', '.', 'valid', '==', '0', ':', '\n', '\n', 'result', '=', 'test', '.', 'function', '(', 'image', ')', '\n', 'else', ':', '\n', 'result', '=', '0', '\n', '"""\n my long comment\n """', '\n', '\n', 'results', '[', 'test', '.', 'name', ']', '=', 'result', '\n', '\n', '\n', 'for', 'fingerprint', 'in', 'JKMCFHNBVCXSDJ', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', '\n', 'if', 'warn', ':', '\n', 'print', '(', '"warning, missing key"', ',', 'test', '.', 'name', ',', '"in"', ',', 'fingerprint', '.', 'name', ')', '\n', 'elif', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', '==', 'result', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '+=', '1', '\n', 'return', 'results', ',', 'fingerprintScores', ''] 105 [6, 30]
# ['\n', 'def', 'doTests', '(', 'tests', ',', 'fingerprints', ',', 'warn', ')', ':', '\n', '\n', '"""\n my documentation\n """', '\n', ' ', 'results', '=', '{', '}', '\n', 'fingerprintScores', '=', '{', '}', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '=', '0', '\n', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'image', '=', 'Png', '(', 'directory', '+', 'test', '.', 'filename', '+', '".png"', ')', '\n', 'if', 'not', 'image', '.', 'valid', '==', '0', ':', '\n', '\n', 'result', '=', 'test', '.', 'function', '(', 'image', ')', '\n', 'else', ':', '\n', 'result', '=', '0', '\n', '"""\n my long comment\n """', '\n', '\n', 'results', '[', 'test', '.', 'name', ']', '=', 'result', '\n', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', '\n', 'if', 'warn', ':', '\n', 'print', '(', '"warning, missing key"', ',', 'test', '.', 'name', ',', '"in"', ',', 'fingerprint', '.', 'name', ')', '\n', 'elif', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', '==', 'result', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '+=', '1', '\n', 'return', 'JKMCFHNBVCXSDJ', ',', 'fingerprintScores', ''] 162 [16, 91, 116, 142]
# ['\n', 'def', 'doTests', '(', 'tests', ',', 'fingerprints', ',', 'warn', ')', ':', '\n', '\n', '"""\n my documentation\n """', '\n', ' ', 'results', '=', '{', '}', '\n', 'fingerprintScores', '=', '{', '}', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '=', '0', '\n', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'image', '=', 'Png', '(', 'directory', '+', 'test', '.', 'filename', '+', '".png"', ')', '\n', 'if', 'not', 'image', '.', 'valid', '==', '0', ':', '\n', '\n', 'result', '=', 'test', '.', 'function', '(', 'image', ')', '\n', 'else', ':', '\n', 'result', '=', '0', '\n', '"""\n my long comment\n """', '\n', '\n', 'results', '[', 'test', '.', 'name', ']', '=', 'result', '\n', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', '\n', 'if', 'warn', ':', '\n', 'print', '(', '"warning, missing key"', ',', 'test', '.', 'name', ',', '"in"', ',', 'fingerprint', '.', 'name', ')', '\n', 'elif', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', '==', 'result', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '+=', '1', '\n', 'return', 'results', ',', 'JKMCFHNBVCXSDJ', ''] 164 [21, 33, 152]
# ['\n', 'def', 'doTests', '(', 'tests', ',', 'fingerprints', ',', 'warn', ')', ':', '\n', '\n', '"""\n my documentation\n """', '\n', ' ', 'results', '=', '{', '}', '\n', 'fingerprintScores', '=', '{', '}', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'JKMCFHNBVCXSDJ', '[', 'fingerprint', '.', 'name', ']', '=', '0', '\n', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'image', '=', 'Png', '(', 'directory', '+', 'test', '.', 'filename', '+', '".png"', ')', '\n', 'if', 'not', 'image', '.', 'valid', '==', '0', ':', '\n', '\n', 'result', '=', 'test', '.', 'function', '(', 'image', ')', '\n', 'else', ':', '\n', 'result', '=', '0', '\n', '"""\n my long comment\n """', '\n', '\n', 'results', '[', 'test', '.', 'name', ']', '=', 'result', '\n', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', '\n', 'if', 'warn', ':', '\n', 'print', '(', '"warning, missing key"', ',', 'test', '.', 'name', ',', '"in"', ',', 'fingerprint', '.', 'name', ')', '\n', 'elif', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', '==', 'result', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '+=', '1', '\n', 'return', 'results', ',', 'fingerprintScores', ''] 33 [21, 152, 164]
# ['\n', 'def', 'doTests', '(', 'tests', ',', 'fingerprints', ',', 'warn', ')', ':', '\n', '\n', '"""\n my documentation\n """', '\n', ' ', 'results', '=', '{', '}', '\n', 'fingerprintScores', '=', '{', '}', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '=', '0', '\n', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'image', '=', 'Png', '(', 'directory', '+', 'test', '.', 'filename', '+', '".png"', ')', '\n', 'if', 'not', 'image', '.', 'valid', '==', '0', ':', '\n', '\n', 'result', '=', 'test', '.', 'function', '(', 'image', ')', '\n', 'else', ':', '\n', 'result', '=', '0', '\n', '"""\n my long comment\n """', '\n', '\n', 'JKMCFHNBVCXSDJ', '[', 'test', '.', 'name', ']', '=', 'result', '\n', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', '\n', 'if', 'warn', ':', '\n', 'print', '(', '"warning, missing key"', ',', 'test', '.', 'name', ',', '"in"', ',', 'fingerprint', '.', 'name', ')', '\n', 'elif', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', '==', 'result', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '+=', '1', '\n', 'return', 'results', ',', 'fingerprintScores', ''] 91 [16, 116, 142, 162]
# ['\n', 'def', 'doTests', '(', 'tests', ',', 'fingerprints', ',', 'warn', ')', ':', '\n', '\n', '"""\n my documentation\n """', '\n', ' ', 'results', '=', '{', '}', '\n', 'fingerprintScores', '=', '{', '}', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '=', '0', '\n', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'image', '=', 'Png', '(', 'directory', '+', 'test', '.', 'filename', '+', '".png"', ')', '\n', 'if', 'not', 'image', '.', 'valid', '==', '0', ':', '\n', '\n', 'result', '=', 'test', '.', 'function', '(', 'JKMCFHNBVCXSDJ', ')', '\n', 'else', ':', '\n', 'result', '=', '0', '\n', '"""\n my long comment\n """', '\n', '\n', 'results', '[', 'test', '.', 'name', ']', '=', 'result', '\n', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', '\n', 'if', 'warn', ':', '\n', 'print', '(', '"warning, missing key"', ',', 'test', '.', 'name', ',', '"in"', ',', 'fingerprint', '.', 'name', ')', '\n', 'elif', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', '==', 'result', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '+=', '1', '\n', 'return', 'results', ',', 'fingerprintScores', ''] 78 [49, 64]
# ['\n', 'def', 'doTests', '(', 'tests', ',', 'fingerprints', ',', 'warn', ')', ':', '\n', '\n', '"""\n my documentation\n """', '\n', ' ', 'results', '=', '{', '}', '\n', 'fingerprintScores', '=', '{', '}', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '=', '0', '\n', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'image', '=', 'Png', '(', 'directory', '+', 'test', '.', 'filename', '+', '".png"', ')', '\n', 'if', 'not', 'image', '.', 'valid', '==', '0', ':', '\n', '\n', 'result', '=', 'test', '.', 'function', '(', 'image', ')', '\n', 'else', ':', '\n', 'result', '=', '0', '\n', '"""\n my long comment\n """', '\n', '\n', 'results', '[', 'test', '.', 'name', ']', '=', 'result', '\n', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', '\n', 'if', 'JKMCFHNBVCXSDJ', ':', '\n', 'print', '(', '"warning, missing key"', ',', 'test', '.', 'name', ',', '"in"', ',', 'fingerprint', '.', 'name', ')', '\n', 'elif', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', '==', 'result', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '+=', '1', '\n', 'return', 'results', ',', 'fingerprintScores', ''] 121 [8]
# ['\n', 'def', 'doTests', '(', 'tests', ',', 'fingerprints', ',', 'warn', ')', ':', '\n', '\n', '"""\n my documentation\n """', '\n', ' ', 'results', '=', '{', '}', '\n', 'fingerprintScores', '=', '{', '}', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'fingerprintScores', '[', 'JKMCFHNBVCXSDJ', '.', 'name', ']', '=', '0', '\n', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'image', '=', 'Png', '(', 'directory', '+', 'test', '.', 'filename', '+', '".png"', ')', '\n', 'if', 'not', 'image', '.', 'valid', '==', '0', ':', '\n', '\n', 'result', '=', 'test', '.', 'function', '(', 'image', ')', '\n', 'else', ':', '\n', 'result', '=', '0', '\n', '"""\n my long comment\n """', '\n', '\n', 'results', '[', 'test', '.', 'name', ']', '=', 'result', '\n', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', '\n', 'if', 'warn', ':', '\n', 'print', '(', '"warning, missing key"', ',', 'test', '.', 'name', ',', '"in"', ',', 'fingerprint', '.', 'name', ')', '\n', 'elif', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', '==', 'result', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '+=', '1', '\n', 'return', 'results', ',', 'fingerprintScores', ''] 35 [28, 103, 114, 134, 140, 154]
# ['\n', 'def', 'doTests', '(', 'tests', ',', 'fingerprints', ',', 'warn', ')', ':', '\n', '\n', '"""\n my documentation\n """', '\n', ' ', 'results', '=', '{', '}', '\n', 'fingerprintScores', '=', '{', '}', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '=', '0', '\n', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'image', '=', 'Png', '(', 'directory', '+', 'test', '.', 'filename', '+', '".png"', ')', '\n', 'if', 'not', 'JKMCFHNBVCXSDJ', '.', 'valid', '==', '0', ':', '\n', '\n', 'result', '=', 'test', '.', 'function', '(', 'image', ')', '\n', 'else', ':', '\n', 'result', '=', '0', '\n', '"""\n my long comment\n """', '\n', '\n', 'results', '[', 'test', '.', 'name', ']', '=', 'result', '\n', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', '\n', 'if', 'warn', ':', '\n', 'print', '(', '"warning, missing key"', ',', 'test', '.', 'name', ',', '"in"', ',', 'fingerprint', '.', 'name', ')', '\n', 'elif', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', '==', 'result', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '+=', '1', '\n', 'return', 'results', ',', 'fingerprintScores', ''] 64 [49, 78]
# ['\n', 'def', 'doTests', '(', 'tests', ',', 'fingerprints', ',', 'warn', ')', ':', '\n', '\n', '"""\n my documentation\n """', '\n', ' ', 'results', '=', '{', '}', '\n', 'fingerprintScores', '=', '{', '}', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '=', '0', '\n', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'image', '=', 'Png', '(', 'directory', '+', 'test', '.', 'filename', '+', '".png"', ')', '\n', 'if', 'not', 'image', '.', 'valid', '==', '0', ':', '\n', '\n', 'result', '=', 'JKMCFHNBVCXSDJ', '.', 'function', '(', 'image', ')', '\n', 'else', ':', '\n', 'result', '=', '0', '\n', '"""\n my long comment\n """', '\n', '\n', 'results', '[', 'test', '.', 'name', ']', '=', 'result', '\n', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', '\n', 'if', 'warn', ':', '\n', 'print', '(', '"warning, missing key"', ',', 'test', '.', 'name', ',', '"in"', ',', 'fingerprint', '.', 'name', ')', '\n', 'elif', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', '==', 'result', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '+=', '1', '\n', 'return', 'results', ',', 'fingerprintScores', ''] 74 [44, 55, 93, 110, 128, 144]
# ['\n', 'def', 'doTests', '(', 'tests', ',', 'fingerprints', ',', 'warn', ')', ':', '\n', '\n', '"""\n my documentation\n """', '\n', ' ', 'results', '=', '{', '}', '\n', 'fingerprintScores', '=', '{', '}', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '=', '0', '\n', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'image', '=', 'Png', '(', 'directory', '+', 'test', '.', 'filename', '+', '".png"', ')', '\n', 'if', 'not', 'image', '.', 'valid', '==', '0', ':', '\n', '\n', 'result', '=', 'test', '.', 'function', '(', 'image', ')', '\n', 'else', ':', '\n', 'result', '=', '0', '\n', '"""\n my long comment\n """', '\n', '\n', 'results', '[', 'JKMCFHNBVCXSDJ', '.', 'name', ']', '=', 'result', '\n', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', '\n', 'if', 'warn', ':', '\n', 'print', '(', '"warning, missing key"', ',', 'test', '.', 'name', ',', '"in"', ',', 'fingerprint', '.', 'name', ')', '\n', 'elif', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', '==', 'result', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '+=', '1', '\n', 'return', 'results', ',', 'fingerprintScores', ''] 93 [44, 55, 74, 110, 128, 144]
# ['\n', 'def', 'doTests', '(', 'tests', ',', 'fingerprints', ',', 'warn', ')', ':', '\n', '\n', '"""\n my documentation\n """', '\n', ' ', 'results', '=', '{', '}', '\n', 'fingerprintScores', '=', '{', '}', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '=', '0', '\n', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'image', '=', 'Png', '(', 'directory', '+', 'test', '.', 'filename', '+', '".png"', ')', '\n', 'if', 'not', 'image', '.', 'valid', '==', '0', ':', '\n', '\n', 'result', '=', 'test', '.', 'function', '(', 'image', ')', '\n', 'else', ':', '\n', 'result', '=', '0', '\n', '"""\n my long comment\n """', '\n', '\n', 'results', '[', 'test', '.', 'name', ']', '=', 'result', '\n', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', '\n', 'if', 'warn', ':', '\n', 'print', '(', '"warning, missing key"', ',', 'test', '.', 'name', ',', '"in"', ',', 'fingerprint', '.', 'name', ')', '\n', 'elif', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', '==', 'JKMCFHNBVCXSDJ', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '+=', '1', '\n', 'return', 'results', ',', 'fingerprintScores', ''] 149 [72, 84, 98]
# ['\n', 'def', 'doTests', '(', 'tests', ',', 'fingerprints', ',', 'warn', ')', ':', '\n', '\n', '"""\n my documentation\n """', '\n', ' ', 'results', '=', '{', '}', '\n', 'fingerprintScores', '=', '{', '}', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '=', '0', '\n', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'image', '=', 'Png', '(', 'directory', '+', 'JKMCFHNBVCXSDJ', '.', 'filename', '+', '".png"', ')', '\n', 'if', 'not', 'image', '.', 'valid', '==', '0', ':', '\n', '\n', 'result', '=', 'test', '.', 'function', '(', 'image', ')', '\n', 'else', ':', '\n', 'result', '=', '0', '\n', '"""\n my long comment\n """', '\n', '\n', 'results', '[', 'test', '.', 'name', ']', '=', 'result', '\n', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', '\n', 'if', 'warn', ':', '\n', 'print', '(', '"warning, missing key"', ',', 'test', '.', 'name', ',', '"in"', ',', 'fingerprint', '.', 'name', ')', '\n', 'elif', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', '==', 'result', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '+=', '1', '\n', 'return', 'results', ',', 'fingerprintScores', ''] 55 [44, 74, 93, 110, 128, 144]
# ['\n', 'def', 'doTests', '(', 'tests', ',', 'fingerprints', ',', 'warn', ')', ':', '\n', '\n', '"""\n my documentation\n """', '\n', ' ', 'results', '=', '{', '}', '\n', 'fingerprintScores', '=', '{', '}', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '=', '0', '\n', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'image', '=', 'Png', '(', 'directory', '+', 'test', '.', 'filename', '+', '".png"', ')', '\n', 'if', 'not', 'image', '.', 'valid', '==', '0', ':', '\n', '\n', 'result', '=', 'test', '.', 'function', '(', 'image', ')', '\n', 'else', ':', '\n', 'result', '=', '0', '\n', '"""\n my long comment\n """', '\n', '\n', 'results', '[', 'test', '.', 'name', ']', '=', 'result', '\n', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'if', 'not', 'JKMCFHNBVCXSDJ', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', '\n', 'if', 'warn', ':', '\n', 'print', '(', '"warning, missing key"', ',', 'test', '.', 'name', ',', '"in"', ',', 'fingerprint', '.', 'name', ')', '\n', 'elif', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', '==', 'result', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '+=', '1', '\n', 'return', 'results', ',', 'fingerprintScores', ''] 110 [44, 55, 74, 93, 128, 144]
# ['\n', 'def', 'doTests', '(', 'tests', ',', 'fingerprints', ',', 'warn', ')', ':', '\n', '\n', '"""\n my documentation\n """', '\n', ' ', 'results', '=', '{', '}', '\n', 'fingerprintScores', '=', '{', '}', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '=', '0', '\n', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'image', '=', 'Png', '(', 'directory', '+', 'test', '.', 'filename', '+', '".png"', ')', '\n', 'if', 'not', 'image', '.', 'valid', '==', '0', ':', '\n', '\n', 'result', '=', 'test', '.', 'function', '(', 'image', ')', '\n', 'else', ':', '\n', 'result', '=', '0', '\n', '"""\n my long comment\n """', '\n', '\n', 'results', '[', 'test', '.', 'name', ']', '=', 'result', '\n', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'JKMCFHNBVCXSDJ', '.', 'results', ':', '\n', '\n', 'if', 'warn', ':', '\n', 'print', '(', '"warning, missing key"', ',', 'test', '.', 'name', ',', '"in"', ',', 'fingerprint', '.', 'name', ')', '\n', 'elif', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', '==', 'result', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '+=', '1', '\n', 'return', 'results', ',', 'fingerprintScores', ''] 114 [28, 35, 103, 134, 140, 154]
# ['\n', 'def', 'doTests', '(', 'tests', ',', 'fingerprints', ',', 'warn', ')', ':', '\n', '\n', '"""\n my documentation\n """', '\n', ' ', 'results', '=', '{', '}', '\n', 'fingerprintScores', '=', '{', '}', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '=', '0', '\n', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'image', '=', 'Png', '(', 'directory', '+', 'test', '.', 'filename', '+', '".png"', ')', '\n', 'if', 'not', 'image', '.', 'valid', '==', '0', ':', '\n', '\n', 'result', '=', 'test', '.', 'function', '(', 'image', ')', '\n', 'else', ':', '\n', 'result', '=', '0', '\n', '"""\n my long comment\n """', '\n', '\n', 'results', '[', 'test', '.', 'name', ']', '=', 'result', '\n', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', '\n', 'if', 'warn', ':', '\n', 'print', '(', '"warning, missing key"', ',', 'test', '.', 'name', ',', '"in"', ',', 'fingerprint', '.', 'name', ')', '\n', 'elif', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', '==', 'result', ':', '\n', 'JKMCFHNBVCXSDJ', '[', 'fingerprint', '.', 'name', ']', '+=', '1', '\n', 'return', 'results', ',', 'fingerprintScores', ''] 152 [21, 33, 164]
# ['\n', 'def', 'doTests', '(', 'tests', ',', 'fingerprints', ',', 'warn', ')', ':', '\n', '\n', '"""\n my documentation\n """', '\n', ' ', 'results', '=', '{', '}', '\n', 'fingerprintScores', '=', '{', '}', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '=', '0', '\n', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'image', '=', 'Png', '(', 'directory', '+', 'test', '.', 'filename', '+', '".png"', ')', '\n', 'if', 'not', 'image', '.', 'valid', '==', '0', ':', '\n', '\n', 'result', '=', 'test', '.', 'function', '(', 'image', ')', '\n', 'else', ':', '\n', 'result', '=', '0', '\n', '"""\n my long comment\n """', '\n', '\n', 'results', '[', 'test', '.', 'name', ']', '=', 'result', '\n', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', '\n', 'if', 'warn', ':', '\n', 'print', '(', '"warning, missing key"', ',', 'JKMCFHNBVCXSDJ', '.', 'name', ',', '"in"', ',', 'fingerprint', '.', 'name', ')', '\n', 'elif', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', '==', 'result', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '+=', '1', '\n', 'return', 'results', ',', 'fingerprintScores', ''] 128 [44, 55, 74, 93, 110, 144]
# ['\n', 'def', 'doTests', '(', 'tests', ',', 'fingerprints', ',', 'warn', ')', ':', '\n', '\n', '"""\n my documentation\n """', '\n', ' ', 'results', '=', '{', '}', '\n', 'fingerprintScores', '=', '{', '}', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '=', '0', '\n', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'image', '=', 'Png', '(', 'directory', '+', 'test', '.', 'filename', '+', '".png"', ')', '\n', 'if', 'not', 'image', '.', 'valid', '==', '0', ':', '\n', '\n', 'result', '=', 'test', '.', 'function', '(', 'image', ')', '\n', 'else', ':', '\n', 'result', '=', '0', '\n', '"""\n my long comment\n """', '\n', '\n', 'results', '[', 'test', '.', 'name', ']', '=', 'result', '\n', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', '\n', 'if', 'warn', ':', '\n', 'print', '(', '"warning, missing key"', ',', 'test', '.', 'name', ',', '"in"', ',', 'JKMCFHNBVCXSDJ', '.', 'name', ')', '\n', 'elif', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', '==', 'result', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '+=', '1', '\n', 'return', 'results', ',', 'fingerprintScores', ''] 134 [28, 35, 103, 114, 140, 154]
# ['\n', 'def', 'doTests', '(', 'tests', ',', 'fingerprints', ',', 'warn', ')', ':', '\n', '\n', '"""\n my documentation\n """', '\n', ' ', 'results', '=', '{', '}', '\n', 'fingerprintScores', '=', '{', '}', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '=', '0', '\n', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'image', '=', 'Png', '(', 'directory', '+', 'test', '.', 'filename', '+', '".png"', ')', '\n', 'if', 'not', 'image', '.', 'valid', '==', '0', ':', '\n', '\n', 'result', '=', 'test', '.', 'function', '(', 'image', ')', '\n', 'else', ':', '\n', 'result', '=', '0', '\n', '"""\n my long comment\n """', '\n', '\n', 'results', '[', 'test', '.', 'name', ']', '=', 'result', '\n', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', '\n', 'if', 'warn', ':', '\n', 'print', '(', '"warning, missing key"', ',', 'test', '.', 'name', ',', '"in"', ',', 'fingerprint', '.', 'name', ')', '\n', 'elif', 'JKMCFHNBVCXSDJ', '.', 'results', '[', 'test', '.', 'name', ']', '==', 'result', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '+=', '1', '\n', 'return', 'results', ',', 'fingerprintScores', ''] 140 [28, 35, 103, 114, 134, 154]
# ['\n', 'def', 'doTests', '(', 'tests', ',', 'fingerprints', ',', 'warn', ')', ':', '\n', '\n', '"""\n my documentation\n """', '\n', ' ', 'results', '=', '{', '}', '\n', 'fingerprintScores', '=', '{', '}', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '=', '0', '\n', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'image', '=', 'Png', '(', 'directory', '+', 'test', '.', 'filename', '+', '".png"', ')', '\n', 'if', 'not', 'image', '.', 'valid', '==', '0', ':', '\n', '\n', 'result', '=', 'test', '.', 'function', '(', 'image', ')', '\n', 'else', ':', '\n', 'result', '=', '0', '\n', '"""\n my long comment\n """', '\n', '\n', 'results', '[', 'test', '.', 'name', ']', '=', 'result', '\n', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', '\n', 'if', 'warn', ':', '\n', 'print', '(', '"warning, missing key"', ',', 'test', '.', 'name', ',', '"in"', ',', 'fingerprint', '.', 'name', ')', '\n', 'elif', 'fingerprint', '.', 'results', '[', 'JKMCFHNBVCXSDJ', '.', 'name', ']', '==', 'result', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '+=', '1', '\n', 'return', 'results', ',', 'fingerprintScores', ''] 144 [44, 55, 74, 93, 110, 128]
# ['\n', 'def', 'doTests', '(', 'tests', ',', 'fingerprints', ',', 'warn', ')', ':', '\n', '\n', '"""\n my documentation\n """', '\n', ' ', 'results', '=', '{', '}', '\n', 'fingerprintScores', '=', '{', '}', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '=', '0', '\n', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'image', '=', 'Png', '(', 'directory', '+', 'test', '.', 'filename', '+', '".png"', ')', '\n', 'if', 'not', 'image', '.', 'valid', '==', '0', ':', '\n', '\n', 'result', '=', 'test', '.', 'function', '(', 'image', ')', '\n', 'else', ':', '\n', 'result', '=', '0', '\n', '"""\n my long comment\n """', '\n', '\n', 'results', '[', 'test', '.', 'name', ']', '=', 'result', '\n', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', '\n', 'if', 'warn', ':', '\n', 'print', '(', '"warning, missing key"', ',', 'test', '.', 'name', ',', '"in"', ',', 'fingerprint', '.', 'name', ')', '\n', 'elif', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', '==', 'result', ':', '\n', 'fingerprintScores', '[', 'JKMCFHNBVCXSDJ', '.', 'name', ']', '+=', '1', '\n', 'return', 'results', ',', 'fingerprintScores', ''] 154 [28, 35, 103, 114, 134, 140]
# ['\n', 'def', 'generateCsv', '(', 'tests', ',', 'fingerprints', ')', ':', '\n', ' ', 'header', '=', '"/"', '\n', 'for', 'test', 'in', 'JKMCFHNBVCXSDJ', ':', '\n', 'header', '=', 'header', '+', '"\\t"', '+', 'test', '.', 'name', '\n', 'print', '(', 'header', ')', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'row', '=', 'fingerprint', '.', 'name', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', 'row', '+=', '"\\t\\"\\""', '\n', 'else', ':', '\n', 'row', '+=', '"\\t"', '+', 'str', '(', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', ')', '\n', 'print', '(', 'row', ')', ''] 18 [4, 52]
# ['\n', 'def', 'generateCsv', '(', 'tests', ',', 'fingerprints', ')', ':', '\n', ' ', 'header', '=', '"/"', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'header', '=', 'header', '+', '"\\t"', '+', 'test', '.', 'name', '\n', 'print', '(', 'header', ')', '\n', '\n', 'for', 'fingerprint', 'in', 'JKMCFHNBVCXSDJ', ':', '\n', 'row', '=', 'fingerprint', '.', 'name', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', 'row', '+=', '"\\t\\"\\""', '\n', 'else', ':', '\n', 'row', '+=', '"\\t"', '+', 'str', '(', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', ')', '\n', 'print', '(', 'row', ')', ''] 40 [6]
# ['\n', 'def', 'generateCsv', '(', 'tests', ',', 'fingerprints', ')', ':', '\n', ' ', 'header', '=', '"/"', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'header', '=', 'header', '+', '"\\t"', '+', 'test', '.', 'name', '\n', 'print', '(', 'JKMCFHNBVCXSDJ', ')', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'row', '=', 'fingerprint', '.', 'name', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', 'row', '+=', '"\\t\\"\\""', '\n', 'else', ':', '\n', 'row', '+=', '"\\t"', '+', 'str', '(', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', ')', '\n', 'print', '(', 'row', ')', ''] 33 [11, 21, 23]
# ['\n', 'def', 'generateCsv', '(', 'tests', ',', 'fingerprints', ')', ':', '\n', ' ', 'header', '=', '"/"', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'header', '=', 'header', '+', '"\\t"', '+', 'test', '.', 'name', '\n', 'print', '(', 'header', ')', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'row', '=', 'fingerprint', '.', 'name', '\n', 'for', 'test', 'in', 'JKMCFHNBVCXSDJ', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', 'row', '+=', '"\\t\\"\\""', '\n', 'else', ':', '\n', 'row', '+=', '"\\t"', '+', 'str', '(', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', ')', '\n', 'print', '(', 'row', ')', ''] 52 [4, 18]
# ['\n', 'def', 'generateCsv', '(', 'tests', ',', 'fingerprints', ')', ':', '\n', ' ', 'header', '=', '"/"', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'header', '=', 'header', '+', '"\\t"', '+', 'test', '.', 'name', '\n', 'print', '(', 'header', ')', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'row', '=', 'JKMCFHNBVCXSDJ', '.', 'name', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', 'row', '+=', '"\\t\\"\\""', '\n', 'else', ':', '\n', 'row', '+=', '"\\t"', '+', 'str', '(', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', ')', '\n', 'print', '(', 'row', ')', ''] 45 [38, 61, 79]
# ['\n', 'def', 'generateCsv', '(', 'tests', ',', 'fingerprints', ')', ':', '\n', ' ', 'header', '=', '"/"', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'header', '=', 'header', '+', '"\\t"', '+', 'test', '.', 'name', '\n', 'print', '(', 'header', ')', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'row', '=', 'fingerprint', '.', 'name', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', 'row', '+=', '"\\t\\"\\""', '\n', 'else', ':', '\n', 'row', '+=', '"\\t"', '+', 'str', '(', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', ')', '\n', 'print', '(', 'JKMCFHNBVCXSDJ', ')', ''] 91 [43, 66, 73]
# ['\n', 'def', 'generateCsv', '(', 'tests', ',', 'fingerprints', ')', ':', '\n', ' ', 'header', '=', '"/"', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'header', '=', 'JKMCFHNBVCXSDJ', '+', '"\\t"', '+', 'test', '.', 'name', '\n', 'print', '(', 'header', ')', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'row', '=', 'fingerprint', '.', 'name', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', 'row', '+=', '"\\t\\"\\""', '\n', 'else', ':', '\n', 'row', '+=', '"\\t"', '+', 'str', '(', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', ')', '\n', 'print', '(', 'row', ')', ''] 23 [11, 21, 33]
# ['\n', 'def', 'generateCsv', '(', 'tests', ',', 'fingerprints', ')', ':', '\n', ' ', 'header', '=', '"/"', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'header', '=', 'header', '+', '"\\t"', '+', 'JKMCFHNBVCXSDJ', '.', 'name', '\n', 'print', '(', 'header', ')', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'row', '=', 'fingerprint', '.', 'name', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', 'row', '+=', '"\\t\\"\\""', '\n', 'else', ':', '\n', 'row', '+=', '"\\t"', '+', 'str', '(', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', ')', '\n', 'print', '(', 'row', ')', ''] 27 [16, 50, 57, 83]
# ['\n', 'def', 'generateCsv', '(', 'tests', ',', 'fingerprints', ')', ':', '\n', ' ', 'header', '=', '"/"', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'header', '=', 'header', '+', '"\\t"', '+', 'test', '.', 'name', '\n', 'print', '(', 'header', ')', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'row', '=', 'fingerprint', '.', 'name', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'if', 'not', 'JKMCFHNBVCXSDJ', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', 'row', '+=', '"\\t\\"\\""', '\n', 'else', ':', '\n', 'row', '+=', '"\\t"', '+', 'str', '(', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', ')', '\n', 'print', '(', 'row', ')', ''] 57 [16, 27, 50, 83]
# ['\n', 'def', 'generateCsv', '(', 'tests', ',', 'fingerprints', ')', ':', '\n', ' ', 'header', '=', '"/"', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'header', '=', 'header', '+', '"\\t"', '+', 'test', '.', 'name', '\n', 'print', '(', 'header', ')', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'row', '=', 'fingerprint', '.', 'name', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'JKMCFHNBVCXSDJ', '.', 'results', ':', '\n', 'row', '+=', '"\\t\\"\\""', '\n', 'else', ':', '\n', 'row', '+=', '"\\t"', '+', 'str', '(', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', ')', '\n', 'print', '(', 'row', ')', ''] 61 [38, 45, 79]
# ['\n', 'def', 'generateCsv', '(', 'tests', ',', 'fingerprints', ')', ':', '\n', ' ', 'header', '=', '"/"', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'header', '=', 'header', '+', '"\\t"', '+', 'test', '.', 'name', '\n', 'print', '(', 'header', ')', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'row', '=', 'fingerprint', '.', 'name', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', 'row', '+=', '"\\t\\"\\""', '\n', 'else', ':', '\n', 'row', '+=', '"\\t"', '+', 'str', '(', 'JKMCFHNBVCXSDJ', '.', 'results', '[', 'test', '.', 'name', ']', ')', '\n', 'print', '(', 'row', ')', ''] 79 [38, 45, 61]
# ['\n', 'def', 'generateCsv', '(', 'tests', ',', 'fingerprints', ')', ':', '\n', ' ', 'header', '=', '"/"', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'header', '=', 'header', '+', '"\\t"', '+', 'test', '.', 'name', '\n', 'print', '(', 'header', ')', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'row', '=', 'fingerprint', '.', 'name', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', 'row', '+=', '"\\t\\"\\""', '\n', 'else', ':', '\n', 'row', '+=', '"\\t"', '+', 'str', '(', 'fingerprint', '.', 'results', '[', 'JKMCFHNBVCXSDJ', '.', 'name', ']', ')', '\n', 'print', '(', 'row', ')', ''] 83 [16, 27, 50, 57]
# ['\n', 'def', 'showResults', '(', 'scores', ',', 'nb', ')', ':', '\n', ' ', 'ordered', '=', 'sorted', '(', 'iter', '(', 'scores', '.', 'items', '(', ')', ')', ',', 'key', '=', 'itemgetter', '(', '1', ')', ')', '\n', 'for', 'result', 'in', 'JKMCFHNBVCXSDJ', ':', '\n', 'print', '(', "'{:20s} {:3d}/{:3d}'", '.', 'format', '(', 'result', '[', '0', ']', ',', 'result', '[', '1', ']', ',', 'nb', ')', ')', ''] 35 [11]
# ['\n', 'def', 'showResults', '(', 'scores', ',', 'nb', ')', ':', '\n', ' ', 'ordered', '=', 'sorted', '(', 'iter', '(', 'scores', '.', 'items', '(', ')', ')', ',', 'key', '=', 'itemgetter', '(', '1', ')', ')', '\n', 'for', 'result', 'in', 'ordered', ':', '\n', 'print', '(', "'{:20s} {:3d}/{:3d}'", '.', 'format', '(', 'result', '[', '0', ']', ',', 'result', '[', '1', ']', ',', 'JKMCFHNBVCXSDJ', ')', ')', ''] 54 [6]
# ['\n', 'def', 'showResults', '(', 'scores', ',', 'nb', ')', ':', '\n', ' ', 'ordered', '=', 'sorted', '(', 'iter', '(', 'JKMCFHNBVCXSDJ', '.', 'items', '(', ')', ')', ',', 'key', '=', 'itemgetter', '(', '1', ')', ')', '\n', 'for', 'result', 'in', 'ordered', ':', '\n', 'print', '(', "'{:20s} {:3d}/{:3d}'", '.', 'format', '(', 'result', '[', '0', ']', ',', 'result', '[', '1', ']', ',', 'nb', ')', ')', ''] 17 [4]
# ['\n', 'def', 'showResults', '(', 'scores', ',', 'nb', ')', ':', '\n', ' ', 'ordered', '=', 'sorted', '(', 'iter', '(', 'scores', '.', 'items', '(', ')', ')', ',', 'key', '=', 'itemgetter', '(', '1', ')', ')', '\n', 'for', 'result', 'in', 'ordered', ':', '\n', 'print', '(', "'{:20s} {:3d}/{:3d}'", '.', 'format', '(', 'JKMCFHNBVCXSDJ', '[', '0', ']', ',', 'result', '[', '1', ']', ',', 'nb', ')', ')', ''] 44 [33, 49]
# ['\n', 'def', 'showResults', '(', 'scores', ',', 'nb', ')', ':', '\n', ' ', 'ordered', '=', 'sorted', '(', 'iter', '(', 'scores', '.', 'items', '(', ')', ')', ',', 'key', '=', 'itemgetter', '(', '1', ')', ')', '\n', 'for', 'result', 'in', 'ordered', ':', '\n', 'print', '(', "'{:20s} {:3d}/{:3d}'", '.', 'format', '(', 'result', '[', '0', ']', ',', 'JKMCFHNBVCXSDJ', '[', '1', ']', ',', 'nb', ')', ')', ''] 49 [33, 44]

# %%
for fun in ast.iter_child_nodes(astree):
    if isinstance(fun, ast.FunctionDef) and len(fun.body) > 0:
        for node in ast.walk(fun):
            if isinstance(node, ast.Str):
                break

# %%
node.pr
# Out:
# '-gen'

# %%
node.first_token.line
# Out:
# '    if not line[1] == "-gen":\n'

# %%
fun.first_token.startpos, fun.last_token.endpos
# Out:
# (7594, 7689)

# %%
fun.first_token.start
# Out:
# (238, 0)

# %%
code.split("\n")[238]
# Out:
# '  print(results)'

# %%
for fun in ast.iter_child_nodes(astree):
    if isinstance(fun, ast.FunctionDef):
        a_fun, b_fun = fun.first_token.startpos, fun.last_token.endpos
        break

# %%
# Out:
# ''

# %%
# Out:
# 1344

# %%
for tokens, comments, scope, pairs in data:
    assert len(pairs)> 1
    for pair in pairs:
        iden1, iden2, loc_idx, rep_idxs = pair
        assert len(scope) >= 3
        assert iden1 in scope
        assert iden2 in scope
        assert tokens[loc_idx] == iden1
        for rep_idx in rep_idxs:
            assert tokens[rep_idx] == iden1
        assert len(rep_idxs) >= 1

# %%
for tokens, comments, scope, pairs in data:
    print(tokens)
    print(comments)
    for pair in pairs:
        print(pair)
# Out:
# ['\n', 'def', 'gamma', '(', 'image', ')', ':', '\n', ' ', 'pixel', '=', 'image', '.', 'getPixelRgb', '(', '120', ',', '140', ')', '\n', 'if', 'pixel', '[', '0', ']', '+', 'pixel', '[', '1', ']', '+', 'pixel', '[', '2', ']', '<', '96', ':', '\n', 'return', '11', '\n', 'else', ':', '\n', 'chunk', '=', 'image', '.', 'getChunk', '(', '"gAMA"', ')', '\n', 'if', 'chunk', '==', 'None', ':', '\n', 'return', '12', '\n', 'gammav', '=', 'unpack', '(', '"!I"', ',', 'chunk', '.', 'content', ')', '\n', 'if', 'gammav', '[', '0', ']', '==', '400000', ':', '\n', 'return', '13', '\n', 'return', '14', '']
# [[-1, '# Fingerprint depending on how the decoder treated the gamma information from the input image']]
# ['image', 'image', 11, [4, 47]]
# ['image', 'gammav', 11, [4, 47]]
# ['chunk', 'chunk', 55, [45, 69]]
# ['chunk', 'image', 55, [45, 69]]
# ['pixel', 'pixel', 31, [9, 21, 26]]
# ['pixel', 'image', 31, [9, 21, 26]]
# ['image', 'image', 47, [4, 11]]
# ['image', 'gammav', 47, [4, 11]]
# ['chunk', 'chunk', 69, [45, 55]]
# ['chunk', 'image', 69, [45, 55]]
# ['gammav', 'gammav', 75, [63]]
# ['gammav', 'chunk', 75, [63]]
# ['pixel', 'pixel', 21, [9, 26, 31]]
# ['pixel', 'gammav', 21, [9, 26, 31]]
# ['pixel', 'pixel', 26, [9, 21, 31]]
# ['pixel', 'chunk', 26, [9, 21, 31]]
# ['\n', 'def', 'physChunk', '(', 'image', ')', ':', '\n', ' ', 'chunk', '=', 'image', '.', 'getChunk', '(', '"pHYs"', ')', '\n', 'if', 'chunk', '==', 'None', ':', '\n', 'return', '11', '\n', 'x', ',', 'y', ',', 'u', '=', 'unpack', '(', '"!IIB"', ',', 'chunk', '.', 'content', ')', '\n', 'if', 'x', '==', '1', ':', '\n', 'return', '12', '\n', 'if', 'x', '==', '1500', ':', '\n', 'return', '13', '\n', 'if', 'x', '==', '1499', ':', '\n', 'return', '14', '\n', 'return', '15', '']
# [[-1, '# Fingerprint depending on how the decoder treated the phys information in the input image'], [67, '# .net ']]
# ['chunk', 'chunk', 19, [9, 37]]
# ['chunk', 'image', 19, [9, 37]]
# ['x', 'x', 43, [27, 52, 61]]
# ['x', 'u', 43, [27, 52, 61]]
# ['x', 'x', 52, [27, 43, 61]]
# ['x', 'y', 52, [27, 43, 61]]
# ['x', 'x', 61, [27, 43, 52]]
# ['x', 'y', 61, [27, 43, 52]]
# ['image', 'image', 11, [4]]
# ['image', 'y', 11, [4]]
# ['chunk', 'chunk', 37, [9, 19]]
# ['chunk', 'y', 37, [9, 19]]
# ['\n', 'def', 'doTests', '(', 'tests', ',', 'fingerprints', ',', 'warn', ')', ':', '\n', '\n', '"""\n my documentation\n """', '\n', ' ', 'results', '=', '{', '}', '\n', 'fingerprintScores', '=', '{', '}', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '=', '0', '\n', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'image', '=', 'Png', '(', 'directory', '+', 'test', '.', 'filename', '+', '".png"', ')', '\n', 'if', 'not', 'image', '.', 'valid', '==', '0', ':', '\n', '\n', 'result', '=', 'test', '.', 'function', '(', 'image', ')', '\n', 'else', ':', '\n', 'result', '=', '0', '\n', '"""\n my long comment\n """', '\n', '\n', 'results', '[', 'test', '.', 'name', ']', '=', 'result', '\n', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', '\n', 'if', 'warn', ':', '\n', 'print', '(', '"warning, missing key"', ',', 'test', '.', 'name', ',', '"in"', ',', 'fingerprint', '.', 'name', ')', '\n', 'elif', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', '==', 'result', ':', '\n', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '+=', '1', '\n', 'return', 'results', ',', 'fingerprintScores', '']
# [[-1, "# Test all the images in a directory (don't print warnings when generating fingerprints)"], [11, '###DCSTR### my documentation'], [25, '# Initialite the count of matching tests to zero for each fingerprint'], [41, '# Execute each test'], [70, '# Only execute the test if there is an image to test'], [89, '# Save the result of the test'], [100, '# Check if the result matches some of the fingeprints and if so, increment the match counter'], [118, '# warn if a fingerprint is missing the result for the test being run']]
# ['fingerprints', 'fingerprints', 30, [6, 105]]
# ['fingerprints', 'warn', 30, [6, 105]]
# ['tests', 'tests', 46, [4]]
# ['tests', 'results', 46, [4]]
# ['result', 'result', 98, [72, 84, 149]]
# ['result', 'test', 98, [72, 84, 149]]
# ['fingerprints', 'fingerprints', 105, [6, 30]]
# ['fingerprints', 'image', 105, [6, 30]]
# ['results', 'results', 162, [16, 91, 116, 142]]
# ['results', 'fingerprints', 162, [16, 91, 116, 142]]
# ['fingerprintScores', 'fingerprintScores', 164, [21, 33, 152]]
# ['fingerprintScores', 'fingerprint', 164, [21, 33, 152]]
# ['fingerprintScores', 'fingerprintScores', 33, [21, 152, 164]]
# ['fingerprintScores', 'warn', 33, [21, 152, 164]]
# ['results', 'results', 91, [16, 116, 142, 162]]
# ['results', 'result', 91, [16, 116, 142, 162]]
# ['image', 'image', 78, [49, 64]]
# ['image', 'fingerprints', 78, [49, 64]]
# ['warn', 'warn', 121, [8]]
# ['warn', 'fingerprints', 121, [8]]
# ['fingerprint', 'fingerprint', 35, [28, 103, 114, 134, 140, 154]]
# ['fingerprint', 'image', 35, [28, 103, 114, 134, 140, 154]]
# ['image', 'image', 64, [49, 78]]
# ['image', 'fingerprint', 64, [49, 78]]
# ['test', 'test', 74, [44, 55, 93, 110, 128, 144]]
# ['test', 'tests', 74, [44, 55, 93, 110, 128, 144]]
# ['test', 'test', 93, [44, 55, 74, 110, 128, 144]]
# ['test', 'tests', 93, [44, 55, 74, 110, 128, 144]]
# ['result', 'result', 149, [72, 84, 98]]
# ['result', 'results', 149, [72, 84, 98]]
# ['test', 'test', 55, [44, 74, 93, 110, 128, 144]]
# ['test', 'fingerprint', 55, [44, 74, 93, 110, 128, 144]]
# ['test', 'test', 110, [44, 55, 74, 93, 128, 144]]
# ['test', 'fingerprintScores', 110, [44, 55, 74, 93, 128, 144]]
# ['fingerprint', 'fingerprint', 114, [28, 35, 103, 134, 140, 154]]
# ['fingerprint', 'test', 114, [28, 35, 103, 134, 140, 154]]
# ['fingerprintScores', 'fingerprintScores', 152, [21, 33, 164]]
# ['fingerprintScores', 'results', 152, [21, 33, 164]]
# ['test', 'test', 128, [44, 55, 74, 93, 110, 144]]
# ['test', 'image', 128, [44, 55, 74, 93, 110, 144]]
# ['fingerprint', 'fingerprint', 134, [28, 35, 103, 114, 140, 154]]
# ['fingerprint', 'result', 134, [28, 35, 103, 114, 140, 154]]
# ['fingerprint', 'fingerprint', 140, [28, 35, 103, 114, 134, 154]]
# ['fingerprint', 'warn', 140, [28, 35, 103, 114, 134, 154]]
# ['test', 'test', 144, [44, 55, 74, 93, 110, 128]]
# ['test', 'image', 144, [44, 55, 74, 93, 110, 128]]
# ['fingerprint', 'fingerprint', 154, [28, 35, 103, 114, 134, 140]]
# ['fingerprint', 'image', 154, [28, 35, 103, 114, 134, 140]]
# ['\n', 'def', 'generateCsv', '(', 'tests', ',', 'fingerprints', ')', ':', '\n', ' ', 'header', '=', '"/"', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'header', '=', 'header', '+', '"\\t"', '+', 'test', '.', 'name', '\n', 'print', '(', 'header', ')', '\n', '\n', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', 'row', '=', 'fingerprint', '.', 'name', '\n', 'for', 'test', 'in', 'tests', ':', '\n', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', 'row', '+=', '"\\t\\"\\""', '\n', 'else', ':', '\n', 'row', '+=', '"\\t"', '+', 'str', '(', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', ')', '\n', 'print', '(', 'row', ')', '']
# [[-1, '# Generate a csv table with all the test results for each fingerprint (which you can then import in LibreOffice or whatever)']]
# ['tests', 'tests', 18, [4, 52]]
# ['tests', 'fingerprint', 18, [4, 52]]
# ['fingerprints', 'fingerprints', 40, [6]]
# ['fingerprints', 'row', 40, [6]]
# ['header', 'header', 33, [11, 21, 23]]
# ['header', 'fingerprints', 33, [11, 21, 23]]
# ['tests', 'tests', 52, [4, 18]]
# ['tests', 'header', 52, [4, 18]]
# ['fingerprint', 'fingerprint', 45, [38, 61, 79]]
# ['fingerprint', 'row', 45, [38, 61, 79]]
# ['row', 'row', 91, [43, 66, 73]]
# ['row', 'header', 91, [43, 66, 73]]
# ['header', 'header', 23, [11, 21, 33]]
# ['header', 'fingerprints', 23, [11, 21, 33]]
# ['test', 'test', 27, [16, 50, 57, 83]]
# ['test', 'row', 27, [16, 50, 57, 83]]
# ['test', 'test', 57, [16, 27, 50, 83]]
# ['test', 'tests', 57, [16, 27, 50, 83]]
# ['fingerprint', 'fingerprint', 61, [38, 45, 79]]
# ['fingerprint', 'row', 61, [38, 45, 79]]
# ['fingerprint', 'fingerprint', 79, [38, 45, 61]]
# ['fingerprint', 'header', 79, [38, 45, 61]]
# ['test', 'test', 83, [16, 27, 50, 57]]
# ['test', 'tests', 83, [16, 27, 50, 57]]
# ['\n', 'def', 'showResults', '(', 'scores', ',', 'nb', ')', ':', '\n', ' ', 'ordered', '=', 'sorted', '(', 'iter', '(', 'scores', '.', 'items', '(', ')', ')', ',', 'key', '=', 'itemgetter', '(', '1', ')', ')', '\n', 'for', 'result', 'in', 'ordered', ':', '\n', 'print', '(', "'{:20s} {:3d}/{:3d}'", '.', 'format', '(', 'result', '[', '0', ']', ',', 'result', '[', '1', ']', ',', 'nb', ')', ')', '']
# [[-1, '# Show the fingerprinting result with the most likely library match at the bottom']]
# ['ordered', 'ordered', 35, [11]]
# ['ordered', 'nb', 35, [11]]
# ['nb', 'nb', 54, [6]]
# ['nb', 'ordered', 54, [6]]
# ['scores', 'scores', 17, [4]]
# ['scores', 'nb', 17, [4]]
# ['result', 'result', 44, [33, 49]]
# ['result', 'nb', 44, [33, 49]]
# ['result', 'result', 49, [33, 44]]
# ['result', 'nb', 49, [33, 44]]

# %%
for tokens, scope, pairs in data:
    for pair in pairs:
        print(pair)
# Out:
# ['image', 'image', 10, [3, 46]]
# ['image', 'pixel', 10, [3, 46]]
# ['chunk', 'chunk', 54, [44, 68]]
# ['chunk', 'pixel', 54, [44, 68]]
# ['pixel', 'pixel', 30, [8, 20, 25]]
# ['pixel', 'gammav', 30, [8, 20, 25]]
# ['image', 'image', 46, [3, 10]]
# ['image', 'gammav', 46, [3, 10]]
# ['chunk', 'chunk', 68, [44, 54]]
# ['chunk', 'gammav', 68, [44, 54]]
# ['gammav', 'gammav', 74, [62]]
# ['gammav', 'pixel', 74, [62]]
# ['pixel', 'pixel', 20, [8, 25, 30]]
# ['pixel', 'chunk', 20, [8, 25, 30]]
# ['pixel', 'pixel', 25, [8, 20, 30]]
# ['pixel', 'chunk', 25, [8, 20, 30]]
# ['chunk', 'chunk', 18, [8, 36]]
# ['chunk', 'image', 18, [8, 36]]
# ['x', 'x', 42, [26, 51, 60]]
# ['x', 'chunk', 42, [26, 51, 60]]
# ['x', 'x', 51, [26, 42, 60]]
# ['x', 'u', 51, [26, 42, 60]]
# ['x', 'x', 60, [26, 42, 51]]
# ['x', 'image', 60, [26, 42, 51]]
# ['image', 'image', 10, [3]]
# ['image', 'x', 10, [3]]
# ['chunk', 'chunk', 36, [8, 18]]
# ['chunk', 'y', 36, [8, 18]]
# ['fingerprints', 'fingerprints', 27, [5, 104]]
# ['fingerprints', 'tests', 27, [5, 104]]
# ['tests', 'tests', 44, [3]]
# ['tests', 'results', 44, [3]]
# ['result', 'result', 96, [71, 83, 149]]
# ['result', 'image', 96, [71, 83, 149]]
# ['fingerprints', 'fingerprints', 104, [5, 27]]
# ['fingerprints', 'warn', 104, [5, 27]]
# ['results', 'results', 162, [12, 89, 115, 142]]
# ['results', 'image', 162, [12, 89, 115, 142]]
# ['fingerprintScores', 'fingerprintScores', 164, [17, 30, 152]]
# ['fingerprintScores', 'tests', 164, [17, 30, 152]]
# ['fingerprintScores', 'fingerprintScores', 30, [17, 152, 164]]
# ['fingerprintScores', 'fingerprints', 30, [17, 152, 164]]
# ['results', 'results', 89, [12, 115, 142, 162]]
# ['results', 'image', 89, [12, 115, 142, 162]]
# ['image', 'image', 77, [47, 62]]
# ['image', 'fingerprint', 77, [47, 62]]
# ['warn', 'warn', 121, [7]]
# ['warn', 'fingerprintScores', 121, [7]]
# ['fingerprint', 'fingerprint', 32, [25, 102, 113, 134, 140, 154]]
# ['fingerprint', 'tests', 32, [25, 102, 113, 134, 140, 154]]
# ['image', 'image', 62, [47, 77]]
# ['image', 'fingerprint', 62, [47, 77]]
# ['test', 'test', 73, [42, 53, 91, 109, 128, 144]]
# ['test', 'tests', 73, [42, 53, 91, 109, 128, 144]]
# ['test', 'test', 91, [42, 53, 73, 109, 128, 144]]
# ['test', 'results', 91, [42, 53, 73, 109, 128, 144]]
# ['result', 'result', 149, [71, 83, 96]]
# ['result', 'image', 149, [71, 83, 96]]
# ['test', 'test', 53, [42, 73, 91, 109, 128, 144]]
# ['test', 'image', 53, [42, 73, 91, 109, 128, 144]]
# ['test', 'test', 109, [42, 53, 73, 91, 128, 144]]
# ['test', 'result', 109, [42, 53, 73, 91, 128, 144]]
# ['fingerprint', 'fingerprint', 113, [25, 32, 102, 134, 140, 154]]
# ['fingerprint', 'warn', 113, [25, 32, 102, 134, 140, 154]]
# ['fingerprintScores', 'fingerprintScores', 152, [17, 30, 164]]
# ['fingerprintScores', 'test', 152, [17, 30, 164]]
# ['test', 'test', 128, [42, 53, 73, 91, 109, 144]]
# ['test', 'results', 128, [42, 53, 73, 91, 109, 144]]
# ['fingerprint', 'fingerprint', 134, [25, 32, 102, 113, 140, 154]]
# ['fingerprint', 'image', 134, [25, 32, 102, 113, 140, 154]]
# ['fingerprint', 'fingerprint', 140, [25, 32, 102, 113, 134, 154]]
# ['fingerprint', 'tests', 140, [25, 32, 102, 113, 134, 154]]
# ['test', 'test', 144, [42, 53, 73, 91, 109, 128]]
# ['test', 'fingerprint', 144, [42, 53, 73, 91, 109, 128]]
# ['fingerprint', 'fingerprint', 154, [25, 32, 102, 113, 134, 140]]
# ['fingerprint', 'fingerprints', 154, [25, 32, 102, 113, 134, 140]]
# ['tests', 'tests', 17, [3, 51]]
# ['tests', 'fingerprint', 17, [3, 51]]
# ['fingerprints', 'fingerprints', 39, [5]]
# ['fingerprints', 'row', 39, [5]]
# ['header', 'header', 32, [10, 20, 22]]
# ['header', 'row', 32, [10, 20, 22]]
# ['tests', 'tests', 51, [3, 17]]
# ['tests', 'row', 51, [3, 17]]
# ['fingerprint', 'fingerprint', 44, [37, 60, 78]]
# ['fingerprint', 'header', 44, [37, 60, 78]]
# ['row', 'row', 90, [42, 65, 72]]
# ['row', 'test', 90, [42, 65, 72]]
# ['header', 'header', 22, [10, 20, 32]]
# ['header', 'fingerprint', 22, [10, 20, 32]]
# ['test', 'test', 26, [15, 49, 56, 82]]
# ['test', 'row', 26, [15, 49, 56, 82]]
# ['test', 'test', 56, [15, 26, 49, 82]]
# ['test', 'header', 56, [15, 26, 49, 82]]
# ['fingerprint', 'fingerprint', 60, [37, 44, 78]]
# ['fingerprint', 'tests', 60, [37, 44, 78]]
# ['fingerprint', 'fingerprint', 78, [37, 44, 60]]
# ['fingerprint', 'tests', 78, [37, 44, 60]]
# ['test', 'test', 82, [15, 26, 49, 56]]
# ['test', 'tests', 82, [15, 26, 49, 56]]
# ['ordered', 'ordered', 34, [10]]
# ['ordered', 'nb', 34, [10]]
# ['nb', 'nb', 53, [5]]
# ['nb', 'scores', 53, [5]]
# ['scores', 'scores', 16, [3]]
# ['scores', 'result', 16, [3]]
# ['result', 'result', 43, [32, 48]]
# ['result', 'nb', 43, [32, 48]]
# ['result', 'result', 48, [32, 43]]
# ['result', 'scores', 48, [32, 43]]

# %%
for li1, li2 in zip(data_v0, data):
    tokens1, scope1, pairs1 = li1
    tokens2, scope2, pairs2 = li2
    for pair1, pair2 in zip(pairs1, pairs2):
        assert pair1[0] == pair2[0]
        #assert pair1[1] == pair2[1]

# %%
a, b = atok.tree.body[0].body[0].value.body.func.first_token.startpos,\
atok.tree.body[0].body[0].value.body.func.last_token.endpos
st1 = st[:a] + special_word + st[b:]
get_tokens(st1, special_word, st[a:b])
# Out:
# (['def',
#   'greet',
#   '(',
#   'a',
#   ')',
#   ':',
#   '# comment 4',
#   '\n',
#   '# comment 2',
#   '\n',
#   ' ',
#   'JKMCFHNBVCXSDJ',
#   '(',
#   '"hello"',
#   ')',
#   'if',
#   'a',
#   'else',
#   'say',
#   '(',
#   '"bye"',
#   ')',
#   '# comment 1',
#   '\n',
#   '# comment 3',
#   '\n',
#   '"""\n big_coment 1\n """',
#   '\n',
#   'return',
#   '1',
#   ''],
#  11,
#  [18])

# %%
set(lines_ast).intersection(set(cp.comments))
# Out:
# {99, 101, 119}

# %%
for lineno, line in enumerate(code.split("\n")):
    print(lineno, line)
# Out:
# 0 #!/usr/bin/python
# 1 #
# 2 # fingerping: A PNG library fingerprinting tool.
# 3 #
# 4 # @author:Dominique Bongard
# 5 #
# 6 #
# 7 # Code is licensed under -- Apache License 2.0 http://www.apache.org/licenses/
# 8 #
# 9
# 10 from collections import namedtuple
# 11 from operator import *
# 12 from struct import *
# 13 import os.path
# 14 import sys
# 15 import zlib
# 16 import binascii
# 17 import itertools
# 18 from xpng import *
# 19
# 20 # A named tuple representing a fingerprint test
# 21 # name = name of the test
# 22 # filename = filename of the png file to test
# 23 # function = function to call to execute the test
# 24 # description = description of the test
# 25 Test = namedtuple("test", "name filename function description")
# 26
# 27 # A named tuple representing the fingerprint of a PNG library
# 28 # name = name of the language / library / tool
# 29 # description = description of the library (e.g. version number)
# 30 # results = a dictionary of test fingerprint test results
# 31 Fingerprint = namedtuple("fingerprint","name description results")
# 32
# 33
# 34 ###############################################
# 35 #
# 36 # Fingerprinting functions
# 37 #
# 38 ###############################################
# 39
# 40
# 41 # The most simple fingerprinting function
# 42 #
# 43 # Returns 0 if the image is absent or empty (meaning the target failed to decode the input image)
# 44 # Returns 10 if the image looks valid at least in surface
# 45 # Returns between 1 and 9 if the image is corrupt
# 46 def conversionSuccess(image):
# 47   return image.valid
# 48
# 49 # All the following tests should return values > 10 (or any kind of object like a list actually)
# 50 ################################################################################################
# 51
# 52 # Fingerprint depending on the correctness of the checksums of the output image
# 53 def correctChecksums(image):
# 54   if image.verifyChecksums():
# 55     return 11
# 56   else:
# 57     return 12
# 58
# 59 # Fingerprint resulting from the set of filters used in the scanlines of the output image (returns a sorted list of the filters)
# 60 def filtersUsed(image):
# 61   return sorted(image.filtersUsed)
# 62
# 63 # Fingerprint depending on the palette used to decode images with two palettes (when not rejected)
# 64 def paletteUsed(image):
# 65   if image.hasColor([185,96,142]) :
# 66     return 11
# 67   elif image.hasColor([96,142,185]) :
# 68     return 12
# 69   else:
# 70     return 13
# 71
# 72 # Fingerprint depending on how the decoder treated the gamma information from the input image
# 73 def gamma(image):
# 74   pixel = image.getPixelRgb(120,140)
# 75   if pixel[0]+pixel[1] + pixel[2] < 96 :
# 76     return 11
# 77   else:
# 78     chunk = image.getChunk("gAMA")
# 79     if chunk == None:
# 80       return 12
# 81     gammav = unpack("!I",chunk.content)
# 82     if gammav[0] == 400000 :
# 83       return 13
# 84     return 14
# 85
# 86 # Fingerprint depending on the ihdr used to decode images with two ihdr (when not rejected)
# 87 def ihdrUsed(image):
# 88   if image.width == 252:
# 89     return 11
# 90   elif image.width == 189:
# 91     return 12
# 92   else :
# 93     return 13
# 94
# 95 # Fingerprint depending on the treatment of images with invalid scanline filters
# 96 def badIdatFilter(image):
# 97   pixel = image.getPixelRgb(5,0)
# 98   if pixel == [65,83,255] :
# 99     return 11 # Most libraries return the correct image
# 100   elif pixel == [57,82,255] :
# 101     return 12 # One library outputs a corrupted image
# 102   return 13
# 103
# 104 # Fingerprint depending on the zlib compression level flag of the output image
# 105 def zlibCompression(image):
# 106   return 11+ image.zlevel
# 107
# 108 # Fingerprint depending on how the decoder treated the phys information in the input image
# 109 def physChunk(image):
# 110   chunk = image.getChunk("pHYs")
# 111   if chunk == None:
# 112     return 11
# 113   x,y,u = unpack("!IIB",chunk.content)
# 114   if x == 1:
# 115     return 12
# 116   if x == 1500:
# 117     return 13
# 118   if x == 1499:
# 119     return 14 # .net
# 120   return 15
# 121
# 122 # Fingerprint depending on how the decoder treated an input image with a tRNS chunk
# 123 def truecolorTrns(image):
# 124   if image.colorType == 6 :
# 125     return 11
# 126   chunk = image.getChunk("tRNS")
# 127   if chunk == None:
# 128     return 12
# 129   return 13
# 130
# 131 ###############################################
# 132
# 133 # include all the tests and fingerprints from external files
# 134
# 135 exec(compile(open("tests.py", "rb").read(), "tests.py", 'exec'))
# 136 exec(compile(open("fingerprints.py", "rb").read(), "fingerprints.py", 'exec'))
# 137
# 138 ###############################################
# 139
# 140
# 141 # Test all the images in a directory (don't print warnings when generating fingerprints)
# 142 def doTests(tests,fingerprints, warn):
# 143   results  = {}
# 144   fingerprintScores = {}
# 145   # Initialite the count of matching tests to zero for each fingerprint
# 146   for fingerprint in fingerprints :
# 147     fingerprintScores[fingerprint.name] = 0
# 148   # Execute each test
# 149   for test in tests:
# 150     image = Png(directory + test.filename+".png")
# 151     if not image.valid == 0:
# 152             # Only execute the test if there is an image to test
# 153       result = test.function(image)
# 154     else :
# 155       result = 0
# 156     # Save the result of the test
# 157     results[test.name] = result
# 158
# 159     # Check if the result matches some of the fingeprints and if so, increment the match counter
# 160     for fingerprint in fingerprints :
# 161       if not test.name in fingerprint.results:
# 162             # warn if a fingerprint is missing the result for the test being run
# 163         if warn:
# 164           print("warning, missing key", test.name,"in", fingerprint.name)
# 165       elif fingerprint.results[test.name] == result :
# 166         fingerprintScores[fingerprint.name] += 1
# 167   return results,fingerprintScores
# 168
# 169 # Generate a csv table with all the test results for each fingerprint (which you can then import in LibreOffice or whatever)
# 170 def generateCsv(tests,fingerprints):
# 171   header = "/"
# 172   for test in tests:
# 173     header = header+ "\t"+test.name
# 174   print(header)
# 175
# 176   for fingerprint in fingerprints:
# 177     row = fingerprint.name
# 178     for test in tests:
# 179       if not test.name in fingerprint.results:
# 180         row += "\t\"\""
# 181       else:
# 182         row += "\t"+ str(fingerprint.results[test.name])
# 183     print(row)
# 184
# 185 # Show the fingerprinting result with the most likely library match at the bottom
# 186 def showResults(scores, nb):
# 187   ordered = sorted(iter(scores.items()), key=itemgetter(1))
# 188   for result in ordered :
# 189     print('{:20s} {:3d}/{:3d}'.format(result[0], result[1], nb))
# 190
# 191 # check if the command line has valid options
# 192 def checkCommandLine(line):
# 193   if len(line) == 3 :
# 194     if not line[1] == "-gen":
# 195       return False
# 196     else:
# 197       return True
# 198   if len(line) == 2:
# 199     if (line[1][0] == "-") and not (line[1] == "-csv"):
# 200       return False
# 201     return True
# 202   return False
# 203
# 204
# 205 ###############################################
# 206 #
# 207 # Main program
# 208 #
# 209 ###############################################
# 210
# 211
# 212 # use reflection to get all the tests and all the fingeprints in lists
# 213 locals =  locals().copy()
# 214 tests = sorted( [t for t in locals.values() if isinstance(t,Test)], key=attrgetter('name'))
# 215 fingerprints = [t for t in locals.values() if isinstance(t,Fingerprint)]
# 216
# 217 if not checkCommandLine(sys.argv):
# 218   print("usage:")
# 219   print("")
# 220   print("fingerping.py path        # Matches the images in the path folder with the fingerprint of known PNG libraries")
# 221   print("fingerping.py -gen path   # Generates a new library fingerprint from the images in the path folder")
# 222   print("fingerping.py -csv        # prints all the known fingerprints as a CSV table")
# 223   sys.exit(0)
# 224
# 225 # Generate a csv output with all the test results for each library fingerprint known to the tool
# 226 if sys.argv[1] == "-csv" :
# 227   generateCsv(tests,fingerprints)
# 228   sys.exit(0)
# 229
# 230 # last command line argument is the directory with all the images to use in a fingerprint test
# 231 directory = sys.argv[len(sys.argv)-1] + "/"
# 232
# 233 results, fingerprintScores = doTests(tests,fingerprints,sys.argv[1] != "-gen")
# 234
# 235 # If the -gen parameter is given on the command line, don't give the fingerprinting results
# 236 # but instead generate a new fingerprint
# 237 if sys.argv[1] == "-gen" :
# 238   print(results)
# 239 else:
# 240   showResults(fingerprintScores,len(tests))

# %%
line = code.split("\n")[220][2:]
for node in ast.walk(ast.parse(line)):
    print(node)
    if hasattr(node, "lineno"):
        print(node.lineno)
# Out:
# <_ast.Module object at 0x7f6071352860>
# <_ast.Expr object at 0x7f6071352978>
# 1
# <_ast.Call object at 0x7f6071352da0>
# 1
# <_ast.Name object at 0x7f6071352630>
# 1
# <_ast.Str object at 0x7f6071352898>
# 1
# <_ast.Load object at 0x7f60a60df160>

# %%
code.split("\n")[46]
# Out:
# 'def conversionSuccess(image):'

# %%
for fun in ast.iter_child_nodes(astree):
    if isinstance(fun, ast.FunctionDef):
        for node in ast.walk(fun):
            if hasattr(node, "comment"):
                print(node, node.comment)
# Out:
# <_ast.Num object at 0x7f60708b5668> Most libraries return the correct image
# <_ast.Num object at 0x7f60708b5ac8> One library outputs a corrupted image
# <_ast.Num object at 0x7f60708b9240> .net

# %%
node

# %%
node.lineno, node.col_offset
# Out:
# (200, 41)

# %%
data
# Out:
# [[['def',
#    'gamma',
#    '(',
#    'image',
#    ')',
#    ':',
#    '\n',
#    ' ',
#    'pixel',
#    '=',
#    'image',
#    '.',
#    'getPixelRgb',
#    '(',
#    '120',
#    ',',
#    '140',
#    ')',
#    '\n',
#    'if',
#    'pixel',
#    '[',
#    '0',
#    ']',
#    '+',
#    'pixel',
#    '[',
#    '1',
#    ']',
#    '+',
#    'pixel',
#    '[',
#    '2',
#    ']',
#    '<',
#    '96',
#    ':',
#    '\n',
#    'return',
#    '11',
#    '\n',
#    'else',
#    ':',
#    '\n',
#    'chunk',
#    '=',
#    'image',
#    '.',
#    'getChunk',
#    '(',
#    "'gAMA'",
#    ')',
#    '\n',
#    'if',
#    'chunk',
#    '==',
#    'None',
#    ':',
#    '\n',
#    'return',
#    '12',
#    '\n',
#    'gammav',
#    '=',
#    'unpack',
#    '(',
#    "'!I'",
#    ',',
#    'chunk',
#    '.',
#    'content',
#    ')',
#    '\n',
#    'if',
#    'gammav',
#    '[',
#    '0',
#    ']',
#    '==',
#    '400000',
#    ':',
#    '\n',
#    'return',
#    '13',
#    '\n',
#    'return',
#    '14',
#    ''],
#   {'chunk', 'gammav', 'image', 'pixel'},
#   [['image', 'image', 10, [3, 46]],
#    ['image', 'chunk', 10, [3, 46]],
#    ['chunk', 'chunk', 54, [44, 68]],
#    ['chunk', 'pixel', 54, [44, 68]],
#    ['pixel', 'pixel', 30, [8, 20, 25]],
#    ['pixel', 'image', 30, [8, 20, 25]],
#    ['image', 'image', 46, [3, 10]],
#    ['image', 'chunk', 46, [3, 10]],
#    ['chunk', 'chunk', 68, [44, 54]],
#    ['chunk', 'gammav', 68, [44, 54]],
#    ['gammav', 'gammav', 74, [62]],
#    ['gammav', 'pixel', 74, [62]],
#    ['pixel', 'pixel', 20, [8, 25, 30]],
#    ['pixel', 'gammav', 20, [8, 25, 30]],
#    ['pixel', 'pixel', 25, [8, 20, 30]],
#    ['pixel', 'image', 25, [8, 20, 30]]]],
#  [['def',
#    'physChunk',
#    '(',
#    'image',
#    ')',
#    ':',
#    '\n',
#    ' ',
#    'chunk',
#    '=',
#    'image',
#    '.',
#    'getChunk',
#    '(',
#    "'pHYs'",
#    ')',
#    '\n',
#    'if',
#    'chunk',
#    '==',
#    'None',
#    ':',
#    '\n',
#    'return',
#    '11',
#    '\n',
#    'x',
#    ',',
#    'y',
#    ',',
#    'u',
#    '=',
#    'unpack',
#    '(',
#    "'!IIB'",
#    ',',
#    'chunk',
#    '.',
#    'content',
#    ')',
#    '\n',
#    'if',
#    'x',
#    '==',
#    '1',
#    ':',
#    '\n',
#    'return',
#    '12',
#    '\n',
#    'if',
#    'x',
#    '==',
#    '1500',
#    ':',
#    '\n',
#    'return',
#    '13',
#    '\n',
#    'if',
#    'x',
#    '==',
#    '1499',
#    ':',
#    '\n',
#    'return',
#    '14',
#    '\n',
#    'return',
#    '15',
#    ''],
#   {'chunk', 'image', 'u', 'x', 'y'},
#   [['chunk', 'chunk', 18, [8, 36]],
#    ['chunk', 'u', 18, [8, 36]],
#    ['x', 'x', 42, [26, 51, 60]],
#    ['x', 'y', 42, [26, 51, 60]],
#    ['x', 'x', 51, [26, 42, 60]],
#    ['x', 'y', 51, [26, 42, 60]],
#    ['x', 'x', 60, [26, 42, 51]],
#    ['x', 'u', 60, [26, 42, 51]],
#    ['image', 'image', 10, [3]],
#    ['image', 'chunk', 10, [3]],
#    ['chunk', 'chunk', 36, [8, 18]],
#    ['chunk', 'y', 36, [8, 18]]]],
#  [['def',
#    'doTests',
#    '(',
#    'tests',
#    ',',
#    'fingerprints',
#    ',',
#    'warn',
#    ')',
#    ':',
#    '\n',
#    ' ',
#    'results',
#    '=',
#    '{',
#    '}',
#    '\n',
#    'fingerprintScores',
#    '=',
#    '{',
#    '}',
#    '\n',
#    'for',
#    'fingerprint',
#    'in',
#    'fingerprints',
#    ':',
#    '\n',
#    'fingerprintScores',
#    '[',
#    'fingerprint',
#    '.',
#    'name',
#    ']',
#    '=',
#    '0',
#    '\n',
#    'for',
#    'test',
#    'in',
#    'tests',
#    ':',
#    '\n',
#    'image',
#    '=',
#    'Png',
#    '(',
#    'directory',
#    '+',
#    'test',
#    '.',
#    'filename',
#    '+',
#    "'.png'",
#    ')',
#    '\n',
#    'if',
#    'not',
#    'image',
#    '.',
#    'valid',
#    '==',
#    '0',
#    ':',
#    '\n',
#    'result',
#    '=',
#    'test',
#    '.',
#    'function',
#    '(',
#    'image',
#    ')',
#    '\n',
#    'else',
#    ':',
#    '\n',
#    'result',
#    '=',
#    '0',
#    '\n',
#    'results',
#    '[',
#    'test',
#    '.',
#    'name',
#    ']',
#    '=',
#    'result',
#    '\n',
#    'for',
#    'fingerprint',
#    'in',
#    'fingerprints',
#    ':',
#    '\n',
#    'if',
#    'not',
#    'test',
#    '.',
#    'name',
#    'in',
#    'fingerprint',
#    '.',
#    'results',
#    ':',
#    '\n',
#    'if',
#    'warn',
#    ':',
#    '\n',
#    'print',
#    '(',
#    "'warning, missing key'",
#    ',',
#    'test',
#    '.',
#    'name',
#    ',',
#    "'in'",
#    ',',
#    '\n',
#    'fingerprint',
#    '.',
#    'name',
#    ')',
#    '\n',
#    'elif',
#    'fingerprint',
#    '.',
#    'results',
#    '[',
#    'test',
#    '.',
#    'name',
#    ']',
#    '==',
#    'result',
#    ':',
#    '\n',
#    'fingerprintScores',
#    '[',
#    'fingerprint',
#    '.',
#    'name',
#    ']',
#    '+=',
#    '1',
#    '\n',
#    'return',
#    'results',
#    ',',
#    'fingerprintScores',
#    ''],
#   {'fingerprint',
#    'fingerprintScores',
#    'fingerprints',
#    'image',
#    'result',
#    'results',
#    'test',
#    'tests',
#    'warn'},
#   [['fingerprints', 'fingerprints', 25, [5, 93]],
#    ['fingerprints', 'tests', 25, [5, 93]],
#    ['tests', 'tests', 40, [3]],
#    ['tests', 'test', 40, [3]],
#    ['result', 'result', 88, [65, 77, 137]],
#    ['result', 'image', 88, [65, 77, 137]],
#    ['fingerprints', 'fingerprints', 93, [5, 25]],
#    ['fingerprints', 'fingerprintScores', 93, [5, 25]],
#    ['results', 'results', 150, [12, 81, 104, 130]],
#    ['results', 'test', 150, [12, 81, 104, 130]],
#    ['fingerprintScores', 'fingerprintScores', 152, [17, 28, 140]],
#    ['fingerprintScores', 'tests', 152, [17, 28, 140]],
#    ['fingerprintScores', 'fingerprintScores', 28, [17, 140, 152]],
#    ['fingerprintScores', 'fingerprint', 28, [17, 140, 152]],
#    ['results', 'results', 81, [12, 104, 130, 150]],
#    ['results', 'test', 81, [12, 104, 130, 150]],
#    ['image', 'image', 71, [43, 58]],
#    ['image', 'fingerprints', 71, [43, 58]],
#    ['warn', 'warn', 108, [7]],
#    ['warn', 'fingerprints', 108, [7]],
#    ['fingerprint', 'fingerprint', 30, [23, 91, 102, 122, 128, 142]],
#    ['fingerprint', 'fingerprints', 30, [23, 91, 102, 122, 128, 142]],
#    ['image', 'image', 58, [43, 71]],
#    ['image', 'warn', 58, [43, 71]],
#    ['test', 'test', 67, [38, 49, 83, 98, 115, 132]],
#    ['test', 'result', 67, [38, 49, 83, 98, 115, 132]],
#    ['test', 'test', 83, [38, 49, 67, 98, 115, 132]],
#    ['test', 'warn', 83, [38, 49, 67, 98, 115, 132]],
#    ['result', 'result', 137, [65, 77, 88]],
#    ['result', 'fingerprintScores', 137, [65, 77, 88]],
#    ['test', 'test', 49, [38, 67, 83, 98, 115, 132]],
#    ['test', 'fingerprintScores', 49, [38, 67, 83, 98, 115, 132]],
#    ['test', 'test', 98, [38, 49, 67, 83, 115, 132]],
#    ['test', 'fingerprint', 98, [38, 49, 67, 83, 115, 132]],
#    ['fingerprint', 'fingerprint', 102, [23, 30, 91, 122, 128, 142]],
#    ['fingerprint', 'image', 102, [23, 30, 91, 122, 128, 142]],
#    ['fingerprintScores', 'fingerprintScores', 140, [17, 28, 152]],
#    ['fingerprintScores', 'result', 140, [17, 28, 152]],
#    ['test', 'test', 115, [38, 49, 67, 83, 98, 132]],
#    ['test', 'image', 115, [38, 49, 67, 83, 98, 132]],
#    ['fingerprint', 'fingerprint', 122, [23, 30, 91, 102, 128, 142]],
#    ['fingerprint', 'tests', 122, [23, 30, 91, 102, 128, 142]],
#    ['fingerprint', 'fingerprint', 128, [23, 30, 91, 102, 122, 142]],
#    ['fingerprint', 'results', 128, [23, 30, 91, 102, 122, 142]],
#    ['test', 'test', 132, [38, 49, 67, 83, 98, 115]],
#    ['test', 'results', 132, [38, 49, 67, 83, 98, 115]],
#    ['fingerprint', 'fingerprint', 142, [23, 30, 91, 102, 122, 128]],
#    ['fingerprint', 'test', 142, [23, 30, 91, 102, 122, 128]]]],
#  [['def',
#    'generateCsv',
#    '(',
#    'tests',
#    ',',
#    'fingerprints',
#    ')',
#    ':',
#    '\n',
#    ' ',
#    'header',
#    '=',
#    "'/'",
#    '\n',
#    'for',
#    'test',
#    'in',
#    'tests',
#    ':',
#    '\n',
#    'header',
#    '=',
#    'header',
#    '+',
#    "'\\t'",
#    '+',
#    'test',
#    '.',
#    'name',
#    '\n',
#    'print',
#    '(',
#    'header',
#    ')',
#    '\n',
#    'for',
#    'fingerprint',
#    'in',
#    'fingerprints',
#    ':',
#    '\n',
#    'row',
#    '=',
#    'fingerprint',
#    '.',
#    'name',
#    '\n',
#    'for',
#    'test',
#    'in',
#    'tests',
#    ':',
#    '\n',
#    'if',
#    'not',
#    'test',
#    '.',
#    'name',
#    'in',
#    'fingerprint',
#    '.',
#    'results',
#    ':',
#    '\n',
#    'row',
#    '+=',
#    '\'\\t""\'',
#    '\n',
#    'else',
#    ':',
#    '\n',
#    'row',
#    '+=',
#    "'\\t'",
#    '+',
#    'str',
#    '(',
#    'fingerprint',
#    '.',
#    'results',
#    '[',
#    'test',
#    '.',
#    'name',
#    ']',
#    ')',
#    '\n',
#    'print',
#    '(',
#    'row',
#    ')',
#    ''],
#   {'fingerprint', 'fingerprints', 'header', 'row', 'test', 'tests'},
#   [['tests', 'tests', 17, [3, 50]],
#    ['tests', 'row', 17, [3, 50]],
#    ['fingerprints', 'fingerprints', 38, [5]],
#    ['fingerprints', 'tests', 38, [5]],
#    ['header', 'header', 32, [10, 20, 22]],
#    ['header', 'row', 32, [10, 20, 22]],
#    ['tests', 'tests', 50, [3, 17]],
#    ['tests', 'fingerprint', 50, [3, 17]],
#    ['fingerprint', 'fingerprint', 43, [36, 59, 77]],
#    ['fingerprint', 'test', 43, [36, 59, 77]],
#    ['row', 'row', 89, [41, 64, 71]],
#    ['row', 'fingerprints', 89, [41, 64, 71]],
#    ['header', 'header', 22, [10, 20, 32]],
#    ['header', 'row', 22, [10, 20, 32]],
#    ['test', 'test', 26, [15, 48, 55, 81]],
#    ['test', 'header', 26, [15, 48, 55, 81]],
#    ['test', 'test', 55, [15, 26, 48, 81]],
#    ['test', 'tests', 55, [15, 26, 48, 81]],
#    ['fingerprint', 'fingerprint', 59, [36, 43, 77]],
#    ['fingerprint', 'row', 59, [36, 43, 77]],
#    ['fingerprint', 'fingerprint', 77, [36, 43, 59]],
#    ['fingerprint', 'header', 77, [36, 43, 59]],
#    ['test', 'test', 81, [15, 26, 48, 55]],
#    ['test', 'header', 81, [15, 26, 48, 55]]]],
#  [['def',
#    'showResults',
#    '(',
#    'scores',
#    ',',
#    'nb',
#    ')',
#    ':',
#    '\n',
#    ' ',
#    'ordered',
#    '=',
#    'sorted',
#    '(',
#    'iter',
#    '(',
#    'scores',
#    '.',
#    'items',
#    '(',
#    ')',
#    ')',
#    ',',
#    'key',
#    '=',
#    'itemgetter',
#    '(',
#    '1',
#    ')',
#    ')',
#    '\n',
#    'for',
#    'result',
#    'in',
#    'ordered',
#    ':',
#    '\n',
#    'print',
#    '(',
#    "'{:20s} {:3d}/{:3d}'",
#    '.',
#    'format',
#    '(',
#    'result',
#    '[',
#    '0',
#    ']',
#    ',',
#    'result',
#    '[',
#    '1',
#    ']',
#    ',',
#    'nb',
#    ')',
#    ')',
#    ''],
#   {'nb', 'ordered', 'result', 'scores'},
#   [['ordered', 'ordered', 34, [10]],
#    ['ordered', 'nb', 34, [10]],
#    ['nb', 'nb', 53, [5]],
#    ['nb', 'result', 53, [5]],
#    ['scores', 'scores', 16, [3]],
#    ['scores', 'ordered', 16, [3]],
#    ['result', 'result', 43, [32, 48]],
#    ['result', 'scores', 43, [32, 48]],
#    ['result', 'result', 48, [32, 43]],
#    ['result', 'ordered', 48, [32, 43]]]]]

# %%
for tokens, scope, pairs in data:
    assert len(pairs)> 1
    for pair in pairs:
        iden1, iden2, loc_idx, rep_idxs = pair
        assert len(scope) >= 3
        assert iden1 in scope
        assert iden2 in scope
        assert tokens[loc_idx] == iden1
        for rep_idx in rep_idxs:
            assert tokens[rep_idx] == iden1
        assert len(rep_idxs) >= 1

# %%
# Сделать проверки
# Что еще нужно запоминать? комментарии, типы переменных? вроде я решила, что типы переменных не нужны

# %%
from horast import parse, unparse
import typed_ast

special_word = "JKMCFHNBVCXSDJ"
data = []

tree = parse(read_file_to_string(filenm))

for fun in typed_ast.ast3.iter_child_nodes(tree):
    if isinstance(fun, typed_ast.ast3.FunctionDef):
        scope = [arg.arg for arg in fun.args.args]
        for node in typed_ast.ast3.walk(fun):
            print(node, isinstance(node, typed_ast.ast3.Name), \
                  isinstance(node.ctx, typed_ast.ast3.Store) if isinstance(node, typed_ast.ast3.Name) else "")
            if isinstance(node, typed_ast.ast3.Name) and isinstance(node.ctx, typed_ast.ast3.Store):
                scope.append(node.id)
        scope = set(scope)
        #print(fun.name, scope)
        #walk_ = 0
        first = True
        if len(scope) >= 3:
            for node in ast.walk(fun):
                if isinstance(node, typed_ast.ast3.Name) and isinstance(node.ctx, typed_ast.ast3.Load)\
                and node.id in scope:
                    #if len(scope) >= 3 or (len(scope) >= 2 and not node.id in scope):
                        id_ = node.id
                        node.id = special_word
                        tokens, idx, remember_idxs = get_tokens(unparse(fun), special_word, id_)
                        assert tokens[idx] == special_word
                        assert np.all([tokens[remem_idx]==id_ for remem_idx in remember_idxs])
                        print(tokens, idx, remember_idxs)
                        node.id = id_
                        #if len(remember_idxs) >= 1:
                        if first:
                            tokens[idx] = id_
                            data.append([tokens, scope, []])
                            first = False
                        data[-1][2].append([id_, id_, idx, remember_idxs]) # correct, correct
                        buggy_id = list(scope.difference({id_}))\
                                   [np.random.randint(low=0, high=len(scope)-1)]
                        data[-1][2].append([id_, buggy_id, idx, remember_idxs]) # correct, buggy
        if not first and len(data[-1][2]) == 2:
            del data[-1]
                            
                        #walk_ += 1
# Out:
# <typed_ast._ast3.FunctionDef object at 0x7f6070846080> False
# <typed_ast._ast3.arguments object at 0x7f60708467f0> False
# <typed_ast._ast3.Return object at 0x7f6070fdb4e0> False
# <typed_ast._ast3.arg object at 0x7f6070846668> False
# <typed_ast._ast3.Attribute object at 0x7f6071979cf8> False
# <typed_ast._ast3.Name object at 0x7f60a4f330b8> True False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.FunctionDef object at 0x7f607180dcc0> False
# <typed_ast._ast3.arguments object at 0x7f607159e668> False
# <typed_ast._ast3.If object at 0x7f6070846a90> False
# <typed_ast._ast3.arg object at 0x7f6074981278> False
# <typed_ast._ast3.Call object at 0x7f6070846208> False
# <typed_ast._ast3.Return object at 0x7f6070846780> False
# <typed_ast._ast3.Return object at 0x7f6070846320> False
# <typed_ast._ast3.Attribute object at 0x7f6070846ac8> False
# <typed_ast._ast3.Num object at 0x7f6070846160> False
# <typed_ast._ast3.Num object at 0x7f6070846978> False
# <typed_ast._ast3.Name object at 0x7f60708466a0> True False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.FunctionDef object at 0x7f6070846438> False
# <typed_ast._ast3.arguments object at 0x7f6070846748> False
# <typed_ast._ast3.Return object at 0x7f6070846898> False
# <typed_ast._ast3.arg object at 0x7f6070846518> False
# <typed_ast._ast3.Call object at 0x7f60708463c8> False
# <typed_ast._ast3.Name object at 0x7f6070846dd8> True False
# <typed_ast._ast3.Attribute object at 0x7f60708467b8> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Name object at 0x7f6070846ef0> True False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.FunctionDef object at 0x7f60708465c0> False
# <typed_ast._ast3.arguments object at 0x7f6070846e80> False
# <typed_ast._ast3.If object at 0x7f6070846b70> False
# <typed_ast._ast3.arg object at 0x7f6070846a20> False
# <typed_ast._ast3.Call object at 0x7f6070846198> False
# <typed_ast._ast3.Return object at 0x7f60708468d0> False
# <typed_ast._ast3.If object at 0x7f6070846eb8> False
# <typed_ast._ast3.Attribute object at 0x7f6070846da0> False
# <typed_ast._ast3.List object at 0x7f6070846278> False
# <typed_ast._ast3.Num object at 0x7f6070846940> False
# <typed_ast._ast3.Call object at 0x7f60708460f0> False
# <typed_ast._ast3.Return object at 0x7f6070846e10> False
# <typed_ast._ast3.Return object at 0x7f6070846cf8> False
# <typed_ast._ast3.Name object at 0x7f6070846f60> True False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Num object at 0x7f60708464a8> False
# <typed_ast._ast3.Num object at 0x7f6070846b00> False
# <typed_ast._ast3.Num object at 0x7f6070846630> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Attribute object at 0x7f6070846f98> False
# <typed_ast._ast3.List object at 0x7f60708466d8> False
# <typed_ast._ast3.Num object at 0x7f6070846f28> False
# <typed_ast._ast3.Num object at 0x7f6070846d68> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Name object at 0x7f6070846d30> True False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Num object at 0x7f6070846550> False
# <typed_ast._ast3.Num object at 0x7f6070846860> False
# <typed_ast._ast3.Num object at 0x7f60708464e0> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.FunctionDef object at 0x7f6070846240> False
# <typed_ast._ast3.arguments object at 0x7f6070846908> False
# <typed_ast._ast3.Assign object at 0x7f6070846128> False
# <typed_ast._ast3.If object at 0x7f6070846fd0> False
# <typed_ast._ast3.arg object at 0x7f6070846e48> False
# <typed_ast._ast3.Name object at 0x7f6070846b38> True True
# <typed_ast._ast3.Call object at 0x7f6070846c18> False
# <typed_ast._ast3.Compare object at 0x7f60708460b8> False
# <typed_ast._ast3.Return object at 0x7f6071c07be0> False
# <typed_ast._ast3.Assign object at 0x7f607089af98> False
# <typed_ast._ast3.If object at 0x7f607089a358> False
# <typed_ast._ast3.Assign object at 0x7f607089a2e8> False
# <typed_ast._ast3.If object at 0x7f607089a390> False
# <typed_ast._ast3.Return object at 0x7f607089a518> False
# <typed_ast._ast3.Store object at 0x7f6072aaf0f0> False
# <typed_ast._ast3.Attribute object at 0x7f6070846710> False
# <typed_ast._ast3.Num object at 0x7f6070846ba8> False
# <typed_ast._ast3.Num object at 0x7f6070846c88> False
# <typed_ast._ast3.BinOp object at 0x7f6070846588> False
# <typed_ast._ast3.Lt object at 0x7f6072aaa668> False
# <typed_ast._ast3.Num object at 0x7f6071c077b8> False
# <typed_ast._ast3.Num object at 0x7f6071c07358> False
# <typed_ast._ast3.Name object at 0x7f607089ad30> True True
# <typed_ast._ast3.Call object at 0x7f607089a438> False
# <typed_ast._ast3.Compare object at 0x7f607089a198> False
# <typed_ast._ast3.Return object at 0x7f607089a550> False
# <typed_ast._ast3.Name object at 0x7f607089a400> True True
# <typed_ast._ast3.Call object at 0x7f607089aa58> False
# <typed_ast._ast3.Compare object at 0x7f607089a160> False
# <typed_ast._ast3.Return object at 0x7f607089a208> False
# <typed_ast._ast3.Num object at 0x7f607089a940> False
# <typed_ast._ast3.Name object at 0x7f6070846400> True False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.BinOp object at 0x7f6070846048> False
# <typed_ast._ast3.Add object at 0x7f6072aaf908> False
# <typed_ast._ast3.Subscript object at 0x7f6071c07da0> False
# <typed_ast._ast3.Store object at 0x7f6072aaf0f0> False
# <typed_ast._ast3.Attribute object at 0x7f607089ab00> False
# <typed_ast._ast3.Str object at 0x7f607089ae10> False
# <typed_ast._ast3.Name object at 0x7f607089a668> True False
# <typed_ast._ast3.Eq object at 0x7f6072aaa518> False
# <typed_ast._ast3.NameConstant object at 0x7f607089a048> False
# <typed_ast._ast3.Num object at 0x7f607089a588> False
# <typed_ast._ast3.Store object at 0x7f6072aaf0f0> False
# <typed_ast._ast3.Name object at 0x7f607089a2b0> True False
# <typed_ast._ast3.Str object at 0x7f607089a898> False
# <typed_ast._ast3.Attribute object at 0x7f607089a908> False
# <typed_ast._ast3.Subscript object at 0x7f607089a5c0> False
# <typed_ast._ast3.Eq object at 0x7f6072aaa518> False
# <typed_ast._ast3.Num object at 0x7f607089a470> False
# <typed_ast._ast3.Num object at 0x7f607089a0b8> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Subscript object at 0x7f60708465f8> False
# <typed_ast._ast3.Add object at 0x7f6072aaf908> False
# <typed_ast._ast3.Subscript object at 0x7f6070846390> False
# <typed_ast._ast3.Name object at 0x7f6071c07400> True False
# <typed_ast._ast3.Index object at 0x7f6071c07e80> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Name object at 0x7f607089acc0> True False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Name object at 0x7f607089a1d0> True False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Name object at 0x7f607089a0f0> True False
# <typed_ast._ast3.Index object at 0x7f607089a240> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Name object at 0x7f6070846828> True False
# <typed_ast._ast3.Index object at 0x7f60708461d0> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Name object at 0x7f60711e9fd0> True False
# <typed_ast._ast3.Index object at 0x7f60711e9780> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Num object at 0x7f6071c07b00> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Num object at 0x7f607089a748> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Num object at 0x7f60708462b0> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Num object at 0x7f60711e9860> False
# <typed_ast._ast3.FunctionDef object at 0x7f607089ada0> False
# <typed_ast._ast3.arguments object at 0x7f607089a3c8> False
# <typed_ast._ast3.If object at 0x7f607089a320> False
# <typed_ast._ast3.arg object at 0x7f607089a4a8> False
# <typed_ast._ast3.Compare object at 0x7f607089a128> False
# <typed_ast._ast3.Return object at 0x7f607089aa20> False
# <typed_ast._ast3.If object at 0x7f60718cd9b0> False
# <typed_ast._ast3.Attribute object at 0x7f607089aa90> False
# <typed_ast._ast3.Eq object at 0x7f6072aaa518> False
# <typed_ast._ast3.Num object at 0x7f607089a8d0> False
# <typed_ast._ast3.Num object at 0x7f60718cd550> False
# <typed_ast._ast3.Compare object at 0x7f60718cd2e8> False
# <typed_ast._ast3.Return object at 0x7f60718cda58> False
# <typed_ast._ast3.Return object at 0x7f60718cdd30> False
# <typed_ast._ast3.Name object at 0x7f607089af60> True False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Attribute object at 0x7f60718cd390> False
# <typed_ast._ast3.Eq object at 0x7f6072aaa518> False
# <typed_ast._ast3.Num object at 0x7f60718cd940> False
# <typed_ast._ast3.Num object at 0x7f60718cd828> False
# <typed_ast._ast3.Num object at 0x7f60718cd710> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Name object at 0x7f60718cd978> True False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.FunctionDef object at 0x7f60718cdef0> False
# <typed_ast._ast3.arguments object at 0x7f60718cd9e8> False
# <typed_ast._ast3.Assign object at 0x7f60718cd3c8> False
# <typed_ast._ast3.If object at 0x7f60718cdfd0> False
# <horast.nodes.Comment object at 0x7f6071e1edd8> False
# <typed_ast._ast3.Return object at 0x7f6070867160> False
# <typed_ast._ast3.arg object at 0x7f60718cdeb8> False
# <typed_ast._ast3.Name object at 0x7f60718cd048> True True
# <typed_ast._ast3.Call object at 0x7f60718cd898> False
# <typed_ast._ast3.Compare object at 0x7f60718cd358> False
# <typed_ast._ast3.Return object at 0x7f607188d4a8> False
# <horast.nodes.Comment object at 0x7f60711f8710> False
# <typed_ast._ast3.If object at 0x7f60717261d0> False
# <typed_ast._ast3.Num object at 0x7f6070867748> False
# <typed_ast._ast3.Store object at 0x7f6072aaf0f0> False
# <typed_ast._ast3.Attribute object at 0x7f60718cdf28> False
# <typed_ast._ast3.Num object at 0x7f60718cd1d0> False
# <typed_ast._ast3.Num object at 0x7f60718cd860> False
# <typed_ast._ast3.Name object at 0x7f60718cdac8> True False
# <typed_ast._ast3.Eq object at 0x7f6072aaa518> False
# <typed_ast._ast3.List object at 0x7f60718cd198> False
# <typed_ast._ast3.Num object at 0x7f607188d0f0> False
# <typed_ast._ast3.Compare object at 0x7f60717266a0> False
# <typed_ast._ast3.Return object at 0x7f60708676a0> False
# <typed_ast._ast3.Name object at 0x7f60718cd0b8> True False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Num object at 0x7f60718cd6a0> False
# <typed_ast._ast3.Num object at 0x7f6070f53b00> False
# <typed_ast._ast3.Num object at 0x7f607188d978> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Name object at 0x7f6070867eb8> True False
# <typed_ast._ast3.Eq object at 0x7f6072aaa518> False
# <typed_ast._ast3.List object at 0x7f6070867400> False
# <typed_ast._ast3.Num object at 0x7f6070867860> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Num object at 0x7f6070867c18> False
# <typed_ast._ast3.Num object at 0x7f60708673c8> False
# <typed_ast._ast3.Num object at 0x7f60708677f0> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.FunctionDef object at 0x7f60708675c0> False
# <typed_ast._ast3.arguments object at 0x7f6070867d30> False
# <typed_ast._ast3.Return object at 0x7f60709ecc50> False
# <typed_ast._ast3.arg object at 0x7f60709ec5c0> False
# <typed_ast._ast3.BinOp object at 0x7f60709ec358> False
# <typed_ast._ast3.Num object at 0x7f60709ec828> False
# <typed_ast._ast3.Add object at 0x7f6072aaf908> False
# <typed_ast._ast3.Attribute object at 0x7f60709ec8d0> False
# <typed_ast._ast3.Name object at 0x7f60709ec748> True False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.FunctionDef object at 0x7f60709ecf28> False
# <typed_ast._ast3.arguments object at 0x7f60709ecac8> False
# <typed_ast._ast3.Assign object at 0x7f60709ec5f8> False
# <typed_ast._ast3.If object at 0x7f60709ecfd0> False
# <typed_ast._ast3.Assign object at 0x7f60709eca90> False
# <typed_ast._ast3.If object at 0x7f60709ec198> False
# <typed_ast._ast3.If object at 0x7f60709eceb8> False
# <typed_ast._ast3.If object at 0x7f60709ec4a8> False
# <horast.nodes.Comment object at 0x7f6071349a20> False
# <typed_ast._ast3.Return object at 0x7f60709ec438> False
# <typed_ast._ast3.arg object at 0x7f60709ecd30> False
# <typed_ast._ast3.Name object at 0x7f60709eccf8> True True
# <typed_ast._ast3.Call object at 0x7f60709ec2b0> False
# <typed_ast._ast3.Compare object at 0x7f60709ec7b8> False
# <typed_ast._ast3.Return object at 0x7f60709ecc88> False
# <typed_ast._ast3.Tuple object at 0x7f60709ec400> False
# <typed_ast._ast3.Call object at 0x7f60709ec630> False
# <typed_ast._ast3.Compare object at 0x7f60709ec208> False
# <typed_ast._ast3.Return object at 0x7f60709ec860> False
# <typed_ast._ast3.Compare object at 0x7f60709ec898> False
# <typed_ast._ast3.Return object at 0x7f60709ec710> False
# <typed_ast._ast3.Compare object at 0x7f60709ec128> False
# <typed_ast._ast3.Return object at 0x7f60709ec0b8> False
# <typed_ast._ast3.Num object at 0x7f60709ecc18> False
# <typed_ast._ast3.Store object at 0x7f6072aaf0f0> False
# <typed_ast._ast3.Attribute object at 0x7f60709ecbe0> False
# <typed_ast._ast3.Str object at 0x7f60709ec1d0> False
# <typed_ast._ast3.Name object at 0x7f60709ec908> True False
# <typed_ast._ast3.Eq object at 0x7f6072aaa518> False
# <typed_ast._ast3.NameConstant object at 0x7f60709ec940> False
# <typed_ast._ast3.Num object at 0x7f60709ec048> False
# <typed_ast._ast3.Name object at 0x7f60709ecdd8> True True
# <typed_ast._ast3.Name object at 0x7f60709ecf98> True True
# <typed_ast._ast3.Name object at 0x7f60709ec160> True True
# <typed_ast._ast3.Store object at 0x7f6072aaf0f0> False
# <typed_ast._ast3.Name object at 0x7f60709ec780> True False
# <typed_ast._ast3.Str object at 0x7f60709ece48> False
# <typed_ast._ast3.Attribute object at 0x7f60709ecb38> False
# <typed_ast._ast3.Name object at 0x7f60709ecda0> True False
# <typed_ast._ast3.Eq object at 0x7f6072aaa518> False
# <typed_ast._ast3.Num object at 0x7f60709ec6d8> False
# <typed_ast._ast3.Num object at 0x7f60709ecba8> False
# <typed_ast._ast3.Name object at 0x7f60709eccc0> True False
# <typed_ast._ast3.Eq object at 0x7f6072aaa518> False
# <typed_ast._ast3.Num object at 0x7f60709ec518> False
# <typed_ast._ast3.Num object at 0x7f60709ec2e8> False
# <typed_ast._ast3.Name object at 0x7f60709ecf60> True False
# <typed_ast._ast3.Eq object at 0x7f6072aaa518> False
# <typed_ast._ast3.Num object at 0x7f60709ecd68> False
# <typed_ast._ast3.Num object at 0x7f60709ec470> False
# <typed_ast._ast3.Name object at 0x7f60709ec4e0> True False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Store object at 0x7f6072aaf0f0> False
# <typed_ast._ast3.Store object at 0x7f6072aaf0f0> False
# <typed_ast._ast3.Store object at 0x7f6072aaf0f0> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Name object at 0x7f60709ec978> True False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.FunctionDef object at 0x7f60709ec6a0> False
# <typed_ast._ast3.arguments object at 0x7f60709ec7f0> False
# <typed_ast._ast3.If object at 0x7f60709ec390> False
# <typed_ast._ast3.Assign object at 0x7f60709ecb70> False
# <typed_ast._ast3.If object at 0x7f60709ec3c8> False
# <typed_ast._ast3.Return object at 0x7f607132f8d0> False
# <typed_ast._ast3.arg object at 0x7f60709ec240> False
# <typed_ast._ast3.Compare object at 0x7f60709ec668> False
# <typed_ast._ast3.Return object at 0x7f60709ec9b0> False
# <typed_ast._ast3.Name object at 0x7f60709ece80> True True
# <typed_ast._ast3.Call object at 0x7f60709ec320> False
# <typed_ast._ast3.Compare object at 0x7f607132fb00> False
# <typed_ast._ast3.Return object at 0x7f607132fe48> False
# <typed_ast._ast3.Num object at 0x7f607132f668> False
# <typed_ast._ast3.Attribute object at 0x7f60709eca20> False
# <typed_ast._ast3.Eq object at 0x7f6072aaa518> False
# <typed_ast._ast3.Num object at 0x7f60709ec080> False
# <typed_ast._ast3.Num object at 0x7f60709ec278> False
# <typed_ast._ast3.Store object at 0x7f6072aaf0f0> False
# <typed_ast._ast3.Attribute object at 0x7f60709ec588> False
# <typed_ast._ast3.Str object at 0x7f60709ecef0> False
# <typed_ast._ast3.Name object at 0x7f607132f6a0> True False
# <typed_ast._ast3.Eq object at 0x7f6072aaa518> False
# <typed_ast._ast3.NameConstant object at 0x7f607132fcf8> False
# <typed_ast._ast3.Num object at 0x7f607132f438> False
# <typed_ast._ast3.Name object at 0x7f60709ecb00> True False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Name object at 0x7f60709ec550> True False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.FunctionDef object at 0x7f607132fc50> False
# <typed_ast._ast3.arguments object at 0x7f607132f320> False
# <typed_ast._ast3.Assign object at 0x7f607132f390> False
# <typed_ast._ast3.Assign object at 0x7f607132fc18> False
# <horast.nodes.Comment object at 0x7f6071b034a8> False
# <typed_ast._ast3.For object at 0x7f607132fa20> False
# <horast.nodes.Comment object at 0x7f6071b03be0> False
# <typed_ast._ast3.For object at 0x7f607132f2e8> False
# <typed_ast._ast3.Return object at 0x7f6070856978> False
# <typed_ast._ast3.arg object at 0x7f607132f978> False
# <typed_ast._ast3.arg object at 0x7f607132fda0> False
# <typed_ast._ast3.arg object at 0x7f607132f400> False
# <typed_ast._ast3.Name object at 0x7f607132f940> True True
# <typed_ast._ast3.Dict object at 0x7f607132f0b8> False
# <typed_ast._ast3.Name object at 0x7f607132fef0> True True
# <typed_ast._ast3.Dict object at 0x7f607132fa58> False
# <typed_ast._ast3.Name object at 0x7f607132fbe0> True True
# <typed_ast._ast3.Name object at 0x7f607132f278> True False
# <typed_ast._ast3.Assign object at 0x7f607132f898> False
# <typed_ast._ast3.Name object at 0x7f607132ff98> True True
# <typed_ast._ast3.Name object at 0x7f607132fdd8> True False
# <typed_ast._ast3.Assign object at 0x7f607132f7b8> False
# <typed_ast._ast3.If object at 0x7f607132f5c0> False
# <horast.nodes.Comment object at 0x7f60715f3f98> False
# <typed_ast._ast3.Assign object at 0x7f6070856f28> False
# <horast.nodes.Comment object at 0x7f60711f8ef0> False
# <typed_ast._ast3.For object at 0x7f60708568d0> False
# <typed_ast._ast3.Tuple object at 0x7f60708562b0> False
# <typed_ast._ast3.Store object at 0x7f6072aaf0f0> False
# <typed_ast._ast3.Store object at 0x7f6072aaf0f0> False
# <typed_ast._ast3.Store object at 0x7f6072aaf0f0> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Subscript object at 0x7f607132fe80> False
# <typed_ast._ast3.Num object at 0x7f607132f710> False
# <typed_ast._ast3.Store object at 0x7f6072aaf0f0> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Name object at 0x7f607132f748> True True
# <typed_ast._ast3.Call object at 0x7f607132f3c8> False
# <typed_ast._ast3.UnaryOp object at 0x7f607132f588> False
# <horast.nodes.Comment object at 0x7f60719d36d8> False
# <typed_ast._ast3.Assign object at 0x7f60715749e8> False
# <typed_ast._ast3.Assign object at 0x7f6070856048> False
# <typed_ast._ast3.Subscript object at 0x7f6070856fd0> False
# <typed_ast._ast3.Name object at 0x7f6070856198> True False
# <typed_ast._ast3.Name object at 0x7f6070856f98> True True
# <typed_ast._ast3.Name object at 0x7f6070856e10> True False
# <typed_ast._ast3.If object at 0x7f6070856080> False
# <typed_ast._ast3.Name object at 0x7f6070856d30> True False
# <typed_ast._ast3.Name object at 0x7f6070856be0> True False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Name object at 0x7f607132f9b0> True False
# <typed_ast._ast3.Index object at 0x7f607132f7f0> False
# <typed_ast._ast3.Store object at 0x7f6072aaf0f0> False
# <typed_ast._ast3.Store object at 0x7f6072aaf0f0> False
# <typed_ast._ast3.Name object at 0x7f607132f048> True False
# <typed_ast._ast3.BinOp object at 0x7f607132f828> False
# <typed_ast._ast3.Not object at 0x7f6072aaa2b0> False
# <typed_ast._ast3.Compare object at 0x7f60715745c0> False
# <typed_ast._ast3.Name object at 0x7f6070856c88> True True
# <typed_ast._ast3.Call object at 0x7f60708567b8> False
# <typed_ast._ast3.Name object at 0x7f6070856ef0> True True
# <typed_ast._ast3.Num object at 0x7f6070856e80> False
# <typed_ast._ast3.Name object at 0x7f6070856278> True False
# <typed_ast._ast3.Index object at 0x7f6070856240> False
# <typed_ast._ast3.Store object at 0x7f6072aaf0f0> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Store object at 0x7f6072aaf0f0> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.UnaryOp object at 0x7f6070856da0> False
# <horast.nodes.Comment object at 0x7f6071454c18> False
# <typed_ast._ast3.If object at 0x7f60708569b0> False
# <typed_ast._ast3.If object at 0x7f60708562e8> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Attribute object at 0x7f607132fba8> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.BinOp object at 0x7f607132f0f0> False
# <typed_ast._ast3.Add object at 0x7f6072aaf908> False
# <typed_ast._ast3.Str object at 0x7f607132fac8> False
# <typed_ast._ast3.Attribute object at 0x7f60715746a0> False
# <typed_ast._ast3.Eq object at 0x7f6072aaa518> False
# <typed_ast._ast3.Num object at 0x7f6071574f98> False
# <typed_ast._ast3.Store object at 0x7f6072aaf0f0> False
# <typed_ast._ast3.Attribute object at 0x7f6070856470> False
# <typed_ast._ast3.Name object at 0x7f6070856940> True False
# <typed_ast._ast3.Store object at 0x7f6072aaf0f0> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Attribute object at 0x7f60708560b8> False
# <typed_ast._ast3.Not object at 0x7f6072aaa2b0> False
# <typed_ast._ast3.Compare object at 0x7f6070856710> False
# <typed_ast._ast3.Name object at 0x7f6070856eb8> True False
# <typed_ast._ast3.Expr object at 0x7f6070856828> False
# <typed_ast._ast3.Compare object at 0x7f60708563c8> False
# <typed_ast._ast3.AugAssign object at 0x7f6070856f60> False
# <typed_ast._ast3.Name object at 0x7f607132f358> True False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Name object at 0x7f607132f240> True False
# <typed_ast._ast3.Add object at 0x7f6072aaf908> False
# <typed_ast._ast3.Attribute object at 0x7f607132fc88> False
# <typed_ast._ast3.Name object at 0x7f60715742e8> True False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Name object at 0x7f6070856b00> True False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Name object at 0x7f6070856128> True False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Attribute object at 0x7f6070856438> False
# <typed_ast._ast3.In object at 0x7f6072aaaa58> False
# <typed_ast._ast3.Attribute object at 0x7f60708560f0> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Call object at 0x7f6070856860> False
# <typed_ast._ast3.Subscript object at 0x7f6070856748> False
# <typed_ast._ast3.Eq object at 0x7f6072aaa518> False
# <typed_ast._ast3.Name object at 0x7f6070856dd8> True False
# <typed_ast._ast3.Subscript object at 0x7f6070856c50> False
# <typed_ast._ast3.Add object at 0x7f6072aaf908> False
# <typed_ast._ast3.Num object at 0x7f6070856160> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Name object at 0x7f607132f780> True False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Name object at 0x7f6070856a20> True False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Name object at 0x7f6070856ba8> True False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Name object at 0x7f6070856b38> True False
# <typed_ast._ast3.Str object at 0x7f60708566a0> False
# <typed_ast._ast3.Attribute object at 0x7f6070856b70> False
# <typed_ast._ast3.Str object at 0x7f60708569e8> False
# <typed_ast._ast3.Attribute object at 0x7f6070856668> False
# <typed_ast._ast3.Attribute object at 0x7f60708564e0> False
# <typed_ast._ast3.Index object at 0x7f6070856390> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Name object at 0x7f6070856400> True False
# <typed_ast._ast3.Index object at 0x7f6070856cc0> False
# <typed_ast._ast3.Store object at 0x7f6072aaf0f0> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Name object at 0x7f6070856e48> True False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Name object at 0x7f6070856908> True False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Name object at 0x7f6070856898> True False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Attribute object at 0x7f60708561d0> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Attribute object at 0x7f6070856cf8> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Name object at 0x7f6070856780> True False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Name object at 0x7f6070856320> True False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.FunctionDef object at 0x7f60708565c0> False
# <typed_ast._ast3.arguments object at 0x7f6070856a58> False
# <typed_ast._ast3.Assign object at 0x7f6070856c18> False
# <typed_ast._ast3.For object at 0x7f6070856518> False
# <typed_ast._ast3.Expr object at 0x7f6071197828> False
# <typed_ast._ast3.For object at 0x7f6071197710> False
# <typed_ast._ast3.arg object at 0x7f6070856ac8> False
# <typed_ast._ast3.arg object at 0x7f6070856a90> False
# <typed_ast._ast3.Name object at 0x7f60708566d8> True True
# <typed_ast._ast3.Str object at 0x7f6070856588> False
# <typed_ast._ast3.Name object at 0x7f6070856d68> True True
# <typed_ast._ast3.Name object at 0x7f6070856630> True False
# <typed_ast._ast3.Assign object at 0x7f6070856208> False
# <typed_ast._ast3.Call object at 0x7f60711976d8> False
# <typed_ast._ast3.Name object at 0x7f6071197f28> True True
# <typed_ast._ast3.Name object at 0x7f6071197978> True False
# <typed_ast._ast3.Assign object at 0x7f6071197550> False
# <typed_ast._ast3.For object at 0x7f60711973c8> False
# <typed_ast._ast3.Expr object at 0x7f60708a6710> False
# <typed_ast._ast3.Store object at 0x7f6072aaf0f0> False
# <typed_ast._ast3.Store object at 0x7f6072aaf0f0> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Name object at 0x7f60708565f8> True True
# <typed_ast._ast3.BinOp object at 0x7f6070856550> False
# <typed_ast._ast3.Name object at 0x7f6071197160> True False
# <typed_ast._ast3.Name object at 0x7f6071197f60> True False
# <typed_ast._ast3.Store object at 0x7f6072aaf0f0> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Name object at 0x7f60711977b8> True True
# <typed_ast._ast3.Attribute object at 0x7f6071197ac8> False
# <typed_ast._ast3.Name object at 0x7f6071197358> True True
# <typed_ast._ast3.Name object at 0x7f6071197d30> True False
# <typed_ast._ast3.If object at 0x7f6071197780> False
# <typed_ast._ast3.Call object at 0x7f60708a64a8> False
# <typed_ast._ast3.Store object at 0x7f6072aaf0f0> False
# <typed_ast._ast3.BinOp object at 0x7f6070856358> False
# <typed_ast._ast3.Add object at 0x7f6072aaf908> False
# <typed_ast._ast3.Attribute object at 0x7f6071197e80> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Store object at 0x7f6072aaf0f0> False
# <typed_ast._ast3.Name object at 0x7f6071197b38> True False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Store object at 0x7f6072aaf0f0> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.UnaryOp object at 0x7f6071197d68> False
# <typed_ast._ast3.AugAssign object at 0x7f6071197438> False
# <typed_ast._ast3.AugAssign object at 0x7f6071197cf8> False
# <typed_ast._ast3.Name object at 0x7f60708a6470> True False
# <typed_ast._ast3.Name object at 0x7f60708a69b0> True False
# <typed_ast._ast3.Name object at 0x7f60708567f0> True False
# <typed_ast._ast3.Add object at 0x7f6072aaf908> False
# <typed_ast._ast3.Str object at 0x7f60711972b0> False
# <typed_ast._ast3.Name object at 0x7f6071197a58> True False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Not object at 0x7f6072aaa2b0> False
# <typed_ast._ast3.Compare object at 0x7f6071197fd0> False
# <typed_ast._ast3.Name object at 0x7f6071197eb8> True True
# <typed_ast._ast3.Add object at 0x7f6072aaf908> False
# <typed_ast._ast3.Str object at 0x7f6071197518> False
# <typed_ast._ast3.Name object at 0x7f6070f353c8> True True
# <typed_ast._ast3.Add object at 0x7f6072aaf908> False
# <typed_ast._ast3.BinOp object at 0x7f6070f35588> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Attribute object at 0x7f6071197320> False
# <typed_ast._ast3.In object at 0x7f6072aaaa58> False
# <typed_ast._ast3.Attribute object at 0x7f60711971d0> False
# <typed_ast._ast3.Store object at 0x7f6072aaf0f0> False
# <typed_ast._ast3.Store object at 0x7f6072aaf0f0> False
# <typed_ast._ast3.Str object at 0x7f6070f356a0> False
# <typed_ast._ast3.Add object at 0x7f6072aaf908> False
# <typed_ast._ast3.Call object at 0x7f6070f35240> False
# <typed_ast._ast3.Name object at 0x7f6071197668> True False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Name object at 0x7f6071197278> True False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Name object at 0x7f60708a6c18> True False
# <typed_ast._ast3.Subscript object at 0x7f60708a6b70> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Attribute object at 0x7f60708a6438> False
# <typed_ast._ast3.Index object at 0x7f60708a68d0> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Name object at 0x7f60708a6f28> True False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Attribute object at 0x7f60708a60f0> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Name object at 0x7f60708a6da0> True False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.FunctionDef object at 0x7f60708a6cf8> False
# <typed_ast._ast3.arguments object at 0x7f60708a6dd8> False
# <typed_ast._ast3.Assign object at 0x7f60708a6c88> False
# <typed_ast._ast3.For object at 0x7f60708a6fd0> False
# <typed_ast._ast3.arg object at 0x7f60708a6f60> False
# <typed_ast._ast3.arg object at 0x7f60708a64e0> False
# <typed_ast._ast3.Name object at 0x7f60708a6630> True True
# <typed_ast._ast3.Call object at 0x7f60708a65f8> False
# <typed_ast._ast3.Name object at 0x7f60708a6e10> True True
# <typed_ast._ast3.Name object at 0x7f60708a6390> True False
# <typed_ast._ast3.Expr object at 0x7f60708a6048> False
# <typed_ast._ast3.Store object at 0x7f6072aaf0f0> False
# <typed_ast._ast3.Name object at 0x7f60708a62b0> True False
# <typed_ast._ast3.Call object at 0x7f60708a6a20> False
# <typed_ast._ast3.keyword object at 0x7f60708a6400> False
# <typed_ast._ast3.Store object at 0x7f6072aaf0f0> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Call object at 0x7f60708a6198> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Name object at 0x7f60708a6160> True False
# <typed_ast._ast3.Call object at 0x7f60708a6978> False
# <typed_ast._ast3.Call object at 0x7f60708a6d30> False
# <typed_ast._ast3.Name object at 0x7f60708a6d68> True False
# <typed_ast._ast3.Call object at 0x7f60708a6f98> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Attribute object at 0x7f60708a6748> False
# <typed_ast._ast3.Name object at 0x7f60708a6588> True False
# <typed_ast._ast3.Num object at 0x7f60708a6278> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Attribute object at 0x7f60708a61d0> False
# <typed_ast._ast3.Subscript object at 0x7f60708a6668> False
# <typed_ast._ast3.Subscript object at 0x7f60708a6208> False
# <typed_ast._ast3.Name object at 0x7f60708a65c0> True False
# <typed_ast._ast3.Name object at 0x7f60708a66d8> True False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Str object at 0x7f60708a6828> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Name object at 0x7f60708a6358> True False
# <typed_ast._ast3.Index object at 0x7f60708a6ac8> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Name object at 0x7f60708a6a90> True False
# <typed_ast._ast3.Index object at 0x7f60708a67f0> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Num object at 0x7f60708a60b8> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Num object at 0x7f60708a6550> False
# <typed_ast._ast3.FunctionDef object at 0x7f60708a6940> False
# <typed_ast._ast3.arguments object at 0x7f60708a6320> False
# <typed_ast._ast3.If object at 0x7f60708a6ef0> False
# <typed_ast._ast3.If object at 0x7f6070fd6898> False
# <typed_ast._ast3.Return object at 0x7f6070fd63c8> False
# <typed_ast._ast3.arg object at 0x7f60708a6860> False
# <typed_ast._ast3.Compare object at 0x7f60708a6cc0> False
# <typed_ast._ast3.If object at 0x7f6070fd6ba8> False
# <typed_ast._ast3.Compare object at 0x7f6070fd67b8> False
# <typed_ast._ast3.If object at 0x7f6070fd6630> False
# <typed_ast._ast3.Return object at 0x7f6070fd6dd8> False
# <typed_ast._ast3.NameConstant object at 0x7f6070fd6d68> False
# <typed_ast._ast3.Call object at 0x7f60708a6908> False
# <typed_ast._ast3.Eq object at 0x7f6072aaa518> False
# <typed_ast._ast3.Num object at 0x7f6070fd6550> False
# <typed_ast._ast3.UnaryOp object at 0x7f6070fd6c88> False
# <typed_ast._ast3.Return object at 0x7f6070fd6cf8> False
# <typed_ast._ast3.Return object at 0x7f6070fd6e48> False
# <typed_ast._ast3.Call object at 0x7f6070fd65f8> False
# <typed_ast._ast3.Eq object at 0x7f6072aaa518> False
# <typed_ast._ast3.Num object at 0x7f6070fd6438> False
# <typed_ast._ast3.BoolOp object at 0x7f6070fd6e80> False
# <typed_ast._ast3.Return object at 0x7f6070fd6a20> False
# <typed_ast._ast3.NameConstant object at 0x7f6070fd69e8> False
# <typed_ast._ast3.Name object at 0x7f60708a6be0> True False
# <typed_ast._ast3.Name object at 0x7f6070fd6278> True False
# <typed_ast._ast3.Not object at 0x7f6072aaa2b0> False
# <typed_ast._ast3.Compare object at 0x7f6070fd6470> False
# <typed_ast._ast3.NameConstant object at 0x7f6070fd60f0> False
# <typed_ast._ast3.NameConstant object at 0x7f6070fd66d8> False
# <typed_ast._ast3.Name object at 0x7f6070fd6240> True False
# <typed_ast._ast3.Name object at 0x7f6070fd6390> True False
# <typed_ast._ast3.And object at 0x7f6072aaf780> False
# <typed_ast._ast3.Compare object at 0x7f6070fd64e0> False
# <typed_ast._ast3.UnaryOp object at 0x7f6070fd6f28> False
# <typed_ast._ast3.NameConstant object at 0x7f6070fd68d0> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Subscript object at 0x7f6070fd6f60> False
# <typed_ast._ast3.Eq object at 0x7f6072aaa518> False
# <typed_ast._ast3.Str object at 0x7f6070fd6c18> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Subscript object at 0x7f6070fd6668> False
# <typed_ast._ast3.Eq object at 0x7f6072aaa518> False
# <typed_ast._ast3.Str object at 0x7f6070fd6828> False
# <typed_ast._ast3.Not object at 0x7f6072aaa2b0> False
# <typed_ast._ast3.Compare object at 0x7f6070fd62b0> False
# <typed_ast._ast3.Name object at 0x7f6070fd62e8> True False
# <typed_ast._ast3.Index object at 0x7f6070fd6320> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Subscript object at 0x7f6070fd6940> False
# <typed_ast._ast3.Index object at 0x7f6070fd6e10> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Subscript object at 0x7f6070fd6908> False
# <typed_ast._ast3.Eq object at 0x7f6072aaa518> False
# <typed_ast._ast3.Str object at 0x7f6070fd60b8> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Num object at 0x7f6070fd6160> False
# <typed_ast._ast3.Name object at 0x7f6070fd6198> True False
# <typed_ast._ast3.Index object at 0x7f6070fd6048> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Num object at 0x7f6070fd6128> False
# <typed_ast._ast3.Name object at 0x7f6070fd6748> True False
# <typed_ast._ast3.Index object at 0x7f6070fd69b0> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Num object at 0x7f6070fd6400> False
# <typed_ast._ast3.Load object at 0x7f6072aaf048> False
# <typed_ast._ast3.Num object at 0x7f6070fd6b70> False

# %%
# ?typed_ast._ast3.arg

# %%
some_code = read_file_to_string(filenm)
sys.path.append("py-ast-utils/")
import source_match
source_match.GetSource(astree, some_code)
assert some_code == module_node.matcher.GetSource()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-4fca8591e099> in <module>
#       1 some_code = read_file_to_string(filenm)
#       2 sys.path.append("py-ast-utils/")
# ----> 3 import source_match
#       4 source_match.GetSource(astree, some_code)
#       5 assert some_code == module_node.matcher.GetSource()
#
# ~/sc_data/py-ast-utils/source_match.py in <module>
#    1847     create_node.SyntaxFreeLine: get_SyntaxFreeLine_expected_parts,
#    1848     _ast.Tuple: TupleSourceMatcher,
# -> 1849     _ast.TryExcept: get_TryExcept_expected_parts,
#    1850     _ast.TryFinally: TryFinallySourceMatcher,
#    1851     _ast.UAdd: get_UAdd_expected_parts,
#
# AttributeError: module '_ast' has no attribute 'TryExcept'

# %%
from horast import parse, unparse

tree = parse("""a = 1  # a equals one after this""")
print(unparse(tree))
# this will print the code with original comment
# Out:
# a = 1  # a equals one after this

# %%
tree = parse(read_file_to_string(filenm))

# %%
import typed_ast
typed_ast._ast3.FunctionDef
# Out:
# typed_ast._ast3.FunctionDef

# %%
funs = []
for node in tree.body:
    if isinstance(node, typed_ast._ast3.FunctionDef):
        funs.append(node)

# %%
node.args.args[0].arg
# Out:
# 'image'

# %%
ret = node.body[0]
ret.value.ctx

# %%
for node in typed_ast.ast3.walk(tree):
    if isinstance(node, typed_ast.ast3.Name):
        print(node.id)
# Out:
# Test
# Fingerprint
# locals
# tests
# fingerprints
# directory
# namedtuple
# namedtuple
# pixel
# pixel
# chunk
# chunk
# exec
# exec
# results
# fingerprintScores
# fingerprint
# fingerprints
# test
# tests
# header
# test
# tests
# fingerprint
# fingerprints
# ordered
# result
# ordered
# sorted
# t
# results
# fingerprintScores
# doTests
# tests
# fingerprints
# image
# sorted
# chunk
# gammav
# pixel
# chunk
# x
# y
# u
# unpack
# x
# x
# x
# chunk
# compile
# compile
# image
# result
# fingerprint
# fingerprints
# results
# fingerprintScores
# header
# print
# header
# row
# test
# tests
# sorted
# t
# t
# checkCommandLine
# print
# print
# print
# print
# print
# generateCsv
# tests
# fingerprints
# print
# results
# showResults
# fingerprintScores
# image
# image
# image
# image
# chunk
# unpack
# image
# image
# pixel
# image
# image
# chunk
# image
# image
# fingerprintScores
# Png
# result
# result
# results
# fingerprint
# print
# row
# iter
# print
# len
# line
# len
# line
# locals
# t
# attrgetter
# isinstance
# t
# Fingerprint
# sys
# sys
# sys
# sys
# sys
# sys
# len
# tests
# image
# pixel
# image
# chunk
# gammav
# image
# image
# warn
# header
# test
# row
# row
# itemgetter
# nb
# isinstance
# t
# Test
# locals
# sys
# pixel
# pixel
# open
# open
# fingerprint
# directory
# image
# test
# test
# result
# scores
# result
# result
# line
# locals
# len
# test
# test
# fingerprint
# print
# fingerprintScores
# test
# fingerprint
# str
# line
# line
# sys
# test
# fingerprint
# fingerprint
# test
# fingerprint
# fingerprint
# test

# %%
print(unparse(funs[6]))
# Out:
# def badIdatFilter(image):
#     pixel = image.getPixelRgb(5, 0)
#     if (pixel == [65, 83, 255]):
#         return 11
#     else:
#         # Most libraries return the correct image
#         if (pixel == [57, 82, 255]):
#             return 12
#     # One library outputs a corrupted image
#     return 13

# %%
s = unparse(funs[6])
for token in tokenize.tokenize(BytesIO(s.encode('utf-8')).readline):
    print(token.string, token.type)
# Out:
# utf-8 57
#
#  56
#
#  56
# def 1
# badIdatFilter 1
# ( 53
# image 1
# ) 53
# : 53
#
#  4
#      5
# pixel 1
# = 53
# image 1
# . 53
# getPixelRgb 1
# ( 53
# 5 2
# , 53
# 0 2
# ) 53
#
#  4
# if 1
# ( 53
# pixel 1
# == 53
# [ 53
# 65 2
# , 53
# 83 2
# , 53
# 255 2
# ] 53
# ) 53
# : 53
#
#  4
#          5
# return 1
# 11 2
#
#  4
#  6
# else 1
# : 53
#
#  4
# # Most libraries return the correct image 55
#
#  56
#          5
# if 1
# ( 53
# pixel 1
# == 53
# [ 53
# 57 2
# , 53
# 82 2
# , 53
# 255 2
# ] 53
# ) 53
# : 53
#
#  4
#              5
# return 1
# 12 2
#
#  4
# # One library outputs a corrupted image  55
#
#  56
#  6
#  6
# return 1
# 13 2
#
#  4
#  6
#  0

# %%
data
# Out:
# [[['def',
#    'gamma',
#    '(',
#    'image',
#    ')',
#    ':',
#    '\n',
#    ' ',
#    'pixel',
#    '=',
#    'image',
#    '.',
#    'getPixelRgb',
#    '(',
#    '120',
#    ',',
#    '140',
#    ')',
#    '\n',
#    'if',
#    'pixel',
#    '[',
#    '0',
#    ']',
#    '+',
#    'pixel',
#    '[',
#    '1',
#    ']',
#    '+',
#    'pixel',
#    '[',
#    '2',
#    ']',
#    '<',
#    '96',
#    ':',
#    '\n',
#    'return',
#    '11',
#    '\n',
#    'else',
#    ':',
#    '\n',
#    'chunk',
#    '=',
#    'image',
#    '.',
#    'getChunk',
#    '(',
#    "'gAMA'",
#    ')',
#    '\n',
#    'if',
#    'chunk',
#    '==',
#    'None',
#    ':',
#    '\n',
#    'return',
#    '12',
#    '\n',
#    'gammav',
#    '=',
#    'unpack',
#    '(',
#    "'!I'",
#    ',',
#    'chunk',
#    '.',
#    'content',
#    ')',
#    '\n',
#    'if',
#    'gammav',
#    '[',
#    '0',
#    ']',
#    '==',
#    '400000',
#    ':',
#    '\n',
#    'return',
#    '13',
#    '\n',
#    'return',
#    '14',
#    ''],
#   {'chunk', 'gammav', 'image', 'pixel'},
#   [['image', 'image', 10, [3, 46]],
#    ['image', 'pixel', 10, [3, 46]],
#    ['chunk', 'chunk', 54, [44, 68]],
#    ['chunk', 'gammav', 54, [44, 68]],
#    ['pixel', 'pixel', 30, [8, 20, 25]],
#    ['pixel', 'image', 30, [8, 20, 25]],
#    ['image', 'image', 46, [3, 10]],
#    ['image', 'pixel', 46, [3, 10]],
#    ['chunk', 'chunk', 68, [44, 54]],
#    ['chunk', 'image', 68, [44, 54]],
#    ['gammav', 'gammav', 74, [62]],
#    ['gammav', 'chunk', 74, [62]],
#    ['pixel', 'pixel', 20, [8, 25, 30]],
#    ['pixel', 'image', 20, [8, 25, 30]],
#    ['pixel', 'pixel', 25, [8, 20, 30]],
#    ['pixel', 'gammav', 25, [8, 20, 30]]]],
#  [['def',
#    'physChunk',
#    '(',
#    'image',
#    ')',
#    ':',
#    '\n',
#    ' ',
#    'chunk',
#    '=',
#    'image',
#    '.',
#    'getChunk',
#    '(',
#    "'pHYs'",
#    ')',
#    '\n',
#    'if',
#    'chunk',
#    '==',
#    'None',
#    ':',
#    '\n',
#    'return',
#    '11',
#    '\n',
#    'x',
#    ',',
#    'y',
#    ',',
#    'u',
#    '=',
#    'unpack',
#    '(',
#    "'!IIB'",
#    ',',
#    'chunk',
#    '.',
#    'content',
#    ')',
#    '\n',
#    'if',
#    'x',
#    '==',
#    '1',
#    ':',
#    '\n',
#    'return',
#    '12',
#    '\n',
#    'if',
#    'x',
#    '==',
#    '1500',
#    ':',
#    '\n',
#    'return',
#    '13',
#    '\n',
#    'if',
#    'x',
#    '==',
#    '1499',
#    ':',
#    '\n',
#    'return',
#    '14',
#    '\n',
#    'return',
#    '15',
#    ''],
#   {'chunk', 'image', 'u', 'x', 'y'},
#   [['chunk', 'chunk', 18, [8, 36]],
#    ['chunk', 'x', 18, [8, 36]],
#    ['x', 'x', 42, [26, 51, 60]],
#    ['x', 'chunk', 42, [26, 51, 60]],
#    ['x', 'x', 51, [26, 42, 60]],
#    ['x', 'image', 51, [26, 42, 60]],
#    ['x', 'x', 60, [26, 42, 51]],
#    ['x', 'chunk', 60, [26, 42, 51]],
#    ['image', 'image', 10, [3]],
#    ['image', 'chunk', 10, [3]],
#    ['chunk', 'chunk', 36, [8, 18]],
#    ['chunk', 'y', 36, [8, 18]]]],
#  [['def',
#    'doTests',
#    '(',
#    'tests',
#    ',',
#    'fingerprints',
#    ',',
#    'warn',
#    ')',
#    ':',
#    '\n',
#    ' ',
#    'results',
#    '=',
#    '{',
#    '}',
#    '\n',
#    'fingerprintScores',
#    '=',
#    '{',
#    '}',
#    '\n',
#    'for',
#    'fingerprint',
#    'in',
#    'fingerprints',
#    ':',
#    '\n',
#    'fingerprintScores',
#    '[',
#    'fingerprint',
#    '.',
#    'name',
#    ']',
#    '=',
#    '0',
#    '\n',
#    'for',
#    'test',
#    'in',
#    'tests',
#    ':',
#    '\n',
#    'image',
#    '=',
#    'Png',
#    '(',
#    'directory',
#    '+',
#    'test',
#    '.',
#    'filename',
#    '+',
#    "'.png'",
#    ')',
#    '\n',
#    'if',
#    'not',
#    'image',
#    '.',
#    'valid',
#    '==',
#    '0',
#    ':',
#    '\n',
#    'result',
#    '=',
#    'test',
#    '.',
#    'function',
#    '(',
#    'image',
#    ')',
#    '\n',
#    'else',
#    ':',
#    '\n',
#    'result',
#    '=',
#    '0',
#    '\n',
#    'results',
#    '[',
#    'test',
#    '.',
#    'name',
#    ']',
#    '=',
#    'result',
#    '\n',
#    'for',
#    'fingerprint',
#    'in',
#    'fingerprints',
#    ':',
#    '\n',
#    'if',
#    'not',
#    'test',
#    '.',
#    'name',
#    'in',
#    'fingerprint',
#    '.',
#    'results',
#    ':',
#    '\n',
#    'if',
#    'warn',
#    ':',
#    '\n',
#    'print',
#    '(',
#    "'warning, missing key'",
#    ',',
#    'test',
#    '.',
#    'name',
#    ',',
#    "'in'",
#    ',',
#    '\n',
#    'fingerprint',
#    '.',
#    'name',
#    ')',
#    '\n',
#    'elif',
#    'fingerprint',
#    '.',
#    'results',
#    '[',
#    'test',
#    '.',
#    'name',
#    ']',
#    '==',
#    'result',
#    ':',
#    '\n',
#    'fingerprintScores',
#    '[',
#    'fingerprint',
#    '.',
#    'name',
#    ']',
#    '+=',
#    '1',
#    '\n',
#    'return',
#    'results',
#    ',',
#    'fingerprintScores',
#    ''],
#   {'fingerprint',
#    'fingerprintScores',
#    'fingerprints',
#    'image',
#    'result',
#    'results',
#    'test',
#    'tests',
#    'warn'},
#   [['fingerprints', 'fingerprints', 25, [5, 93]],
#    ['fingerprints', 'result', 25, [5, 93]],
#    ['tests', 'tests', 40, [3]],
#    ['tests', 'warn', 40, [3]],
#    ['result', 'result', 88, [65, 77, 137]],
#    ['result', 'fingerprintScores', 88, [65, 77, 137]],
#    ['fingerprints', 'fingerprints', 93, [5, 25]],
#    ['fingerprints', 'test', 93, [5, 25]],
#    ['results', 'results', 150, [12, 81, 104, 130]],
#    ['results', 'test', 150, [12, 81, 104, 130]],
#    ['fingerprintScores', 'fingerprintScores', 152, [17, 28, 140]],
#    ['fingerprintScores', 'result', 152, [17, 28, 140]],
#    ['fingerprintScores', 'fingerprintScores', 28, [17, 140, 152]],
#    ['fingerprintScores', 'warn', 28, [17, 140, 152]],
#    ['results', 'results', 81, [12, 104, 130, 150]],
#    ['results', 'result', 81, [12, 104, 130, 150]],
#    ['image', 'image', 71, [43, 58]],
#    ['image', 'fingerprint', 71, [43, 58]],
#    ['warn', 'warn', 108, [7]],
#    ['warn', 'fingerprintScores', 108, [7]],
#    ['fingerprint', 'fingerprint', 30, [23, 91, 102, 122, 128, 142]],
#    ['fingerprint', 'result', 30, [23, 91, 102, 122, 128, 142]],
#    ['image', 'image', 58, [43, 71]],
#    ['image', 'fingerprint', 58, [43, 71]],
#    ['test', 'test', 67, [38, 49, 83, 98, 115, 132]],
#    ['test', 'fingerprints', 67, [38, 49, 83, 98, 115, 132]],
#    ['test', 'test', 83, [38, 49, 67, 98, 115, 132]],
#    ['test', 'fingerprint', 83, [38, 49, 67, 98, 115, 132]],
#    ['result', 'result', 137, [65, 77, 88]],
#    ['result', 'tests', 137, [65, 77, 88]],
#    ['test', 'test', 49, [38, 67, 83, 98, 115, 132]],
#    ['test', 'results', 49, [38, 67, 83, 98, 115, 132]],
#    ['test', 'test', 98, [38, 49, 67, 83, 115, 132]],
#    ['test', 'image', 98, [38, 49, 67, 83, 115, 132]],
#    ['fingerprint', 'fingerprint', 102, [23, 30, 91, 122, 128, 142]],
#    ['fingerprint', 'result', 102, [23, 30, 91, 122, 128, 142]],
#    ['fingerprintScores', 'fingerprintScores', 140, [17, 28, 152]],
#    ['fingerprintScores', 'tests', 140, [17, 28, 152]],
#    ['test', 'test', 115, [38, 49, 67, 83, 98, 132]],
#    ['test', 'warn', 115, [38, 49, 67, 83, 98, 132]],
#    ['fingerprint', 'fingerprint', 122, [23, 30, 91, 102, 128, 142]],
#    ['fingerprint', 'fingerprintScores', 122, [23, 30, 91, 102, 128, 142]],
#    ['fingerprint', 'fingerprint', 128, [23, 30, 91, 102, 122, 142]],
#    ['fingerprint', 'fingerprintScores', 128, [23, 30, 91, 102, 122, 142]],
#    ['test', 'test', 132, [38, 49, 67, 83, 98, 115]],
#    ['test', 'result', 132, [38, 49, 67, 83, 98, 115]],
#    ['fingerprint', 'fingerprint', 142, [23, 30, 91, 102, 122, 128]],
#    ['fingerprint', 'fingerprints', 142, [23, 30, 91, 102, 122, 128]]]],
#  [['def',
#    'generateCsv',
#    '(',
#    'tests',
#    ',',
#    'fingerprints',
#    ')',
#    ':',
#    '\n',
#    ' ',
#    'header',
#    '=',
#    "'/'",
#    '\n',
#    'for',
#    'test',
#    'in',
#    'tests',
#    ':',
#    '\n',
#    'header',
#    '=',
#    'header',
#    '+',
#    "'\\t'",
#    '+',
#    'test',
#    '.',
#    'name',
#    '\n',
#    'print',
#    '(',
#    'header',
#    ')',
#    '\n',
#    'for',
#    'fingerprint',
#    'in',
#    'fingerprints',
#    ':',
#    '\n',
#    'row',
#    '=',
#    'fingerprint',
#    '.',
#    'name',
#    '\n',
#    'for',
#    'test',
#    'in',
#    'tests',
#    ':',
#    '\n',
#    'if',
#    'not',
#    'test',
#    '.',
#    'name',
#    'in',
#    'fingerprint',
#    '.',
#    'results',
#    ':',
#    '\n',
#    'row',
#    '+=',
#    '\'\\t""\'',
#    '\n',
#    'else',
#    ':',
#    '\n',
#    'row',
#    '+=',
#    "'\\t'",
#    '+',
#    'str',
#    '(',
#    'fingerprint',
#    '.',
#    'results',
#    '[',
#    'test',
#    '.',
#    'name',
#    ']',
#    ')',
#    '\n',
#    'print',
#    '(',
#    'row',
#    ')',
#    ''],
#   {'fingerprint', 'fingerprints', 'header', 'row', 'test', 'tests'},
#   [['tests', 'tests', 17, [3, 50]],
#    ['tests', 'header', 17, [3, 50]],
#    ['fingerprints', 'fingerprints', 38, [5]],
#    ['fingerprints', 'tests', 38, [5]],
#    ['header', 'header', 32, [10, 20, 22]],
#    ['header', 'fingerprint', 32, [10, 20, 22]],
#    ['tests', 'tests', 50, [3, 17]],
#    ['tests', 'fingerprint', 50, [3, 17]],
#    ['fingerprint', 'fingerprint', 43, [36, 59, 77]],
#    ['fingerprint', 'fingerprints', 43, [36, 59, 77]],
#    ['row', 'row', 89, [41, 64, 71]],
#    ['row', 'fingerprint', 89, [41, 64, 71]],
#    ['header', 'header', 22, [10, 20, 32]],
#    ['header', 'test', 22, [10, 20, 32]],
#    ['test', 'test', 26, [15, 48, 55, 81]],
#    ['test', 'header', 26, [15, 48, 55, 81]],
#    ['test', 'test', 55, [15, 26, 48, 81]],
#    ['test', 'row', 55, [15, 26, 48, 81]],
#    ['fingerprint', 'fingerprint', 59, [36, 43, 77]],
#    ['fingerprint', 'tests', 59, [36, 43, 77]],
#    ['fingerprint', 'fingerprint', 77, [36, 43, 59]],
#    ['fingerprint', 'fingerprints', 77, [36, 43, 59]],
#    ['test', 'test', 81, [15, 26, 48, 55]],
#    ['test', 'row', 81, [15, 26, 48, 55]]]],
#  [['def',
#    'showResults',
#    '(',
#    'scores',
#    ',',
#    'nb',
#    ')',
#    ':',
#    '\n',
#    ' ',
#    'ordered',
#    '=',
#    'sorted',
#    '(',
#    'iter',
#    '(',
#    'scores',
#    '.',
#    'items',
#    '(',
#    ')',
#    ')',
#    ',',
#    'key',
#    '=',
#    'itemgetter',
#    '(',
#    '1',
#    ')',
#    ')',
#    '\n',
#    'for',
#    'result',
#    'in',
#    'ordered',
#    ':',
#    '\n',
#    'print',
#    '(',
#    "'{:20s} {:3d}/{:3d}'",
#    '.',
#    'format',
#    '(',
#    'result',
#    '[',
#    '0',
#    ']',
#    ',',
#    'result',
#    '[',
#    '1',
#    ']',
#    ',',
#    'nb',
#    ')',
#    ')',
#    ''],
#   {'nb', 'ordered', 'result', 'scores'},
#   [['ordered', 'ordered', 34, [10]],
#    ['ordered', 'scores', 34, [10]],
#    ['nb', 'nb', 53, [5]],
#    ['nb', 'scores', 53, [5]],
#    ['scores', 'scores', 16, [3]],
#    ['scores', 'nb', 16, [3]],
#    ['result', 'result', 43, [32, 48]],
#    ['result', 'scores', 43, [32, 48]],
#    ['result', 'result', 48, [32, 43]],
#    ['result', 'ordered', 48, [32, 43]]]]]

# %%
s = set([1, 2, 3])
s.difference({1}), s
# Out:
# ({2, 3}, {1, 2, 3})

# %%
astor.to_source(fun)
# Out:
# "if JKMCFHNBVCXSDJ.argv[1] == '-gen':\n    JKMCFHNBVCXSDJ(JKMCFHNBVCXSDJ)\nelse:\n    JKMCFHNBVCXSDJ(JKMCFHNBVCXSDJ, JKMCFHNBVCXSDJ(JKMCFHNBVCXSDJ))\n"

# %%
get_tokens(astor.to_source(fun), special_word)
# Out:
# utf-8 False
# if False
# JKMCFHNBVCXSDJ True
# . False
# argv False
# [ False
# 1 False
# ] False
# == False
# '-gen' False
# : False
# JKMCFHNBVCXSDJ True
# ( False
# JKMCFHNBVCXSDJ True
# ) False
# else False
# : False
# JKMCFHNBVCXSDJ True
# ( False
# JKMCFHNBVCXSDJ True
# , False
# JKMCFHNBVCXSDJ True
# ( False
# JKMCFHNBVCXSDJ True
# ) False
# ) False
#  False
#  False
# (['if',
#   'JKMCFHNBVCXSDJ',
#   '.',
#   'argv',
#   '[',
#   '1',
#   ']',
#   '==',
#   "'-gen'",
#   ':',
#   'JKMCFHNBVCXSDJ',
#   '(',
#   'JKMCFHNBVCXSDJ',
#   ')',
#   'else',
#   ':',
#   'JKMCFHNBVCXSDJ',
#   '(',
#   'JKMCFHNBVCXSDJ',
#   ',',
#   'JKMCFHNBVCXSDJ',
#   '(',
#   'JKMCFHNBVCXSDJ',
#   ')',
#   ')',
#   '',
#   ''],
#  22)

# %%
for child in ast.iter_child_nodes(astree):
    if isinstance(child, ast.FunctionDef) and child.name=="gamma":
        break

# %%
child.name, child.body, child.args, list(ast.iter_child_nodes(child))
# Out:
# ('gamma',
#  [<_ast.Assign at 0x7f63cf89ea58>, <_ast.If at 0x7f63cf89e198>],
#  <_ast.arguments at 0x7f63cf89bf98>,
#  [<_ast.arguments at 0x7f63cf89bf98>,
#   <_ast.Assign at 0x7f63cf89ea58>,
#   <_ast.If at 0x7f63cf89e198>])

# %%
if_ = child.body[1]
if_.body, if_.orelse, if_.test
# Out:
# ([<_ast.Return at 0x7f63cf89e550>],
#  [<_ast.Assign at 0x7f63cf89e5c0>,
#   <_ast.If at 0x7f63cf89e710>,
#   <_ast.Assign at 0x7f63cf89e860>,
#   <_ast.If at 0x7f63cf89e9e8>,
#   <_ast.Return at 0x7f63cebf2ba8>],
#  <_ast.Compare at 0x7f63cf89e1d0>)

# %%
arg = child.args.args[0]
arg.arg
# Out:
# 'image'

# %%
node.id, node.col_offset, node.ctx, node.lineno
# Out:
# ('Test', 0, <_ast.Store at 0x7f6403b53208>, 26)

# %%
ast.Name()

# %%
ast.Load

# %%
from tokenize import tokenize, untokenize, NUMBER, STRING, NAME, OP
from io import BytesIO

def decistmt(s):
    """Substitute Decimals for floats in a string of statements.

    >>> from decimal import Decimal
    >>> s = 'print(+21.3e-5*-.1234/81.7)'
    >>> decistmt(s)
    "print (+Decimal ('21.3e-5')*-Decimal ('.1234')/Decimal ('81.7'))"

    The format of the exponent is inherited from the platform C library.
    Known cases are "e-007" (Windows) and "e-07" (not Windows).  Since
    we're only showing 12 digits, and the 13th isn't close to 5, the
    rest of the output should be platform-independent.

    >>> exec(s)  #doctest: +ELLIPSIS
    -3.21716034272e-0...7

    Output from calculations with Decimal should be identical across all
    platforms.

    >>> exec(decistmt(s))
    -3.217160342717258261933904529E-7
    """
    result = []
    g = tokenize(BytesIO(s.encode('utf-8')).readline)  # tokenize the string
    for toknum, tokval, _, _, _ in g:
        if toknum == NUMBER and '.' in tokval:  # replace NUMBER tokens
            result.extend([
                (NAME, 'Decimal'),
                (OP, '('),
                (STRING, repr(tokval)),
                (OP, ')')
            ])
        else:
            result.append((toknum, tokval))
    return untokenize(result)#.decode('utf-8')

# %%
decistmt(code)
# Out:
# b"if sys .argv [1 ]=='-gen':print (results )else :showResults (fingerprintScores ,len (tests ))"
# b"if sys .argv [1 ]=='-gen':print (results )else :showResults (fingerprintScores ,len (tests ))"

# %%
code
# Out:
# "if sys.argv[1] == '-gen': print(results) else: showResults(fingerprintScores, len(tests))"
# "if sys.argv[1] == '-gen': print(results) else: showResults(fingerprintScores, len(tests))"

# %%
import ast, asttokens
st='''
def greet(a): # comment 4
  """
  doc
  """
  # comment 2
  say("hello") if a else   say("bye") # comment 1
  # comment 3
  """
  big_coment 1  
  """
  return 1
'''
atok = asttokens.ASTTokens(st, parse=True)
for node in ast.walk(atok.tree):
    if hasattr(node, 'lineno'):
        code_list = []
        for token in atok.get_tokens(node, include_extra=True):
            code_list.append(token.string)
            print(token.string, token.type)
        print(node, code_list)
# Out:
# def 1
# greet 1
# ( 53
# a 1
# ) 53
# : 53
# # comment 4 55
#
#  4
#    5
# """
#   doc
#   """ 3
#
#  4
# # comment 2 55
#
#  56
# say 1
# ( 53
# "hello" 3
# ) 53
# if 1
# a 1
# else 1
# say 1
# ( 53
# "bye" 3
# ) 53
# # comment 1 55
#
#  4
# # comment 3 55
#
#  56
# """
#   big_coment 1
#   """ 3
#
#  4
# return 1
# 1 2
# <_ast.FunctionDef object at 0x7f606cc159e8> ['def', 'greet', '(', 'a', ')', ':', '# comment 4', '\n', '  ', '"""\n  doc\n  """', '\n', '# comment 2', '\n', 'say', '(', '"hello"', ')', 'if', 'a', 'else', 'say', '(', '"bye"', ')', '# comment 1', '\n', '# comment 3', '\n', '"""\n  big_coment 1  \n  """', '\n', 'return', '1']
# """
#   doc
#   """ 3
# <_ast.Expr object at 0x7f606cc15908> ['"""\n  doc\n  """']
# say 1
# ( 53
# "hello" 3
# ) 53
# if 1
# a 1
# else 1
# say 1
# ( 53
# "bye" 3
# ) 53
# <_ast.Expr object at 0x7f606cc15358> ['say', '(', '"hello"', ')', 'if', 'a', 'else', 'say', '(', '"bye"', ')']
# """
#   big_coment 1
#   """ 3
# <_ast.Expr object at 0x7f606cc154e0> ['"""\n  big_coment 1  \n  """']
# return 1
# 1 2
# <_ast.Return object at 0x7f606cc15198> ['return', '1']
# a 1
# <_ast.arg object at 0x7f606cc15b00> ['a']
# """
#   doc
#   """ 3
# <_ast.Str object at 0x7f606cc156a0> ['"""\n  doc\n  """']
# say 1
# ( 53
# "hello" 3
# ) 53
# if 1
# a 1
# else 1
# say 1
# ( 53
# "bye" 3
# ) 53
# <_ast.IfExp object at 0x7f606cc15d68> ['say', '(', '"hello"', ')', 'if', 'a', 'else', 'say', '(', '"bye"', ')']
# """
#   big_coment 1
#   """ 3
# <_ast.Str object at 0x7f606cc15588> ['"""\n  big_coment 1  \n  """']
# 1 2
# <_ast.Num object at 0x7f606cc15630> ['1']
# a 1
# <_ast.Name object at 0x7f606cc150b8> ['a']
# say 1
# ( 53
# "hello" 3
# ) 53
# <_ast.Call object at 0x7f606cc15ac8> ['say', '(', '"hello"', ')']
# say 1
# ( 53
# "bye" 3
# ) 53
# <_ast.Call object at 0x7f606cc15828> ['say', '(', '"bye"', ')']
# say 1
# <_ast.Name object at 0x7f606cc15eb8> ['say']
# "hello" 3
# <_ast.Str object at 0x7f606cc15f60> ['"hello"']
# say 1
# <_ast.Name object at 0x7f606cc15780> ['say']
# "bye" 3
# <_ast.Str object at 0x7f606cc15a20> ['"bye"']

# %%
import custom_tokenize
import importlib
importlib.reload(custom_tokenize)
# Out:
# <module 'custom_tokenize' from '/Vol0/user/hse/nadiinchi/sc_data/custom_tokenize.py'>

# %%
tokens = []
for token in tokenize.tokenize(BytesIO(read_file_to_string('new_files/CoAxLab/DeBaCl/debacl/level_set_tree.py').encode('utf-8')).readline):
    #print(token.string, token.type)
    tokens.append([token.string, token.type])
print(tokens)
# Out:
# [['utf-8', 57], ['"""\nMain functions and classes for the DEnsity-BAsed CLustering (DeBaCl) toolbox.\nIncludes functions to construct and modify level set trees, and level set tree\nmethods for retrieving clusters and plotting.\n"""', 3], ['\n', 4], ['\n', 56], ['## Built-in packages', 55], ['\n', 56], ['\n', 56], ['\n', 56], ['\n', 56], ['import', 1], ['logging', 1], ['as', 1], ['_logging', 1], ['\n', 4], ['import', 1], ['copy', 1], ['as', 1], ['_copy', 1], ['\n', 4], ['import', 1], ['pickle', 1], ['as', 1], ['_pickle', 1], ['\n', 4], ['import', 1], ['debacl', 1], ['.', 53], ['utils', 1], ['as', 1], ['_utl', 1], ['\n', 4], ['\n', 56], ['_logging', 1], ['.', 53], ['basicConfig', 1], ['(', 53], ['level', 1], ['=', 53], ['_logging', 1], ['.', 53], ['INFO', 1], [',', 53], ['datefmt', 1], ['=', 53], ["'%Y-%m-%d %I:%M:%S'", 3], [',', 53], ['\n', 56], ['format', 1], ['=', 53], ["'%(levelname)s (%(asctime)s): %(message)s'", 3], [')', 53], ['\n', 4], ['\n', 56], ['## Required packages', 55], ['\n', 56], ['try', 1], [':', 53], ['\n', 4], ['    ', 5], ['import', 1], ['numpy', 1], ['as', 1], ['_np', 1], ['\n', 4], ['import', 1], ['networkx', 1], ['as', 1], ['_nx', 1], ['\n', 4], ['from', 1], ['prettytable', 1], ['import', 1], ['PrettyTable', 1], ['as', 1], ['_PrettyTable', 1], ['\n', 4], ['', 6], ['except', 1], [':', 53], ['\n', 4], ['    ', 5], ['raise', 1], ['ImportError', 1], ['(', 53], ['"DeBaCl requires the numpy, networkx, and "', 3], ['+', 53], ['\n', 56], ['"prettytable packages."', 3], [')', 53], ['\n', 4], ['\n', 56], ['## Soft dependencies', 55], ['\n', 56], ['', 6], ['try', 1], [':', 53], ['\n', 4], ['    ', 5], ['import', 1], ['matplotlib', 1], ['.', 53], ['pyplot', 1], ['as', 1], ['_plt', 1], ['\n', 4], ['from', 1], ['matplotlib', 1], ['.', 53], ['collections', 1], ['import', 1], ['LineCollection', 1], ['as', 1], ['_LineCollection', 1], ['\n', 4], ['_HAS_MPL', 1], ['=', 53], ['True', 1], ['\n', 4], ['', 6], ['except', 1], [':', 53], ['\n', 4], ['    ', 5], ['_HAS_MPL', 1], ['=', 53], ['False', 1], ['\n', 4], ['_logging', 1], ['.', 53], ['warning', 1], ['(', 53], ['"Matplotlib could not be loaded, so DeBaCl plots will "', 3], ['+', 53], ['\n', 56], ['"fail."', 3], [')', 53], ['\n', 4], ['\n', 56], ['\n', 56], ['', 6], ['class', 1], ['ConnectedComponent', 1], ['(', 53], ['object', 1], [')', 53], [':', 53], ['\n', 4], ['    ', 5], ['"""\n    Define a connected component for level set tree construction. A level set\n    tree is really just a set of ConnectedComponent objects.\n    """', 3], ['\n', 4], ['\n', 56], ['def', 1], ['__init__', 1], ['(', 53], ['self', 1], [',', 53], ['idnum', 1], [',', 53], ['parent', 1], [',', 53], ['children', 1], [',', 53], ['start_level', 1], [',', 53], ['end_level', 1], [',', 53], ['\n', 56], ['start_mass', 1], [',', 53], ['end_mass', 1], [',', 53], ['members', 1], [')', 53], [':', 53], ['\n', 4], ['\n', 56], ['        ', 5], ['self', 1], ['.', 53], ['idnum', 1], ['=', 53], ['idnum', 1], ['\n', 4], ['self', 1], ['.', 53], ['parent', 1], ['=', 53], ['parent', 1], ['\n', 4], ['self', 1], ['.', 53], ['children', 1], ['=', 53], ['children', 1], ['\n', 4], ['self', 1], ['.', 53], ['start_level', 1], ['=', 53], ['start_level', 1], ['\n', 4], ['self', 1], ['.', 53], ['end_level', 1], ['=', 53], ['end_level', 1], ['\n', 4], ['self', 1], ['.', 53], ['start_mass', 1], ['=', 53], ['start_mass', 1], ['\n', 4], ['self', 1], ['.', 53], ['end_mass', 1], ['=', 53], ['end_mass', 1], ['\n', 4], ['self', 1], ['.', 53], ['members', 1], ['=', 53], ['members', 1], ['\n', 4], ['\n', 56], ['\n', 56], ['', 6], ['', 6], ['class', 1], ['LevelSetTree', 1], ['(', 53], ['object', 1], [')', 53], [':', 53], ['\n', 4], ['    ', 5], ['"""\n    Level Set Tree attributes and methods. The level set tree is a collection\n    of connected components organized hierarchically, based on a density\n    estimate and connectivity graph.\n\n    .. warning::\n\n        LevelSetTree objects should not generally be instantiated directly,\n      ...

# %%
##### TOKENIZE TEST
st='''
# Fingerprint depending on how the decoder treated the gamma information from the input image
def gamma(image):
  pixel = JKMCFHNBVCXSDJ.getPixelRgb(120,140)
  if pixel[0]+pixel[1] + pixel[2] < 96 :
    return 11
  else:
    chunk = image.getChunk("gAMA")
    if chunk == None:
      return 12
    gammav = unpack("!I",chunk.content)
    if gammav[0] == 400000 :
      return 13
    return 14
'''
tokens = []
for token in tokenize.tokenize(BytesIO(st.encode('utf-8')).readline):
    print(token.string, token.type)
    tokens.append([token.string, token.type])
print(tokens)
# Out:
# utf-8 57
#
#  56
# # Fingerprint depending on how the decoder treated the gamma information from the input image 55
#
#  56
# def 1
# gamma 1
# ( 53
# image 1
# ) 53
# : 53
#
#  4
#    5
# pixel 1
# = 53
# JKMCFHNBVCXSDJ 1
# . 53
# getPixelRgb 1
# ( 53
# 120 2
# , 53
# 140 2
# ) 53
#
#  4
# if 1
# pixel 1
# [ 53
# 0 2
# ] 53
# + 53
# pixel 1
# [ 53
# 1 2
# ] 53
# + 53
# pixel 1
# [ 53
# 2 2
# ] 53
# < 53
# 96 2
# : 53
#
#  4
#      5
# return 1
# 11 2
#
#  4
#  6
# else 1
# : 53
#
#  4
#      5
# chunk 1
# = 53
# image 1
# . 53
# getChunk 1
# ( 53
# "gAMA" 3
# ) 53
#
#  4
# if 1
# chunk 1
# == 53
# None 1
# : 53
#
#  4
#        5
# return 1
# 12 2
#
#  4
#  6
# gammav 1
# = 53
# unpack 1
# ( 53
# "!I" 3
# , 53
# chunk 1
# . 53
# content 1
# ) 53
#
#  4
# if 1
# gammav 1
# [ 53
# 0 2
# ] 53
# == 53
# 400000 2
# : 53
#
#  4
#        5
# return 1
# 13 2
#
#  4
#  6
# return 1
# 14 2
#
#  4
#  6
#  6
#  0
# [['utf-8', 57], ['\n', 56], ['# Fingerprint depending on how the decoder treated the gamma information from the input image', 55], ['\n', 56], ['def', 1], ['gamma', 1], ['(', 53], ['image', 1], [')', 53], [':', 53], ['\n', 4], ['  ', 5], ['pixel', 1], ['=', 53], ['JKMCFHNBVCXSDJ', 1], ['.', 53], ['getPixelRgb', 1], ['(', 53], ['120', 2], [',', 53], ['140', 2], [')', 53], ['\n', 4], ['if', 1], ['pixel', 1], ['[', 53], ['0', 2], [']', 53], ['+', 53], ['pixel', 1], ['[', 53], ['1', 2], [']', 53], ['+', 53], ['pixel', 1], ['[', 53], ['2', 2], [']', 53], ['<', 53], ['96', 2], [':', 53], ['\n', 4], ['    ', 5], ['return', 1], ['11', 2], ['\n', 4], ['', 6], ['else', 1], [':', 53], ['\n', 4], ['    ', 5], ['chunk', 1], ['=', 53], ['image', 1], ['.', 53], ['getChunk', 1], ['(', 53], ['"gAMA"', 3], [')', 53], ['\n', 4], ['if', 1], ['chunk', 1], ['==', 53], ['None', 1], [':', 53], ['\n', 4], ['      ', 5], ['return', 1], ['12', 2], ['\n', 4], ['', 6], ['gammav', 1], ['=', 53], ['unpack', 1], ['(', 53], ['"!I"', 3], [',', 53], ['chunk', 1], ['.', 53], ['content', 1], [')', 53], ['\n', 4], ['if', 1], ['gammav', 1], ['[', 53], ['0', 2], [']', 53], ['==', 53], ['400000', 2], [':', 53], ['\n', 4], ['      ', 5], ['return', 1], ['13', 2], ['\n', 4], ['', 6], ['return', 1], ['14', 2], ['\n', 4], ['', 6], ['', 6], ['', 0]]

# %%
tokenize.DEDENT, tokenize.INDENT, tokenize.COMMENT, \
tokenize.ENDMARKER, tokenize.ERRORTOKEN, tokenize.NEWLINE, tokenize.NL
# Out:
# (6, 5, 55, 0, 54, 4, 56)

# %%
atok.tree.body[0].body[0].value.body.func.id = "myfun"

# %%
atok.tree.body[0]

# %%
a, b = atok.tree.body[0].first_token.startpos, atok.tree.body[0].last_token.endpos
st[a:b]
# Out:
# 'def greet(a):\n  # comment 2\n  say("hello") if a else say("bye") # comment 1\n  # comment 3\n  return 1'

# %%
for node in ast.walk(atok.tree):
    if hasattr(node, 'lineno'):
        code_list = []
        if hasattr(node, "id"):
            print(node.id)
        for token in atok.get_tokens(node, include_extra=True):
            code_list.append(token.string)
        print(node, code_list)
# Out:
# <_ast.FunctionDef object at 0x7f60707b8a20> ['def', 'greet', '(', 'a', ')', ':', '\n', '# comment 2', '\n', '  ', 'say', '(', '"hello"', ')', 'if', 'a', 'else', 'say', '(', '"bye"', ')', '# comment 1', '\n', '# comment 3', '\n', 'return', '1']
# <_ast.Expr object at 0x7f60707b8588> ['say', '(', '"hello"', ')', 'if', 'a', 'else', 'say', '(', '"bye"', ')']
# <_ast.Return object at 0x7f6071a6b860> ['return', '1']
# <_ast.arg object at 0x7f60707b8ac8> ['a']
# <_ast.IfExp object at 0x7f60707b8f28> ['say', '(', '"hello"', ')', 'if', 'a', 'else', 'say', '(', '"bye"', ')']
# <_ast.Num object at 0x7f6071a6b588> ['1']
# a
# <_ast.Name object at 0x7f60717f7be0> ['a']
# <_ast.Call object at 0x7f60717f7f60> ['say', '(', '"hello"', ')']
# <_ast.Call object at 0x7f60717f7710> ['say', '(', '"bye"', ')']
# myfun
# <_ast.Name object at 0x7f60717f7828> ['say']
# <_ast.Str object at 0x7f60717f7ac8> ['"hello"']
# say
# <_ast.Name object at 0x7f6071a6bbe0> ['say']
# <_ast.Str object at 0x7f6071a6b160> ['"bye"']

# %%
# ?asttokens.ASTTokens

# %%
import re
import tokenize
from io import BytesIO

def get_tokens(f, special_word, remember_word, docstring_word="###DCSTR###", docstring=""):
    #code = re.sub('\t+', ' ', f.strip())
    #code = re.sub(' +', ' ', code)
    code = f
    tokens = []
    remember_idxs = []
    special_idx = -1
    comments = []
    prev_string = None
    for token in tokenize.tokenize(BytesIO(code.encode('utf-8')).readline):
        if not token.type in {55}:
            # code
            if token.type == 3:
                string_ = '"str"'
            elif token.type == 5:
                string_ = "<indent>"
            elif token.type == 6:
                string_ = "<dedent>"
            elif token.type == 0:
                string_ = "<endf>"
            elif token.type == 54:
                string_ = "<errtoken>"
            elif token.type == 56:
                string_ = "<nl>"
            elif token.type == 4: # to avoid "\r\n" and ""
                string_ = "\n"
            else:
                string_ = token.string
            if string_ not in {"\n", "<nl>"} or \
                (string_ == "\n" and prev_string != "\n") or\
                (string_ == "<nl>" and prev_string != "<nl>"):
                # filter out what we do not remember: repeating \n
                if string_ == "":
                    raise ValueError("%s\n%s %s %s"%(code, \
                                                        token.type, token.string, prev_string))
                tokens.append(string_)
                if string_ == special_word:
                    special_idx = len(tokens)-2
                if string_ == remember_word:
                    remember_idxs.append(len(tokens)-2)
            prev_string = string_
        else:
            # comment
            if token.string == docstring_word:
                comments.append([len(tokens)-2, \
                                 docstring_word+" "+docstring])
            else:
                if len(''.join(filter(str.isalpha, token.string)))>0:
                     comments.append([len(tokens)-2, token.string])
    return tokens[1:], special_idx, remember_idxs, comments

def get_pre_post_comments(fun, code_lines):
    fun_line_first = fun.first_token.start[0] - 1
    fun_line_last = fun.last_token.end[0] - 1
    if (fun_line_first >= 2 and len(code_lines[fun_line_first-1].strip()) >= 1 and\
        code_lines[fun_line_first-1].strip()[0] == "#" \
        and code_lines[fun_line_first-2].strip()=="") or\
        (fun_line_first == 1 and len(code_lines[fun_line_first-1].strip()) >= 1 and \
        code_lines[fun_line_first-1].strip()[0] == "#"):
        precomment = code_lines[fun_line_first-1].strip()+"\n"
    else:
        precomment = ""
    if (fun_line_last <= len(code_lines)-3 and len(code_lines[fun_line_last+1].strip()) >= 1 and \
        code_lines[fun_line_last+1].strip()[0] == "#" \
        and code_lines[fun_line_last+2].strip()=="") or\
        (fun_line_last == len(code_lines)-2 and len(code_lines[fun_line_last+1].strip()) >= 1 and\
         code_lines[fun_line_last+1].strip()[0] == "#"):
        postcomment = "\n"+code_lines[fun_line_last+1].strip()
    else:
        postcomment = ""
    return precomment, postcomment

# %%
import asttokens

special_word = "JKMCFHNBVCXSDJ"
data = []

def process_file(filenm, data):

    code = read_file_to_string(filenm)
    code_lines = code.splitlines()
    atok = asttokens.ASTTokens(code, parse=True)
    astree = atok.tree


    for fun in ast.iter_child_nodes(astree):
        if isinstance(fun, ast.FunctionDef) and len(fun.body) > 0:
            a_fun, b_fun = fun.first_token.startpos, fun.last_token.endpos
            precomment, postcomment = get_pre_post_comments(fun, code_lines)
            body_start = fun.body[0].first_token.startpos
            docstring = ast.get_docstring(fun)
            if not docstring:
                docstring_placeholder = ""
            else:
                docstring_placeholder = "\n###DCSTR###\n"
            scope = [arg.arg for arg in fun.args.args]
            for node in ast.walk(fun):
                # collecting scope
                if isinstance(node, ast.Name) and isinstance(node.ctx, ast.Store):
                    scope.append(node.id)
            scope = set(scope)
            first = True
            if len(scope) >= 3:
                for node in ast.walk(fun):
                    if isinstance(node, ast.Name) and isinstance(node.ctx, ast.Load) and node.id in scope:
                        id_ = node.id
                        a, b = node.first_token.startpos, node.last_token.endpos
                        node_code = precomment + code[a_fun:body_start]+docstring_placeholder+\
                        code[body_start:a] + special_word + code[b:b_fun] + postcomment
                        tokens, idx, remember_idxs, comments = get_tokens(node_code, special_word, id_,\
                                                                         docstring=docstring)
                        assert tokens[idx] == special_word
                        assert np.all([tokens[remem_idx]==id_ for remem_idx in remember_idxs])
                        #print(tokens, idx, remember_idxs)
                        node.id = id_
                        if first:
                            tokens[idx] = id_
                            data.append([code[a_fun:b_fun], tokens, comments, list(scope), []])
                            first = False
                        #data[-1][3].append([id_, id_, idx, remember_idxs]) # correct, correct
                        buggy_id = list(scope.difference({id_}))\
                                   [np.random.randint(low=0, high=len(scope)-1)]
                        data[-1][-1].append([id_, buggy_id, idx, remember_idxs]) # correct, buggy
            if not first and len(data[-1][-1]) <= 1:
                del data[-1]

# %%
files = []
for r, d, f in os.walk("new_files/"):
    for file in f:
        if file.endswith(".py"):
            files.append(os.path.join(r, file))
#process_file(filenm, data)

# %%
for file in files[:100]:
    process_file(file, data)

# %%
len(data)
# Out:
# 198

# %%
import json
len(json.dumps(data))
# Out:
# 950110

# %%
import traceback
import logging

try:
    print(1)
    raise ValueError("print")
except Exception as e:
    print(traceback.format_exc())
# Out:
# 1
# Traceback (most recent call last):
#   File "<ipython-input-344-ab93c6bc8f15>", line 6, in <module>
#     raise ValueError("print")
# ValueError: print

# %%
files[:10]
# Out:
# ['new_files/fingerping.py',
#  'new_files/CoAxLab/DeBaCl/docs/conf.py',
#  'new_files/CoAxLab/DeBaCl/debacl/level_set_tree.py',
#  'new_files/ClockworkNet/wtop/robots/create_robots_resources.py',
#  'new_files/ClockworkNet/wtop/robots/compare_robots_configs.py',
#  'new_files/ClockworkNet/wtop/robots/trie.py',
#  'new_files/BioinformaticsCore/MetagenomeDB/doc/conf.py',
#  'new_files/BioinformaticsCore/MetagenomeDB/lib/MetagenomeDB/tools/__init__.py',
#  'new_files/BioinformaticsCore/MetagenomeDB/lib/MetagenomeDB/utils/__init__.py',
#  'new_files/BioinformaticsCore/MetagenomeDB/lib/MetagenomeDB/utils/tree.py']

# %%
print(read_file_to_string("new_files/CoAxLab/DeBaCl/debacl/level_set_tree.py"))
# Out:
# """
# Main functions and classes for the DEnsity-BAsed CLustering (DeBaCl) toolbox.
# Includes functions to construct and modify level set trees, and level set tree
# methods for retrieving clusters and plotting.
# """
#
# ## Built-in packages
#
#
#
# import logging as _logging
# import copy as _copy
# import pickle as _pickle
# import debacl.utils as _utl
#
# _logging.basicConfig(level=_logging.INFO, datefmt='%Y-%m-%d %I:%M:%S',
#                      format='%(levelname)s (%(asctime)s): %(message)s')
#
# ## Required packages
# try:
#     import numpy as _np
#     import networkx as _nx
#     from prettytable import PrettyTable as _PrettyTable
# except:
#     raise ImportError("DeBaCl requires the numpy, networkx, and " +
#                       "prettytable packages.")
#
# ## Soft dependencies
# try:
#     import matplotlib.pyplot as _plt
#     from matplotlib.collections import LineCollection as _LineCollection
#     _HAS_MPL = True
# except:
#     _HAS_MPL = False
#     _logging.warning("Matplotlib could not be loaded, so DeBaCl plots will " +
#                      "fail.")
#
#
# class ConnectedComponent(object):
#     """
#     Define a connected component for level set tree construction. A level set
#     tree is really just a set of ConnectedComponent objects.
#     """
#
#     def __init__(self, idnum, parent, children, start_level, end_level,
#                  start_mass, end_mass, members):
#
#         self.idnum = idnum
#         self.parent = parent
#         self.children = children
#         self.start_level = start_level
#         self.end_level = end_level
#         self.start_mass = start_mass
#         self.end_mass = end_mass
#         self.members = members
#
#
# class LevelSetTree(object):
#     """
#     Level Set Tree attributes and methods. The level set tree is a collection
#     of connected components organized hierarchically, based on a density
#     estimate and connectivity graph.
#
#     .. warning::
#
#         LevelSetTree objects should not generally be instantiated directly,
#         because they will contain empty node hierarchies. Use the constructors
#         :func:`construct_tree` or :func:`construct_tree_from_graph` to
#         instantiate a LevelSetTree model.
#
#     Parameters
#     ----------
#     density : list[float] or numpy array
#         Estimated probability density for each point. This defines the order in
#         which the points are removed from the similarity graph as the Level Set
#         Tree is grown upward from the root.
#
#     levels : array_like
#         Probability density levels at which to find clusters. Defines the
#         vertical resolution of the tree.
#     """
#
#     def __init__(self, density=[], levels=[]):
#         self.density = density
#         self.levels = levels
#         self.num_levels = len(levels)
#         self.prune_threshold = None
#         self.nodes = {}
#         self._subgraphs = {}
#
#     def __repr__(self):
#         """
#         Print the tree summary table.
#         """
#         return self.__str__()
#
#     def __str__(self):
#         """
#         Print the tree summary table.
#         """
#         summary = _PrettyTable(["id", "start_level", "end_level", "start_mass",
#                                 "end_mass", "size", "parent", "children"])
#         for node_id, v in list(self.nodes.items()):
#             summary.add_row([node_id,
#                              v.start_level,
#                              v.end_level,
#                              v.start_mass,
#                              v.end_mass,
#                              len(v.members),
#                              v.parent,
#                              v.children])
#
#         for col in ["start_level", "end_level", "start_mass", "end_mass"]:
#             summary.float_format[col] = "5.3"
#
#         return summary.get_string()
#
#     def prune(self, threshold):
#         """
#         Prune the tree by recursively merging small leaf nodes into larger
#         sibling nodes. The LevelSetTree is *immutable*, so pruning returns a
#         new LevelSetTree whose nodes all contain more points than 'threshold'.
#
#         Parameters
#         ----------
#         threshold : int
#             Nodes smaller than this will be merged.
#
#         Returns
#         -------
#         out : LevelSetTree
#             A pruned level set tree. The original tree is unchanged.
#
#         Examples
#         --------
#         >>> X = numpy.random.rand(100, 2)
#         >>> tree = debacl.construct_tree(X, k=8, prune_threshold=2)
#         >>> tree2 = tree.prune(threshold=12)
#         """
#         return self._merge_by_size(threshold)
#
#     def save(self, filename):
#         """
#         Save a level set tree object to file. All members of the level set tree
#         are serialized with the `pickle` module.
#
#         Parameters
#         ----------
#         filename : str
#             File name for the saved tree. Any filename extension should work
#             (although operating system requirements still apply).
#
#         See Also
#         --------
#         load_tree
#
#         Examples
#         --------
#         >>> X = numpy.random.rand(100, 2)
#         >>> tree = debacl.construct_tree(X, k=8, prune_threshold=5)
#         >>> tree.save('my_tree')
#         """
#         with open(filename, 'wb') as f:
#             _pickle.dump(self, f, _pickle.HIGHEST_PROTOCOL)
#
#     def plot(self, form='mass', horizontal_spacing='uniform', color_nodes=[],
#              colormap='Dark2'):
#         """
#         Plot the level set tree as a dendrogram and return coordinates and
#         colors of the branches.
#
#         Parameters
#         ----------
#         form : {'mass', 'density', 'branch-mass'}, optional
#
#             Main form of the plot.
#
#             - 'density': the traditional form of the LST dendrogram where the
#               vertical scale is density levels.
#
#             - 'mass' (default): very similar to the 'density' form, but draws
#               the dendrogram based on the mass of upper (density) level sets.
#
#             - 'branch-mass': each node is drawn in the dendrogram so that its
#               length is proportional to its mass, *excluding* the masses of the
#               node's children. In this form, the lengths of the segments
#               representing the tree nodes sum to 1.
#
#         horizontal_spacing : {'uniform', 'proportional'}, optional
#             Determines how much horizontal space each level set tree node is
#             given. The default of "uniform" gives each child node an equal
#             fraction of the parent node's horizontal space. If set to
#             'proportional', then horizontal space is allocated proportionally
#             to the mass of a node relative to its siblings.
#
#         color_nodes : list, optional
#             Nodes to color in the level set tree. For each node, the subtree
#             for which that node is the root is drawn with a single color.
#
#         colormap : str, optional
#             Matplotlib colormap, used only if 'color_nodes' contains at least
#             one node index. Default is the 'Dark2' colormap. "Qualitative"
#             colormaps are highly recommended.
#
#         Returns
#         -------
#         fig : matplotlib figure
#             Use fig.show() to view, fig.savefig() to save, etc.
#
#         node_colors : dict
#             RGBA 4-tuple
#
#         node_coords : dict
#             Coordinates of vertical line segment endpoints representing LST
#             nodes.
#
#         split_coords : dict
#             Coordinates of horizontal line segment endpoints, representing
#             splits in the level set tree. There is a horizontal line segment
#             for *each* child in a split, and the keys in the 'split_coords'
#             dictionary indicate to which *child* the line segment belongs.
#
#         Examples
#         --------
#         >>> X = numpy.random.rand(100, 2)
#         >>> tree = debacl.construct_tree(X, k=8, prune_threshold=5)
#         >>> plot = tree.plot(form='density')
#         >>> fig = plot[0]
#         >>> fig.show()
#         """
#
#         ## Validate inputs
#         if not isinstance(color_nodes, list):
#             raise TypeError("The 'color_nodes' parameter must be a list.")
#
#         if not set(color_nodes).issubset(list(self.nodes.keys())):
#             raise ValueError("The 'color_nodes' parameter contains values " +
#                              "that do not correspond to tree nodes. This " +
#                              "tree's node indices are found in the first " +
#                              "column of the printed tree.")
#
#         ## Constants
#         gap = 0.05
#         min_node_width = 1.2
#
#         ## Initialize the plot containers
#         node_coords = {}
#         split_coords = {}
#
#         ## Find the root connected components and corresponding plot intervals
#         ix_root = _np.array([k for k, v in self.nodes.items()
#                              if v.parent is None])
#         n_root = len(ix_root)
#         census = _np.array([len(self.nodes[x].members) for x in ix_root],
#                            dtype=_np.float)
#         n = sum(census)
#
#         seniority = _np.argsort(census)[::-1]
#         ix_root = ix_root[seniority]
#         census = census[seniority]
#
#         if horizontal_spacing == 'proportional':
#             weights = census / n
#             intervals = _np.cumsum(weights)
#             intervals = _np.insert(intervals, 0, 0.0)
#         else:
#             intervals = _np.linspace(0.0, 1.0, n_root + 1)
#
#         ## Do a depth-first search on each root to get segments for each branch
#         for i, ix in enumerate(ix_root):
#             if form == 'branch-mass':
#                 branch = self._construct_mass_map(
#                     ix, 0.0, (intervals[i], intervals[i + 1]),
#                     horizontal_spacing)
#             else:
#                 branch = self._construct_branch_map(
#                     ix, (intervals[i], intervals[i + 1]), form,
#                     horizontal_spacing, sort=True)
#
#             branch_node_coords, branch_split_coords, _, _ = branch
#             node_coords.update(branch_node_coords)
#             split_coords.update(branch_split_coords)
#
#         ## Find the fraction of nodes in each segment (to use as line widths)
#         node_widths = {k: max(min_node_width, 12.0 * len(node.members) / n)
#                        for k, node in list(self.nodes.items())}
#
#         ## Get the relevant vertical ticks
#         primary_ticks = [(x[0][1], x[1][1]) for x in list(node_coords.values())]
#         primary_ticks = _np.unique(_np.array(primary_ticks).flatten())
#         primary_labels = [str(round(tick, 2)) for tick in primary_ticks]
#
#         ## Set up the plot framework
#         fig, ax = _plt.subplots()
#         ax.set_position([0.11, 0.05, 0.78, 0.93])
#         ax.set_xlim((-0.04, 1.04))
#         ax.set_xticks([])
#         ax.set_xticklabels([])
#         ax.yaxis.grid(color='gray')
#         ax.set_yticks(primary_ticks)
#         ax.set_yticklabels(primary_labels)
#
#         ## Form-specific details
#         if form == 'branch-mass':
#             kappa_max = max(primary_ticks)
#             ax.set_ylim((-1.0 * gap * kappa_max, 1.04 * kappa_max))
#             ax.set_ylabel("branch mass")
#
#         elif form == 'density':
#             ax.set_ylabel("density level")
#             ymin = min([v.start_level for v in self.nodes.values()])
#             ymax = max([v.end_level for v in self.nodes.values()])
#             rng = ymax - ymin
#             ax.set_ylim(ymin - gap * rng, ymax + 0.05 * rng)
#
#         elif form == 'mass':
#             ax.set_ylabel("mass level")
#             ymin = min([v.start_mass for v in self.nodes.values()])
#             ymax = max([v.end_mass for v in self.nodes.values()])
#             rng = ymax - ymin
#             ax.set_ylim(ymin - gap * rng, ymax + 0.05 * ymax)
#
#         else:
#             raise ValueError('Plot form not understood')
#
#         ## Color the line segments.
#         node_colors = {k: [0.0, 0.0, 0.0, 1.0] for k, v in list(self.nodes.items())}
#         palette = _plt.get_cmap(colormap)
#         colorset = palette(_np.linspace(0, 1, len(color_nodes)))
#
#         for i, ix in enumerate(color_nodes):
#             subtree = self._make_subtree(ix)
#
#             for ix_sub in list(subtree.nodes.keys()):
#                 node_colors[ix_sub] = list(colorset[i])
#
#         ## Add the line segments to the figure.
#         line_coords = [node_coords[c] for c in list(node_coords.keys())]
#         line_widths = [node_widths[c] for c in list(node_coords.keys())]
#         line_colors = [node_colors[c] for c in list(node_coords.keys())]
#
#         node_lines = _LineCollection(line_coords, linewidths=line_widths,
#                                      colors=line_colors)
#         ax.add_collection(node_lines)
#
#         line_coords = [split_coords[c] for c in list(split_coords.keys())]
#         line_colors = [node_colors[c] for c in list(split_coords.keys())]
#
#         split_lines = _LineCollection(line_coords, colors=line_colors)
#         ax.add_collection(split_lines)
#
#         return fig, node_coords, split_coords, node_colors
#
#     def get_clusters(self, method='leaf', fill_background=False, **kwargs):
#         """
#         Retrieve cluster labels from the level set tree. There are several ways
#         to do this with a level set tree, and a particular strategy can be
#         specified with the `method` parameter.
#
#         Parameters
#         ----------
#         method : {'leaf', 'first-k', 'upper-level-set', 'k-level'}, optional
#             Method for obtaining cluster labels from the tree.
#
#             - 'leaf': treat each leaf of the tree as a separate cluster.
#
#             - 'first-k': find the first K non-overlapping clusters from the
#               roots of the tree.
#
#             - 'upper-level-set': cluster by cutting the tree at a specified
#               density or mass level.
#
#             - 'k-level': returns clusters at the lowest density level that has
#               k nodes.
#
#         fill_background : bool, optional
#             If True, a label of -1 is assigned to background points, i.e. those
#             instances not otherwise assigned to a high-density cluster. If
#             False, the background points are omitted from the output.
#
#         Other Parameters
#         ----------------
#         k : int
#             If `method` is 'first-k' or 'k-level', this is the desired number
#             of clusters.
#
#         threshold : float
#             If `method` is 'upper-level-set', this is the threshold at which to
#             cut the tree.
#
#         form : {'density', 'mass'}
#             If `method` is 'upper-level-set', this is vertical scale which
#             'threshold' refers to.
#
#         Returns
#         -------
#         labels : 2-dimensional numpy array
#             Each row corresponds to an observation. The first column indicates
#             the index of the observation in the original data matrix, and the
#             second column is the index of the LST node to which the observation
#             belongs, *with respect to the clustering*. Note that the set of
#             observations in this "foreground" set is typically smaller than the
#             original dataset.
#
#         See Also
#         --------
#         debacl.utils.reindex_cluster_labels, get_leaf_nodes
#
#         Examples
#         --------
#         >>> X = numpy.random.rand(100, 2)
#         >>> tree = debacl.construct_tree(X, k=8, prune_threshold=5)
#         >>> labels = tree.get_clusters(method='leaf')
#         """
#
#         ## Retrieve foreground labels.
#         if method == 'leaf':
#             labels = self._leaf_cluster()
#
#         elif method == 'first-k':
#             required = set(['k'])
#             if not set(kwargs.keys()).issuperset(required):
#                 raise ValueError("Incorrect arguments for the first-k " +
#                                  "cluster labeling method.")
#             else:
#                 k = kwargs.get('k')
#                 labels = self._first_K_cluster(k)
#
#         elif method == 'upper-level-set':
#             required = set(['threshold', 'form'])
#             if not set(kwargs.keys()).issuperset(required):
#                 raise ValueError("Incorrect arguments for the upper-set " +
#                                  "cluster labeling method.")
#             else:
#                 threshold = kwargs.get('threshold')
#                 form = kwargs.get('form')
#                 labels = self._upper_set_cluster(threshold, form)
#
#         elif method == 'k-level':
#             required = set(['k'])
#             if not set(kwargs.keys()).issuperset(required):
#                 raise ValueError("Incorrect arguments for the k-level " +
#                                  "cluster labeling method.")
#             else:
#                 k = kwargs.get('k')
#                 labels = self._first_K_level_cluster(k)
#
#         else:
#             raise ValueError("Cluster labeling method not understood.")
#
#         ## If requested, fill in the background labels with -1
#         if fill_background:
#             n = len(self.density)
#             full_labels = _np.vstack((_np.arange(n), [-1] * n)).T
#             full_labels[labels[:, 0], 1] = labels[:, 1]
#             labels = full_labels
#
#         return labels
#
#     def get_leaf_nodes(self):
#         """
#         Return the indices of leaf nodes in the level set tree.
#
#         Returns
#         -------
#         leaves : list
#             List of LST leaf node indices.
#
#         See Also
#         --------
#         get_clusters
#
#         Examples
#         --------
#         >>> X = numpy.random.rand(100, 2)
#         >>> tree = debacl.construct_tree(X, k=8, prune_threshold=5)
#         >>> leaves = tree.get_leaf_nodes()
#         >>> print(leaves)
#         [1, 5, 6]
#         """
#         return [k for k, v in list(self.nodes.items()) if v.children == []]
#
#     def branch_partition(self):
#         """
#         Partition the input data. Each instance's assigned label is the index
#         of the *highest density* node to which the point belongs. This is
#         similar to retrieving high-density clusters with background points
#         labeled, except here the background points are labeled according to
#         their internal node membership as well (not just that they're
#         background points).
#
#         Returns
#         -------
#         labels : 2-dimensional numpy array
#             Each row corresponds to an observation. The first column indicates
#             the index of the observation in the original data matrix, and the
#             second column is the index of the LST node to which the observation
#             belongs.
#
#         See Also
#         --------
#         get_clusters
#
#         Examples
#         --------
#         >>> X = numpy.random.rand(100, 2)
#         >>> tree = debacl.construct_tree(X, k=8, prune_threshold=5)
#         >>> labels = tree.branch_partition()
#         """
#         points = []
#         labels = []
#
#         for ix, node in list(self.nodes.items()):
#             branch_members = node.members.copy()
#
#             for ix_child in node.children:
#                 child_node = self.nodes[ix_child]
#                 branch_members.difference_update(child_node.members)
#
#             points.extend(branch_members)
#             labels += ([ix] * len(branch_members))
#
#         partition = _np.array([points, labels], dtype=_np.int).T
#         return partition
#
#     def _make_subtree(self, ix):
#         """
#         Return the subtree with node 'ix' as the root, and all ancestors of
#         'ix'.
#
#         Parameters
#         ----------
#         ix : int
#             Node to use at the root of the new tree.
#
#         Returns
#         -------
#         T : LevelSetTree
#             A completely independent level set tree, with 'ix' as the root
#             node.
#         """
#
#         T = LevelSetTree()
#         T.nodes[ix] = _copy.deepcopy(self.nodes[ix])
#         T.nodes[ix].parent = None
#         queue = self.nodes[ix].children[:]
#
#         while len(queue) > 0:
#             branch_ix = queue.pop()
#             T.nodes[branch_ix] = self.nodes[branch_ix]
#             queue += self.nodes[branch_ix].children
#
#         return T
#
#     def _merge_by_size(self, threshold):
#         """
#         Prune splits from a tree based on size of child nodes. Merge members of
#         child nodes rather than removing them.
#
#         Parameters
#         ----------
#         threshold : numeric
#             Tree branches with fewer members than this will be merged into
#             larger siblings or parents.
#
#         Returns
#         -------
#         tree : LevelSetTree
#             A pruned level set tree. The original tree is unchanged.
#         """
#
#         tree = _copy.deepcopy(self)
#         tree.prune_threshold = threshold
#
#         ## remove small root branches
#         small_roots = [k for k, v in tree.nodes.items()
#                        if v.parent is None and len(v.members) <= threshold]
#
#         for root in small_roots:
#             root_tree = tree._make_subtree(root)
#             for ix in root_tree.nodes.keys():
#                 del tree.nodes[ix]
#
#         ## main pruning
#         parents = [k for k, v in tree.nodes.items()
#                    if len(v.children) >= 1]
#         parents = _np.sort(parents)[::-1]
#
#         for ix_parent in parents:
#             parent = tree.nodes[ix_parent]
#
#             # get size of each child
#             kid_size = {k: len(tree.nodes[k].members) for k in parent.children}
#
#             # count children larger than 'threshold'
#             n_bigkid = sum(_np.array(list(kid_size.values())) >= threshold)
#
#             if n_bigkid == 0:
#                 # update parent's end level and end mass
#                 parent.end_level = max([tree.nodes[k].end_level
#                                         for k in parent.children])
#                 parent.end_mass = max([tree.nodes[k].end_mass
#                                        for k in parent.children])
#
#                 # remove small kids from the tree
#                 for k in parent.children:
#                     del tree.nodes[k]
#                 parent.children = []
#
#             elif n_bigkid == 1:
#                 pass
#                 # identify the big kid
#                 ix_bigkid = [k for k, v in kid_size.items()
#                              if v >= threshold][0]
#                 bigkid = tree.nodes[ix_bigkid]
#
#                 # update k's end level and end mass
#                 parent.end_level = bigkid.end_level
#                 parent.end_mass = bigkid.end_mass
#
#                 # set grandkids' parent to k
#                 for c in bigkid.children:
#                     tree.nodes[c].parent = ix_parent
#
#                 # delete small kids
#                 for k in parent.children:
#                     if k != ix_bigkid:
#                         del tree.nodes[k]
#
#                 # set k's children to grandkids
#                 parent.children = bigkid.children
#
#                 # delete the single big kid
#                 del tree.nodes[ix_bigkid]
#
#             else:
#                 pass  # do nothing here
#
#         return tree
#
#     def _leaf_cluster(self):
#         """
#         Set every leaf node as a foreground cluster.
#
#         Returns
#         -------
#         labels : 2-dimensional numpy array
#             Each row corresponds to an observation. The first column indicates
#             the index of the observation in the original data matrix, and the
#             second column is the integer cluster label (starting at 0). Note
#             that the set of observations in this "foreground" set is typically
#             smaller than the original dataset.
#
#         leaves : list
#             Indices of tree nodes corresponding to foreground clusters. This is
#             the same as 'nodes' for other clustering functions, but here they
#             are also the leaves of the tree.
#         """
#
#         leaves = self.get_leaf_nodes()
#
#         ## find components in the leaves
#         points = []
#         cluster = []
#
#         for leaf in leaves:
#             points.extend(self.nodes[leaf].members)
#             cluster += ([leaf] * len(self.nodes[leaf].members))
#
#         labels = _np.array([points, cluster], dtype=_np.int).T
#         return labels
#
#     def _first_K_cluster(self, k):
#         """
#         Returns foreground cluster labels for the 'k' modes with the lowest
#         start levels. In principle, this is the 'k' leaf nodes with the
#         smallest indices, but this function double checks by finding and
#         ordering all leaf start values and ordering.
#
#         Parameters
#         ----------
#         k : int
#             The desired number of clusters.
#
#         Returns
#         -------
#         labels : 2-dimensional numpy array
#             Each row corresponds to an observation. The first column indicates
#             the index of the observation in the original data matrix, and the
#             second column is the integer cluster label (starting at 0). Note
#             that the set of observations in this "foreground" set is typically
#             smaller than the original dataset.
#
#         nodes : list
#             Indices of tree nodes corresponding to foreground clusters.
#         """
#
#         parents = _np.array([u for u, v in list(self.nodes.items())
#                              if len(v.children) > 0])
#         roots = [u for u, v in list(self.nodes.items()) if v.parent is None]
#         splits = [self.nodes[u].end_level for u in parents]
#         order = _np.argsort(splits)
#         star_parents = parents[order[:(k - len(roots))]]
#
#         children = [u for u, v in list(self.nodes.items()) if v.parent is None]
#         for u in star_parents:
#             children += self.nodes[u].children
#
#         nodes = [x for x in children if
#                  sum(_np.in1d(self.nodes[x].children, children)) == 0]
#
#         points = []
#         cluster = []
#
#         for c in nodes:
#             cluster_pts = self.nodes[c].members
#             points.extend(cluster_pts)
#             cluster += ([c] * len(cluster_pts))
#
#         labels = _np.array([points, cluster], dtype=_np.int).T
#         return labels
#
#     def _upper_set_cluster(self, threshold, form='mass'):
#         """
#         Set foreground clusters by finding connected components at an upper
#         level set or upper mass set.
#
#         Parameters
#         ----------
#         threshold : float
#             The level or mass value that defines the foreground set of points,
#             depending on 'form'.
#
#         form : {'mass', 'density'}
#             Determines if the 'cut' threshold is a density level value or a
#             mass value (i.e. fraction of data in the background set)
#
#         Returns
#         -------
#         labels : 2-dimensional numpy array
#             Each row corresponds to an observation. The first column indicates
#             the index of the observation in the original data matrix, and the
#             second column is the integer cluster label (starting at 0). Note
#             that the set of observations in this "foreground" set is typically
#             smaller than the original dataset.
#
#         nodes : list
#             Indices of tree nodes corresponding to foreground clusters.
#         """
#
#         ## identify upper level points and the nodes active at the cut
#         if form == 'mass':
#             density_level = self._mass_to_density(mass=threshold)
#             return self._upper_set_cluster(threshold=density_level,
#                                            form='density')
#
#         else:
#             upper_level_set = _np.where(_np.array(self.density) > threshold)[0]
#             active_nodes = [k for k, v in self.nodes.items()
#                             if (v.start_level <= threshold and
#                                 v.end_level > threshold)]
#
#             ## find intersection between upper set points and each active
#             #  component
#             points = []
#             cluster = []
#
#             for c in active_nodes:
#                 cluster_mask = _np.in1d(upper_level_set,
#                                         list(self.nodes[c].members))
#                 cluster_pts = upper_level_set[cluster_mask]
#                 points.extend(cluster_pts)
#                 cluster += ([c] * len(cluster_pts))
#
#             labels = _np.array([points, cluster], dtype=_np.int).T
#             return labels
#
#     def _first_K_level_cluster(self, k):
#         """
#         Use the first K clusters to appear in the level set tree as foreground
#         clusters. In general, K-1 clusters will appear at a lower level than
#         the K'th cluster; this function returns all members from all K clusters
#         (rather than only the members in the upper level set where the K'th
#         cluster appears). There are not always K clusters available in a level
#         set tree - see LevelSetTree.findKCut for details on default behavior in
#         this case.
#
#         Parameters
#         ----------
#         k : int
#             Desired number of clusters.
#
#         Returns
#         -------
#         labels : 2-dimensional numpy array
#             Each row corresponds to an observation. The first column indicates
#             the index of the observation in the original data matrix, and the
#             second column is the integer cluster label (starting at 0). Note
#             that the set of observations in this "foreground" set is typically
#             smaller than the original dataset.
#
#         nodes : list
#             Indices of tree nodes corresponding to foreground clusters.
#         """
#
#         cut = self._find_K_cut(k)
#         nodes = [e for e, v in self.nodes.items()
#                  if v.start_level <= cut and v.end_level > cut]
#
#         points = []
#         cluster = []
#
#         for c in nodes:
#
#             cluster_pts = self.nodes[c].members
#             points.extend(cluster_pts)
#             cluster += ([c] * len(cluster_pts))
#
#         labels = _np.array([points, cluster], dtype=_np.int).T
#         return labels
#
#     def _collapse_leaves(self, active_nodes):
#         """
#         Removes descendant nodes for the branches in 'active_nodes'.
#
#         Parameters
#         ----------
#         active_nodes : array-like
#             List of nodes to use as the leaves in the collapsed tree.
#
#         Returns
#         -------
#         """
#
#         for ix in active_nodes:
#             subtree = self._make_subtree(ix)
#
#             max_end_level = max([v.end_level for v in list(subtree.nodes.values())])
#             max_end_mass = max([v.end_mass for v in list(subtree.nodes.values())])
#
#             self.nodes[ix].end_level = max_end_level
#             self.nodes[ix].end_mass = max_end_mass
#             self.nodes[ix].children = []
#
#             for u in list(subtree.nodes.keys()):
#                 if u != ix:
#                     del self.nodes[u]
#
#     def _find_K_cut(self, k):
#         """
#         Find the lowest level cut that has k connected components. If there are
#         no levels that have k components, then find the lowest level that has
#         at least k components. If no levels have > k components, find the
#         lowest level that has the maximum number of components.
#
#         Parameters
#         ----------
#         k : int
#             Desired number of clusters/nodes/components.
#
#         Returns
#         -------
#         cut : float
#             Lowest density level where there are k nodes.
#         """
#
#         ## Find the lowest level to cut at that has k or more clusters
#         starts = [v.start_level for v in self.nodes.values()]
#         ends = [v.end_level for v in self.nodes.values()]
#         crits = _np.unique(starts + ends)
#         nclust = {}
#
#         for c in crits:
#             nclust[c] = len([e for e, v in self.nodes.items()
#                              if v.start_level <= c and v.end_level > c])
#
#         width = _np.max(list(nclust.values()))
#
#         if k in list(nclust.values()):
#             cut = _np.min([e for e, v in nclust.items() if v == k])
#         else:
#             if width < k:
#                 cut = _np.min([e for e, v in nclust.items() if v == width])
#             else:
#                 ktemp = _np.min([v for v in nclust.values() if v > k])
#                 cut = _np.min([e for e, v in nclust.items() if v == ktemp])
#
#         return cut
#
#     def _construct_branch_map(self, ix, interval, form, horizontal_spacing,
#                               sort):
#         """
#         Map level set tree nodes to locations in a plot canvas. Finds the plot
#         coordinates of vertical line segments corresponding to LST nodes and
#         horizontal line segments corresponding to node splits. Also provides
#         indices of vertical segments and splits for downstream use with
#         interactive plot picker tools. This function is not meant to be called
#         by the user; it is a helper function for the LevelSetTree.plot()
#         method. This function is recursive: it calls itself to map the
#         coordinates of children of the current node 'ix'.
#
#         Parameters
#         ----------
#         ix : int
#             The tree node to map.
#
#         interval: length 2 tuple of floats
#             Horizontal space allocated to node 'ix'.
#
#         form : {'density', 'mass'}, optional
#
#         horizontal_spacing : {'uniform', 'proportional'}, optional
#             Determines how much horizontal space each level set tree node is
#             given. See LevelSetTree.plot() for more information.
#
#         sort : bool
#             If True, sort sibling nodes from most to least points and draw left
#             to right. Also sorts root nodes in the same way.
#
#         Returns
#         -------
#         segments : dict
#             A dictionary with values that contain the coordinates of vertical
#             line segment endpoints. This is only useful to the interactive
#             analysis tools.
#
#         segmap : list
#             Indicates the order of the vertical line segments as returned by
#             the recursive coordinate mapping function, so they can be picked by
#             the user in the interactive tools.
#
#         splits : dict
#             Dictionary values contain the coordinates of horizontal line
#             segments (i.e. node splits).
#
#         splitmap : list
#             Indicates the order of horizontal line segments returned by
#             recursive coordinate mapping function, for use with interactive
#             tools.
#         """
#
#         ## get children
#         children = _np.array(self.nodes[ix].children)
#         n_child = len(children)
#
#         ## if there's no children, just one segment at the interval mean
#         if n_child == 0:
#             xpos = _np.mean(interval)
#             segments = {}
#             segmap = [ix]
#             splits = {}
#             splitmap = []
#
#             if form == 'density':
#                 segments[ix] = (
#                     ([xpos, self.nodes[ix].start_level],
#                      [xpos, self.nodes[ix].end_level]))
#             else:
#                 segments[ix] = (
#                     ([xpos, self.nodes[ix].start_mass],
#                      [xpos, self.nodes[ix].end_mass]))
#
#         ## else, construct child branches then figure out parent's
#         ## position
#         else:
#             parent_range = interval[1] - interval[0]
#             segments = {}
#             segmap = [ix]
#             splits = {}
#             splitmap = []
#
#             census = _np.array([len(self.nodes[x].members) for x in children],
#                                dtype=_np.float)
#             weights = census / sum(census)
#
#             if sort is True:
#                 seniority = _np.argsort(weights)[::-1]
#                 children = children[seniority]
#                 weights = weights[seniority]
#
#             ## get relative branch intervals
#             if horizontal_spacing == 'uniform':
#                 child_intervals = _np.cumsum(weights)
#                 child_intervals = _np.insert(child_intervals, 0, 0.0)
#
#             elif horizontal_spacing == 'proportional':
#                 child_intervals = _np.linspace(0.0, 1.0, n_child + 1)
#
#             else:
#                 raise ValueError("'horizontal_spacing' argument not " +
#                                  "understood. 'horizontal_spacing' " +
#                                  "must be either 'uniform' or 'proportional'.")
#
#             ## loop over the children
#             for j, child in enumerate(children):
#
#                 ## translate local interval to absolute interval
#                 branch_interval = (
#                     interval[0] + child_intervals[j] * parent_range,
#                     interval[0] + child_intervals[j + 1] * parent_range)
#
#                 ## recurse on the child
#                 branch = self._construct_branch_map(child, branch_interval,
#                                                     form, horizontal_spacing,
#                                                     sort)
#                 branch_segs, branch_splits, branch_segmap, \
#                     branch_splitmap = branch
#
#                 segmap += branch_segmap
#                 splitmap += branch_splitmap
#                 splits = dict(list(splits.items()) + list(branch_splits.items()))
#                 segments = dict(list(segments.items()) + list(branch_segs.items()))
#
#             ## find the middle of the children's x-position and make vertical
#             #  segment ix
#             children_xpos = _np.array([segments[k][0][0] for k in children])
#             xpos = _np.mean(children_xpos)
#
#             ## add horizontal segments to the list
#             for child in children:
#                 splitmap.append(child)
#                 child_xpos = segments[child][0][0]
#
#                 if form == 'density':
#                     splits[child] = (
#                         [xpos, self.nodes[ix].end_level],
#                         [child_xpos, self.nodes[ix].end_level])
#                 else:
#                     splits[child] = (
#                         [xpos, self.nodes[ix].end_mass],
#                         [child_xpos, self.nodes[ix].end_mass])
#
#             ## add vertical segment for current node
#             if form == 'density':
#                 segments[ix] = (
#                     ([xpos, self.nodes[ix].start_level],
#                      [xpos, self.nodes[ix].end_level]))
#             else:
#                 segments[ix] = (
#                     ([xpos, self.nodes[ix].start_mass],
#                      [xpos, self.nodes[ix].end_mass]))
#
#         return segments, splits, segmap, splitmap
#
#     def _construct_mass_map(self, ix, start_pile, interval,
#                             horizontal_spacing):
#         """
#         Map level set tree nodes to locations in a plot canvas. Finds the plot
#         coordinates of vertical line segments corresponding to LST nodes and
#         horizontal line segments corresponding to node splits. Also provides
#         indices of vertical segments and splits for downstream use with
#         interactive plot picker tools. This function is not meant to be called
#         by the user; it is a helper function for the LevelSetTree.plot()
#         method. This function is recursive: it calls itself to map the
#         coordinates of children of the current node 'ix'. Differs from
#         'constructBranchMap' by setting the height of each vertical segment to
#         be proportional to the number of points in the corresponding LST node.
#
#         Parameters
#         ----------
#         ix : int
#             The tree node to map.
#
#         start_pile: float
#             The height of the branch on the plot at it's start (i.e. lower
#             terminus).
#
#         interval: length 2 tuple of floats
#             Horizontal space allocated to node 'ix'.
#
#         horizontal_spacing : {'uniform', 'proportional'}, optional
#             Determines how much horizontal space each level set tree node is
#             given. See LevelSetTree.plot() for more information.
#
#         Returns
#         -------
#         segments : dict
#             A dictionary with values that contain the coordinates of vertical
#             line segment endpoints. This is only useful to the interactive
#             analysis tools.
#
#         segmap : list
#             Indicates the order of the vertical line segments as returned by
#             the recursive coordinate mapping function, so they can be picked by
#             the user in the interactive tools.
#
#         splits : dict
#             Dictionary values contain the coordinates of horizontal line
#             segments (i.e. node splits).
#
#         splitmap : list
#             Indicates the order of horizontal line segments returned by
#             recursive coordinate mapping function, for use with interactive
#             tools.
#         """
#
#         size = float(len(self.nodes[ix].members))
#
#         ## get children
#         children = _np.array(self.nodes[ix].children)
#         n_child = len(children)
#
#         ## if there's no children, just one segment at the interval mean
#         if n_child == 0:
#             xpos = _np.mean(interval)
#             end_pile = start_pile + size / len(self.density)
#             segments = {}
#             segmap = [ix]
#             splits = {}
#             splitmap = []
#             segments[ix] = ([xpos, start_pile], [xpos, end_pile])
#
#         else:
#             parent_range = interval[1] - interval[0]
#             segments = {}
#             segmap = [ix]
#             splits = {}
#             splitmap = []
#
#             census = _np.array([len(self.nodes[x].members) for x in children],
#                                dtype=_np.float)
#             weights = census / sum(census)
#
#             seniority = _np.argsort(weights)[::-1]
#             children = children[seniority]
#             weights = weights[seniority]
#
#             ## get relative branch intervals
#             if horizontal_spacing == 'proportional':
#                 child_intervals = _np.cumsum(weights)
#                 child_intervals = _np.insert(child_intervals, 0, 0.0)
#             else:
#                 child_intervals = _np.linspace(0.0, 1.0, n_child + 1)
#
#             ## find height of the branch
#             end_pile = start_pile + (size - sum(census)) / len(self.density)
#
#             ## loop over the children
#             for j, child in enumerate(children):
#
#                 ## translate local interval to absolute interval
#                 branch_interval = (
#                     interval[0] + child_intervals[j] * parent_range,
#                     interval[0] + child_intervals[j + 1] * parent_range)
#
#                 ## recurse on the child
#                 branch = self._construct_mass_map(child, end_pile,
#                                                   branch_interval,
#                                                   horizontal_spacing)
#                 branch_segs, branch_splits, branch_segmap, \
#                     branch_splitmap = branch
#
#                 segmap += branch_segmap
#                 splitmap += branch_splitmap
#                 splits = dict(list(splits.items()) + list(branch_splits.items()))
#                 segments = dict(list(segments.items()) + list(branch_segs.items()))
#
#             ## find the middle of the children's x-position and make vertical
#             ## segment ix
#             children_xpos = _np.array([segments[k][0][0] for k in children])
#             xpos = _np.mean(children_xpos)
#
#             ## add horizontal segments to the list
#             for child in children:
#                 splitmap.append(child)
#                 child_xpos = segments[child][0][0]
#                 splits[child] = ([xpos, end_pile], [child_xpos, end_pile])
#
#             ## add vertical segment for current node
#             segments[ix] = ([xpos, start_pile], [xpos, end_pile])
#
#         return segments, splits, segmap, splitmap
#
#     def _mass_to_density(self, mass):
#         """
#         Convert the specified mass level value into a density level value.
#
#         Parameters
#         ----------
#         mass : float
#             Float in the interval [0.0, 1.0], with the desired fraction of all
#             points.
#
#         Returns
#         -------
#         level: float
#             Density level corresponding to the 'mass' fraction of background
#             points.
#         """
#         density_order = _np.argsort(self.density)
#         n = len(self.density)
#         mass_fraction = max(0, int(round(mass * n)) - 1)
#         level_index = density_order[mass_fraction]
#         level = self.density[level_index]
#
#         return level
#
#
# #############################################
# ### LEVEL SET TREE CONSTRUCTION FUNCTIONS ###
# #############################################
# def construct_tree(X, k, prune_threshold=None, num_levels=None, verbose=False):
#     """
#     Construct a level set tree from tabular data.
#
#     Parameters
#     ----------
#     X : 2-dimensional numpy array
#         Numeric dataset, where each row represents one observation.
#
#     k : int
#         Number of observations to consider as neighbors to a given point.
#
#     prune_threshold : int, optional
#         Leaf nodes with fewer than this number of members are recursively
#         merged into larger nodes. If 'None' (the default), then no pruning
#         is performed.
#
#     num_levels : int, optional
#         Number of density levels in the constructed tree. If None (default),
#         `num_levels` is internally set to be the number of rows in `X`.
#
#     verbose : bool, optional
#         If True, a progress indicator is printed at every 100th level of tree
#         construction.
#
#     Returns
#     -------
#     T : LevelSetTree
#         A pruned level set tree.
#
#     See Also
#     --------
#     construct_tree_from_graph, LevelSetTree
#
#     Examples
#     --------
#     >>> X = numpy.random.rand(100, 2)
#     >>> tree = debacl.construct_tree(X, k=8, prune_threshold=5)
#     >>> print(tree)
#     +----+-------------+-----------+------------+----------+------+--------+----------+
#     | id | start_level | end_level | start_mass | end_mass | size | parent | children |
#     +----+-------------+-----------+------------+----------+------+--------+----------+
#     | 0  |    0.000    |   0.870   |   0.000    |  0.450   | 100  |  None  |  [3, 4]  |
#     | 3  |    0.870    |   3.364   |   0.450    |  0.990   |  17  |   0    |    []    |
#     | 4  |    0.870    |   1.027   |   0.450    |  0.520   |  35  |   0    |  [7, 8]  |
#     | 7  |    1.027    |   1.755   |   0.520    |  0.870   |  8   |   4    |    []    |
#     | 8  |    1.027    |   3.392   |   0.520    |  1.000   |  23  |   4    |    []    |
#     +----+-------------+-----------+------------+----------+------+--------+----------+
#     """
#
#     sim_graph, radii = _utl.knn_graph(X, k, method='brute_force')
#
#     n, p = X.shape
#     density = _utl.knn_density(radii, n, p, k)
#
#     tree = construct_tree_from_graph(adjacency_list=sim_graph, density=density,
#                                      prune_threshold=prune_threshold,
#                                      num_levels=num_levels, verbose=verbose)
#
#     return tree
#
#
# def construct_tree_from_graph(adjacency_list, density, prune_threshold=None,
#                               num_levels=None, verbose=False):
#     """
#     Construct a level set tree from a similarity graph and a density estimate.
#
#     Parameters
#     ----------
#     adjacency_list : list [list]
#         Adjacency list of the k-nearest neighbors graph on the data. Each entry
#         contains the indices of the `k` closest neighbors to the data point at
#         the same row index.
#
#     density : list [float]
#         Estimate of the density function, evaluated at the data points
#         represented by the keys in `adjacency_list`.
#
#     prune_threshold : int, optional
#         Leaf nodes with fewer than this number of members are recursively
#         merged into larger nodes. If 'None' (the default), then no pruning
#         is performed.
#
#     num_levels : list int, optional
#         Number of density levels in the constructed tree. If None (default),
#         `num_levels` is internally set to be the number of rows in `X`.
#
#     verbose : bool, optional
#         If True, a progress indicator is printed at every 100th level of tree
#         construction.
#
#     Returns
#     -------
#     T : levelSetTree
#         See the LevelSetTree class for attributes and method definitions.
#
#     See Also
#     --------
#     construct_tree, LevelSetTree
#
#     Examples
#     --------
#     >>> X = numpy.random.rand(100, 2)
#     >>> knn_graph, radii = debacl.utils.knn_graph(X, k=8)
#     >>> density = debacl.utils.knn_density(radii, n=100, p=2, k=8)
#     >>> tree = debacl.construct_tree_from_graph(knn_graph, density,
#     ...                                         prune_threshold=5)
#     >>> print(tree)
#     +----+-------------+-----------+------------+----------+------+--------+----------+
#     | id | start_level | end_level | start_mass | end_mass | size | parent | children |
#     +----+-------------+-----------+------------+----------+------+--------+----------+
#     | 0  |    0.000    |   0.768   |   0.000    |  0.390   | 100  |  None  |  [1, 2]  |
#     | 1  |    0.768    |   1.494   |   0.390    |  0.790   |  30  |   0    |  [7, 8]  |
#     | 2  |    0.768    |   4.812   |   0.390    |  1.000   |  31  |   0    |    []    |
#     | 7  |    1.494    |   2.375   |   0.790    |  0.950   |  6   |   1    |    []    |
#     | 8  |    1.494    |   2.308   |   0.790    |  0.940   |  5   |   1    |    []    |
#     +----+-------------+-----------+------------+----------+------+--------+----------+
#     """
#
#     ## Initialize the graph and cluster tree
#     levels = _utl.define_density_mass_grid(density, num_levels=num_levels)
#
#     G = _nx.from_dict_of_lists(
#         {i: neighbors for i, neighbors in enumerate(adjacency_list)})
#
#     T = LevelSetTree(density, levels)
#
#     ## Figure out roots of the tree
#     cc0 = _nx.connected_components(G)
#
#     for i, c in enumerate(cc0):  # c is only the vertex list, not the subgraph
#         T._subgraphs[i] = G.subgraph(c)
#         T.nodes[i] = ConnectedComponent(
#             i, parent=None, children=[], start_level=0., end_level=None,
#             start_mass=0., end_mass=None, members=c)
#
#     # Loop through the removal grid
#     previous_level = 0.
#     n = float(len(adjacency_list))
#
#     for i, level in enumerate(levels):
#         if verbose and i % 100 == 0:
#             _logging.info("iteration {}".format(i))
#
#         ## figure out which points to remove, i.e. the background set.
#         bg = _np.where((density > previous_level) & (density <= level))[0]
#         previous_level = level
#
#         ## compute the mass after the current bg set is removed
#         old_vcount = sum([x.number_of_nodes()
#                           for x in T._subgraphs.values()])
#         current_mass = 1. - ((old_vcount - len(bg)) / n)
#
#         # loop through active components, i.e. subgraphs
#         deactivate_keys = []     # subgraphs to deactivate at the iter end
#         activate_subgraphs = {}  # new subgraphs to add at the end of the iter
#
#         for (k, H) in T._subgraphs.items():
#
#             ## remove nodes at the current level
#             H.remove_nodes_from(bg)
#
#             ## check if subgraph has vanished
#             if H.number_of_nodes() == 0:
#                 T.nodes[k].end_level = level
#                 T.nodes[k].end_mass = current_mass
#                 deactivate_keys.append(k)
#
#             else:  # subgraph hasn't vanished
#
#                 ## check if subgraph now has multiple connected components
#                 # NOTE: this is *the* bottleneck
#                 if not _nx.is_connected(H):
#
#                     ## deactivate the parent subgraph
#                     T.nodes[k].end_level = level
#                     T.nodes[k].end_mass = current_mass
#                     deactivate_keys.append(k)
#
#                     ## start a new subgraph & node for each child component
#                     cc = _nx.connected_components(H)
#
#                     for c in cc:
#                         new_key = max(T.nodes.keys()) + 1
#                         T.nodes[k].children.append(new_key)
#                         activate_subgraphs[new_key] = H.subgraph(c)
#
#                         T.nodes[new_key] = ConnectedComponent(
#                             new_key, parent=k, children=[], start_level=level,
#                             end_level=None, start_mass=current_mass,
#                             end_mass=None, members=c)
#
#         # update active components
#         for k in deactivate_keys:
#             del T._subgraphs[k]
#
#         T._subgraphs.update(activate_subgraphs)
#
#     ## Prune the tree
#     if prune_threshold is not None:
#         T = T.prune(threshold=prune_threshold)
#
#     return T
#
#
# def load_tree(filename):
#     """
#     Load a saved tree from file.
#
#     Parameters
#     ----------
#     filename : str
#         Filename to load.
#
#     Returns
#     -------
#     T : LevelSetTree
#         The loaded and reconstituted level set tree object.
#
#     See Also
#     --------
#     LevelSetTree.save
#
#     Examples
#     --------
#     >>> X = numpy.random.rand(100, 2)
#     >>> tree = debacl.construct_tree(X, k=8, prune_threshold=5)
#     >>> tree.save('my_tree')
#     >>> tree2 = debacl.load_tree('my_tree')
#     """
#     with open(filename, 'rb') as f:
#         T = _pickle.load(f)
#
#     return T

# %%
files[:10]
# Out:
# ['new_files/fingerping.py',
#  'new_files/CoAxLab/DeBaCl/docs/conf.py',
#  'new_files/CoAxLab/DeBaCl/debacl/level_set_tree.py',
#  'new_files/ClockworkNet/wtop/robots/create_robots_resources.py',
#  'new_files/ClockworkNet/wtop/robots/compare_robots_configs.py',
#  'new_files/ClockworkNet/wtop/robots/trie.py',
#  'new_files/BioinformaticsCore/MetagenomeDB/doc/conf.py',
#  'new_files/BioinformaticsCore/MetagenomeDB/lib/MetagenomeDB/tools/__init__.py',
#  'new_files/BioinformaticsCore/MetagenomeDB/lib/MetagenomeDB/utils/__init__.py',
#  'new_files/BioinformaticsCore/MetagenomeDB/lib/MetagenomeDB/utils/tree.py']

# %%
for source, tokens, comments, scope, pairs in data:
    print(tokens)
    print(comments)
    for pair in pairs:
        print(pair)
# Out:
# ['<nl>', 'def', 'gamma', '(', 'image', ')', ':', '\n', '<indent>', 'pixel', '=', 'image', '.', 'getPixelRgb', '(', '120', ',', '140', ')', '\n', 'if', 'pixel', '[', '0', ']', '+', 'pixel', '[', '1', ']', '+', 'pixel', '[', '2', ']', '<', '96', ':', '\n', '<indent>', 'return', '11', '\n', '<dedent>', 'else', ':', '\n', '<indent>', 'chunk', '=', 'image', '.', 'getChunk', '(', '"str"', ')', '\n', 'if', 'chunk', '==', 'None', ':', '\n', '<indent>', 'return', '12', '\n', '<dedent>', 'gammav', '=', 'unpack', '(', '"str"', ',', 'chunk', '.', 'content', ')', '\n', 'if', 'gammav', '[', '0', ']', '==', '400000', ':', '\n', '<indent>', 'return', '13', '\n', '<dedent>', 'return', '14', '\n', '<dedent>', '<dedent>', '<endf>']
# [[-1, '# Fingerprint depending on how the decoder treated the gamma information from the input image']]
# ['image', 'chunk', 11, [4, 50]]
# ['chunk', 'gammav', 58, [48, 74]]
# ['pixel', 'image', 31, [9, 21, 26]]
# ['image', 'chunk', 50, [4, 11]]
# ['chunk', 'gammav', 74, [48, 58]]
# ['gammav', 'chunk', 80, [68]]
# ['pixel', 'chunk', 21, [9, 26, 31]]
# ['pixel', 'chunk', 26, [9, 21, 31]]
# ['<nl>', 'def', 'physChunk', '(', 'image', ')', ':', '\n', '<indent>', 'chunk', '=', 'image', '.', 'getChunk', '(', '"str"', ')', '\n', 'if', 'chunk', '==', 'None', ':', '\n', '<indent>', 'return', '11', '\n', '<dedent>', 'x', ',', 'y', ',', 'u', '=', 'unpack', '(', '"str"', ',', 'chunk', '.', 'content', ')', '\n', 'if', 'x', '==', '1', ':', '\n', '<indent>', 'return', '12', '\n', '<dedent>', 'if', 'x', '==', '1500', ':', '\n', '<indent>', 'return', '13', '\n', '<dedent>', 'if', 'x', '==', '1499', ':', '\n', '<indent>', 'return', '14', '\n', '<dedent>', 'return', '15', '\n', '<dedent>', '<endf>']
# [[-1, '# Fingerprint depending on how the decoder treated the phys information in the input image'], [74, '# .net ']]
# ['chunk', 'image', 19, [9, 39]]
# ['x', 'y', 45, [29, 56, 67]]
# ['x', 'y', 56, [29, 45, 67]]
# ['x', 'image', 67, [29, 45, 56]]
# ['image', 'u', 11, [4]]
# ['chunk', 'u', 39, [9, 19]]
# ['<nl>', 'def', 'doTests', '(', 'tests', ',', 'fingerprints', ',', 'warn', ')', ':', '\n', '<nl>', '"str"', '\n', '<indent>', 'results', '=', '{', '}', '\n', 'fingerprintScores', '=', '{', '}', '\n', '<nl>', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', '<indent>', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '=', '0', '\n', '<nl>', '<dedent>', 'for', 'test', 'in', 'tests', ':', '\n', '<indent>', 'image', '=', 'Png', '(', 'directory', '+', 'test', '.', 'filename', '+', '"str"', ')', '\n', 'if', 'not', 'image', '.', 'valid', '==', '0', ':', '\n', '<nl>', '<indent>', 'result', '=', 'test', '.', 'function', '(', 'image', ')', '\n', '<dedent>', 'else', ':', '\n', '<indent>', 'result', '=', '0', '\n', '<dedent>', '"str"', '\n', '<nl>', 'results', '[', 'test', '.', 'name', ']', '=', 'result', '\n', '<nl>', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', '<indent>', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', '<nl>', '<indent>', 'if', 'warn', ':', '\n', '<indent>', 'print', '(', '"str"', ',', 'test', '.', 'name', ',', '"str"', ',', 'fingerprint', '.', 'name', ')', '\n', '<dedent>', '<dedent>', 'elif', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', '==', 'result', ':', '\n', '<indent>', 'fingerprintScores', '[', 'fingerprint', '.', 'name', ']', '+=', '1', '\n', '<dedent>', '<dedent>', '<dedent>', 'return', 'results', ',', 'fingerprintScores', '\n', '<dedent>', '<endf>']
# [[-1, "# Test all the images in a directory (don't print warnings when generating fingerprints)"], [12, '###DCSTR### my documentation'], [25, '# Initialite the count of matching tests to zero for each fingerprint'], [42, '# Execute each test'], [73, '# Only execute the test if there is an image to test'], [96, '# Save the result of the test'], [107, '# Check if the result matches some of the fingeprints and if so, increment the match counter'], [125, '# warn if a fingerprint is missing the result for the test being run']]
# ['fingerprints', 'fingerprintScores', 30, [6, 111]]
# ['tests', 'image', 48, [4]]
# ['result', 'image', 105, [76, 90, 160]]
# ['fingerprints', 'warn', 111, [6, 30]]
# ['results', 'warn', 177, [16, 98, 123, 153]]
# ['fingerprintScores', 'warn', 179, [21, 34, 164]]
# ['fingerprintScores', 'test', 34, [21, 164, 179]]
# ['results', 'warn', 98, [16, 123, 153, 177]]
# ['image', 'test', 82, [52, 67]]
# ['warn', 'fingerprints', 129, [8]]
# ['fingerprint', 'image', 36, [28, 109, 121, 143, 151, 166]]
# ['image', 'tests', 67, [52, 82]]
# ['test', 'fingerprints', 78, [46, 58, 100, 117, 137, 155]]
# ['test', 'results', 100, [46, 58, 78, 117, 137, 155]]
# ['result', 'fingerprintScores', 160, [76, 90, 105]]
# ['test', 'results', 58, [46, 78, 100, 117, 137, 155]]
# ['test', 'tests', 117, [46, 58, 78, 100, 137, 155]]
# ['fingerprint', 'result', 121, [28, 36, 109, 143, 151, 166]]
# ['fingerprintScores', 'fingerprints', 164, [21, 34, 179]]
# ['test', 'fingerprint', 137, [46, 58, 78, 100, 117, 155]]
# ['fingerprint', 'results', 143, [28, 36, 109, 121, 151, 166]]
# ['fingerprint', 'results', 151, [28, 36, 109, 121, 143, 166]]
# ['test', 'tests', 155, [46, 58, 78, 100, 117, 137]]
# ['fingerprint', 'result', 166, [28, 36, 109, 121, 143, 151]]
# ['<nl>', 'def', 'generateCsv', '(', 'tests', ',', 'fingerprints', ')', ':', '\n', '<indent>', 'header', '=', '"str"', '\n', 'for', 'test', 'in', 'tests', ':', '\n', '<indent>', 'header', '=', 'header', '+', '"str"', '+', 'test', '.', 'name', '\n', '<dedent>', 'print', '(', 'header', ')', '\n', '<nl>', 'for', 'fingerprint', 'in', 'fingerprints', ':', '\n', '<indent>', 'row', '=', 'fingerprint', '.', 'name', '\n', 'for', 'test', 'in', 'tests', ':', '\n', '<indent>', 'if', 'not', 'test', '.', 'name', 'in', 'fingerprint', '.', 'results', ':', '\n', '<indent>', 'row', '+=', '"str"', '\n', '<dedent>', 'else', ':', '\n', '<indent>', 'row', '+=', '"str"', '+', 'str', '(', 'fingerprint', '.', 'results', '[', 'test', '.', 'name', ']', ')', '\n', '<dedent>', '<dedent>', 'print', '(', 'row', ')', '\n', '<dedent>', '<dedent>', '<endf>']
# [[-1, '# Generate a csv table with all the test results for each fingerprint (which you can then import in LibreOffice or whatever)']]
# ['tests', 'fingerprint', 18, [4, 55]]
# ['fingerprints', 'tests', 42, [6]]
# ['header', 'row', 35, [11, 22, 24]]
# ['tests', 'row', 55, [4, 18]]
# ['fingerprint', 'row', 48, [40, 65, 86]]
# ['row', 'fingerprints', 100, [46, 71, 80]]
# ['header', 'tests', 24, [11, 22, 35]]
# ['test', 'fingerprints', 28, [16, 53, 61, 90]]
# ['test', 'fingerprint', 61, [16, 28, 53, 90]]
# ['fingerprint', 'fingerprints', 65, [40, 48, 86]]
# ['fingerprint', 'tests', 86, [40, 48, 65]]
# ['test', 'fingerprints', 90, [16, 28, 53, 61]]
# ['<nl>', 'def', 'showResults', '(', 'scores', ',', 'nb', ')', ':', '\n', '<indent>', 'ordered', '=', 'sorted', '(', 'iter', '(', 'scores', '.', 'items', '(', ')', ')', ',', 'key', '=', 'itemgetter', '(', '1', ')', ')', '\n', 'for', 'result', 'in', 'ordered', ':', '\n', '<indent>', 'print', '(', '"str"', '.', 'format', '(', 'result', '[', '0', ']', ',', 'result', '[', '1', ']', ',', 'nb', ')', ')', '\n', '<dedent>', '<dedent>', '<endf>']
# [[-1, '# Show the fingerprinting result with the most likely library match at the bottom']]
# ['ordered', 'scores', 35, [11]]
# ['nb', 'scores', 55, [6]]
# ['scores', 'result', 17, [4]]
# ['result', 'scores', 45, [33, 50]]
# ['result', 'nb', 50, [33, 45]]
# ['def', 'construct_tree', '(', 'X', ',', 'k', ',', 'prune_threshold', '=', 'None', ',', 'num_levels', '=', 'None', ',', 'verbose', '=', 'False', ')', ':', '\n', '<nl>', '"str"', '\n', '<nl>', '<indent>', 'sim_graph', ',', 'radii', '=', '_utl', '.', 'knn_graph', '(', 'X', ',', 'k', ',', 'method', '=', '"str"', ')', '\n', '<nl>', 'n', ',', 'p', '=', 'X', '.', 'shape', '\n', 'density', '=', '_utl', '.', 'knn_density', '(', 'radii', ',', 'n', ',', 'p', ',', 'k', ')', '\n', '<nl>', 'tree', '=', 'construct_tree_from_graph', '(', 'adjacency_list', '=', 'sim_graph', ',', 'density', '=', 'density', ',', '<nl>', 'prune_threshold', '=', 'prune_threshold', ',', '<nl>', 'num_levels', '=', 'num_levels', ',', 'verbose', '=', 'verbose', ')', '\n', '<nl>', 'return', 'tree', '\n', '<dedent>', '<endf>']
# [[21, "###DCSTR### Construct a level set tree from tabular data.\n\nParameters\n----------\nX : 2-dimensional numpy array\n    Numeric dataset, where each row represents one observation.\n\nk : int\n    Number of observations to consider as neighbors to a given point.\n\nprune_threshold : int, optional\n    Leaf nodes with fewer than this number of members are recursively\n    merged into larger nodes. If 'None' (the default), then no pruning\n    is performed.\n\nnum_levels : int, optional\n    Number of density levels in the constructed tree. If None (default),\n    `num_levels` is internally set to be the number of rows in `X`.\n\nverbose : bool, optional\n    If True, a progress indicator is printed at every 100th level of tree\n    construction.\n\nReturns\n-------\nT : LevelSetTree\n    A pruned level set tree.\n\nSee Also\n--------\nconstruct_tree_from_graph, LevelSetTree\n\nExamples\n--------\n>>> X = numpy.random.rand(100, 2)\n>>> tree = debacl.construct_tree(X, k=8, prune_threshold=5)\n>>> print(tree)\n+----+-------------+-----------+------------+----------+------+--------+----------+\n| id | start_level | end_level | start_mass | end_mass | size | parent | children |\n+----+-------------+-----------+------------+----------+------+--------+----------+\n| 0  |    0.000    |   0.870   |   0.000    |  0.450   | 100  |  None  |  [3, 4]  |\n| 3  |    0.870    |   3.364   |   0.450    |  0.990   |  17  |   0    |    []    |\n| 4  |    0.870    |   1.027   |   0.450    |  0.520   |  35  |   0    |  [7, 8]  |\n| 7  |    1.027    |   1.755   |   0.520    |  0.870   |  8   |   4    |    []    |\n| 8  |    1.027    |   3.392   |   0.520    |  1.000   |  23  |   4    |    []    |\n+----+-------------+-----------+------------+----------+------+--------+----------+"]]
# ['tree', 'k', 97, [68]]
# ['X', 'num_levels', 34, [3, 48]]
# ['k', 'prune_threshold', 36, [5, 64]]
# ['X', 'tree', 48, [3, 34]]
# ['radii', 'p', 58, [28]]
# ['n', 'radii', 60, [44]]
# ['p', 'prune_threshold', 62, [46]]
# ['k', 'num_levels', 64, [5, 36]]
# ['sim_graph', 'tree', 74, [26]]
# ['density', 'p', 78, [52, 76]]
# ['prune_threshold', 'n', 83, [7, 81]]
# ['num_levels', 'p', 88, [11, 86]]
# ['verbose', 'density', 92, [15, 90]]
# ['def', 'construct_tree_from_graph', '(', 'adjacency_list', ',', 'density', ',', 'prune_threshold', '=', 'None', ',', '<nl>', 'num_levels', '=', 'None', ',', 'verbose', '=', 'False', ')', ':', '\n', '<nl>', '"str"', '\n', '<nl>', '<indent>', 'levels', '=', '_utl', '.', 'define_density_mass_grid', '(', 'density', ',', 'num_levels', '=', 'num_levels', ')', '\n', '<nl>', 'G', '=', '_nx', '.', 'from_dict_of_lists', '(', '<nl>', '{', 'i', ':', 'neighbors', 'for', 'i', ',', 'neighbors', 'in', 'enumerate', '(', 'adjacency_list', ')', '}', ')', '\n', '<nl>', 'T', '=', 'LevelSetTree', '(', 'density', ',', 'levels', ')', '\n', '<nl>', 'cc0', '=', '_nx', '.', 'connected_components', '(', 'G', ')', '\n', '<nl>', 'for', 'i', ',', 'c', 'in', 'enumerate', '(', 'cc0', ')', ':', '\n', '<indent>', 'T', '.', '_subgraphs', '[', 'i', ']', '=', 'G', '.', 'subgraph', '(', 'c', ')', '\n', 'T', '.', 'nodes', '[', 'i', ']', '=', 'ConnectedComponent', '(', '<nl>', 'i', ',', 'parent', '=', 'None', ',', 'children', '=', '[', ']', ',', 'start_level', '=', '0.', ',', 'end_level', '=', 'None', ',', '<nl>', 'start_mass', '=', '0.', ',', 'end_mass', '=', 'None', ',', 'members', '=', 'c', ')', '\n', '<nl>', '<dedent>', 'previous_level', '=', '0.', '\n', 'n', '=', 'float', '(', 'len', '(', 'adjacency_list', ')', ')', '\n', '<nl>', 'for', 'i', ',', 'level', 'in', 'enumerate', '(', 'levels', ')', ':', '\n', '<indent>', 'if', 'verbose', 'and', 'i', '%', '100', '==', '0', ':', '\n', '<indent>', '_logging', '.', 'info', '(', '"str"', '.', 'format', '(', 'i', ')', ')', '\n', '<nl>', '<dedent>', 'bg', '=', '_np', '.', 'where', '(', '(', 'density', '>', 'previous_level', ')', '&', '(', 'density', '<=', 'level', ')', ')', '[', '0', ']', '\n', 'previous_level', '=', 'level', '\n', '<nl>', 'old_vcount', '=', 'sum', '(', '[', 'x', '.', 'number_of_nodes', '(', ')', '<nl>', 'for', 'x', 'in', 'T', '.', '_subgraphs', '.', 'values', '(', ')', ']', ')', '\n', 'current_mass', '=', '1.', '-', '(', '(', 'old_vcount', '-', 'len', '(', 'bg', ')', ')', '/', 'n', ')', '\n', '<nl>', 'deactivate_keys', '=', '[', ']', '\n', 'activate_subgraphs', '=', '{', '}', '\n', '<nl>', 'for', '(', 'k', ',', 'H', ')', 'in', 'T', '.', '_subgraphs', '.', 'items', '(', ')', ':', '\n', '<nl>', '<indent>', 'H', '.', 'remove_nodes_from', '(', 'bg', ')', '\n', '<nl>', 'if', 'H', '.', 'number_of_nodes', '(', ')', '==', '0', ':', '\n', '<indent>', 'T', '.', 'nodes', '[', 'k', ']', '.', 'end_level', '=', 'level', '\n', 'T', '.', 'nodes', '[', 'k', ']', '.', 'end_mass', '=', 'current_mass', '\n', 'deactivate_keys', '.', 'append', '(', 'k', ')', '\n', '<nl>', '<dedent>', 'else', ':', '\n', '<nl>', '<indent>', 'if', 'not', '_nx', '.', 'is_connected', '(', 'H', ')', ':', '\n', '<nl>', '<indent>', 'T', '.', 'nodes', '[', 'k', ']', '.', 'end_level', '=', 'level', '\n', 'T', '.', 'nodes', '[', 'k', ']', '.', 'end_mass', '=', 'current_mass', '\n', 'deactivate_keys', '.', 'append', '(', 'k', ')', '\n', '<nl>', 'cc', '=', '_nx', '.', 'connected_components', '(', 'H', ')', '\n', '<nl>', 'for', 'c', 'in', 'cc', ':', '\n', '<indent>', 'new_key', '=', 'max', '(', 'T', '.', 'nodes', '.', 'keys', '(', ')', ')', '+', '1', '\n', 'T', '.', 'nodes', '[', 'k', ']', '.', 'children', '.', 'append', '(', 'new_key', ')', '\n', 'activate_subgraphs', '[', 'new_key', ']', '=', 'H', '.', 'subgraph', '(', 'c', ')', '\n', '<nl>', 'T', '.', 'nodes', '[', 'new_key', ']', '=', 'ConnectedComponent', '(', '<nl>', 'new_key', ',', 'parent', '=', 'k', ',', 'children', '=', '[', ']', ',', 'start_level', '=', 'level', ',', '<nl>', 'end_level', '=', 'None', ',', 'start_mass', '=', 'current_mass', ',', '<nl>', 'end_mass', '=', 'None', ',', 'members', '=', 'c', ')', '\n', '<nl>', '<dedent>', '<dedent>', '<dedent>', '<dedent>', 'for', 'k', 'in', 'deactivate_keys', ':', '\n', '<indent>', 'del', 'T', '.', '_subgraphs', '[', 'k', ']', '\n', '<nl>', '<dedent>', 'T', '.', '_subgraphs', '.', 'update', '(', 'activate_subgraphs', ')', '\n', '<nl>', '<dedent>', 'if ...
# [[22, "###DCSTR### Construct a level set tree from a similarity graph and a density estimate.\n\nParameters\n----------\nadjacency_list : list [list]\n    Adjacency list of the k-nearest neighbors graph on the data. Each entry\n    contains the indices of the `k` closest neighbors to the data point at\n    the same row index.\n\ndensity : list [float]\n    Estimate of the density function, evaluated at the data points\n    represented by the keys in `adjacency_list`.\n\nprune_threshold : int, optional\n    Leaf nodes with fewer than this number of members are recursively\n    merged into larger nodes. If 'None' (the default), then no pruning\n    is performed.\n\nnum_levels : list int, optional\n    Number of density levels in the constructed tree. If None (default),\n    `num_levels` is internally set to be the number of rows in `X`.\n\nverbose : bool, optional\n    If True, a progress indicator is printed at every 100th level of tree\n    construction.\n\nReturns\n-------\nT : levelSetTree\n    See the LevelSetTree class for attributes and method definitions.\n\nSee Also\n--------\nconstruct_tree, LevelSetTree\n\nExamples\n--------\n>>> X = numpy.random.rand(100, 2)\n>>> knn_graph, radii = debacl.utils.knn_graph(X, k=8)\n>>> density = debacl.utils.knn_density(radii, n=100, p=2, k=8)\n>>> tree = debacl.construct_tree_from_graph(knn_graph, density,\n...                                         prune_threshold=5)\n>>> print(tree)\n+----+-------------+-----------+------------+----------+------+--------+----------+\n| id | start_level | end_level | start_mass | end_mass | size | parent | children |\n+----+-------------+-----------+------------+----------+------+--------+----------+\n| 0  |    0.000    |   0.768   |   0.000    |  0.390   | 100  |  None  |  [1, 2]  |\n| 1  |    0.768    |   1.494   |   0.390    |  0.790   |  30  |   0    |  [7, 8]  |\n| 2  |    0.768    |   4.812   |   0.390    |  1.000   |  31  |   0    |    []    |\n| 7  |    1.494    |   2.375   |   0.790    |  0.950   |  6   |   1    |    []    |\n| 8  |    1.494    |   2.308   |   0.790    |  0.940   |  5   |   1    |    []    |\n+----+-------------+-----------+------------+----------+------+--------+----------+"], [25, '## Initialize the graph and cluster tree'], [74, '## Figure out roots of the tree'], [94, '# c is only the vertex list, not the subgraph'], [154, '# Loop through the removal grid'], [206, '## figure out which points to remove, i.e. the background set.'], [234, '## compute the mass after the current bg set is removed'], [276, '# loop through active components, i.e. subgraphs'], [280, '# subgraphs to deactivate at the iter end'], [285, '# new subgraphs to add at the end of the iter'], [304, '## remove nodes at the current level'], [313, '## check if subgraph has vanished'], [357, "# subgraph hasn't vanished"], [359, '## check if subgraph now has multiple connected components'], [359, '# NOTE: this is *the* bottleneck'], [371, '## deactivate the parent subgraph'], [402, '## start a new subgraph & node for each child component'], [506, '# update active components'], [537, '## Prune the tree']]
# ['T', 'cc', 561, [65, 97, 111, 249, 295, 325, 336, 373, 384, 424, 435, 462, 519, 528, 547, 549]]
# ['density', 'i', 33, [5, 69, 215, 221]]
# ['density', 'cc', 69, [5, 33, 215, 221]]
# ['levels', 'i', 71, [27, 178]]
# ['G', 'density', 81, [41, 104]]
# ['cc0', 'verbose', 92, [75]]
# ['levels', 'neighbors', 178, [27, 71]]
# ['level', 'cc0', 232, [174, 223, 334, 382, 485]]
# ['deactivate_keys', 'current_mass', 514, [277, 347, 395]]
# ['prune_threshold', 'activate_subgraphs', 540, [7, 555]]
# ['num_levels', 'adjacency_list', 37, [12, 35]]
# ['i', 'activate_subgraphs', 49, [53, 86, 101, 115, 121, 172, 186, 202]]
# ['neighbors', 'prune_threshold', 51, [55]]
# ['c', 'num_levels', 108, [88, 151, 414, 458, 503]]
# ['i', 'c', 121, [49, 53, 86, 101, 115, 172, 186, 202]]
# ['adjacency_list', 'density', 166, [3, 59]]
# ['verbose', 'density', 184, [16]]
# ['activate_subgraphs', 'density', 534, [282, 449]]
# ['T', 'activate_subgraphs', 97, [65, 111, 249, 295, 325, 336, 373, 384, 424, 435, 462, 519, 528, 547, 549, 561]]
# ['i', 'cc', 101, [49, 53, 86, 115, 121, 172, 186, 202]]
# ['G', 'previous_level', 104, [41, 81]]
# ['T', 'old_vcount', 111, [65, 97, 249, 295, 325, 336, 373, 384, 424, 435, 462, 519, 528, 547, 549, 561]]
# ['i', 'T', 115, [49, 53, 86, 101, 121, 172, 186, 202]]
# ['c', 'bg', 151, [88, 108, 414, 458, 503]]
# ['n', 'verbose', 273, [160]]
# ['bg', 'k', 310, [208, 269]]
# ['level', 'previous_level', 334, [174, 223, 232, 382, 485]]
# ['current_mass', 'cc0', 345, [259, 393, 494]]
# ['T', 'prune_threshold', 549, [65, 97, 111, 249, 295, 325, 336, 373, 384, 424, 435, 462, 519, 528, 547, 561]]
# ['prune_threshold', 'density', 555, [7, 540]]
# ['adjacency_list', 'x', 59, [3, 166]]
# ['i', 'density', 186, [49, 53, 86, 101, 115, 121, 172, 202]]
# ['i', 'old_vcount', 202, [49, 53, 86, 101, 115, 121, 172, 186]]
# ['old_vcount', 'num_levels', 265, [235]]
# ['T', 'adjacency_list', 295, [65, 97, 111, 249, 325, 336, 373, 384, 424, 435, 462, 519, 528, 547, 549, 561]]
# ['H', 'adjacency_list', 306, [292, 315, 367, 409, 454]]
# ['k', 'num_levels', 351, [290, 329, 340, 377, 388, 399, 439, 476, 512, 523]]
# ['level', 'k', 382, [174, 223, 232, 334, 485]]
# ['current_mass', 'neighbors', 393, [259, 345, 494]]
# ['cc', 'deactivate_keys', 416, [403]]
# ['T', 'level', 519, [65, 97, 111, 249, 295, 325, 336, 373, 384, 424, 435, 462, 528, 547, 549, 561]]
# ['k', 'x', 523, [290, 329, 340, 351, 377, 388, 399, 439, 476, 512]]
# ['T', 'k', 528, [65, 97, 111, 249, 295, 325, 336, 373, 384, 424, 435, 462, 519, 547, 549, 561]]
# ['density', 'current_mass', 215, [5, 33, 69, 221]]
# ['previous_level', 'bg', 217, [156, 230]]
# ['density', 'n', 221, [5, 33, 69, 215]]
# ['level', 'new_key', 223, [174, 232, 334, 382, 485]]
# ['x', 'H', 240, [247]]
# ['bg', 'old_vcount', 269, [208, 310]]
# ['H', 'i', 315, [292, 306, 367, 409, 454]]
# ['deactivate_keys', 'c', 347, [277, 395, 514]]
# ['H', 'bg', 367, [292, 306, 315, 409, 454]]
# ['k', 'deactivate_keys', 399, [290, 329, 340, 351, 377, 388, 439, 476, 512, 523]]
# ['H', 'old_vcount', 409, [292, 306, 315, 367, 454]]
# ['T', 'H', 325, [65, 97, 111, 249, 295, 336, 373, 384, 424, 435, 462, 519, 528, 547, 549, 561]]
# ['k', 'num_levels', 329, [290, 340, 351, 377, 388, 399, 439, 476, 512, 523]]
# ['T', 'num_levels', 336, [65, 97, 111, 249, 295, 325, 373, 384, 424, 435, 462, 519, 528, 547, 549, 561]]
# ['k', 'levels', 340, [290, 329, 351, 377, 388, 399, 439, 476, 512, 523]]
# ['deactivate_keys', 'T', 395, [277, 347, 514]]
# ['new_key', 'old_vcount', 446, [420, 451, 466, 472]]
# ['activate_subgraphs', 'H', 449, [282, 534]]
# ['c', 'level', 458, [88, 108, 151, 414, 503]]
# ['new_key', 'cc', 472, [420, 446, 451, 466]]
# ['T', 'old_vcount', 249, [65, 97, 111, 295, 325, 336, 373, 384, 424, 435, 462, 519, 528, 547, 549, 561]]
# ['T', 'bg', 373, [65, 97, 111, 249, 295, 325, 336, 384, 424, 435, 462, 519, 528, 547, 549, 561]]
# ['k', 'verbose', 377, [290, 329, 340, 351, 388, 399, 439, 476, 512, 523]]
# ['T', 'num_levels', 384, [65, 97, 111, 249, 295, 325, 336, 373, 424, 435, 462, 519, 528, 547, 549, 561]]
# ['k', 'c', 388, [290, 329, 340, 351, 377, 399, 439, 476, 512, 523]]
# ['new_key', 'activate_subgraphs', 451, [420, 446, 466, 472]]
# ['H', 'deactivate_keys', 454, [292, 306, 315, 367, 409]]
# ['T', 'deactivate_keys', 462, [65, 97, 111, 249, 295, 325, 336, 373, 384, 424, 435, 519, 528, 547, 549, 561]]
# ['new_key', 'level', 466, [420, 446, 451, 472]]
# ['k', 'previous_level', 476, [290, 329, 340, 351, 377, 388, 399, 439, 512, 523]]
# ['level', 'old_vcount', 485, [174, 223, 232, 334, 382]]
# ['current_mass', 'c', 494, [259, 345, 393]]
# ['c', 'new_key', 503, [88, 108, 151, 414, 458]]
# ['T', 'prune_threshold', 424, [65, 97, 111, 249, 295, 325, 336, 373, 384, 435, 462, 519, 528, 547, 549, 561]]
# ['T', 'previous_level', 435, [65, 97, 111, 249, 295, 325, 336, 373, 384, 424, 462, 519, 528, 547, 549, 561]]
# ['k', 'activate_subgraphs', 439, [290, 329, 340, 351, 377, 388, 399, 476, 512, 523]]
# ['def', 'load_tree', '(', 'filename', ')', ':', '\n', '<nl>', '"str"', '\n', '<indent>', 'with', 'open', '(', 'filename', ',', '"str"', ')', 'as', 'f', ':', '\n', '<indent>', 'T', '=', '_pickle', '.', 'load', '(', 'f', ')', '\n', '<nl>', '<dedent>', 'return', 'T', '\n', '<dedent>', '<endf>']
# [[7, "###DCSTR### Load a saved tree from file.\n\nParameters\n----------\nfilename : str\n    Filename to load.\n\nReturns\n-------\nT : LevelSetTree\n    The loaded and reconstituted level set tree object.\n\nSee Also\n--------\nLevelSetTree.save\n\nExamples\n--------\n>>> X = numpy.random.rand(100, 2)\n>>> tree = debacl.construct_tree(X, k=8, prune_threshold=5)\n>>> tree.save('my_tree')\n>>> tree2 = debacl.load_tree('my_tree')"]]
# ['T', 'f', 35, [23]]
# ['filename', 'f', 14, [3]]
# ['f', 'filename', 29, [19]]
# ['def', 'add_others_to_robots', '(', 'robots', ',', 'others_list', ')', ':', '\n', '<nl>', '"str"', '\n', '<indent>', 'for', 'other', 'in', 'others_list', ':', '\n', '<indent>', 'robots', '.', 'add', '(', 'other', ')', '\n', '<dedent>', 'return', 'robots', '\n', '<dedent>', '<endf>']
# [[9, '###DCSTR### Add others to robots set.']]
# ['others_list', 'robots', 16, [5]]
# ['robots', 'others_list', 29, [3, 20]]
# ['other', 'robots', 24, [14]]
# ['robots', 'others_list', 20, [3, 29]]
# ['def', 'add_xml_names_to_robots', '(', 'robots', ',', 'xml_file', ')', ':', '\n', '<nl>', '"str"', '\n', '<indent>', 'dom', '=', 'parse', '(', 'xml_file', ')', '\n', 'user_agents', '=', 'list', '(', ')', '\n', 'for', 'robot', 'in', 'dom', '.', 'getElementsByTagName', '(', '"str"', ')', ':', '\n', '<indent>', 'for', 'node', 'in', 'robot', '.', 'childNodes', ':', '\n', '<indent>', 'if', 'node', '.', 'localName', '==', '"str"', ':', '\n', '<indent>', 'family', '=', 'node', '.', 'firstChild', '.', 'data', '.', 'strip', '(', ')', '\n', '<dedent>', 'if', 'node', '.', 'localName', '==', '"str"', ':', '\n', '<indent>', 'name', '=', 'node', '.', 'firstChild', '.', 'data', '.', 'strip', '(', ')', '\n', '<dedent>', 'if', 'node', '.', 'localName', '==', '"str"', ':', '\n', '<indent>', 'user_agents', '.', 'append', '(', 'node', '.', 'firstChild', '.', 'data', '.', 'strip', '(', ')', ')', '\n', '<nl>', '<dedent>', '<dedent>', 'if', 'len', '(', 'family', ')', '>', '3', ':', '\n', '<indent>', 'name', '=', 'family', '\n', '<nl>', '<dedent>', 'name_new', '=', 're_trailing_version', '.', 'search', '(', 'name', ')', '\n', 'if', 'name_new', ':', '\n', '<indent>', 'name', '=', 'name_new', '.', 'group', '(', '"str"', ')', '\n', '<dedent>', 'if', 'name', '.', 'endswith', '(', '"str"', ')', ':', '\n', '<indent>', 'name', '=', 'name', '.', 'rstrip', '(', '"str"', ')', '\n', '<dedent>', 'robots', '.', 'add', '(', 'name', '.', 'strip', '(', ')', ')', '\n', '<dedent>', 'return', 'robots', ',', 'sorted', '(', 'user_agents', ')', '\n', '<dedent>', '<endf>']
# [[9, '###DCSTR### Add robots from "Data for UASparser" in XML format to robots set.'], [114, '# Use the family title instead of the name, if it is long enough'], [131, '# Remove trailing versions (length protected in regex)']]
# ['xml_file', 'dom', 17, [5]]
# ['name_new', 'robot', 144, [134, 150]]
# ['robots', 'name', 191, [3, 178]]
# ['dom', 'family', 29, [13]]
# ['robot', 'user_agents', 41, [27]]
# ['family', 'name', 130, [56, 121]]
# ['name', 'robot', 140, [78, 128, 148, 159, 168, 170, 182]]
# ['user_agents', 'name_new', 195, [20, 100]]
# ['family', 'name', 121, [56, 130]]
# ['name', 'node', 159, [78, 128, 140, 148, 168, 170, 182]]
# ['robots', 'name_new', 178, [3, 191]]
# ['node', 'user_agents', 48, [39, 58, 70, 80, 92, 104]]
# ['node', 'name', 70, [39, 48, 58, 80, 92, 104]]
# ['node', 'robot', 92, [39, 48, 58, 70, 80, 104]]
# ['name_new', 'name', 150, [134, 144]]
# ['name', 'name_new', 170, [78, 128, 140, 148, 159, 168, 182]]
# ['name', 'robot', 182, [78, 128, 140, 148, 159, 168, 170]]
# ['user_agents', 'node', 100, [20, 195]]
# ['node', 'name_new', 58, [39, 48, 70, 80, 92, 104]]
# ['node', 'family', 80, [39, 48, 58, 70, 92, 104]]
# ['node', 'robots', 104, [39, 48, 58, 70, 80, 92]]
# ['def', 'create_optmized_robots_regex', '(', 'robots', ')', ':', '\n', '<nl>', '"str"', '\n', '<indent>', 'optimized_robots', '=', 'trie', '.', 'Trie', '(', ')', '\n', 'for', 'robot', 'in', 'sorted', '(', 'robots', ')', ':', '\n', '<indent>', 'optimized_robots', '.', 'add', '(', 'robot', ')', '\n', '<dedent>', 'return', 'optimized_robots', '.', 'regexp', '(', ')', '\n', '<dedent>', '<endf>']
# [[7, '###DCSTR### Create an optimized regex from list of robots using a trie.']]
# ['robots', 'optimized_robots', 24, [3]]
# ['robot', 'robots', 33, [20]]
# ['optimized_robots', 'robots', 38, [11, 29]]
# ['optimized_robots', 'robots', 29, [11, 38]]
# ['def', 'main', '(', ')', ':', '\n', '<indent>', 'robots', '=', 'set', '(', ')', '\n', '<nl>', 'args', '=', 'parser_setup', '(', ')', '\n', '<nl>', 'if', 'args', '.', 'file', ':', '\n', '<indent>', 'xml_file', '=', 'args', '.', 'file', '\n', '<dedent>', 'else', ':', '\n', '<indent>', 'download_uasparser_xml', '(', 'download_xml_url', ',', 'file_uasparser_xml', ')', '\n', 'xml_file', '=', 'file_uasparser_xml', '\n', '<nl>', '<dedent>', 'robots', '=', 'add_others_to_robots', '(', 'robots', ',', 'others', ')', '\n', 'robots', ',', 'user_agents', '=', 'add_xml_names_to_robots', '(', 'robots', ',', 'xml_file', ')', '\n', 'optibots', '=', 'create_optmized_robots_regex', '(', 'robots', ')', '\n', '<nl>', 'with', 'io', '.', 'open', '(', 'file_robots_config', ',', '"str"', ',', 'encoding', '=', '"str"', ')', 'as', 'fh', ':', '\n', '<indent>', 'fh', '.', 'write', '(', '"str"', ')', '\n', 'fh', '.', 'write', '(', '"str"', '%', 'optibots', ')', '\n', '<nl>', '<dedent>', 'with', 'io', '.', 'open', '(', 'file_user_agents', ',', '"str"', ',', 'encoding', '=', '"str"', ')', 'as', 'fh', ':', '\n', '<indent>', 'for', 'agent', 'in', 'user_agents', ':', '\n', '<indent>', 'fh', '.', 'write', '(', '"str"', '%', 'agent', ')', '\n', '<dedent>', '<dedent>', '<dedent>', '<endf>']
# [[12, '# Command Line Options'], [79, '# write out robots config excerpt'], [114, '# write out robot users agents for testing']]
# ['args', 'xml_file', 22, [14, 30]]
# ['robots', 'user_agents', 56, [7, 52, 61, 67, 76]]
# ['robots', 'user_agents', 67, [7, 52, 56, 61, 76]]
# ['xml_file', 'agent', 69, [28, 46]]
# ['robots', 'user_agents', 76, [7, 52, 56, 61, 67]]
# ['user_agents', 'args', 137, [63]]
# ['args', 'fh', 30, [14, 22]]
# ['fh', 'xml_file', 98, [94, 105, 130, 141]]
# ['fh', 'robots', 105, [94, 98, 130, 141]]
# ['optibots', 'agent', 111, [72]]
# ['fh', 'xml_file', 141, [94, 98, 105, 130]]
# ['agent', 'robots', 147, [135]]
# ['def', 'read_and_compile_pattern_from_file', '(', 'config_file', ')', ':', '\n', '<nl>', '"str"', '\n', '<indent>', 'config', '=', 'configparser', '.', 'ConfigParser', '(', ')', '\n', 'config', '.', 'readfp', '(', 'open', '(', 'config_file', ')', ')', '\n', 're_robots', '=', 're', '.', 'compile', '(', 'config', '.', 'get', '(', '"str"', ',', '"str"', ')', ',', 're', '.', 'I', ')', '\n', 'return', 're_robots', '\n', '<dedent>', '<endf>']
# [[7, '###DCSTR### Read INI config file and compile robots regex from robots key in\npatterns section.']]
# ['re_robots', 'config_file', 50, [29]]
# ['config', 'config_file', 19, [11, 35]]
# ['config_file', 'config', 25, [3]]
# ['config', 'config_file', 35, [11, 19]]
# ['def', 'evalute_robots_pattern', '(', 're_robots', ')', ':', '\n', '<nl>', '"str"', '\n', '<indent>', 'matched', '=', '0', '\n', 'missed', '=', '0', '\n', 'i', '=', '1', '\n', 'with', 'io', '.', 'open', '(', 'file_user_agents', ',', '"str"', ',', 'encoding', '=', '"str"', ')', 'as', 'fh', ':', '\n', '<indent>', 'for', 'line', 'in', 'fh', ':', '\n', '<indent>', 'if', 're_robots', '.', 'search', '(', 'line', ')', ':', '\n', '<indent>', 'matched', '+=', '1', '\n', '<nl>', '<dedent>', 'else', ':', '\n', '<indent>', 'missed', '+=', '1', '\n', '<nl>', '<dedent>', 'i', '+=', '1', '\n', '<dedent>', '<dedent>', 'return', 'matched', ',', 'missed', '\n', '<dedent>', '<endf>']
# [[7, '###DCSTR### Evalute robots regex for hits and misses against robots user agents\nfile.'], [61, '# print "+%s:" % i, line.strip()'], [71, '# print "-%s:" % i, line.strip()']]
# ['fh', 'matched', 44, [37]]
# ['matched', 'line', 81, [11, 58]]
# ['missed', 'matched', 83, [15, 68]]
# ['line', 'matched', 53, [42]]
# ['re_robots', 'fh', 49, [3]]
# ['def', 'evaluate_config', '(', 'config_file', ',', 'iterations', ')', ':', '\n', '<nl>', '"str"', '\n', '<nl>', '<indent>', 're_robots', '=', 'read_and_compile_pattern_from_file', '(', 'config_file', ')', '\n', 'matched', '=', 'int', '(', ')', '\n', 'missed', '=', 'int', '(', ')', '\n', 'duration_total', '=', 'float', '(', ')', '\n', 'for', 'i', 'in', 'range', '(', '0', ',', 'iterations', ')', ':', '\n', '<indent>', 'start', '=', 'time', '.', 'clock', '(', ')', '\n', 'matched', ',', 'missed', '=', 'evalute_robots_pattern', '(', 're_robots', ')', '\n', 'end', '=', 'time', '.', 'clock', '(', ')', '\n', 'duration', '=', 'end', '-', 'start', '\n', 'duration_total', '+=', 'duration', '\n', '<dedent>', 'return', 'matched', ',', 'missed', ',', 'duration_total', '/', 'iterations', '\n', '<dedent>', '<endf>']
# [[9, "###DCSTR### Evalute config's robots pattern and benchmark duration."], [11, '# Reading the pattern and compling is not included in the duration. As the'], [12, '# data is quickly supplied by the file system cache, it becomes irrelevent.']]
# ['config_file', 're_robots', 18, [3]]
# ['iterations', 'matched', 46, [5, 94]]
# ['duration', 'config_file', 84, [76]]
# ['matched', 'duration_total', 88, [21, 59]]
# ['missed', 'start', 90, [27, 61]]
# ['re_robots', 'start', 65, [14]]
# ['end', 'i', 78, [68]]
# ['start', 're_robots', 80, [51]]
# ['duration_total', 'matched', 92, [33, 82]]
# ['iterations', 'duration', 94, [5, 46]]
# ['def', 'display_results', '(', 'name', ',', 'config_file', ',', 'data', ',', 'old_data', '=', 'None', ')', ':', '\n', '<nl>', '"str"', '\n', '<indent>', 'matched', ',', 'missed', ',', 'duration', '=', 'data', '\n', 'msg', '=', '"str"', '%', '(', 'name', ',', 'config_file', ')', '\n', 'print', '(', 'msg', ')', '\n', 'print', '(', '"str"', '*', 'len', '(', 'msg', ')', ')', '\n', 'if', 'old_data', 'is', 'None', ':', '\n', '<indent>', 'print', '(', '"str"', '%', 'matched', ')', '\n', 'print', '(', '"str"', '%', 'missed', ')', '\n', 'print', '(', '"str"', '%', 'duration', ')', '\n', 'print', '(', ')', '\n', '<dedent>', 'else', ':', '\n', '<indent>', 'old_matched', ',', 'old_missed', ',', 'old_duration', '=', 'old_data', '\n', 'print', '(', '"str"', '%', 'matched', ',', 'end', '=', '"str"', ')', '\n', 'if', 'matched', '>', 'old_matched', ':', '\n', '<indent>', 'adj', '=', '"str"', '\n', '<dedent>', 'else', ':', '\n', '<indent>', 'adj', '=', '"str"', '\n', '<dedent>', 'diff_abs', '=', 'abs', '(', 'old_matched', '-', 'matched', ')', '\n', 'diff_percent', '=', 'diff_abs', '/', 'float', '(', 'old_matched', ')', '*', '100', '\n', 'print', '(', '"str"', '%', '(', 'diff_percent', ',', 'adj', ')', ')', '\n', 'print', '(', '"str"', '%', 'missed', ')', '\n', 'print', '(', '"str"', '%', 'duration', ',', 'end', '=', '"str"', ')', '\n', 'if', 'duration', '<', 'old_duration', ':', '\n', '<indent>', 'adj', '=', '"str"', '\n', '<dedent>', 'else', ':', '\n', '<indent>', 'adj', '=', '"str"', '\n', '<dedent>', 'diff_abs', '=', 'abs', '(', 'old_duration', '-', 'duration', ')', '\n', 'diff_percent', '=', 'diff_abs', '/', 'float', '(', 'old_duration', ')', '*', '100', '\n', 'print', '(', '"str"', '%', '(', 'diff_percent', ',', 'adj', ')', ')', '\n', '<dedent>', '<dedent>', '<endf>']
# [[15, '###DCSTR### Display results of config evaluation.']]
# ['data', 'old_missed', 25, [7]]
# ['msg', 'old_missed', 39, [27, 48]]
# ['old_data', 'diff_percent', 53, [9, 95]]
# ['old_data', 'data', 95, [9, 53]]
# ['name', 'msg', 32, [3]]
# ['config_file', 'msg', 34, [5]]
# ['matched', 'old_missed', 109, [19, 63, 101, 135]]
# ['old_matched', 'old_missed', 111, [89, 133, 144]]
# ['duration', 'msg', 179, [23, 77, 171, 205]]
# ['old_duration', 'diff_abs', 181, [93, 203, 214]]
# ['msg', 'config_file', 48, [27, 39]]
# ['matched', 'msg', 63, [19, 101, 109, 135]]
# ['missed', 'data', 70, [21, 164]]
# ['duration', 'adj', 77, [23, 171, 179, 205]]
# ['matched', 'old_data', 101, [19, 63, 109, 135]]
# ['old_matched', 'adj', 133, [89, 111, 144]]
# ['matched', 'adj', 135, [19, 63, 101, 109]]
# ['diff_abs', 'missed', 140, [129, 199, 210]]
# ['missed', 'msg', 164, [21, 70]]
# ['duration', 'old_duration', 171, [23, 77, 179, 205]]
# ['old_duration', 'msg', 203, [93, 181, 214]]
# ['duration', 'diff_percent', 205, [23, 77, 171, 179]]
# ['diff_abs', 'old_duration', 210, [129, 140, 199]]
# ['old_matched', 'diff_percent', 144, [89, 111, 133]]
# ['diff_percent', 'old_duration', 154, [138, 208, 224]]
# ['adj', 'msg', 156, [115, 124, 185, 194, 226]]
# ['old_duration', 'matched', 214, [93, 181, 203]]
# ['diff_percent', 'name', 224, [138, 154, 208]]
# ['adj', 'diff_abs', 226, [115, 124, 156, 185, 194]]
# ['def', 'main', '(', ')', ':', '\n', '<nl>', '<indent>', 'args', '=', 'parser_setup', '(', ')', '\n', '<nl>', 'old_data', '=', 'evaluate_config', '(', 'args', '.', 'old_config', ',', 'args', '.', 'iterations', ')', '\n', 'display_results', '(', '"str"', ',', 'args', '.', 'old_config', ',', 'old_data', ')', '\n', '<nl>', 'new_data', '=', 'evaluate_config', '(', 'args', '.', 'new_config', ',', 'args', '.', 'iterations', ')', '\n', 'display_results', '(', '"str"', ',', 'args', '.', 'new_config', ',', 'new_data', ',', 'old_data', ')', '\n', '<dedent>', '<endf>']
# [[5, '# Command Line Options'], [13, '# Old config'], [38, '# New config']]
# ['old_data', 'new_data', 36, [15, 63]]
# ['new_data', 'args', 61, [40]]
# ['old_data', 'new_data', 63, [15, 36]]
# ['args', 'old_data', 19, [8, 23, 32, 44, 48, 57]]
# ['args', 'old_data', 23, [8, 19, 32, 44, 48, 57]]
# ['args', 'new_data', 32, [8, 19, 23, 44, 48, 57]]
# ['args', 'old_data', 44, [8, 19, 23, 32, 48, 57]]
# ['args', 'old_data', 48, [8, 19, 23, 32, 44, 57]]
# ['args', 'new_data', 57, [8, 19, 23, 32, 44, 48]]
# ['def', 'include', '(', 'template_name', ',', 'globals', ')', ':', '\n', '<indent>', 'fn', '=', 'os', '.', 'path', '.', 'join', '(', 'os', '.', 'path', '.', 'dirname', '(', '__file__', ')', ',', '"str"', '%', 'template_name', ')', '\n', 'assert', '(', 'os', '.', 'path', '.', 'exists', '(', 'fn', ')', ')', '\n', 'exec', '(', 'compile', '(', 'open', '(', 'fn', ',', '"str"', ')', '.', 'read', '(', ')', ',', 'fn', ',', '"str"', ')', ',', 'globals', ')', '\n', '<dedent>', '<endf>']
# []
# ['fn', 'globals', 40, [10, 50, 59]]
# ['globals', 'template_name', 64, [5]]
# ['template_name', 'fn', 29, [3]]
# ['fn', 'globals', 59, [10, 40, 50]]
# ['fn', 'template_name', 50, [10, 40, 59]]
# ['def', 'expand_key', '(', 'key', ',', 'separator', '=', '"str"', ')', ':', '\n', '<nl>', '"str"', '\n', '<indent>', 'key_t', '=', 'type', '(', 'key', ')', '\n', '<nl>', 'if', '(', 'key_t', '==', 'list', ')', ':', '\n', '<indent>', 'key', '=', 'tuple', '(', 'key', ')', '\n', '<nl>', '<dedent>', 'elif', '(', 'key_t', '==', 'str', ')', 'or', '(', 'key_t', '==', 'str', ')', ':', '\n', '<indent>', 'key', '=', 'tuple', '(', 'key', '.', 'split', '(', 'separator', ')', ')', '\n', '<nl>', '<dedent>', 'elif', '(', 'key_t', '!=', 'tuple', ')', ':', '\n', '<indent>', 'raise', 'ValueError', '(', '"str"', '%', 'key', ')', '\n', '<nl>', '<dedent>', 'if', '(', 'len', '(', 'key', ')', '==', '0', ')', ':', '\n', '<indent>', 'raise', 'ValueError', '(', '"str"', ')', '\n', '<nl>', '<dedent>', 'for', 'i', ',', 'subkey', 'in', 'enumerate', '(', 'key', ')', ':', '\n', '<indent>', 'if', '(', 'subkey', '.', 'startswith', '(', '"str"', ')', ')', 'and', '(', 'i', '+', '1', '<', 'len', '(', 'key', ')', ')', ':', '\n', '<indent>', 'raise', 'ValueError', '(', '"str"', '%', '(', 'separator', '.', 'join', '(', 'key', ')', ',', 'subkey', ')', ')', '\n', '<nl>', '<dedent>', '<dedent>', 'return', 'key', '\n', '<dedent>', '<endf>']
# [[11, '###DCSTR### Expand a dot-notation key into a list\n        ']]
# ['key', 'i', 165, [3, 19, 32, 36, 56, 60, 84, 93, 116, 138, 154]]
# ['key', 'separator', 19, [3, 32, 36, 56, 60, 84, 93, 116, 138, 154, 165]]
# ['key_t', 'key', 25, [15, 43, 49, 72]]
# ['key', 'separator', 116, [3, 19, 32, 36, 56, 60, 84, 93, 138, 154, 165]]
# ['key', 'separator', 36, [3, 19, 32, 56, 60, 84, 93, 116, 138, 154, 165]]
# ['key', 'subkey', 93, [3, 19, 32, 36, 56, 60, 84, 116, 138, 154, 165]]
# ['key_t', 'i', 43, [15, 25, 49, 72]]
# ['key_t', 'i', 49, [15, 25, 43, 72]]
# ['key_t', 'key', 72, [15, 25, 43, 49]]
# ['separator', 'key', 64, [5, 150]]
# ['subkey', 'separator', 123, [112, 157]]
# ['i', 'separator', 132, [110]]
# ['key', 'separator', 138, [3, 19, 32, 36, 56, 60, 84, 93, 116, 154, 165]]
# ['key', 'subkey', 60, [3, 19, 32, 36, 56, 84, 93, 116, 138, 154, 165]]
# ['key', 'key_t', 84, [3, 19, 32, 36, 56, 60, 93, 116, 138, 154, 165]]
# ['subkey', 'key_t', 157, [112, 123]]
# ['key', 'subkey', 154, [3, 19, 32, 36, 56, 60, 84, 93, 116, 138, 165]]
# ['separator', 'i', 150, [5, 64]]
# ['def', 'set', '(', 'dictionary', ',', 'key', ',', 'value', ')', ':', '\n', '<nl>', '"str"', '\n', '<indent>', 'is_leaf', ',', 'root', '=', '(', 'len', '(', 'key', ')', '==', '1', ')', ',', 'key', '[', '0', ']', '\n', '<nl>', 'if', '(', 'is_leaf', ')', ':', '\n', '<indent>', 'dictionary', '[', 'root', ']', '=', 'value', '\n', '<dedent>', 'else', ':', '\n', '<indent>', 'if', '(', 'not', 'root', 'in', 'dictionary', ')', ':', '\n', '<indent>', 'dictionary', '[', 'root', ']', '=', '{', '}', '\n', '<nl>', '<dedent>', 'set', '(', 'dictionary', '[', 'root', ']', ',', 'key', '[', '1', ':', ']', ',', 'value', ')', '\n', '<dedent>', '<dedent>', '<endf>']
# [[11, "###DCSTR### Insert a nested key into a dictionary\n\nParameters:\n        - **dictionary**: dictionary to populate\n        - **key**: nested key, as a list\n        - **value**: value to set\n\nExample:\n        > m = {}\n        > set(m, ('a', 'b', 'c'), 1)\n        > print m\n        {'a': {'b': {'c': 1}}}"]]
# ['is_leaf', 'root', 36, [15]]
# ['value', 'key', 46, [7, 86]]
# ['key', 'is_leaf', 28, [5, 22, 80]]
# ['dictionary', 'value', 41, [3, 58, 63, 75]]
# ['value', 'key', 86, [7, 46]]
# ['key', 'value', 22, [5, 28, 80]]
# ['root', 'is_leaf', 43, [17, 56, 65, 77]]
# ['root', 'dictionary', 56, [17, 43, 65, 77]]
# ['dictionary', 'is_leaf', 58, [3, 41, 63, 75]]
# ['dictionary', 'value', 63, [3, 41, 58, 75]]
# ['dictionary', 'value', 75, [3, 41, 58, 63]]
# ['key', 'value', 80, [5, 22, 28]]
# ['root', 'dictionary', 65, [17, 43, 56, 77]]
# ['root', 'dictionary', 77, [17, 43, 56, 65]]
# ['def', 'get', '(', 'dictionary', ',', 'key', ')', ':', '\n', '<nl>', '"str"', '\n', '<indent>', 'is_leaf', ',', 'root', '=', '(', 'len', '(', 'key', ')', '==', '1', ')', ',', 'key', '[', '0', ']', '\n', '<nl>', 'if', '(', 'is_leaf', ')', ':', '\n', '<indent>', 'return', 'dictionary', '[', 'root', ']', '\n', '<dedent>', 'else', ':', '\n', '<indent>', 'return', 'get', '(', 'dictionary', '[', 'root', ']', ',', 'key', '[', '1', ':', ']', ')', '\n', '<dedent>', '<dedent>', '<endf>']
# [[9, '###DCSTR### Query a nested key from a dictionary\n\nParameters:\n        - **dictionary**: dictionary to query\n        - **key**: nested key, as a list']]
# ['is_leaf', 'dictionary', 34, [13]]
# ['key', 'is_leaf', 26, [5, 20, 58]]
# ['dictionary', 'key', 40, [3, 53]]
# ['key', 'is_leaf', 20, [5, 26, 58]]
# ['root', 'key', 42, [15, 55]]
# ['dictionary', 'is_leaf', 53, [3, 40]]
# ['key', 'root', 58, [5, 20, 26]]
# ['root', 'dictionary', 55, [15, 42]]
# ['def', 'delete', '(', 'dictionary', ',', 'key', ')', ':', '\n', '<nl>', '"str"', '\n', '<indent>', 'is_leaf', ',', 'root', '=', '(', 'len', '(', 'key', ')', '==', '1', ')', ',', 'key', '[', '0', ']', '\n', '<nl>', 'if', '(', 'type', '(', 'dictionary', ')', '!=', 'dict', ')', ':', '\n', '<indent>', 'raise', 'KeyError', '(', 'root', ')', '\n', '<nl>', '<dedent>', 'if', '(', 'is_leaf', ')', ':', '\n', '<indent>', 'del', 'dictionary', '[', 'root', ']', '\n', '<nl>', '<dedent>', 'else', ':', '\n', '<indent>', 'delete', '(', 'dictionary', '[', 'root', ']', ',', 'key', '[', '1', ':', ']', ')', '\n', 'if', '(', 'len', '(', 'dictionary', '[', 'root', ']', ')', '==', '0', ')', ':', '\n', '<indent>', 'del', 'dictionary', '[', 'root', ']', '\n', '<dedent>', '<dedent>', '<dedent>', '<endf>']
# [[9, '###DCSTR### Delete a nested key from a dictionary\n\nParameters:\n        - **dictionary**: dictionary to modify\n        - **key**: nested key to delete, as a list']]
# ['is_leaf', 'dictionary', 54, [13]]
# ['key', 'root', 26, [5, 20, 78]]
# ['dictionary', 'key', 36, [3, 60, 73, 89, 101]]
# ['root', 'is_leaf', 47, [15, 62, 75, 91, 103]]
# ['dictionary', 'root', 60, [3, 36, 73, 89, 101]]
# ['key', 'root', 20, [5, 26, 78]]
# ['root', 'is_leaf', 62, [15, 47, 75, 91, 103]]
# ['dictionary', 'root', 73, [3, 36, 60, 89, 101]]
# ['key', 'root', 78, [5, 20, 26]]
# ['dictionary', 'root', 101, [3, 36, 60, 73, 89]]
# ['root', 'dictionary', 75, [15, 47, 62, 91, 103]]
# ['dictionary', 'root', 89, [3, 36, 60, 73, 101]]
# ['root', 'dictionary', 103, [15, 47, 62, 75, 91]]
# ['root', 'dictionary', 91, [15, 47, 62, 75, 103]]
# ['def', 'contains', '(', 'dictionary', ',', 'key', ')', ':', '\n', '<nl>', '"str"', '\n', '<indent>', 'is_leaf', ',', 'root', '=', '(', 'len', '(', 'key', ')', '==', '1', ')', ',', 'key', '[', '0', ']', '\n', '<nl>', 'if', '(', 'root', 'in', 'dictionary', ')', ':', '\n', '<indent>', 'if', '(', 'is_leaf', ')', ':', '\n', '<indent>', 'return', 'True', '\n', '<nl>', '<dedent>', 'if', '(', 'type', '(', 'dictionary', '[', 'root', ']', ')', '!=', 'dict', ')', ':', '\n', '<indent>', 'return', 'False', '\n', '<nl>', '<dedent>', 'return', 'contains', '(', 'dictionary', '[', 'root', ']', ',', 'key', '[', '1', ':', ']', ')', '\n', '<nl>', '<dedent>', 'return', 'False', '\n', '<dedent>', '<endf>']
# [[9, '###DCSTR### Test if a dictionary contains a nested key\n\nParameters:\n        - **dictionary**: dictionary to evaluate\n        - **key**: nested key to test, as a list']]
# ['root', 'dictionary', 34, [15, 59, 78]]
# ['dictionary', 'root', 36, [3, 57, 76]]
# ['is_leaf', 'dictionary', 43, [13]]
# ['key', 'is_leaf', 26, [5, 20, 81]]
# ['key', 'dictionary', 20, [5, 26, 81]]
# ['dictionary', 'key', 76, [3, 36, 57]]
# ['key', 'root', 81, [5, 20, 26]]
# ['dictionary', 'root', 57, [3, 36, 76]]
# ['root', 'is_leaf', 78, [15, 34, 59]]
# ['root', 'dictionary', 59, [15, 34, 78]]
# ['def', 'items', '(', 'dictionary', ')', ':', '\n', '<nl>', '"str"', '\n', '<indent>', 'def', 'walk', '(', 'node', ',', 'b', '=', '[', ']', ')', ':', '\n', '<indent>', 'items', '=', '[', ']', '\n', '<nl>', 'for', 'key', 'in', 'node', ':', '\n', '<indent>', 'branch', ',', 'value', '=', 'b', '+', 'list', '(', 'expand_key', '(', 'key', ')', ')', ',', 'node', '[', 'key', ']', '\n', '<nl>', 'if', '(', 'type', '(', 'value', ')', '==', 'dict', ')', ':', '\n', '<indent>', 'items', '.', 'extend', '(', 'walk', '(', 'value', ',', 'branch', ')', ')', '\n', '<dedent>', 'else', ':', '\n', '<indent>', 'items', '.', 'append', '(', '(', 'tuple', '(', 'branch', ')', ',', 'value', ')', ')', '\n', '<nl>', '<dedent>', '<dedent>', 'return', 'items', '\n', '<nl>', '<dedent>', 'return', 'walk', '(', 'dictionary', ')', '\n', '<dedent>', '<endf>']
# [[7, "###DCSTR### Iterate through a nested dictionary and return all\nkeys (as lists) and values\n\nParameters:\n        - **dictionary**: dictionary to browse\n\nExample:\n        > m = {'a': {'b': {'c': 1}, 'd': 2}}\n        > print items(m)\n        [(('a', 'b', 'c'), 1), (('a', 'd'), 2)]"]]
# ['items', 'dictionary', 104, [1, 24, 69, 86]]
# ['dictionary', 'items', 111, [3]]
# ['value', 'branch', 61, [39, 75, 96]]
# ['key', 'branch', 53, [31, 47]]
# ['items', 'branch', 69, [1, 24, 86, 104]]
# ['value', 'dictionary', 75, [39, 61, 96]]
# ['branch', 'value', 77, [37, 93]]
# ['items', 'dictionary', 86, [1, 24, 69, 104]]
# ['value', 'dictionary', 96, [39, 61, 75]]
# ['key', 'items', 47, [31, 53]]
# ['branch', 'dictionary', 93, [37, 77]]
# ['def', 'expand', '(', 'dictionary', ',', 'separator', '=', '"str"', ')', ':', '\n', '<nl>', '"str"', '\n', '<indent>', 'd', '=', '{', '}', '\n', 'for', 'key', ',', 'value', 'in', 'dictionary', '.', 'items', '(', ')', ':', '\n', '<indent>', 'set', '(', 'd', ',', 'expand_key', '(', 'key', ',', 'separator', ')', ',', 'value', ')', '\n', '<nl>', '<dedent>', 'return', 'd', '\n', '<dedent>', '<endf>']
# [[11, '###DCSTR### Transform a dictionary with dot-notation keys into a nested dictionary\n\nParameters:\n        - **dictionary**: dictionary to transform\n\nExample:\n        > m = {"a.b.c": 1}\n        > print expand(m)\n        {"a": {"b": {"c": 1}}}']]
# ['d', 'separator', 50, [15, 35]]
# ['dictionary', 'd', 25, [3]]
# ['d', 'separator', 35, [15, 50]]
# ['value', 'key', 44, [23]]
# ['key', 'value', 39, [21]]
# ['separator', 'dictionary', 41, [5]]
# ['def', 'flatten', '(', 'dictionary', ',', 'separator', '=', '"str"', ')', ':', '\n', '<nl>', '"str"', '\n', '<indent>', 'd', '=', '{', '}', '\n', 'for', '(', 'key', ',', 'value', ')', 'in', 'items', '(', 'dictionary', ')', ':', '\n', '<nl>', '<indent>', 'if', '(', 'key', '[', '-', '1', ']', '.', 'startswith', '(', '"str"', ')', ')', ':', '\n', '<indent>', 'd', '[', 'separator', '.', 'join', '(', 'key', '[', ':', '-', '1', ']', ')', ']', '=', '{', 'key', '[', '-', '1', ']', ':', 'value', '}', '\n', '<dedent>', 'else', ':', '\n', '<indent>', 'd', '[', 'separator', '.', 'join', '(', 'key', ')', ']', '=', 'value', '\n', '<nl>', '<dedent>', '<dedent>', 'return', 'd', '\n', '<dedent>', '<endf>']
# [[11, '###DCSTR### Transform a nested dictionary into a dictionary with dot-notations\n\nParameters:\n        - **dictionary**: dictionary to transform\n\nExample:\n        > m = {"a": {"b": {"c": 1}}}\n        > print flatten(m)\n        {"a.b.c": 1}'], [32, "# hack: we don't want to flatten special MongoDB"], [33, "# keys (everything starting with a '$')"]]
# ['d', 'value', 97, [15, 51, 81]]
# ['dictionary', 'key', 29, [3]]
# ['value', 'separator', 91, [24, 73]]
# ['d', 'value', 51, [15, 81, 97]]
# ['value', 'key', 73, [24, 91]]
# ...
# ['lat', 'hr', 40, [15]]
# ['row', 'lat', 29, [5]]
# ['a', 'hr', 45, [19]]
# ['t', 'pa', 47, [23]]
# ['def', '_high_quality_on_locations', '(', ')', ':', '\n', '<indent>', 'pth', '=', 'os', '.', 'path', '.', 'join', '(', 'os', '.', 'path', '.', 'dirname', '(', '__file__', ')', ',', '"str"', ',', '"str"', ')', '\n', 'rows', '=', 'list', '(', 'map', '(', 'int', ',', 'open', '(', 'pth', ')', '.', 'readlines', '(', ')', ')', ')', '\n', 'cat', '=', 'get_catalog', '(', ')', '\n', '<nl>', 'return', '[', '_on_args', '(', 'cat', ',', 'row', ')', 'for', 'row', 'in', 'rows', ']', '\n', '<dedent>', '<endf>']
# []
# ['cat', 'rows', 59, [48]]
# ['row', 'cat', 61, [64]]
# ['rows', 'cat', 66, [29]]
# ['pth', 'row', 39, [7]]
# ['def', 'bubble_params', '(', 'bubbles', '=', 'None', ')', ':', '\n', '<indent>', 'c', '=', 'get_catalog', '(', ')', '\n', 'bubbles', '=', 'bubbles', 'or', 'list', '(', 'range', '(', 'len', '(', 'c', ')', ')', ')', '\n', '<nl>', 'result', '=', '[', ']', '\n', 'for', 'b', 'in', 'bubbles', ':', '\n', '<indent>', 'args', '=', '_on_args', '(', 'c', ',', 'b', ')', '\n', 'result', '.', 'append', '(', '[', 'int', '(', 'np', '.', 'round', '(', 'args', '[', '0', ']', ')', ')', ',', 'args', '[', '0', ']', ',', 'args', '[', '1', ']', ',', 'args', '[', '2', ']', ']', ')', '\n', '<dedent>', 'return', 'result', '\n', '<dedent>', '<endf>']
# []
# ['bubbles', 'c', 40, [3, 16, 18]]
# ['result', 'c', 90, [32, 53]]
# ['bubbles', 'args', 18, [3, 16, 40]]
# ['c', 'result', 48, [10, 26]]
# ['b', 'result', 50, [38]]
# ['result', 'c', 53, [32, 90]]
# ['c', 'bubbles', 26, [10, 48]]
# ['args', 'c', 71, [44, 64, 76, 81]]
# ['args', 'c', 76, [44, 64, 71, 81]]
# ['args', 'b', 81, [44, 64, 71, 76]]
# ['args', 'result', 64, [44, 71, 76, 81]]
# ['def', 'on_stamp_params', '(', ')', ':', '\n', '<nl>', '"str"', '\n', '<indent>', 'for', 'l', ',', 'b', ',', 'r', 'in', '_high_quality_on_locations', '(', ')', ':', '\n', '<indent>', 'yield', 'int', '(', 'np', '.', 'round', '(', 'l', ')', ')', ',', 'l', ',', 'b', ',', 'r', '\n', '<dedent>', '<dedent>', '<endf>']
# [[6, '###DCSTR### Iterate over medium quality + examples,\nyield tuples of (field_lon, lcen, bcen, r)\n\nThese can be fed to Extractor objects']]
# ['l', 'b', 34, [11, 30]]
# ['b', 'r', 36, [13]]
# ['r', 'b', 38, [15]]
# ['l', 'r', 30, [11, 34]]
# ['def', 'highest_quality_on_params', '(', ')', ':', '\n', '<nl>', '"str"', '\n', '<indent>', 'pth', '=', 'os', '.', 'path', '.', 'join', '(', 'os', '.', 'path', '.', 'dirname', '(', '__file__', ')', ',', '"str"', ',', '"str"', ',', '"str"', ')', '\n', 'data', '=', 'pickle', '.', 'load', '(', 'open', '(', 'pth', ')', ')', '\n', 'for', 'k', ',', '(', 'l', ',', 'b', ',', 'r', ')', 'in', 'list', '(', 'data', '.', 'items', '(', ')', ')', ':', '\n', '<indent>', 'if', 'os', '.', 'path', '.', 'exists', '(', 'os', '.', 'path', '.', 'join', '(', 'os', '.', 'path', '.', 'dirname', '(', 'pth', ')', ',', 'k', ')', ')', ':', '\n', '<indent>', 'yield', 'int', '(', 'np', '.', 'round', '(', 'l', ')', ')', ',', 'l', ',', 'b', ',', 'r', '\n', '<dedent>', '<dedent>', '<dedent>', '<endf>']
# [[6, '###DCSTR### Iterate over highest-confidence + examples\nyield tuples of (field_lon, lcen, bcen, r)']]
# ['pth', 'b', 42, [10, 87]]
# ['data', 'l', 59, [34]]
# ['k', 'b', 90, [47]]
# ['pth', 'data', 87, [10, 42]]
# ['l', 'r', 107, [50, 103]]
# ['b', 'l', 109, [52]]
# ['r', 'data', 111, [54]]
# ['l', 'r', 103, [50, 107]]
# ['def', 'filter', '(', 'hit_rate', '=', '0.3', ')', ':', '\n', '<indent>', 'cat', '=', 'get_catalog', '(', ')', '\n', 'infile', '=', '"str"', '\n', 'on_id', '=', 'np', '.', 'array', '(', 'list', '(', 'map', '(', 'int', ',', 'list', '(', 'h5py', '.', 'File', '(', 'infile', ',', '"str"', ')', '[', '"str"', ']', '.', 'keys', '(', ')', ')', ')', ')', ')', '\n', '<nl>', 'rgbs', '=', 'list', '(', 'h5py', '.', 'File', '(', 'infile', ',', '"str"', ')', '[', '"str"', ']', '.', 'values', '(', ')', ')', '\n', '<nl>', 'def', 'has_green', '(', 'rgb', ')', ':', '\n', '<indent>', 'return', '(', 'rgb', '[', ':', ',', ':', ',', '1', ']', '==', '0', ')', '.', 'mean', '(', ')', '<', '0.3', '\n', '<nl>', '<dedent>', 'good', '=', 'np', '.', 'array', '(', '[', 'has_green', '(', 'r', ')', 'for', 'r', 'in', 'rgbs', ']', ',', 'dtype', '=', 'np', '.', 'bool', ')', '\n', '<nl>', 'good', '=', 'good', '&', '(', 'cat', '[', 'on_id', ',', '-', '1', ']', '>', '0.3', ')', '\n', 'result', '=', '[', '_on_args', '(', 'cat', ',', 'row', ')', 'for', 'row', 'in', 'on_id', '[', 'good', ']', ']', '\n', 'return', 'result', '\n', '<dedent>', '<endf>']
# [[76, '#has green channel...'], [131, '#...and hit rate > 0.3']]
# ['result', 'cat', 167, [148]]
# ['good', 'row', 134, [107, 132, 162]]
# ['cat', 'rgbs', 153, [10, 137]]
# ['row', 'rgbs', 155, [158]]
# ['r', 'cat', 116, [119]]
# ['rgbs', 'row', 121, [55]]
# ['cat', 'rgbs', 137, [10, 153]]
# ['on_id', 'hit_rate', 160, [20, 139]]
# ['good', 'result', 162, [107, 132, 134]]
# ['infile', 'cat', 63, [16, 38]]
# ['on_id', 'hit_rate', 139, [20, 160]]
# ['infile', 'on_id', 38, [16, 63]]
# ['def', 'main', '(', ')', ':', '\n', '<indent>', 'pth', '=', '"str"', '\n', '<nl>', 'result', '=', 'list', '(', 'filter', '(', ')', ')', '\n', '<nl>', 'with', 'open', '(', 'pth', ',', '"str"', ')', 'as', 'outfile', ':', '\n', '<indent>', 'pickle', '.', 'dump', '(', 'result', ',', 'outfile', ')', '\n', '<dedent>', '<dedent>', '<endf>']
# []
# ['pth', 'outfile', 25, [7]]
# ['result', 'pth', 38, [12]]
# ['outfile', 'result', 40, [30]]
# ['def', 'get_url', '(', 'url', ',', 'fname', ',', 'target_dir', '=', '"str"', ')', ':', '\n', '<nl>', '"str"', '\n', '<indent>', 'outfile', '=', 'os', '.', 'path', '.', 'join', '(', 'target_dir', '+', 'fname', ')', '\n', 'if', 'os', '.', 'path', '.', 'exists', '(', 'outfile', ')', 'and', '(', 'os', '.', 'path', '.', 'getsize', '(', 'outfile', ')', '>', '0', ')', ':', '\n', '<indent>', 'return', '\n', '<nl>', '<dedent>', 'print', '(', '"str"', '%', '(', 'url', '+', 'fname', ')', ')', '\n', 'data', '=', 'urlopen', '(', 'url', '+', 'fname', ')', '\n', '<nl>', 'if', 'data', '.', 'getcode', '(', ')', '!=', '200', ':', '\n', '<indent>', 'print', '(', '"str"', '%', '(', 'url', '+', 'fname', ',', 'data', '.', 'getcode', '(', ')', ')', ')', '\n', 'return', '\n', '<nl>', '<dedent>', 't0', '=', 'time', '(', ')', '\n', 'with', 'open', '(', 'outfile', ',', '"str"', ')', 'as', 'out', ':', '\n', '<indent>', 'out', '.', 'write', '(', 'data', '.', 'read', '(', ')', ')', '\n', '<dedent>', 't1', '=', 'time', '(', ')', '\n', 'print', '(', '"str"', '%', '(', 't1', '-', 't0', ')', ')', '\n', '<dedent>', '<endf>']
# [[13, '###DCSTR### Save a file from the internet\n\nParameters\n----------\nurl : The url to download\nfname : The filename to save to\ntarget_dir : The directory to save into. Default= galaxy/raw']]
# ['target_dir', 'fname', 25, [7]]
# ['fname', 'out', 27, [5, 66, 76, 98]]
# ['outfile', 'url', 37, [17, 47, 121]]
# ['url', 'target_dir', 74, [3, 64, 96]]
# ['fname', 'data', 76, [5, 27, 66, 98]]
# ['outfile', 'data', 121, [17, 37, 47]]
# ['outfile', 'data', 47, [17, 37, 121]]
# ['url', 'fname', 64, [3, 74, 96]]
# ['fname', 't0', 66, [5, 27, 76, 98]]
# ['data', 'fname', 81, [70, 100, 134]]
# ['out', 't1', 130, [126]]
# ['t1', 'data', 153, [142]]
# ['t0', 'outfile', 155, [112]]
# ['data', 'outfile', 134, [70, 81, 100]]
# ['url', 't0', 96, [3, 64, 74]]
# ['fname', 'out', 98, [5, 27, 66, 76]]
# ['data', 'fname', 100, [70, 81, 134]]
# ['def', 'get_glimpse', '(', 'folder', ',', 'lon', ',', 'survey', '=', '"str"', ')', ':', '\n', '<nl>', '"str"', '\n', '<nl>', '<indent>', 'base_url', '=', '"str"', '%', 'survey', '\n', 'i3', '=', '"str"', '%', 'lon', '\n', 'i4', '=', '"str"', '%', 'lon', '\n', 'get_url', '(', 'base_url', '+', 'folder', ',', 'i3', ')', '\n', 'get_url', '(', 'base_url', '+', 'folder', ',', 'i4', ')', '\n', '<dedent>', '<endf>']
# [[13, "###DCSTR### Download GLIMPSE images I3 and I4 for a single longitude\n\nParameters\n----------\nfolder : Sub-directory on IPAC website (e.g. 'GLON_10-30')\nlon : Longitude tile to grab\nsurvey : Optional survey ('I', 'II')"]]
# ['survey', 'base_url', 22, [7]]
# ['lon', 'i4', 28, [5, 34]]
# ['lon', 'i3', 34, [5, 28]]
# ['i3', 'survey', 42, [24]]
# ['i4', 'survey', 51, [30]]
# ['base_url', 'survey', 38, [18, 47]]
# ['folder', 'survey', 40, [3, 49]]
# ['base_url', 'folder', 47, [18, 38]]
# ['folder', 'i4', 49, [3, 40]]
# ['def', 'get_mips', '(', 'lon', ')', ':', '\n', '<nl>', '"str"', '\n', '<nl>', '<indent>', 'base_url', '=', '"str"', '\n', '<nl>', 'pos', '=', '"str"', '%', 'lon', '\n', 'neg', '=', '"str"', '%', 'lon', '\n', '<nl>', 'get_url', '(', 'base_url', ',', 'pos', ')', '\n', 'get_url', '(', 'base_url', ',', 'neg', ')', '\n', '<dedent>', '<endf>']
# [[7, '###DCSTR### Download MIPS images at b = +/- .5deg\n\nParameters\n----------\nlon : Longitude to grab']]
# ['lon', 'base_url', 21, [3, 27]]
# ['lon', 'base_url', 27, [3, 21]]
# ['base_url', 'lon', 32, [12, 39]]
# ['pos', 'neg', 34, [17]]
# ['base_url', 'pos', 39, [12, 32]]
# ['neg', 'base_url', 41, [23]]
# ['def', 'get_all', '(', 'threads', '=', '5', ')', ':', '\n', '<nl>', '"str"', '\n', '<indent>', 'p', '=', 'Pool', '(', 'threads', ')', '\n', '<nl>', 'lon', '=', 'list', '(', 'range', '(', '12', ',', '30', ',', '3', ')', ')', '\n', 'folder', '=', '"str"', '\n', 'p', '.', 'map', '(', 'partial', '(', 'get_glimpse', ',', 'folder', ')', ',', 'lon', ')', '\n', '<nl>', 'lon', '=', 'list', '(', 'range', '(', '30', ',', '52', ',', '3', ')', ')', '\n', 'folder', '=', '"str"', '\n', 'p', '.', 'map', '(', 'partial', '(', 'get_glimpse', ',', 'folder', ')', ',', 'lon', ')', '\n', '<nl>', 'lon', '=', 'list', '(', 'range', '(', '33', ',', '67', ',', '3', ')', ')', '\n', 'folder', '=', '"str"', '\n', 'p', '.', 'map', '(', 'partial', '(', 'get_glimpse', ',', 'folder', ')', ',', 'lon', ')', '\n', '<nl>', 'lon', '=', 'list', '(', 'range', '(', '294', ',', '310', ',', '3', ')', ')', '\n', 'folder', '=', '"str"', '\n', 'p', '.', 'map', '(', 'partial', '(', 'get_glimpse', ',', 'folder', ')', ',', 'lon', ')', '\n', '<nl>', 'lon', '=', 'list', '(', 'range', '(', '312', ',', '328', ',', '3', ')', ')', '\n', 'folder', '=', '"str"', '\n', 'p', '.', 'map', '(', 'partial', '(', 'get_glimpse', ',', 'folder', ')', ',', 'lon', ')', '\n', '<nl>', 'lon', '=', 'list', '(', 'range', '(', '330', ',', '349', ',', '3', ')', ')', '\n', 'folder', '=', '"str"', '\n', 'p', '.', 'map', '(', 'partial', '(', 'get_glimpse', ',', 'folder', ')', ',', 'lon', ')', '\n', '<nl>', 'lon', '=', 'list', '(', 'range', '(', '0', ',', '10', ',', '3', ')', ')', '\n', 'folder', '=', '"str"', '\n', 'p', '.', 'map', '(', 'partial', '(', 'get_glimpse', ',', 'folder', ',', 'survey', '=', '"str"', ')', ',', 'lon', ')', '\n', '<nl>', 'lon', '=', 'list', '(', 'range', '(', '351', ',', '358', ',', '3', ')', ')', '\n', 'folder', '=', '"str"', '\n', 'p', '.', 'map', '(', 'partial', '(', 'get_glimpse', ',', 'folder', ',', 'survey', '=', '"str"', ')', ',', 'lon', ')', '\n', '<nl>', 'lon', '=', 'list', '(', 'range', '(', '70', ')', ')', '\n', 'p', '.', 'map', '(', 'get_mips', ',', 'lon', ')', '\n', '<nl>', 'lon', '=', 'list', '(', 'range', '(', '292', ',', '361', ')', ')', '\n', 'p', '.', 'map', '(', 'get_mips', ',', 'lon', ')', '\n', '<dedent>', '<endf>']
# [[9, '###DCSTR### Grab all the data\n\nParameters\n----------\nThreads : how many worker threads to use'], [292, '#XXX GLIMPSE 3D']]
# ['threads', 'folder', 17, [3]]
# ['lon', 'folder', 50, [21, 54, 83, 87, 116, 120, 149, 153, 182, 186, 215, 219, 252, 256, 289, 293, 309, 313, 331]]
# ['lon', 'threads', 83, [21, 50, 54, 87, 116, 120, 149, 153, 182, 186, 215, 219, 252, 256, 289, 293, 309, 313, 331]]
# ['lon', 'folder', 116, [21, 50, 54, 83, 87, 120, 149, 153, 182, 186, 215, 219, 252, 256, 289, 293, 309, 313, 331]]
# ['lon', 'p', 149, [21, 50, 54, 83, 87, 116, 120, 153, 182, 186, 215, 219, 252, 256, 289, 293, 309, 313, 331]]
# ['lon', 'threads', 182, [21, 50, 54, 83, 87, 116, 120, 149, 153, 186, 215, 219, 252, 256, 289, 293, 309, 313, 331]]
# ['lon', 'p', 215, [21, 50, 54, 83, 87, 116, 120, 149, 153, 182, 186, 219, 252, 256, 289, 293, 309, 313, 331]]
# ['lon', 'threads', 252, [21, 50, 54, 83, 87, 116, 120, 149, 153, 182, 186, 215, 219, 256, 289, 293, 309, 313, 331]]
# ['lon', 'folder', 289, [21, 50, 54, 83, 87, 116, 120, 149, 153, 182, 186, 215, 219, 252, 256, 293, 309, 313, 331]]
# ['lon', 'p', 309, [21, 50, 54, 83, 87, 116, 120, 149, 153, 182, 186, 215, 219, 252, 256, 289, 293, 313, 331]]
# ['lon', 'threads', 331, [21, 50, 54, 83, 87, 116, 120, 149, 153, 182, 186, 215, 219, 252, 256, 289, 293, 309, 313]]
# ['p', 'folder', 39, [13, 72, 105, 138, 171, 204, 237, 274, 303, 325]]
# ['folder', 'threads', 47, [35, 68, 80, 101, 113, 134, 146, 167, 179, 200, 212, 233, 245, 270, 282]]
# ['p', 'folder', 72, [13, 39, 105, 138, 171, 204, 237, 274, 303, 325]]
# ['folder', 'threads', 80, [35, 47, 68, 101, 113, 134, 146, 167, 179, 200, 212, 233, 245, 270, 282]]
# ['p', 'folder', 105, [13, 39, 72, 138, 171, 204, 237, 274, 303, 325]]
# ['folder', 'p', 113, [35, 47, 68, 80, 101, 134, 146, 167, 179, 200, 212, 233, 245, 270, 282]]
# ['p', 'folder', 138, [13, 39, 72, 105, 171, 204, 237, 274, 303, 325]]
# ['folder', 'p', 146, [35, 47, 68, 80, 101, 113, 134, 167, 179, 200, 212, 233, 245, 270, 282]]
# ['p', 'threads', 171, [13, 39, 72, 105, 138, 204, 237, 274, 303, 325]]
# ['folder', 'threads', 179, [35, 47, 68, 80, 101, 113, 134, 146, 167, 200, 212, 233, 245, 270, 282]]
# ['p', 'folder', 204, [13, 39, 72, 105, 138, 171, 237, 274, 303, 325]]
# ['folder', 'threads', 212, [35, 47, 68, 80, 101, 113, 134, 146, 167, 179, 200, 233, 245, 270, 282]]
# ['p', 'lon', 237, [13, 39, 72, 105, 138, 171, 204, 274, 303, 325]]
# ['folder', 'threads', 245, [35, 47, 68, 80, 101, 113, 134, 146, 167, 179, 200, 212, 233, 270, 282]]
# ['p', 'threads', 274, [13, 39, 72, 105, 138, 171, 204, 237, 303, 325]]
# ['folder', 'p', 282, [35, 47, 68, 80, 101, 113, 134, 146, 167, 179, 200, 212, 233, 245, 270]]
# ['p', 'lon', 303, [13, 39, 72, 105, 138, 171, 204, 237, 274, 325]]
# ['p', 'threads', 325, [13, 39, 72, 105, 138, 171, 204, 237, 274, 303]]
# ['def', 'main', '(', ')', ':', '\n', '<nl>', '<indent>', 'ex', '=', 'RGBExtractor', '(', ')', '\n', 'ex', '.', 'shp', '=', '(', '100', ',', '100', ')', '\n', '<nl>', 'data', '=', 'list', '(', 'filter', '(', 'hit_rate', '=', '0.2', ')', ')', '\n', '<nl>', 'params', '=', '{', '}', '\n', 'for', 'i', ',', 'd', 'in', 'enumerate', '(', 'data', ')', ':', '\n', '<indent>', 'd1', '=', 'list', '(', 'd', ')', '\n', 'd2', '=', 'list', '(', 'd', ')', '\n', 'd2', '[', '-', '1', ']', '*=', '2', '\n', '<nl>', 'l', '=', 'int', '(', 'np', '.', 'round', '(', 'd', '[', '0', ']', ')', ')', '\n', 'd1', '=', '[', 'l', ']', '+', 'd1', '\n', 'd2', '=', '[', 'l', ']', '+', 'd2', '\n', '<nl>', 'im', '=', 'np', '.', 'hstack', '(', '(', 'ex', '(', '*', 'd1', ')', ',', 'ex', '(', '*', 'd2', ')', ')', ')', '\n', 'pth', '=', '"str"', '%', 'i', '\n', 'params', '[', 'pth', ']', '=', 'd', '\n', 'pth', '=', 'os', '.', 'path', '.', 'join', '(', '"str"', ',', 'pth', ')', '\n', 'imsave', '(', 'pth', ',', 'im', ')', '\n', '<nl>', '<dedent>', 'pth', '=', 'os', '.', 'path', '.', 'join', '(', '"str"', ',', '"str"', ')', '\n', 'with', 'open', '(', 'pth', ',', '"str"', ')', 'as', 'outfile', ':', '\n', '<indent>', 'pickle', '.', 'dump', '(', 'params', ',', 'outfile', ')', '\n', '<dedent>', '<dedent>', '<endf>']
# []
# ['ex', 'd', 14, [8, 117, 123]]
# ['data', 'd1', 50, [25]]
# ['d', 'd1', 142, [46, 59, 66, 86]]
# ['d', 'l', 59, [46, 66, 86, 142]]
# ['d', 'im', 66, [46, 59, 86, 142]]
# ['d2', 'ex', 69, [62, 101, 107, 126]]
# ['d1', 'data', 99, [55, 93, 120]]
# ['d2', 'data', 107, [62, 69, 101, 126]]
# ['i', 'im', 135, [44]]
# ['params', 'd1', 137, [38, 195]]
# ['pth', 'im', 154, [131, 139, 144, 159, 166, 182]]
# ['pth', 'd2', 159, [131, 139, 144, 154, 166, 182]]
# ['im', 'd', 161, [110]]
# ['pth', 'outfile', 182, [131, 139, 144, 154, 159, 166]]
# ['params', 'l', 195, [38, 137]]
# ['outfile', 'd', 197, [187]]
# ['l', 'd1', 96, [78, 104]]
# ['l', 'im', 104, [78, 96]]
# ['pth', 'data', 139, [131, 144, 154, 159, 166, 182]]
# ['d', 'im', 86, [46, 59, 66, 142]]
# ['ex', 'd2', 117, [8, 14, 123]]
# ['ex', 'i', 123, [8, 14, 117]]
# ['d1', 'ex', 120, [55, 93, 99]]
# ['d2', 'params', 126, [62, 69, 101, 107]]

# %%
for source, tokens, comments, scope, pairs in data:
    assert len(pairs)> 1
    for pair in pairs:
        iden1, iden2, loc_idx, rep_idxs = pair
        assert len(scope) >= 3
        assert iden1 in scope
        assert iden2 in scope
        assert tokens[loc_idx] == iden1
        for rep_idx in rep_idxs:
            assert tokens[rep_idx] == iden1
        assert len(rep_idxs) >= 1

# %%
for source, tokens, comments, scope, pairs in data:
    print("----------------Data-----------------------")
    print(source)
    print("---------------Ours----------------")
    offset = 0
    for loc, com in comments:
        tokens = tokens[:loc+offset+1] + [com+"\n"] + tokens[loc+offset+1:]
        offset +=1
    print(" ".join(tokens))
    print("----------------------------------------------")
    print("----------------------------------------------")
# Out:
# ----------------Data-----------------------
# def gamma(image):
#   pixel = image.getPixelRgb(120,140)
#   if pixel[0]+pixel[1] + pixel[2] < 96 :
#     return 11
#   else:
#     chunk = image.getChunk("gAMA")
#     if chunk == None:
#       return 12
#     gammav = unpack("!I",chunk.content)
#     if gammav[0] == 400000 :
#       return 13
#     return 14
# ---------------Ours----------------
# # Fingerprint depending on how the decoder treated the gamma information from the input image
#  <nl> def gamma ( image ) :
#  <indent> pixel = image . getPixelRgb ( 120 , 140 )
#  if pixel [ 0 ] + pixel [ 1 ] + pixel [ 2 ] < 96 :
#  <indent> return 11
#  <dedent> else :
#  <indent> chunk = image . getChunk ( "str" )
#  if chunk == None :
#  <indent> return 12
#  <dedent> gammav = unpack ( "str" , chunk . content )
#  if gammav [ 0 ] == 400000 :
#  <indent> return 13
#  <dedent> return 14
#  <dedent> <dedent> <endf>
# ----------------------------------------------
# ----------------------------------------------
# ----------------Data-----------------------
# def physChunk(image):
#   chunk = image.getChunk("pHYs")
#   if chunk == None:
#     return 11
#   x,y,u = unpack("!IIB",chunk.content)
#   if x == 1:
#     return 12
#   if x == 1500:
#     return 13
#   if x == 1499:
#     return 14 # .net
#   return 15
# ---------------Ours----------------
# # Fingerprint depending on how the decoder treated the phys information in the input image
#  <nl> def physChunk ( image ) :
#  <indent> chunk = image . getChunk ( "str" )
#  if chunk == None :
#  <indent> return 11
#  <dedent> x , y , u = unpack ( "str" , chunk . content )
#  if x == 1 :
#  <indent> return 12
#  <dedent> if x == 1500 :
#  <indent> return 13
#  <dedent> if x == 1499 :
#  <indent> return 14 # .net
#
#  <dedent> return 15
#  <dedent> <endf>
# ----------------------------------------------
# ----------------------------------------------
# ----------------Data-----------------------
# def doTests(tests,fingerprints, warn):
#   """
#   my documentation
#   """
#   results  = {}
#   fingerprintScores = {}
#   # Initialite the count of matching tests to zero for each fingerprint
#   for fingerprint in fingerprints :
#     fingerprintScores[fingerprint.name] = 0
#   # Execute each test
#   for test in tests:
#     image = Png(directory + test.filename+".png")
#     if not image.valid == 0:
#             # Only execute the test if there is an image to test
#       result = test.function(image)
#     else :
#       result = 0
#     """
#     my long comment
#     """
#     # Save the result of the test
#     results[test.name] = result
#
#     # Check if the result matches some of the fingeprints and if so, increment the match counter
#     for fingerprint in fingerprints :
#       if not test.name in fingerprint.results:
#             # warn if a fingerprint is missing the result for the test being run
#         if warn:
#           print("warning, missing key", test.name,"in", fingerprint.name)
#       elif fingerprint.results[test.name] == result :
#         fingerprintScores[fingerprint.name] += 1
#   return results,fingerprintScores
# ---------------Ours----------------
# # Test all the images in a directory (don't print warnings when generating fingerprints)
#  <nl> def doTests ( tests , fingerprints , warn ) :
#  <nl> ###DCSTR### my documentation
#  "str"
#  <indent> results = { }
#  fingerprintScores = { }
#  # Initialite the count of matching tests to zero for each fingerprint
#  <nl> for fingerprint in fingerprints :
#  <indent> fingerprintScores [ fingerprint . name ] = 0
#  # Execute each test
#  <nl> <dedent> for test in tests :
#  <indent> image = Png ( directory + test . filename + "str" )
#  if not image . valid == 0 :
#  # Only execute the test if there is an image to test
#  <nl> <indent> result = test . function ( image )
#  <dedent> else :
#  <indent> result = 0
#  <dedent> "str"
#  # Save the result of the test
#  <nl> results [ test . name ] = result
#  <nl> # Check if the result matches some of the fingeprints and if so, increment the match counter
#  for fingerprint in fingerprints :
#  <indent> if not test . name in fingerprint . results :
#  # warn if a fingerprint is missing the result for the test being run
#  <nl> <indent> if warn :
#  <indent> print ( "str" , test . name , "str" , fingerprint . name )
#  <dedent> <dedent> elif fingerprint . results [ test . name ] == result :
#  <indent> fingerprintScores [ fingerprint . name ] += 1
#  <dedent> <dedent> <dedent> return results , fingerprintScores
#  <dedent> <endf>
# ----------------------------------------------
# ----------------------------------------------
# ----------------Data-----------------------
# def generateCsv(tests,fingerprints):
#   header = "/"
#   for test in tests:
#     header = header+ "\t"+test.name
#   print(header)
#
#   for fingerprint in fingerprints:
#     row = fingerprint.name
#     for test in tests:
#       if not test.name in fingerprint.results:
#         row += "\t\"\""
#       else:
#         row += "\t"+ str(fingerprint.results[test.name])
#     print(row)
# ---------------Ours----------------
# # Generate a csv table with all the test results for each fingerprint (which you can then import in LibreOffice or whatever)
#  <nl> def generateCsv ( tests , fingerprints ) :
#  <indent> header = "str"
#  for test in tests :
#  <indent> header = header + "str" + test . name
#  <dedent> print ( header )
#  <nl> for fingerprint in fingerprints :
#  <indent> row = fingerprint . name
#  for test in tests :
#  <indent> if not test . name in fingerprint . results :
#  <indent> row += "str"
#  <dedent> else :
#  <indent> row += "str" + str ( fingerprint . results [ test . name ] )
#  <dedent> <dedent> print ( row )
#  <dedent> <dedent> <endf>
# ----------------------------------------------
# ----------------------------------------------
# ----------------Data-----------------------
# def showResults(scores, nb):
#   ordered = sorted(iter(scores.items()), key=itemgetter(1))
#   for result in ordered :
#     print('{:20s} {:3d}/{:3d}'.format(result[0], result[1], nb))
# ---------------Ours----------------
# # Show the fingerprinting result with the most likely library match at the bottom
#  <nl> def showResults ( scores , nb ) :
#  <indent> ordered = sorted ( iter ( scores . items ( ) ) , key = itemgetter ( 1 ) )
#  for result in ordered :
#  <indent> print ( "str" . format ( result [ 0 ] , result [ 1 ] , nb ) )
#  <dedent> <dedent> <endf>
# ----------------------------------------------
# ----------------------------------------------
# ----------------Data-----------------------
# def construct_tree(X, k, prune_threshold=None, num_levels=None, verbose=False):
#     """
#     Construct a level set tree from tabular data.
#
#     Parameters
#     ----------
#     X : 2-dimensional numpy array
#         Numeric dataset, where each row represents one observation.
#
#     k : int
#         Number of observations to consider as neighbors to a given point.
#
#     prune_threshold : int, optional
#         Leaf nodes with fewer than this number of members are recursively
#         merged into larger nodes. If 'None' (the default), then no pruning
#         is performed.
#
#     num_levels : int, optional
#         Number of density levels in the constructed tree. If None (default),
#         `num_levels` is internally set to be the number of rows in `X`.
#
#     verbose : bool, optional
#         If True, a progress indicator is printed at every 100th level of tree
#         construction.
#
#     Returns
#     -------
#     T : LevelSetTree
#         A pruned level set tree.
#
#     See Also
#     --------
#     construct_tree_from_graph, LevelSetTree
#
#     Examples
#     --------
#     >>> X = numpy.random.rand(100, 2)
#     >>> tree = debacl.construct_tree(X, k=8, prune_threshold=5)
#     >>> print(tree)
#     +----+-------------+-----------+------------+----------+------+--------+----------+
#     | id | start_level | end_level | start_mass | end_mass | size | parent | children |
#     +----+-------------+-----------+------------+----------+------+--------+----------+
#     | 0  |    0.000    |   0.870   |   0.000    |  0.450   | 100  |  None  |  [3, 4]  |
#     | 3  |    0.870    |   3.364   |   0.450    |  0.990   |  17  |   0    |    []    |
#     | 4  |    0.870    |   1.027   |   0.450    |  0.520   |  35  |   0    |  [7, 8]  |
#     | 7  |    1.027    |   1.755   |   0.520    |  0.870   |  8   |   4    |    []    |
#     | 8  |    1.027    |   3.392   |   0.520    |  1.000   |  23  |   4    |    []    |
#     +----+-------------+-----------+------------+----------+------+--------+----------+
#     """
#
#     sim_graph, radii = _utl.knn_graph(X, k, method='brute_force')
#
#     n, p = X.shape
#     density = _utl.knn_density(radii, n, p, k)
#
#     tree = construct_tree_from_graph(adjacency_list=sim_graph, density=density,
#                                      prune_threshold=prune_threshold,
#                                      num_levels=num_levels, verbose=verbose)
#
#     return tree
# ---------------Ours----------------
# def construct_tree ( X , k , prune_threshold = None , num_levels = None , verbose = False ) :
#  <nl> ###DCSTR### Construct a level set tree from tabular data.
#
# Parameters
# ----------
# X : 2-dimensional numpy array
#     Numeric dataset, where each row represents one observation.
#
# k : int
#     Number of observations to consider as neighbors to a given point.
#
# prune_threshold : int, optional
#     Leaf nodes with fewer than this number of members are recursively
#     merged into larger nodes. If 'None' (the default), then no pruning
#     is performed.
#
# num_levels : int, optional
#     Number of density levels in the constructed tree. If None (default),
#     `num_levels` is internally set to be the number of rows in `X`.
#
# verbose : bool, optional
#     If True, a progress indicator is printed at every 100th level of tree
#     construction.
#
# Returns
# -------
# T : LevelSetTree
#     A pruned level set tree.
#
# See Also
# --------
# construct_tree_from_graph, LevelSetTree
#
# Examples
# --------
# >>> X = numpy.random.rand(100, 2)
# >>> tree = debacl.construct_tree(X, k=8, prune_threshold=5)
# >>> print(tree)
# +----+-------------+-----------+------------+----------+------+--------+----------+
# | id | start_level | end_level | start_mass | end_mass | size | parent | children |
# +----+-------------+-----------+------------+----------+------+--------+----------+
# | 0  |    0.000    |   0.870   |   0.000    |  0.450   | 100  |  None  |  [3, 4]  |
# | 3  |    0.870    |   3.364   |   0.450    |  0.990   |  17  |   0    |    []    |
# | 4  |    0.870    |   1.027   |   0.450    |  0.520   |  35  |   0    |  [7, 8]  |
# | 7  |    1.027    |   1.755   |   0.520    |  0.870   |  8   |   4    |    []    |
# | 8  |    1.027    |   3.392   |   0.520    |  1.000   |  23  |   4    |    []    |
# +----+-------------+-----------+------------+----------+------+--------+----------+
#  "str"
#  <nl> <indent> sim_graph , radii = _utl . knn_graph ( X , k , method = "str" )
#  <nl> n , p = X . shape
#  density = _utl . knn_density ( radii , n , p , k )
#  <nl> tree = construct_tree_from_graph ( adjacency_list = sim_graph , density = density , <nl> prune_threshold = prune_threshold , <nl> num_levels = num_levels , verbose = verbose )
#  <nl> return tree
#  <dedent> <endf>
# ----------------------------------------------
# ----------------------------------------------
# ----------------Data-----------------------
# def construct_tree_from_graph(adjacency_list, density, prune_threshold=None,
#                               num_levels=None, verbose=False):
#     """
#     Construct a level set tree from a similarity graph and a density estimate.
#
#     Parameters
#     ----------
#     adjacency_list : list [list]
#         Adjacency list of the k-nearest neighbors graph on the data. Each entry
#         contains the indices of the `k` closest neighbors to the data point at
#         the same row index.
#
#     density : list [float]
#         Estimate of the density function, evaluated at the data points
#         represented by the keys in `adjacency_list`.
#
#     prune_threshold : int, optional
#         Leaf nodes with fewer than this number of members are recursively
#         merged into larger nodes. If 'None' (the default), then no pruning
#         is performed.
#
#     num_levels : list int, optional
#         Number of density levels in the constructed tree. If None (default),
#         `num_levels` is internally set to be the number of rows in `X`.
#
#     verbose : bool, optional
#         If True, a progress indicator is printed at every 100th level of tree
#         construction.
#
#     Returns
#     -------
#     T : levelSetTree
#         See the LevelSetTree class for attributes and method definitions.
#
#     See Also
#     --------
#     construct_tree, LevelSetTree
#
#     Examples
#     --------
#     >>> X = numpy.random.rand(100, 2)
#     >>> knn_graph, radii = debacl.utils.knn_graph(X, k=8)
#     >>> density = debacl.utils.knn_density(radii, n=100, p=2, k=8)
#     >>> tree = debacl.construct_tree_from_graph(knn_graph, density,
#     ...                                         prune_threshold=5)
#     >>> print(tree)
#     +----+-------------+-----------+------------+----------+------+--------+----------+
#     | id | start_level | end_level | start_mass | end_mass | size | parent | children |
#     +----+-------------+-----------+------------+----------+------+--------+----------+
#     | 0  |    0.000    |   0.768   |   0.000    |  0.390   | 100  |  None  |  [1, 2]  |
#     | 1  |    0.768    |   1.494   |   0.390    |  0.790   |  30  |   0    |  [7, 8]  |
#     | 2  |    0.768    |   4.812   |   0.390    |  1.000   |  31  |   0    |    []    |
#     | 7  |    1.494    |   2.375   |   0.790    |  0.950   |  6   |   1    |    []    |
#     | 8  |    1.494    |   2.308   |   0.790    |  0.940   |  5   |   1    |    []    |
#     +----+-------------+-----------+------------+----------+------+--------+----------+
#     """
#
#     ## Initialize the graph and cluster tree
#     levels = _utl.define_density_mass_grid(density, num_levels=num_levels)
#
#     G = _nx.from_dict_of_lists(
#         {i: neighbors for i, neighbors in enumerate(adjacency_list)})
#
#     T = LevelSetTree(density, levels)
#
#     ## Figure out roots of the tree
#     cc0 = _nx.connected_components(G)
#
#     for i, c in enumerate(cc0):  # c is only the vertex list, not the subgraph
#         T._subgraphs[i] = G.subgraph(c)
#         T.nodes[i] = ConnectedComponent(
#             i, parent=None, children=[], start_level=0., end_level=None,
#             start_mass=0., end_mass=None, members=c)
#
#     # Loop through the removal grid
#     previous_level = 0.
#     n = float(len(adjacency_list))
#
#     for i, level in enumerate(levels):
#         if verbose and i % 100 == 0:
#             _logging.info("iteration {}".format(i))
#
#         ## figure out which points to remove, i.e. the background set.
#         bg = _np.where((density > previous_level) & (density <= level))[0]
#         previous_level = level
#
#         ## compute the mass after the current bg set is removed
#         old_vcount = sum([x.number_of_nodes()
#                           for x in T._subgraphs.values()])
#         current_mass = 1. - ((old_vcount - len(bg)) / n)
#
#         # loop through active components, i.e. subgraphs
#         deactivate_keys = []     # subgraphs to deactivate at the iter end
#         activate_subgraphs = {}  # new subgraphs to add at the end of the iter
#
#         for (k, H) in T._subgraphs.items():
#
#             ## remove nodes at the current level
#             H.remove_nodes_from(bg)
#
#             ## check if subgraph has vanished
#             if H.number_of_nodes() == 0:
#                 T.nodes[k].end_level = level
#                 T.nodes[k].end_mass = current_mass
#                 deactivate_keys.append(k)
#
#             else:  # subgraph hasn't vanished
#
#                 ## check if subgraph now has multiple connected components
#                 # NOTE: this is *the* bottleneck
#                 if not _nx.is_connected(H):
#
#                     ## deactivate the parent subgraph
#                     T.nodes[k].end_level = level
#                     T.nodes[k].end_mass = current_mass
#                     deactivate_keys.append(k)
#
#                     ## start a new subgraph & node for each child component
#                     cc = _nx.connected_components(H)
#
#                     for c in cc:
#                         new_key = max(T.nodes.keys()) + 1
#                         T.nodes[k].children.append(new_key)
#                         activate_subgraphs[new_key] = H.subgraph(c)
#
#                         T.nodes[new_key] = ConnectedComponent(
#                             new_key, parent=k, children=[], start_level=level,
#                             end_level=None, start_mass=current_mass,
#                             end_mass=None, members=c)
#
#         # update active components
#         for k in deactivate_keys:
#             del T._subgraphs[k]
#
#         T._subgraphs.update(activate_subgraphs)
#
#     ## Prune the tree
#     if prune_threshold is not None:
#         T = T.prune(threshold=prune_threshold)
#
#     return T
# ---------------Ours----------------
# def construct_tree_from_graph ( adjacency_list , density , prune_threshold = None , <nl> num_levels = None , verbose = False ) :
#  <nl> ###DCSTR### Construct a level set tree from a similarity graph and a density estimate.
#
# Parameters
# ----------
# adjacency_list : list [list]
#     Adjacency list of the k-nearest neighbors graph on the data. Each entry
#     contains the indices of the `k` closest neighbors to the data point at
#     the same row index.
#
# density : list [float]
#     Estimate of the density function, evaluated at the data points
#     represented by the keys in `adjacency_list`.
#
# prune_threshold : int, optional
#     Leaf nodes with fewer than this number of members are recursively
#     merged into larger nodes. If 'None' (the default), then no pruning
#     is performed.
#
# num_levels : list int, optional
#     Number of density levels in the constructed tree. If None (default),
#     `num_levels` is internally set to be the number of rows in `X`.
#
# verbose : bool, optional
#     If True, a progress indicator is printed at every 100th level of tree
#     construction.
#
# Returns
# -------
# T : levelSetTree
#     See the LevelSetTree class for attributes and method definitions.
#
# See Also
# --------
# construct_tree, LevelSetTree
#
# Examples
# --------
# >>> X = numpy.random.rand(100, 2)
# >>> knn_graph, radii = debacl.utils.knn_graph(X, k=8)
# >>> density = debacl.utils.knn_density(radii, n=100, p=2, k=8)
# >>> tree = debacl.construct_tree_from_graph(knn_graph, density,
# ...                                         prune_threshold=5)
# >>> print(tree)
# +----+-------------+-----------+------------+----------+------+--------+----------+
# | id | start_level | end_level | start_mass | end_mass | size | parent | children |
# +----+-------------+-----------+------------+----------+------+--------+----------+
# | 0  |    0.000    |   0.768   |   0.000    |  0.390   | 100  |  None  |  [1, 2]  |
# | 1  |    0.768    |   1.494   |   0.390    |  0.790   |  30  |   0    |  [7, 8]  |
# | 2  |    0.768    |   4.812   |   0.390    |  1.000   |  31  |   0    |    []    |
# | 7  |    1.494    |   2.375   |   0.790    |  0.950   |  6   |   1    |    []    |
# | 8  |    1.494    |   2.308   |   0.790    |  0.940   |  5   |   1    |    []    |
# +----+-------------+-----------+------------+----------+------+--------+----------+
#  "str"
#  <nl> ## Initialize the graph and cluster tree
#  <indent> levels = _utl . define_density_mass_grid ( density , num_levels = num_levels )
#  <nl> G = _nx . from_dict_of_lists ( <nl> { i : neighbors for i , neighbors in enumerate ( adjacency_list ) } )
#  <nl> T = LevelSetTree ( density , levels )
#  <nl> ## Figure out roots of the tree
#  cc0 = _nx . connected_components ( G )
#  <nl> for i , c in enumerate ( cc0 ) : # c is only the vertex list, not the subgraph
#
#  <indent> T . _subgraphs [ i ] = G . subgraph ( c )
#  T . nodes [ i ] = ConnectedComponent ( <nl> i , parent = None , children = [ ] , start_level = 0. , end_level = None , <nl> start_mass = 0. , end_mass = None , members = c )
#  <nl> # Loop through the removal grid
#  <dedent> previous_level = 0.
#  n = float ( len ( adjacency_list ) )
#  <nl> for i , level in enumerate ( levels ) :
#  <indent> if verbose and i % 100 == 0 :
#  <indent> _logging . info ( "str" . format ( i ) )
#  <nl> ## figure out which points to remove, i.e. the background set.
#  <dedent> bg = _np . where ( ( density > previous_level ) & ( density <= level ) ) [ 0 ]
#  previous_level = level
#  <nl> ## compute the mass after the current bg set is removed
#  old_vcount = sum ( [ x . number_of_nodes ( ) <nl> for x in T . _subgraphs . values ( ) ] )
#  current_mass = 1. - ( ( old_vcount - len ( bg ) ) / n )
#  <nl> # loop through active components, i.e. subgraphs
#  deactivate_keys = [ ] # subgraphs to deactivate at the iter end
#
#  activate_subgraphs = { } # new subgraphs to add at the end of the iter
#
#  <nl> for ( k , H ) in T . _subgraphs . items ( ) :
#  <nl> ## remove nodes at the current level
#  <indent> H . remove_nodes_from ( bg )
#  <nl> ## check if subgraph has vanished
#  if H . number_of_nodes ( ) == 0 :
#  <indent> T . nodes [ k ] . end_level = level
#  T . nodes [ k ] . end_mass = current_mass
#  deactivate_keys . append ( k )
#  <nl> <dedent> else : # subgraph hasn't vanished
#
#  <nl> ## check if subgraph now has multiple connected components
#  # NOTE: this is *the* bottleneck
#  <indent> if not _nx . is_connected ( H ) :
#  <nl> ## deactivate the parent subgraph
#  <indent> T . nodes [ k ] . end_level = level
#  T . nodes [ k ] . end_mass = current_mass
#  deactivate_keys . append ( k )
#  <nl> ## start a new subgraph & node for each child component
#  cc = _nx . connected_components ( H )
#  <nl> for c in cc :
#  <indent> new_key = max ( T . nodes . keys ( ) ) + 1
#  T . nodes [ k ] . children . append ( new_key )
#  activate_subgraphs [ new_key ] = H . subgraph ( c )
#  <nl> T . nodes [ new_key ] = ConnectedComponent ( <nl> new_key , parent = k , children = [ ] , start_level = level , <nl> end_level = None , start_mass = current_mass , <nl> end_mass = None , members = c )
#  <nl> # update active components
#  <dedent> <dedent> <dedent> <dedent> for k in deactivate_keys :
#  <indent> del T . _subgraphs [ k ]
#  <nl> <dedent> T . _subgraphs . update ( activate_subgraphs )
#  <nl> ## Prune the tree
#  <dedent> if prune_threshold is not None :
#  <indent> T = T . prune ( threshold = prune_threshold )
#  <nl> <dedent> return T
#  <dedent> <endf>
# ----------------------------------------------
# ----------------------------------------------
# ----------------Data-----------------------
# def load_tree(filename):
#     """
#     Load a saved tree from file.
#
#     Parameters
#     ----------
#     filename : str
#         Filename to load.
#
#     Returns
#     -------
#     T : LevelSetTree
#         The loaded and reconstituted level set tree object.
#
#     See Also
#     --------
#     LevelSetTree.save
#
#     Examples
#     --------
#     >>> X = numpy.random.rand(100, 2)
#     >>> tree = debacl.construct_tree(X, k=8, prune_threshold=5)
#     >>> tree.save('my_tree')
#     >>> tree2 = debacl.load_tree('my_tree')
#     """
#     with open(filename, 'rb') as f:
#         T = _pickle.load(f)
#
#     return T
# ---------------Ours----------------
# def load_tree ( filename ) :
#  <nl> ###DCSTR### Load a saved tree from file.
#
# Parameters
# ----------
# filename : str
#     Filename to load.
#
# Returns
# -------
# T : LevelSetTree
#     The loaded and reconstituted level set tree object.
#
# See Also
# --------
# LevelSetTree.save
#
# Examples
# --------
# >>> X = numpy.random.rand(100, 2)
# >>> tree = debacl.construct_tree(X, k=8, prune_threshold=5)
# >>> tree.save('my_tree')
# >>> tree2 = debacl.load_tree('my_tree')
#  "str"
#  <indent> with open ( filename , "str" ) as f :
#  <indent> T = _pickle . load ( f )
#  <nl> <dedent> return T
#  <dedent> <endf>
# ----------------------------------------------
# ----------------------------------------------
# ----------------Data-----------------------
# def add_others_to_robots(robots, others_list):
#     """Add others to robots set."""
#     for other in others_list:
#         robots.add(other)
#     return robots
# ---------------Ours----------------
# def add_others_to_robots ( robots , others_list ) :
#  <nl> ###DCSTR### Add others to robots set.
#  "str"
#  <indent> for other in others_list :
#  <indent> robots . add ( other )
#  <dedent> return robots
#  <dedent> <endf>
# ----------------------------------------------
# ----------------------------------------------
# ----------------Data-----------------------
# def add_xml_names_to_robots(robots, xml_file):
#     """Add robots from "Data for UASparser" in XML format to robots set."""
#     dom = parse(xml_file)
#     user_agents = list()
#     for robot in dom.getElementsByTagName("robot"):
#         for node in robot.childNodes:
#             if node.localName == "family":
#                 family = node.firstChild.data.strip()
#             if node.localName == "name":
#                 name = node.firstChild.data.strip()
#             if node.localName == "useragent":
#                 user_agents.append(node.firstChild.data.strip())
#         # Use the family title instead of the name, if it is long enough
#         if len(family) > 3:
#             name = family
#         # Remove trailing versions (length protected in regex)
#         name_new = re_trailing_version.search(name)
#         if name_new:
#             name = name_new.group("robot")
#         if name.endswith(" b"):
#             name = name.rstrip(" b")
#         robots.add(name.strip())
#     return robots, sorted(user_agents)
# ---------------Ours----------------
# def add_xml_names_to_robots ( robots , xml_file ) :
#  <nl> ###DCSTR### Add robots from "Data for UASparser" in XML format to robots set.
#  "str"
#  <indent> dom = parse ( xml_file )
#  user_agents = list ( )
#  for robot in dom . getElementsByTagName ( "str" ) :
#  <indent> for node in robot . childNodes :
#  <indent> if node . localName == "str" :
#  <indent> family = node . firstChild . data . strip ( )
#  <dedent> if node . localName == "str" :
#  <indent> name = node . firstChild . data . strip ( )
#  <dedent> if node . localName == "str" :
#  <indent> user_agents . append ( node . firstChild . data . strip ( ) )
#  # Use the family title instead of the name, if it is long enough
#  <nl> <dedent> <dedent> if len ( family ) > 3 :
#  <indent> name = family
#  # Remove trailing versions (length protected in regex)
#  <nl> <dedent> name_new = re_trailing_version . search ( name )
#  if name_new :
#  <indent> name = name_new . group ( "str" )
#  <dedent> if name . endswith ( "str" ) :
#  <indent> name = name . rstrip ( "str" )
#  <dedent> robots . add ( name . strip ( ) )
#  <dedent> return robots , sorted ( user_agents )
#  <dedent> <endf>
# ----------------------------------------------
# ----------------------------------------------
# ----------------Data-----------------------
# def create_optmized_robots_regex(robots):
#     """Create an optimized regex from list of robots using a trie."""
#     optimized_robots = trie.Trie()
#     for robot in sorted(robots):
#         optimized_robots.add(robot)
#     return optimized_robots.regexp()
# ---------------Ours----------------
# def create_optmized_robots_regex ( robots ) :
#  <nl> ###DCSTR### Create an optimized regex from list of robots using a trie.
#  "str"
#  <indent> optimized_robots = trie . Trie ( )
#  for robot in sorted ( robots ) :
#  <indent> optimized_robots . add ( robot )
#  <dedent> return optimized_robots . regexp ( )
#  <dedent> <endf>
# ----------------------------------------------
# ----------------------------------------------
# ----------------Data-----------------------
# def main():
#     robots = set()
#     # Command Line Options
#     args = parser_setup()
#
#     if args.file:
#         xml_file = args.file
#     else:
#         download_uasparser_xml(download_xml_url, file_uasparser_xml)
#         xml_file = file_uasparser_xml
#
#     robots = add_others_to_robots(robots, others)
#     robots, user_agents = add_xml_names_to_robots(robots, xml_file)
#     optibots = create_optmized_robots_regex(robots)
#
#     # write out robots config excerpt
#     with io.open(file_robots_config, "w", encoding="utf8") as fh:
#         fh.write("[patterns]\n")
#         fh.write("robots=%s\n" % optibots)
#
#     # write out robot users agents for testing
#     with io.open(file_user_agents, "w", encoding="utf8") as fh:
#         for agent in user_agents:
#             fh.write("%s\n" % agent)
# ---------------Ours----------------
# def main ( ) :
#  <indent> robots = set ( )
#  # Command Line Options
#  <nl> args = parser_setup ( )
#  <nl> if args . file :
#  <indent> xml_file = args . file
#  <dedent> else :
#  <indent> download_uasparser_xml ( download_xml_url , file_uasparser_xml )
#  xml_file = file_uasparser_xml
#  <nl> <dedent> robots = add_others_to_robots ( robots , others )
#  robots , user_agents = add_xml_names_to_robots ( robots , xml_file )
#  optibots = create_optmized_robots_regex ( robots )
#  <nl> # write out robots config excerpt
#  with io . open ( file_robots_config , "str" , encoding = "str" ) as fh :
#  <indent> fh . write ( "str" )
#  fh . write ( "str" % optibots )
#  <nl> # write out robot users agents for testing
#  <dedent> with io . open ( file_user_agents , "str" , encoding = "str" ) as fh :
#  <indent> for agent in user_agents :
#  <indent> fh . write ( "str" % agent )
#  <dedent> <dedent> <dedent> <endf>
# ----------------------------------------------
# ----------------------------------------------
# ----------------Data-----------------------
# def read_and_compile_pattern_from_file(config_file):
#     """Read INI config file and compile robots regex from robots key in
#     patterns section.
#     """
#     config = configparser.ConfigParser()
#     config.readfp(open(config_file))
#     re_robots = re.compile(config.get("patterns", "robots"), re.I)
#     return re_robots
# ---------------Ours----------------
# def read_and_compile_pattern_from_file ( config_file ) :
#  <nl> ###DCSTR### Read INI config file and compile robots regex from robots key in
# patterns section.
#  "str"
#  <indent> config = configparser . ConfigParser ( )
#  config . readfp ( open ( config_file ) )
#  re_robots = re . compile ( config . get ( "str" , "str" ) , re . I )
#  return re_robots
#  <dedent> <endf>
# ----------------------------------------------
# ----------------------------------------------
# ----------------Data-----------------------
# def evalute_robots_pattern(re_robots):
#     """Evalute robots regex for hits and misses against robots user agents
#     file.
#     """
#     matched = 0
#     missed = 0
#     i = 1
#     with io.open(file_user_agents, "r", encoding="utf8") as fh:
#         for line in fh:
#             if re_robots.search(line):
#                 matched += 1
#                 # print "+%s:" % i, line.strip()
#             else:
#                 missed += 1
#                 # print "-%s:" % i, line.strip()
#             i += 1
#     return matched, missed
# ---------------Ours----------------
# def evalute_robots_pattern ( re_robots ) :
#  <nl> ###DCSTR### Evalute robots regex for hits and misses against robots user agents
# file.
#  "str"
#  <indent> matched = 0
#  missed = 0
#  i = 1
#  with io . open ( file_user_agents , "str" , encoding = "str" ) as fh :
#  <indent> for line in fh :
#  <indent> if re_robots . search ( line ) :
#  <indent> matched += 1
#  # print "+%s:" % i, line.strip()
#  <nl> <dedent> else :
#  <indent> missed += 1
#  # print "-%s:" % i, line.strip()
#  <nl> <dedent> i += 1
#  <dedent> <dedent> return matched , missed
#  <dedent> <endf>
# ----------------------------------------------
# ----------------------------------------------
# ----------------Data-----------------------
# def evaluate_config(config_file, iterations):
#     """Evalute config's robots pattern and benchmark duration."""
#     # Reading the pattern and compling is not included in the duration. As the
#     # data is quickly supplied by the file system cache, it becomes irrelevent.
#     re_robots = read_and_compile_pattern_from_file(config_file)
#     matched = int()
#     missed = int()
#     duration_total = float()
#     for i in range(0, iterations):
#         start = time.clock()
#         matched, missed = evalute_robots_pattern(re_robots)
#         end = time.clock()
#         duration = end - start
#         duration_total += duration
#     return matched, missed, duration_total / iterations
# ---------------Ours----------------
# def evaluate_config ( config_file , iterations ) :
#  <nl> ###DCSTR### Evalute config's robots pattern and benchmark duration.
#  "str"
#  # Reading the pattern and compling is not included in the duration. As the
#  <nl> # data is quickly supplied by the file system cache, it becomes irrelevent.
#  <indent> re_robots = read_and_compile_pattern_from_file ( config_file )
#  matched = int ( )
#  missed = int ( )
#  duration_total = float ( )
#  for i in range ( 0 , iterations ) :
#  <indent> start = time . clock ( )
#  matched , missed = evalute_robots_pattern ( re_robots )
#  end = time . clock ( )
#  duration = end - start
#  duration_total += duration
#  <dedent> return matched , missed , duration_total / iterations
#  <dedent> <endf>
# ----------------------------------------------
# ----------------------------------------------
# ----------------Data-----------------------
# def display_results(name, config_file, data, old_data=None):
#     """Display results of config evaluation."""
#     matched, missed, duration = data
#     msg = "%s Config (%s)" % (name, config_file)
#     print(msg)
#     print("=" * len(msg))
#     if old_data is None:
#         print("matched: %5d" % matched)
#         print("missed:  %5d" % missed)
#         print("duration:%9.3fs" % duration)
#         print()
#     else:
#         old_matched, old_missed, old_duration = old_data
#         print("matched: %5d" % matched, end=' ')
#         if matched > old_matched:
#             adj = "more"
#         else:
#             adj = "less"
#         diff_abs = abs(old_matched - matched)
#         diff_percent = diff_abs / float(old_matched) * 100
#         print("     (%.0f%% %s)" % (diff_percent, adj))
#         print("missed:  %5d" % missed)
#         print("duration:%9.3fs" % duration, end=' ')
#         if duration < old_duration:
#             adj = "faster"
#         else:
#             adj = "slower"
#         diff_abs = abs(old_duration - duration)
#         diff_percent = diff_abs / float(old_duration) * 100
#         print("(%.0f%% %s)" % (diff_percent, adj))
# ---------------Ours----------------
# def display_results ( name , config_file , data , old_data = None ) :
#  <nl> ###DCSTR### Display results of config evaluation.
#  "str"
#  <indent> matched , missed , duration = data
#  msg = "str" % ( name , config_file )
#  print ( msg )
#  print ( "str" * len ( msg ) )
#  if old_data is None :
#  <indent> print ( "str" % matched )
#  print ( "str" % missed )
#  print ( "str" % duration )
#  print ( )
#  <dedent> else :
#  <indent> old_matched , old_missed , old_duration = old_data
#  print ( "str" % matched , end = "str" )
#  if matched > old_matched :
#  <indent> adj = "str"
#  <dedent> else :
#  <indent> adj = "str"
#  <dedent> diff_abs = abs ( old_matched - matched )
#  diff_percent = diff_abs / float ( old_matched ) * 100
#  print ( "str" % ( diff_percent , adj ) )
#  print ( "str" % missed )
#  print ( "str" % duration , end = "str" )
#  if duration < old_duration :
#  <indent> adj = "str"
#  <dedent> else :
#  <indent> adj = "str"
#  <dedent> diff_abs = abs ( old_duration - duration )
#  diff_percent = diff_abs / float ( old_duration ) * 100
#  print ( "str" % ( diff_percent , adj ) )
#  <dedent> <dedent> <endf>
# ----------------------------------------------
# ----------------------------------------------
# ----------------Data-----------------------
# def main():
#     # Command Line Options
#     args = parser_setup()
#     # Old config
#     old_data = evaluate_config(args.old_config, args.iterations)
#     display_results("Old", args.old_config, old_data)
#     # New config
#     new_data = evaluate_config(args.new_config, args.iterations)
#     display_results("New", args.new_config, new_data, old_data)
# ---------------Ours----------------
# def main ( ) :
#  # Command Line Options
#  <nl> <indent> args = parser_setup ( )
#  # Old config
#  <nl> old_data = evaluate_config ( args . old_config , args . iterations )
#  display_results ( "str" , args . old_config , old_data )
#  # New config
#  <nl> new_data = evaluate_config ( args . new_config , args . iterations )
#  display_results ( "str" , args . new_config , new_data , old_data )
#  <dedent> <endf>
# ----------------------------------------------
# ----------------------------------------------
# ----------------Data-----------------------
# def include (template_name, globals):
# 	fn = os.path.join(os.path.dirname(__file__), "mdb_%s.py" % template_name)
# 	assert (os.path.exists(fn))
# 	exec(compile(open(fn, "rb").read(), fn, 'exec'), globals)
# ---------------Ours----------------
# def include ( template_name , globals ) :
#  <indent> fn = os . path . join ( os . path . dirname ( __file__ ) , "str" % template_name )
#  assert ( os . path . exists ( fn ) )
#  exec ( compile ( open ( fn , "str" ) . read ( ) , fn , "str" ) , globals )
#  <dedent> <endf>
# ----------------------------------------------
# ----------------------------------------------
# ----------------Data-----------------------
# def expand_key (key, separator = '.'):
# 	""" Expand a dot-notation key into a list
# 	"""
# 	key_t = type(key)
#
# 	if (key_t == list):
# 		key = tuple(key)
#
# 	elif (key_t == str) or (key_t == str):
# 		key = tuple(key.split(separator))
#
# 	elif (key_t != tuple):
# 		raise ValueError("Malformed key: '%s'" % key)
#
# 	if (len(key) == 0):
# 		raise ValueError("Empty key")
#
# 	for i, subkey in enumerate(key):
# 		if (subkey.startswith('$')) and (i+1 < len(key)):
# 			raise ValueError("Malformed key '%s': special keys ('%s'?) must be last" % (separator.join(key), subkey))
#
# 	return key
# ---------------Ours----------------
# def expand_key ( key , separator = "str" ) :
#  <nl> ###DCSTR### Expand a dot-notation key into a list
#
#  "str"
#  <indent> key_t = type ( key )
#  <nl> if ( key_t == list ) :
#  <indent> key = tuple ( key )
#  <nl> <dedent> elif ( key_t == str ) or ( key_t == str ) :
#  <indent> key = tuple ( key . split ( separator ) )
#  <nl> <dedent> elif ( key_t != tuple ) :
#  <indent> raise ValueError ( "str" % key )
#  <nl> <dedent> if ( len ( key ) == 0 ) :
#  <indent> raise ValueError ( "str" )
#  <nl> <dedent> for i , subkey in enumerate ( key ) :
#  <indent> if ( subkey . startswith ( "str" ) ) and ( i + 1 < len ( key ) ) :
#  <indent> raise ValueError ( "str" % ( separator . join ( key ) , subkey ) )
#  <nl> <dedent> <dedent> return key
#  <dedent> <endf>
# ----------------------------------------------
# ----------------------------------------------
# ----------------Data-----------------------
# def set (dictionary, key, value):
# 	""" Insert a nested key into a dictionary
#
# 	Parameters:
# 		- **dictionary**: dictionary to populate
# 		- **key**: nested key, as a list
# 		- **value**: value to set
#
# 	Example:
# 		> m = {}
# 		> set(m, ('a', 'b', 'c'), 1)
# 		> print m
# 		{'a': {'b': {'c': 1}}}
# 	"""
# 	is_leaf, root = (len(key) == 1), key[0]
#
# 	if (is_leaf):
# 		dictionary[root] = value
# 	else:
# 		if (not root in dictionary):
# 			dictionary[root] = {}
#
# 		set(dictionary[root], key[1:], value)
# ---------------Ours----------------
# def set ( dictionary , key , value ) :
#  <nl> ###DCSTR### Insert a nested key into a dictionary
#
# Parameters:
#         - **dictionary**: dictionary to populate
#         - **key**: nested key, as a list
#         - **value**: value to set
#
# Example:
#         > m = {}
#         > set(m, ('a', 'b', 'c'), 1)
#         > print m
#         {'a': {'b': {'c': 1}}}
#  "str"
#  <indent> is_leaf , root = ( len ( key ) == 1 ) , key [ 0 ]
#  <nl> if ( is_leaf ) :
#  <indent> dictionary [ root ] = value
#  <dedent> else :
#  <indent> if ( not root in dictionary ) :
#  <indent> dictionary [ root ] = { }
#  <nl> <dedent> set ( dictionary [ root ] , key [ 1 : ] , value )
#  <dedent> <dedent> <endf>
# ----------------------------------------------
# ----------------------------------------------
# ----------------Data-----------------------
# def get (dictionary, key):
# 	""" Query a nested key from a dictionary
#
# 	Parameters:
# 		- **dictionary**: dictionary to query
# 		- **key**: nested key, as a list
# 	"""
# 	is_leaf, root = (len(key) == 1), key[0]
#
# 	if (is_leaf):
# 		return dictionary[root]
# 	else:
# 		return get(dictionary[root], key[1:])
# ---------------Ours----------------
# def get ( dictionary , key ) :
#  <nl> ###DCSTR### Query a nested key from a dictionary
#
# Parameters:
#         - **dictionary**: dictionary to query
#         - **key**: nested key, as a list
#  "str"
#  <indent> is_leaf , root = ( len ( key ) == 1 ) , key [ 0 ]
#  <nl> if ( is_leaf ) :
#  <indent> return dictionary [ root ]
#  <dedent> else :
#  <indent> return get ( dictionary [ root ] , key [ 1 : ] )
#  <dedent> <dedent> <endf>
# ----------------------------------------------
# ----------------------------------------------
# ----------------Data-----------------------
# def delete (dictionary, key):
# 	""" Delete a nested key from a dictionary
#
# 	Parameters:
# 		- **dictionary**: dictionary to modify
# 		- **key**: nested key to delete, as a list
# 	"""
# 	is_leaf, root = (len(key) == 1), key[0]
#
# 	if (type(dictionary) != dict):
# 		raise KeyError(root)
#
# 	if (is_leaf):
# 		del dictionary[root]
#
# 	else:
# 		delete(dictionary[root], key[1:])
# 		if (len(dictionary[root]) == 0):
# 			del dictionary[root]
# ---------------Ours----------------
# def delete ( dictionary , key ) :
#  <nl> ###DCSTR### Delete a nested key from a dictionary
#
# Parameters:
#         - **dictionary**: dictionary to modify
#         - **key**: nested key to delete, as a list
#  "str"
#  <indent> is_leaf , root = ( len ( key ) == 1 ) , key [ 0 ]
#  <nl> if ( type ( dictionary ) != dict ) :
#  <indent> raise KeyError ( root )
#  <nl> <dedent> if ( is_leaf ) :
#  <indent> del dictionary [ root ]
#  <nl> <dedent> else :
#  <indent> delete ( dictionary [ root ] , key [ 1 : ] )
#  if ( len ( dictionary [ root ] ) == 0 ) :
#  <indent> del dictionary [ root ]
#  <dedent> <dedent> <dedent> <endf>
# ----------------------------------------------
# ----------------------------------------------
# ----------------Data-----------------------
# def contains (dictionary, key):
# 	""" Test if a dictionary contains a nested key
#
# 	Parameters:
# 		- **dictionary**: dictionary to evaluate
# 		- **key**: nested key to test, as a list
# 	"""
# 	is_leaf, root = (len(key) == 1), key[0]
#
# 	if (root in dictionary):
# 		if (is_leaf):
# 			return True
#
# 		if (type(dictionary[root]) != dict):
# 			return False
#
# 		return contains(dictionary[root], key[1:])
#
# 	return False
# ---------------Ours----------------
# def contains ( dictionary , key ) :
#  <nl> ###DCSTR### Test if a dictionary contains a nested key
#
# Parameters:
#         - **dictionary**: dictionary to evaluate
#         - **key**: nested key to test, as a list
#  "str"
#  <indent> is_leaf , root = ( len ( key ) == 1 ) , key [ 0 ]
#  <nl> if ( root in dictionary ) :
#  <indent> if ( is_leaf ) :
#  <indent> return True
#  <nl> <dedent> if ( type ( dictionary [ root ] ) != dict ) :
#  <indent> return False
#  <nl> <dedent> return contains ( dictionary [ root ] , key [ 1 : ] )
#  <nl> <dedent> return False
#  <dedent> <endf>
# ----------------------------------------------
# ----------------------------------------------
# ----------------Data-----------------------
# def items (dictionary):
# 	""" Iterate through a nested dictionary and return all
# 	keys (as lists) and values
#
# 	Parameters:
# 		- **dictionary**: dictionary to browse
#
# 	Example:
# 		> m = {'a': {'b': {'c': 1}, 'd': 2}}
# 		> print items(m)
# 		[(('a', 'b', 'c'), 1), (('a', 'd'), 2)]
# 	"""
# 	def walk (node, b = []):
# 		items = []
#
# 		for key in node:
# 			branch, value = b + list(expand_key(key)), node[key]
#
# 			if (type(value) == dict):
# 				items.extend(walk(value, branch))
# 			else:
# 				items.append((tuple(branch), value))
#
# 		return items
#
# 	return walk(dictionary)
# ---------------Ours----------------
# def items ( dictionary ) :
#  <nl> ###DCSTR### Iterate through a nested dictionary and return all
# keys (as lists) and values
#
# Parameters:
#         - **dictionary**: dictionary to browse
#
# Example:
#         > m = {'a': {'b': {'c': 1}, 'd': 2}}
#         > print items(m)
#         [(('a', 'b', 'c'), 1), (('a', 'd'), 2)]
#  "str"
#  <indent> def walk ( node , b = [ ] ) :
#  <indent> items = [ ]
#  <nl> for key in node :
#  <indent> branch , value = b + list ( expand_key ( key ) ) , node [ key ]
#  <nl> if ( type ( value ) == dict ) :
#  <indent> items . extend ( walk ( value , branch ) )
#  <dedent> else :
#  <indent> items . append ( ( tuple ( branch ) , value ) )
#  <nl> <dedent> <dedent> return items
#  <nl> <dedent> return walk ( dictionary )
#  <dedent> <endf>
# ----------------------------------------------
# ----------------------------------------------
# ----------------Data-----------------------
# def expand (dictionary, separator = '.'):
# 	""" Transform a dictionary with dot-notation keys into a nested dictionary
#
# 	Parameters:
# 		- **dictionary**: dictionary to transform
#
# 	Example:
# 		> m = {"a.b.c": 1}
# 		> print expand(m)
# 		{"a": {"b": {"c": 1}}}
# 	"""
# 	d = {}
# 	for key, value in dictionary.items():
# 		set(d, expand_key(key, separator), value)
#
# 	return d
# ---------------Ours----------------
# def expand ( dictionary , separator = "str" ) :
#  <nl> ###DCSTR### Transform a dictionary with dot-notation keys into a nested dictionary
#
# Parameters:
#         - **dictionary**: dictionary to transform
#
# Example:
#         > m = {"a.b.c": 1}
#         > print expand(m)
#         {"a": {"b": {"c": 1}}}
#  "str"
#  <indent> d = { }
#  for key , value in dictionary . items ( ) :
#  <indent> set ( d , expand_key ( key , separator ) , value )
#  <nl> <dedent> return d
#  <dedent> <endf>
# ----------------------------------------------
# ----------------------------------------------
# ----------------Data-----------------------
# def flatten (dictionary, separator = '.'):
# 	""" Transform a nested dictionary into a dictionary with dot-notations
#
# 	Parameters:
# 		- **dictionary**: dictionary to transform
#
# 	Example:
# 		> m = {"a": {"b": {"c": 1}}}
# 		> print flatten(m)
# 		{"a.b.c": 1}
# 	"""
# 	d = {}
# 	for (key, value) in items(dictionary):
# 		# hack: we don't want to flatten special MongoDB
# 		# keys (everything starting with a '$')
# 		if (key[-1].startswith('$')):
# 			d[separator.join(key[:-1])] = {key[-1]: value}
# 		else:
# 			d[separator.join(key)] = value
#
# 	return d
# ---------------Ours----------------
# def flatten ( dictionary , separator = "str" ) :
#  <nl> ###DCSTR### Transform a nested dictionary into a dictionary with dot-notations
#
# Parameters:
#         - **dictionary**: dictionary to transform
#
# Example:
#         > m = {"a": {"b": {"c": 1}}}
#         > print flatten(m)
#         {"a.b.c": 1}
#  "str"
#  <indent> d = { }
#  for ( key , value ) in items ( dictionary ) :
#  # hack: we don't want to flatten special MongoDB
#  <nl> # keys (everything starting with a '$')
#  <indent> if ( key [ - 1 ] . startswith ( "str" ) ) :
#  <indent> d [ separator . join ( key [ : - 1 ] ) ] = { key [ - 1 ] : value }
#  <dedent> else :
#  <indent> d [ separator . join ( key ) ] = value
#  <nl> <dedent> <dedent> return d
#  <dedent> <endf>
# ----------------------------------------------
# ----------------------------------------------
# ----------------Data-----------------------
# def traverse (dictionary, selector = lambda x: False, key_modifier = lambda x: x, value_modifier = lambda x: x):
# 	""" Traverse a nested dictionary and modify keys or values
#
# 	Parameters:
# 		- **dictionary**: dictionary to transform
# 		- **selector**: boolean function receiving each key and sub-key; if
# 		  returns True, then this key and its value will be modified
# 		- **key_modifier**: function receiving a key to modify; its return is
# 		  used as the new key value
# 		- **value_modifier**: function receiving a value to modify; its return
# 		  is used as the new value
# 	"""
# 	tree = {}
#
# 	for key in dictionary:
# 		value = dictionary[key]
# 		selected = selector(key)
#
# 		if (selected):
# 			key = key_modifier(key)
#
# 		if (type(value) == dict):
# 			tree[key] = traverse(value, selector, key_modifier, value_modifier)
#
# 		elif (selected):
# 			tree[key] = value_modifier(value)
#
# 		else:
# 			tree[key] = value
#
# 	return tree
# ---------------Ours----------------
# def traverse ( dictionary , selector = lambda x : False , key_modifier = lambda x : x , value_modifier = lambda x : x ) :
#  <nl> ###DCSTR### Traverse a nested dictionary and modify keys or values
#
# Parameters:
#         - **dictionary**: dictionary to transform
# ...
#             prettyval = repr(val)
#             if len(prettyval) > 150:
#                 prettyval = "<%s instance>" % (type(val).__name__)
#
#             msg = "{0}\n\n\tEncountered when evaluating {1}{2}".format(
#                 inst, prettyval, self)
#
#             new_exc = exc_cls(msg)
#             new_exc._RERAISE = True
#             Q.__debug_info__ = QDebug(self, self, val, val)
#
#             six.reraise(exc_cls, new_exc, tb)
#
#     return wrapper
# ---------------Ours----------------
# def _helpful_failure ( method ) :
#  <nl> ###DCSTR### Decorator for eval_ that prints a helpful error message
# if an exception is generated in a Q expression
#  "str"
#  <nl> <indent> @ wraps ( method )
#  def wrapper ( self , val ) :
#  <indent> try :
#  <indent> return method ( self , val )
#  <dedent> except :
#  <indent> exc_cls , inst , tb = sys . exc_info ( )
#  <nl> if hasattr ( inst , "str" ) :
#  <indent> _ , expr , _ , inner_val = Q . __debug_info__
#  Q . __debug_info__ = QDebug ( self , expr , val , inner_val )
#  raise
#  <nl> <dedent> if issubclass ( exc_cls , KeyError ) : # Overrides formatting
#
#  <indent> exc_cls = QKeyError
#  <nl> # Show val, unless it's too long
#  <dedent> prettyval = repr ( val )
#  if len ( prettyval ) > 150 :
#  <indent> prettyval = "str" % ( type ( val ) . __name__ )
#  <nl> <dedent> msg = "str" . format ( <nl> inst , prettyval , self )
#  <nl> new_exc = exc_cls ( msg )
#  new_exc . _RERAISE = True
#  Q . __debug_info__ = QDebug ( self , self , val , val )
#  <nl> six . reraise ( exc_cls , new_exc , tb )
#  <nl> <dedent> <dedent> return wrapper
#  <dedent> <endf>
# ----------------------------------------------
# ----------------------------------------------
# ----------------Data-----------------------
# def enhance_contrast(rgb):
#     """A preprocessing step that enhances the local contrast of each
#     color channel"""
#     s = rgb.shape
#     d = disk(s[0] / 5)
#     for i in range(3):
#         rgb[:, :, i] = percentile_autolevel(rgb[:, :, i], d, p0=.1, p1=.9)
#     return rgb
# ---------------Ours----------------
# def enhance_contrast ( rgb ) :
#  <nl> ###DCSTR### A preprocessing step that enhances the local contrast of each
# color channel
#  "str"
#  <indent> s = rgb . shape
#  d = disk ( s [ 0 ] / 5 )
#  for i in range ( 3 ) :
#  <indent> rgb [ : , : , i ] = percentile_autolevel ( rgb [ : , : , i ] , d , p0 = .1 , p1 = .9 )
#  <dedent> return rgb
#  <dedent> <endf>
# ----------------------------------------------
# ----------------------------------------------
# ----------------Data-----------------------
# def _on_args(catalog, row):
#     """Given the row of the DR1 catalog, turn into
#     (lon, lat, radius) tuple
#     """
#     lon, lat, pa, a, b, t, hr = catalog[row]
#     pa *= -1
#     return lon, lat, 1.3 * (a + t)
# ---------------Ours----------------
# def _on_args ( catalog , row ) :
#  <nl> ###DCSTR### Given the row of the DR1 catalog, turn into
# (lon, lat, radius) tuple
#  "str"
#  <indent> lon , lat , pa , a , b , t , hr = catalog [ row ]
#  pa *= - 1
#  return lon , lat , 1.3 * ( a + t )
#  <dedent> <endf>
# ----------------------------------------------
# ----------------------------------------------
# ----------------Data-----------------------
# def _high_quality_on_locations():
#     pth = os.path.join(os.path.dirname(__file__), 'data', 'vetted.txt')
#     rows = list(map(int, open(pth).readlines()))
#     cat = get_catalog()
#
#     return [_on_args(cat, row) for row in rows]
# ---------------Ours----------------
# def _high_quality_on_locations ( ) :
#  <indent> pth = os . path . join ( os . path . dirname ( __file__ ) , "str" , "str" )
#  rows = list ( map ( int , open ( pth ) . readlines ( ) ) )
#  cat = get_catalog ( )
#  <nl> return [ _on_args ( cat , row ) for row in rows ]
#  <dedent> <endf>
# ----------------------------------------------
# ----------------------------------------------
# ----------------Data-----------------------
# def bubble_params(bubbles=None):
#     c = get_catalog()
#     bubbles = bubbles or list(range(len(c)))
#
#     result = []
#     for b in bubbles:
#         args = _on_args(c, b)
#         result.append([int(np.round(args[0])), args[0], args[1], args[2]])
#     return result
# ---------------Ours----------------
# def bubble_params ( bubbles = None ) :
#  <indent> c = get_catalog ( )
#  bubbles = bubbles or list ( range ( len ( c ) ) )
#  <nl> result = [ ]
#  for b in bubbles :
#  <indent> args = _on_args ( c , b )
#  result . append ( [ int ( np . round ( args [ 0 ] ) ) , args [ 0 ] , args [ 1 ] , args [ 2 ] ] )
#  <dedent> return result
#  <dedent> <endf>
# ----------------------------------------------
# ----------------------------------------------
# ----------------Data-----------------------
# def on_stamp_params():
#     """Iterate over medium quality + examples,
#     yield tuples of (field_lon, lcen, bcen, r)
#
#     These can be fed to Extractor objects
#     """
#     for l, b, r in _high_quality_on_locations():
#         yield int(np.round(l)), l, b, r
# ---------------Ours----------------
# def on_stamp_params ( ) :
#  <nl> ###DCSTR### Iterate over medium quality + examples,
# yield tuples of (field_lon, lcen, bcen, r)
#
# These can be fed to Extractor objects
#  "str"
#  <indent> for l , b , r in _high_quality_on_locations ( ) :
#  <indent> yield int ( np . round ( l ) ) , l , b , r
#  <dedent> <dedent> <endf>
# ----------------------------------------------
# ----------------------------------------------
# ----------------Data-----------------------
# def highest_quality_on_params():
#     """Iterate over highest-confidence + examples
#     yield tuples of (field_lon, lcen, bcen, r)
#     """
#     pth = os.path.join(os.path.dirname(__file__), 'data', 'best', 'data.pkl')
#     data = pickle.load(open(pth))
#     for k, (l, b, r) in list(data.items()):
#         if os.path.exists(os.path.join(os.path.dirname(pth), k)):
#             yield int(np.round(l)), l, b, r
# ---------------Ours----------------
# def highest_quality_on_params ( ) :
#  <nl> ###DCSTR### Iterate over highest-confidence + examples
# yield tuples of (field_lon, lcen, bcen, r)
#  "str"
#  <indent> pth = os . path . join ( os . path . dirname ( __file__ ) , "str" , "str" , "str" )
#  data = pickle . load ( open ( pth ) )
#  for k , ( l , b , r ) in list ( data . items ( ) ) :
#  <indent> if os . path . exists ( os . path . join ( os . path . dirname ( pth ) , k ) ) :
#  <indent> yield int ( np . round ( l ) ) , l , b , r
#  <dedent> <dedent> <dedent> <endf>
# ----------------------------------------------
# ----------------------------------------------
# ----------------Data-----------------------
# def filter(hit_rate=0.3):
#     cat = get_catalog()
#     infile = 'stamps2.h5'
#     on_id = np.array(list(map(int, list(h5py.File(infile, 'r')['on'].keys()))))
#
#     rgbs = list(h5py.File(infile, 'r')['on'].values())
#
#     #has green channel...
#     def has_green(rgb):
#         return (rgb[:, :, 1] == 0).mean() < 0.3
#
#     good = np.array([has_green(r) for r in rgbs], dtype=np.bool)
#
#     #...and hit rate > 0.3
#     good = good & (cat[on_id, -1] > 0.3)
#     result = [_on_args(cat, row) for row in on_id[good]]
#     return result
# ---------------Ours----------------
# def filter ( hit_rate = 0.3 ) :
#  <indent> cat = get_catalog ( )
#  infile = "str"
#  on_id = np . array ( list ( map ( int , list ( h5py . File ( infile , "str" ) [ "str" ] . keys ( ) ) ) ) )
#  <nl> rgbs = list ( h5py . File ( infile , "str" ) [ "str" ] . values ( ) )
#  <nl> #has green channel...
#  def has_green ( rgb ) :
#  <indent> return ( rgb [ : , : , 1 ] == 0 ) . mean ( ) < 0.3
#  <nl> <dedent> good = np . array ( [ has_green ( r ) for r in rgbs ] , dtype = np . bool )
#  <nl> #...and hit rate > 0.3
#  good = good & ( cat [ on_id , - 1 ] > 0.3 )
#  result = [ _on_args ( cat , row ) for row in on_id [ good ] ]
#  return result
#  <dedent> <endf>
# ----------------------------------------------
# ----------------------------------------------
# ----------------Data-----------------------
# def main():
#     pth = 'hiq.pkl'
#
#     result = list(filter())
#
#     with open(pth, 'w') as outfile:
#         pickle.dump(result, outfile)
# ---------------Ours----------------
# def main ( ) :
#  <indent> pth = "str"
#  <nl> result = list ( filter ( ) )
#  <nl> with open ( pth , "str" ) as outfile :
#  <indent> pickle . dump ( result , outfile )
#  <dedent> <dedent> <endf>
# ----------------------------------------------
# ----------------------------------------------
# ----------------Data-----------------------
# def get_url(url, fname, target_dir='galaxy/raw/'):
#     """ Save a file from the internet
#
#     Parameters
#     ----------
#     url : The url to download
#     fname : The filename to save to
#     target_dir : The directory to save into. Default= galaxy/raw
#     """
#     outfile = os.path.join(target_dir + fname)
#     if os.path.exists(outfile) and (os.path.getsize(outfile) > 0):
#         return
#
#     print('+%s' % (url + fname))
#     data = urlopen(url + fname)
#
#     if data.getcode() != 200:
#         print('%s returned status code %i' % (url + fname, data.getcode()))
#         return
#
#     t0 = time()
#     with open(outfile, 'wb') as out:
#         out.write(data.read())
#     t1 = time()
#     print('Downloaded in %i seconds' % (t1 - t0))
# ---------------Ours----------------
# def get_url ( url , fname , target_dir = "str" ) :
#  <nl> ###DCSTR### Save a file from the internet
#
# Parameters
# ----------
# url : The url to download
# fname : The filename to save to
# target_dir : The directory to save into. Default= galaxy/raw
#  "str"
#  <indent> outfile = os . path . join ( target_dir + fname )
#  if os . path . exists ( outfile ) and ( os . path . getsize ( outfile ) > 0 ) :
#  <indent> return
#  <nl> <dedent> print ( "str" % ( url + fname ) )
#  data = urlopen ( url + fname )
#  <nl> if data . getcode ( ) != 200 :
#  <indent> print ( "str" % ( url + fname , data . getcode ( ) ) )
#  return
#  <nl> <dedent> t0 = time ( )
#  with open ( outfile , "str" ) as out :
#  <indent> out . write ( data . read ( ) )
#  <dedent> t1 = time ( )
#  print ( "str" % ( t1 - t0 ) )
#  <dedent> <endf>
# ----------------------------------------------
# ----------------------------------------------
# ----------------Data-----------------------
# def get_glimpse(folder, lon, survey='I'):
#     """Download GLIMPSE images I3 and I4 for a single longitude
#
#     Parameters
#     ----------
#     folder : Sub-directory on IPAC website (e.g. 'GLON_10-30')
#     lon : Longitude tile to grab
#     survey : Optional survey ('I', 'II')
#     """
#
#     base_url = 'http://irsa.ipac.caltech.edu/data/SPITZER/GLIMPSE/images/%s/1.2_mosaics_v3.5/' % survey
#     i3 = 'GLM_%3.3i00+0000_mosaic_I3.fits' % lon
#     i4 = 'GLM_%3.3i00+0000_mosaic_I4.fits' % lon
#     get_url(base_url + folder, i3)
#     get_url(base_url + folder, i4)
# ---------------Ours----------------
# def get_glimpse ( folder , lon , survey = "str" ) :
#  <nl> ###DCSTR### Download GLIMPSE images I3 and I4 for a single longitude
#
# Parameters
# ----------
# folder : Sub-directory on IPAC website (e.g. 'GLON_10-30')
# lon : Longitude tile to grab
# survey : Optional survey ('I', 'II')
#  "str"
#  <nl> <indent> base_url = "str" % survey
#  i3 = "str" % lon
#  i4 = "str" % lon
#  get_url ( base_url + folder , i3 )
#  get_url ( base_url + folder , i4 )
#  <dedent> <endf>
# ----------------------------------------------
# ----------------------------------------------
# ----------------Data-----------------------
# def get_mips(lon):
#     """ Download MIPS images at b = +/- .5deg
#
#     Parameters
#     ----------
#     lon : Longitude to grab
#     """
#
#     base_url = 'http://irsa.ipac.caltech.edu/data/SPITZER/MIPSGAL/images/mosaics24/'
#
#     pos = 'MG%3.3i0p005_024.fits' % lon
#     neg = 'MG%3.3i0n005_024.fits' % lon
#
#     get_url(base_url, pos)
#     get_url(base_url, neg)
# ---------------Ours----------------
# def get_mips ( lon ) :
#  <nl> ###DCSTR### Download MIPS images at b = +/- .5deg
#
# Parameters
# ----------
# lon : Longitude to grab
#  "str"
#  <nl> <indent> base_url = "str"
#  <nl> pos = "str" % lon
#  neg = "str" % lon
#  <nl> get_url ( base_url , pos )
#  get_url ( base_url , neg )
#  <dedent> <endf>
# ----------------------------------------------
# ----------------------------------------------
# ----------------Data-----------------------
# def get_all(threads=5):
#     """ Grab all the data
#
#     Parameters
#     ----------
#     Threads : how many worker threads to use
#     """
#     p = Pool(threads)
#
#     lon = list(range(12, 30, 3))
#     folder = 'GLON_10-30/'
#     p.map(partial(get_glimpse, folder), lon)
#
#     lon = list(range(30, 52, 3))
#     folder = 'GLON_30-53/'
#     p.map(partial(get_glimpse, folder), lon)
#
#     lon = list(range(33, 67, 3))
#     folder = 'GLON_53-66/'
#     p.map(partial(get_glimpse, folder), lon)
#
#     lon = list(range(294, 310, 3))
#     folder = 'GLON_284_295-310/'
#     p.map(partial(get_glimpse, folder), lon)
#
#     lon = list(range(312, 328, 3))
#     folder = 'GLON_310-330/'
#     p.map(partial(get_glimpse, folder), lon)
#
#     lon = list(range(330, 349, 3))
#     folder = 'GLON_330-350/'
#     p.map(partial(get_glimpse, folder), lon)
#
#     lon = list(range(0, 10, 3))
#     folder = ''
#     p.map(partial(get_glimpse, folder, survey='II'), lon)
#
#     lon = list(range(351, 358, 3))
#     folder = ''
#     p.map(partial(get_glimpse, folder, survey='II'), lon)
#
#     #XXX GLIMPSE 3D
#
#     lon = list(range(70))
#     p.map(get_mips, lon)
#
#     lon = list(range(292, 361))
#     p.map(get_mips, lon)
# ---------------Ours----------------
# def get_all ( threads = 5 ) :
#  <nl> ###DCSTR### Grab all the data
#
# Parameters
# ----------
# Threads : how many worker threads to use
#  "str"
#  <indent> p = Pool ( threads )
#  <nl> lon = list ( range ( 12 , 30 , 3 ) )
#  folder = "str"
#  p . map ( partial ( get_glimpse , folder ) , lon )
#  <nl> lon = list ( range ( 30 , 52 , 3 ) )
#  folder = "str"
#  p . map ( partial ( get_glimpse , folder ) , lon )
#  <nl> lon = list ( range ( 33 , 67 , 3 ) )
#  folder = "str"
#  p . map ( partial ( get_glimpse , folder ) , lon )
#  <nl> lon = list ( range ( 294 , 310 , 3 ) )
#  folder = "str"
#  p . map ( partial ( get_glimpse , folder ) , lon )
#  <nl> lon = list ( range ( 312 , 328 , 3 ) )
#  folder = "str"
#  p . map ( partial ( get_glimpse , folder ) , lon )
#  <nl> lon = list ( range ( 330 , 349 , 3 ) )
#  folder = "str"
#  p . map ( partial ( get_glimpse , folder ) , lon )
#  <nl> lon = list ( range ( 0 , 10 , 3 ) )
#  folder = "str"
#  p . map ( partial ( get_glimpse , folder , survey = "str" ) , lon )
#  <nl> lon = list ( range ( 351 , 358 , 3 ) )
#  folder = "str"
#  p . map ( partial ( get_glimpse , folder , survey = "str" ) , lon )
#  <nl> #XXX GLIMPSE 3D
#  lon = list ( range ( 70 ) )
#  p . map ( get_mips , lon )
#  <nl> lon = list ( range ( 292 , 361 ) )
#  p . map ( get_mips , lon )
#  <dedent> <endf>
# ----------------------------------------------
# ----------------------------------------------
# ----------------Data-----------------------
# def main():
#
#     ex = RGBExtractor()
#     ex.shp = (100, 100)
#
#     data = list(filter(hit_rate=0.2))
#
#     params = {}
#     for i, d in enumerate(data):
#         d1 = list(d)
#         d2 = list(d)
#         d2[-1] *= 2
#
#         l = int(np.round(d[0]))
#         d1 = [l] + d1
#         d2 = [l] + d2
#
#         im = np.hstack((ex(*d1), ex(*d2)))
#         pth = "vet_%4.4i.png" % i
#         params[pth] = d
#         pth = os.path.join('best', pth)
#         imsave(pth, im)
#
#     pth = os.path.join('best', 'data.pkl')
#     with open(pth, 'w') as outfile:
#         pickle.dump(params, outfile)
# ---------------Ours----------------
# def main ( ) :
#  <nl> <indent> ex = RGBExtractor ( )
#  ex . shp = ( 100 , 100 )
#  <nl> data = list ( filter ( hit_rate = 0.2 ) )
#  <nl> params = { }
#  for i , d in enumerate ( data ) :
#  <indent> d1 = list ( d )
#  d2 = list ( d )
#  d2 [ - 1 ] *= 2
#  <nl> l = int ( np . round ( d [ 0 ] ) )
#  d1 = [ l ] + d1
#  d2 = [ l ] + d2
#  <nl> im = np . hstack ( ( ex ( * d1 ) , ex ( * d2 ) ) )
#  pth = "str" % i
#  params [ pth ] = d
#  pth = os . path . join ( "str" , pth )
#  imsave ( pth , im )
#  <nl> <dedent> pth = os . path . join ( "str" , "str" )
#  with open ( pth , "str" ) as outfile :
#  <indent> pickle . dump ( params , outfile )
#  <dedent> <dedent> <endf>
# ----------------------------------------------
# ----------------------------------------------

# %%
# !pip install eradicate
# Out:
# Collecting eradicate
#   Downloading https://files.pythonhosted.org/packages/65/ed/5b4506e122114f9439482d2a810ade4aa06cc4e306185931889e58b47f46/eradicate-1.0.tar.gz
# Building wheels for collected packages: eradicate
#   Running setup.py bdist_wheel for eradicate ... done
#   Stored in directory: /Vol0/user/hse/nadiinchi/.cache/pip/wheels/c7/af/bd/d2b0fcf41166336bc389bfb13c1fb35efc50712cebbf9fdb33
# Successfully built eradicate
# mkl-random 1.0.1 requires cython, which is not installed.
# Installing collected packages: eradicate
# Successfully installed eradicate-1.0
# You are using pip version 10.0.1, however version 19.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import eradicate

# %%
for source, tokens, comments, scope, pairs in data:
    for loc, com in comments:
        com_filtered = "\n".join(list(eradicate.filter_commented_out_code\
                             (com, aggressive=False)))
        if com_filtered == "":
            print(com)
            print(com_filtered)
            print("----------------------------------------------------")
# Out:
# # print "+%s:" % i, line.strip()
#
# ----------------------------------------------------
# # print "-%s:" % i, line.strip()
#
# ----------------------------------------------------
# #gear.append(gear[0])
#
# ----------------------------------------------------
# ##    _lastInteract = _clock()
#
# ----------------------------------------------------
# #newy = 24
#
# ----------------------------------------------------
# #newheight = newheight - 96
#
# ----------------------------------------------------
# #time.sleep(15) # test subprocess not responding
#
# ----------------------------------------------------
# ###DCSTR### Version of imp.find_module() that handles hierarchical module names
#
# ----------------------------------------------------
# #print "bind(%s, %s, %s) called." % (sequence, func, add)
#
# ----------------------------------------------------
# #print "event_add(%s,%s) was called"%(repr(virtual),repr(sequences))
#
# ----------------------------------------------------
# ###DCSTR### replace info[2], a traceback instance, by its ID
#
# ----------------------------------------------------
# ##    E2 = extrusion(frame=f2, pos=E1.pos, shape=shapes.circle(radius=1.5)-shapes.circle(radius=1.0), color=color.yellow)
#
# ----------------------------------------------------
# ##    E2.scale[1] = 0.5
#
# ----------------------------------------------------
# ###DCSTR### Find the nearest __init__() in the class tree.
#
# ----------------------------------------------------
# #newy = 24
#
# ----------------------------------------------------
# #newheight = newheight - 96
#
# ----------------------------------------------------
# ###DCSTR### Version of imp.find_module() that handles hierarchical module names
#
# ----------------------------------------------------

# %%
files = []
for r, d, f in os.walk("data"):
    for file in f:
        if file.endswith(".py"):
            files.append(os.path.join(r, file))
#process_file(filenm, data)

# %%
len(files)
# Out:
# 150000

# %%
files[464]
# Out:
# 'data/byt3bl33d3r/pth-toolkit/lib/python2.7/site-packages/samba/tests/auth.py'

# %%
new_folder = "data_3"
os.makedirs(new_folder, exist_ok=True)
for file in files:
    try:
        os.system('~/miniconda3/envs/python2/bin/2to3 data/0xcite/fingerping/fingerping.py -o new_files -w -n --no-diffs')
# Out:
#   File "<ipython-input-550-567921564710>", line 5
#     os.system('~/miniconda3/envs/python2/bin/2to3 data/0xcite/fingerping/fingerping.py -o new_files -w -n --no-diffs')
#                                                                                                                       ^
# SyntaxError: unexpected EOF while parsing

# %%
new_folder = "data_3"
os.makedirs(new_folder, exist_ok=True)
file = files[3]
os.system("~/miniconda3/envs/python2/bin/2to3 %s -o %s -w -n --no-diffs"%\
                  (file, new_folder+file[4:]))
# Out:
# 0

# %%
from collections import deque
def walk(node):
    """
    Recursively yield all descendant nodes in the tree starting at *node*
    (including *node* itself), in no specified order.  This is useful if you
    only want to modify nodes in place and don't care about the context.
    """
    count = 0
    todo = deque([node])
    while todo:
        node = todo.popleft()
        if isinstance(node, ast.FunctionDef):
            count += 1
            print("here")
        else:
            todo.extend(ast.iter_child_nodes(node))
            print("here")
        #yield node
    print("here", count)
    return count

# %%
walk(atok.tree)
# Out:
# here
# here
# here 1
# 1

# %%
num = np.random.randint(len(files))
print(num)
print(read_file_to_string(files[num]))
# Out:
# 1621
# """
# UK-specific Form helpers
# """
#
# import re
#
# from django.forms.fields import CharField, Select
# from django.forms import ValidationError
# from django.utils.translation import ugettext_lazy as _
#
# class UKPostcodeField(CharField):
#     """
#     A form field that validates its input is a UK postcode.
#
#     The regular expression used is sourced from the schema for British Standard
#     BS7666 address types: http://www.govtalk.gov.uk/gdsc/schemas/bs7666-v2-0.xsd
#
#     The value is uppercased and a space added in the correct place, if required.
#     """
#     default_error_messages = {
#         'invalid': _('Enter a valid postcode.'),
#     }
#     outcode_pattern = '[A-PR-UWYZ]([0-9]{1,2}|([A-HIK-Y][0-9](|[0-9]|[ABEHMNPRVWXY]))|[0-9][A-HJKSTUW])'
#     incode_pattern = '[0-9][ABD-HJLNP-UW-Z]{2}'
#     postcode_regex = re.compile(r'^(GIR 0AA|%s %s)$' % (outcode_pattern, incode_pattern))
#     space_regex = re.compile(r' *(%s)$' % incode_pattern)
#
#     def clean(self, value):
#         value = super(UKPostcodeField, self).clean(value)
#         if value == '':
#             return value
#         postcode = value.upper().strip()
#         # Put a single space before the incode (second part).
#         postcode = self.space_regex.sub(r' \1', postcode)
#         if not self.postcode_regex.search(postcode):
#             raise ValidationError(self.error_messages['invalid'])
#         return postcode
#
# class UKCountySelect(Select):
#     """
#     A Select widget that uses a list of UK Counties/Regions as its choices.
#     """
#     def __init__(self, attrs=None):
#         from uk_regions import UK_REGION_CHOICES
#         super(UKCountySelect, self).__init__(attrs, choices=UK_REGION_CHOICES)
#
# class UKNationSelect(Select):
#     """
#     A Select widget that uses a list of UK Nations as its choices.
#     """
#     def __init__(self, attrs=None):
#         from uk_regions import UK_NATIONS_CHOICES
#         super(UKNationSelect, self).__init__(attrs, choices=UK_NATIONS_CHOICES)

# %%
for node in ast.walk(ast.parse(read_file_to_string(files[num]))):
    if isinstance(node, ast.ClassDef):
        break

# %%
node.body[6].name
# Out:
# 'clean'

# %%
for child in ast.iter_child_nodes(node):
    print(child)
